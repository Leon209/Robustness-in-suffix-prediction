# %%
import importlib
import sys
import torch
import pickle
import os
from tqdm.notebook import tqdm

sys.path.insert(0, '..')
sys.path.insert(0, '../..')
sys.path.insert(0, '../../..')
sys.path.insert(0, '../../../..')
sys.path.insert(0, '../../../../..')



from model.dropout_uncertainty_enc_dec_LSTM.dropout_uncertainty_model import DropoutUncertaintyEncoderDecoderLSTM
from evaluation.probabilistic_evaluation import ProbabilisticEvaluation

# %%
# Load model
#file_path_model = '../../../training_variational_dropout/sepsis/Sepsis_full_no_grad_norm_robustness.pkl'
file_path_model = '../../../training_variational_dropout/BPIC20/BPIC_2020_setting_2_2.pkl'
output_dir = '../../../../../evaluation_results/robustness/BPIC20/test/'
model = DropoutUncertaintyEncoderDecoderLSTM.load(file_path_model, dropout=0.1)

file_path_original = '../../../../../encoded_data/BPIC20/BPIC_2020_all_5_val.pkl'
file_path_perturbed = '../../../../../encoded_data/BPIC20/BPIC_2020_all_5_val.pkl'
file_path_redo_activity = '../../../../../encoded_data/BPIC20/val_new.pkl'
file_path_redo_activity_pert = '../../../../../encoded_data/BPIC20/last_event_attack_all.pkl'




original_dataset = torch.load(file_path_original, weights_only=False)
perturbed_dataset = torch.load(file_path_perturbed, weights_only=False)
redo_activity_dataset = torch.load(file_path_redo_activity, weights_only=False)
redo_activity_pert_dataset = torch.load(file_path_redo_activity_pert, weights_only=False)


print(f"Original dataset loaded: {len(original_dataset)} cases")
print(f"Perturbed dataset loaded: {len(perturbed_dataset)} cases")
# Out:
# Data set categories:  ([('concept:name', 18, {'Declaration APPROVED by ADMINISTRATION': 1, 'Declaration APPROVED by BUDGET OWNER': 2, 'Declaration APPROVED by PRE_APPROVER': 3, 'Declaration FINAL_APPROVED by SUPERVISOR': 4, 'Declaration FOR_APPROVAL by PRE_APPROVER': 5, 'Declaration FOR_APPROVAL by SUPERVISOR': 6, 'Declaration REJECTED by ADMINISTRATION': 7, 'Declaration REJECTED by BUDGET OWNER': 8, 'Declaration REJECTED by EMPLOYEE': 9, 'Declaration REJECTED by MISSING': 10, 'Declaration REJECTED by PRE_APPROVER': 11, 'Declaration REJECTED by SUPERVISOR': 12, 'Declaration SAVED by EMPLOYEE': 13, 'Declaration SUBMITTED by EMPLOYEE': 14, 'EOS': 15, 'Payment Handled': 16, 'Request Payment': 17}), ('org:resource', 4, {'EOS': 1, 'STAFF MEMBER': 2, 'SYSTEM': 3}), ('org:role', 9, {'ADMINISTRATION': 1, 'BUDGET OWNER': 2, 'EMPLOYEE': 3, 'EOS': 4, 'MISSING': 5, 'PRE_APPROVER': 6, 'SUPERVISOR': 7, 'UNDEFINED': 8}), ('case:BudgetNumber', 3, {'EOS': 1, 'budget 86566': 2}), ('case:DeclarationNumber', 6535, {'EOS': 1, 'UNKNOWN': 2, 'declaration number 120850': 3, 'declaration number 120856': 4, 'declaration number 120861': 5, 'declaration number 120866': 6, 'declaration number 120875': 7, 'declaration number 120880': 8, 'declaration number 120885': 9, 'declaration number 120891': 10, 'declaration number 120902': 11, 'declaration number 120907': 12, 'declaration number 120915': 13, 'declaration number 120920': 14, 'declaration number 120925': 15, 'declaration number 120934': 16, 'declaration number 120939': 17, 'declaration number 120944': 18, 'declaration number 120954': 19, 'declaration number 120959': 20, 'declaration number 120965': 21, 'declaration number 120971': 22, 'declaration number 120976': 23, 'declaration number 120981': 24, 'declaration number 120986': 25, 'declaration number 120992': 26, 'declaration number 120997': 27, 'declaration number 121002': 28, 'declaration number 121007': 29, 'declaration number 121012': 30, 'declaration number 121018': 31, 'declaration number 121023': 32, 'declaration number 121028': 33, 'declaration number 121033': 34, 'declaration number 121038': 35, 'declaration number 121043': 36, 'declaration number 121048': 37, 'declaration number 121053': 38, 'declaration number 121059': 39, 'declaration number 121070': 40, 'declaration number 121078': 41, 'declaration number 121083': 42, 'declaration number 121088': 43, 'declaration number 121093': 44, 'declaration number 121098': 45, 'declaration number 121103': 46, 'declaration number 121108': 47, 'declaration number 121113': 48, 'declaration number 121118': 49, 'declaration number 121126': 50, 'declaration number 121131': 51, 'declaration number 121137': 52, 'declaration number 121143': 53, 'declaration number 121148': 54, 'declaration number 121153': 55, 'declaration number 121158': 56, 'declaration number 121164': 57, 'declaration number 121170': 58, 'declaration number 121176': 59, 'declaration number 121181': 60, 'declaration number 121190': 61, 'declaration number 121195': 62, 'declaration number 121201': 63, 'declaration number 121206': 64, 'declaration number 121211': 65, 'declaration number 121217': 66, 'declaration number 121222': 67, 'declaration number 121228': 68, 'declaration number 121233': 69, 'declaration number 121239': 70, 'declaration number 121251': 71, 'declaration number 121257': 72, 'declaration number 121262': 73, 'declaration number 121271': 74, 'declaration number 121276': 75, 'declaration number 121281': 76, 'declaration number 121286': 77, 'declaration number 121292': 78, 'declaration number 121297': 79, 'declaration number 121302': 80, 'declaration number 121307': 81, 'declaration number 121313': 82, 'declaration number 121318': 83, 'declaration number 121324': 84, 'declaration number 121330': 85, 'declaration number 121335': 86, 'declaration number 121340': 87, 'declaration number 121345': 88, 'declaration number 121355': 89, 'declaration number 121360': 90, 'declaration number 121366': 91, 'declaration number 121371': 92, 'd ...
# Encoder input features:  [['concept:name', 'org:resource', 'org:role', 'case:BudgetNumber', 'case:DeclarationNumber'], ['case_elapsed_time', 'event_elapsed_time', 'day_in_week', 'seconds_in_day']]
# Decoder input+output features:  [['concept:name'], ['case_elapsed_time']]
#
#
# Sequence length of decoder output:  4
#
#
# Cells hidden size:  128
# Number of LSTM layer:  4
# Dropout rate:  0.1
#
#
# Encoder number of labels for each input feature (categorical, numerical):  [[18, 4, 9, 3, 6535], [1, 1, 1, 1]]
# Encoder indices of tensors in dataset used as input:  [[0, 1, 2, 3, 4], [0, 1, 2, 3]]
# Embeddings encoder:  ModuleList(
#   (0): Embedding(18, 8)
#   (1): Embedding(4, 3)
#   (2): Embedding(9, 5)
#   (3): Embedding(3, 3)
#   (4): Embedding(6535, 219)
# )
# Total embedding feature size encoder:  238
# Total numerical feature size encoder:  4
# Input feature size encoder:  242
# Encoder initialized!
#
# Decoder label values size for each categorical input feature:  [18]
# Decoder label values size for each numerical input feature:  [1]
# Decoder indices of tensors in dataset used as input:  [[0], [0]]
# Embeddings decoder:  ModuleList(
#   (0): Embedding(18, 8)
# )
# Total embedding feature size decoder:  8
# Total numerical feature size decoder:  1
# Input feature size decoder:  9
# Output feature list of dicts (featue name, feature output size) of decoder:  [{'concept:name': 18}, {'case_elapsed_time': 1}]
# Decoder initialized!
#
# Output feature list of dicts (featue name, tensor index in dataset) of decoder:  [{'concept:name': 0}, {'case_elapsed_time': 0}]
# /Users/leonurny/.local/share/virtualenvs/Probabilistic_Suffix_Prediction_U-ED-LSTM_-32bEAP25/lib/python3.13/site-packages/sklearn/base.py:442: InconsistentVersionWarning: Trying to unpickle estimator OrdinalEncoder from version 1.5.2 when using version 1.7.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/leonurny/.local/share/virtualenvs/Probabilistic_Suffix_Prediction_U-ED-LSTM_-32bEAP25/lib/python3.13/site-packages/sklearn/base.py:442: InconsistentVersionWarning: Trying to unpickle estimator SimpleImputer from version 1.5.2 when using version 1.7.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/leonurny/.local/share/virtualenvs/Probabilistic_Suffix_Prediction_U-ED-LSTM_-32bEAP25/lib/python3.13/site-packages/sklearn/base.py:442: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.5.2 when using version 1.7.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/leonurny/.local/share/virtualenvs/Probabilistic_Suffix_Prediction_U-ED-LSTM_-32bEAP25/lib/python3.13/site-packages/sklearn/base.py:442: InconsistentVersionWarning: Trying to unpickle estimator OrdinalEncoder from version 1.5.2 when using version 1.7.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/leonurny/.local/share/virtualenvs/Probabilistic_Suffix_Prediction_U-ED-LSTM_-32bEAP25/lib/python3.13/site-packages/sklearn/base.py:442: InconsistentVersionWarning: Trying to unpickle estimator SimpleImputer from version 1.5.2 when using version 1.7.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/leonurny/.local/share/virtualenvs/Probabilistic_Suffix_Prediction_U-ED-LSTM_-32bEAP25/lib/python3.13/site-packages/sklearn/base.py:442: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.5.2 when using version 1.7.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Original dataset loaded: 10364 cases
# Perturbed dataset loaded: 10364 cases

# %%
# # Sample 10% of observations for faster inference
# import random

# # Set random seed for reproducibility (optional)
# random.seed(17)

# # Get all keys from both datasets
# all_keys_orig = list(redo_activity_dataset.keys())
# all_keys_pert = list(redo_activity_pert_dataset.keys())

# # Ensure both datasets have the same keys
# assert set(all_keys_orig) == set(all_keys_pert), "Datasets must have matching keys"

# # Calculate 5% sample size
# sample_size = max(1, int(len(all_keys_orig) * 0.05))

# # Randomly sample 10% of the keys
# sampled_keys = random.sample(all_keys_orig, sample_size)

# # Create new dictionaries with only sampled keys
# redo_activity_dataset = {key: redo_activity_dataset[key] for key in sampled_keys}
# redo_activity_pert_dataset = {key: redo_activity_pert_dataset[key] for key in sampled_keys}

# print(f"Sampled {len(sampled_keys)} observations ({len(sampled_keys)/len(all_keys_orig)*100:.1f}%) from {len(all_keys_orig)} total observations")
# print(f"Original dataset now has {len(redo_activity_dataset)} entries")
# print(f"Perturbed dataset now has {len(redo_activity_pert_dataset)} entries")

# %%
#tMp
# file_path_model = '../../../training_variational_dropout/BPIC17/BPIC_2017_setting_2.pkl'
# model = DropoutUncertaintyEncoderDecoderLSTM.load(file_path_model, dropout=0.1)

# %%
# Create evaluation instances (NON-RANDOM ORDER)
eval_original = ProbabilisticEvaluation(
    model, original_dataset,
    concept_name='concept:name',
    num_processes=1, 
    growing_num_values=['case_elapsed_time'],
    samples_per_case=100,
    sample_argmax=False,
    use_variance_cat=True,
    use_variance_num=True,
    all_cat=['concept:name'],
    all_num=['case_elapsed_time'],
    dataset_predefined_prefixes=redo_activity_dataset
)

eval_perturbed = ProbabilisticEvaluation(
    model, original_dataset,
    concept_name='concept:name',
    num_processes=1, 
    growing_num_values=['case_elapsed_time'],
    samples_per_case=100,
    sample_argmax=False,
    use_variance_cat=True,
    use_variance_num=True,
    all_cat=['concept:name'],
    all_num=['case_elapsed_time'],
    dataset_predefined_prefixes=redo_activity_dataset
)

print("ProbabilisticEvaluation instances created")
# Out:
# ProbabilisticEvaluation instances created

# %%
# Import robustness metrics module
import robustness.evaluator.robustness_metrics
#importlib.reload(robustness.robustness_metrics)
from robustness.evaluator.robustness_metrics import save_chunk

print("Robustness metrics module imported")

# Helper functions for filtering predictions and calculating remaining time
def filter_prediction_events(prediction_list, concept_name='concept:name'):
    """Filter prediction events to only include concept:name and case_elapsed_time"""
    if prediction_list is None:
        return None
    filtered = []
    for event in prediction_list:
        if not isinstance(event, dict):
            continue
        filtered_event = {}
        if concept_name in event:
            filtered_event[concept_name] = event[concept_name]
        if 'case_elapsed_time' in event:
            filtered_event['case_elapsed_time'] = event['case_elapsed_time']
        filtered.append(filtered_event)
    return filtered

def calculate_remaining_time(prefix, prediction, concept_name='concept:name'):
    """Calculate remaining time from prefix and prediction"""
    if not prefix or not prediction:
        return None
    if not isinstance(prefix[-1], dict) or 'case_elapsed_time' not in prefix[-1]:
        return None
    if not isinstance(prediction[-1], dict) or 'case_elapsed_time' not in prediction[-1]:
        return None
    current_time = prefix[-1]['case_elapsed_time']
    final_time = prediction[-1]['case_elapsed_time']
    return final_time - current_time

def calculate_sampled_remaining_times(prefix, predicted_suffixes, concept_name='concept:name'):
    """Calculate remaining time for each sample in predicted_suffixes"""
    if not prefix or not predicted_suffixes:
        return None
    if not isinstance(prefix[-1], dict) or 'case_elapsed_time' not in prefix[-1]:
        return None
    current_time = prefix[-1]['case_elapsed_time']
    
    remaining_times = []
    for sample in predicted_suffixes:
        if not sample or not isinstance(sample[-1], dict) or 'case_elapsed_time' not in sample[-1]:
            remaining_times.append(None)
        else:
            final_time = sample[-1]['case_elapsed_time']
            remaining_times.append(final_time - current_time)
    return remaining_times
# Out:
# Robustness metrics module imported

# %%
# Main evaluation loop
os.makedirs(output_dir, exist_ok=True)

save_every = 50
results = {}
concept_name = 'concept:name'  # Match the concept_name used in ProbabilisticEvaluation

for i, ((case_name_orig, prefix_len_orig, prefix_orig, predicted_suffixes_orig, suffix_orig, mean_pred_orig),
        (case_name_pert, prefix_len_pert, prefix_pert, predicted_suffixes_pert, suffix_pert, mean_pred_pert)) in enumerate(
    tqdm(zip(eval_original.evaluate_with_predifined_prefix(random_order=False), 
             eval_perturbed.evaluate_with_predifined_prefix(random_order=False)), 
         desc="Evaluating robustness")):
    
    # Ensure we're comparing the same case and prefix length
    assert case_name_orig == case_name_pert, f"Case mismatch: {case_name_orig} != {case_name_pert}"

    assert prefix_len_orig == prefix_len_pert, f"Prefix length mismatch: {prefix_len_orig} != {prefix_len_pert}"

    # Filter predictions to only include concept:name and case_elapsed_time
    mean_pred_orig_filtered = filter_prediction_events(mean_pred_orig, concept_name=concept_name)
    predicted_suffixes_orig_filtered = [filter_prediction_events(sample, concept_name=concept_name) 
                                        for sample in predicted_suffixes_orig] if predicted_suffixes_orig else None
    
    mean_pred_pert_filtered = filter_prediction_events(mean_pred_pert, concept_name=concept_name)
    predicted_suffixes_pert_filtered = [filter_prediction_events(sample, concept_name=concept_name) 
                                        for sample in predicted_suffixes_pert] if predicted_suffixes_pert else None
    
    # Calculate remaining times immediately
    mean_pred_remaining_time_orig = calculate_remaining_time(prefix_orig, mean_pred_orig, concept_name=concept_name)
    sampled_remaining_time_orig = calculate_sampled_remaining_times(prefix_orig, predicted_suffixes_orig, concept_name=concept_name)
    
    mean_pred_remaining_time_pert = calculate_remaining_time(prefix_pert, mean_pred_pert, concept_name=concept_name)
    sampled_remaining_time_pert = calculate_sampled_remaining_times(prefix_pert, predicted_suffixes_pert, concept_name=concept_name)

    # Store results with new structure
    key = (case_name_orig, prefix_len_orig)
    results[key] = {
        'original': (
            prefix_orig,  # Keep all fields
            suffix_orig,  # Keep all fields
            mean_pred_orig_filtered,  # Filtered: only concept:name and case_elapsed_time
            predicted_suffixes_orig_filtered,  # Filtered: only concept:name and case_elapsed_time
            mean_pred_remaining_time_orig,  # NEW: single float
            sampled_remaining_time_orig  # NEW: list of floats
        ),
        'perturbed': (
            prefix_pert,  # Keep all fields
            suffix_pert,  # Keep all fields
            mean_pred_pert_filtered,  # Filtered: only concept:name and case_elapsed_time
            predicted_suffixes_pert_filtered,  # Filtered: only concept:name and case_elapsed_time
            mean_pred_remaining_time_pert,  # NEW: single float
            sampled_remaining_time_pert  # NEW: list of floats
        ),
    }

    print(mean_pred_orig_filtered)

    
    if (i + 1) % save_every == 0:
        save_chunk(results, i, output_dir)
        results = {}

if len(results):
    save_chunk(results, i, output_dir)

print("Robustness evaluation completed!")
# Out:
# Evaluating robustness: 0it [00:00, ?it/s]
#   0%|          | 0/5660 [00:00<?, ?it/s]
#   0%|          | 0/5660 [00:00<?, ?it/s]
# [{'concept:name': 'Declaration FINAL_APPROVED by SUPERVISOR', 'case_elapsed_time': array([428840.45885128])}, {'concept:name': 'Request Payment', 'case_elapsed_time': array([484135.05033143])}, {'concept:name': 'Payment Handled', 'case_elapsed_time': array([598830.98117471])}]
# [{'concept:name': 'Declaration FINAL_APPROVED by SUPERVISOR', 'case_elapsed_time': array([693519.01228155])}, {'concept:name': 'Request Payment', 'case_elapsed_time': array([693519.01228155])}, {'concept:name': 'Payment Handled', 'case_elapsed_time': array([693519.01228155])}]
# [{'concept:name': 'Request Payment', 'case_elapsed_time': array([783538.00970188])}, {'concept:name': 'Request Payment', 'case_elapsed_time': array([783538.00970188])}, {'concept:name': 'Payment Handled', 'case_elapsed_time': array([783538.00970188])}]
# [{'concept:name': 'Declaration FINAL_APPROVED by SUPERVISOR', 'case_elapsed_time': array([428841.33211117])}, {'concept:name': 'Request Payment', 'case_elapsed_time': array([484136.22299471])}, {'concept:name': 'Payment Handled', 'case_elapsed_time': array([598831.8544346])}]
# [{'concept:name': 'Declaration FINAL_APPROVED by SUPERVISOR', 'case_elapsed_time': array([343141.13502461])}, {'concept:name': 'Request Payment', 'case_elapsed_time': array([457889.87392045])}, {'concept:name': 'Payment Handled', 'case_elapsed_time': array([580069.44161172])}]
# [{'concept:name': 'Request Payment', 'case_elapsed_time': array([319799.09785249])}, {'concept:name': 'Request Payment', 'case_elapsed_time': array([516479.09952186])}, {'concept:name': 'Payment Handled', 'case_elapsed_time': array([607601.55437273])}]
# [{'concept:name': 'Declaration FINAL_APPROVED by SUPERVISOR', 'case_elapsed_time': array([428841.53171343])}, {'concept:name': 'Request Payment', 'case_elapsed_time': array([484136.44754725])}, {'concept:name': 'Payment Handled', 'case_elapsed_time': array([598832.12888771])}]
# [{'concept:name': 'Declaration FINAL_APPROVED by SUPERVISOR', 'case_elapsed_time': array([343141.23482574])}, {'concept:name': 'Request Payment', 'case_elapsed_time': array([457890.14837356])}, {'concept:name': 'Payment Handled', 'case_elapsed_time': array([580069.64121398])}]
# [{'concept:name': 'Request Payment', 'case_elapsed_time': array([319791.3882152])}, {'concept:name': 'Request Payment', 'case_elapsed_time': array([516474.95777497])}, {'concept:name': 'Payment Handled', 'case_elapsed_time': array([607598.80984166])}]
# [{'concept:name': 'Declaration FINAL_APPROVED by SUPERVISOR', 'case_elapsed_time': array([428853.78230212])}, {'concept:name': 'Request Payment', 'case_elapsed_time': array([484151.29296533])}, {'concept:name': 'Payment Handled', 'case_elapsed_time': array([598842.90740974])}]
# [{'concept:name': 'Declaration FINAL_APPROVED by SUPERVISOR', 'case_elapsed_time': array([343153.31076246])}, {'concept:name': 'Request Payment', 'case_elapsed_time': array([457910.35810237])}, {'concept:name': 'Payment Handled', 'case_elapsed_time': array([580082.97713997])}]
# [{'concept:name': 'Declaration FINAL_APPROVED by SUPERVISOR', 'case_elapsed_time': array([380918.57604291])}, {'concept:name': 'Request Payment', 'case_elapsed_time': array([472505.47494427])}, {'concept:name': 'Payment Handled', 'case_elapsed_time': array([595887.63377594])}]
# [{'concept:name': 'Request Payment', 'case_elapsed_time': array([324399.65548873])}, {'concept:name': 'Request Payment', 'case_elapsed_time': array([519241.6945992])}, {'concept:name': 'Payment Handled', 'case_elapsed_time': array([609293.50787856])}]
# [{'concept:name': 'Declaration FINAL_APPROVED by SUPERVISOR', 'case_elapsed_time': array([428846.14751569])}, {'concept:name': 'Request Payment', 'case_elapsed_time': array([484143.33382522])}, {'concept:name': 'Payment Handled', 'case_elapsed_time': array([598836.73221482])}]
# [{'concept:name': 'Declaration FINAL_APPROVED by SUPERVISOR', 'case_elapsed_time': array([343152.28780088])}, {'concept:name': 'Request Payment', 'case_elapsed_time': array([457896.01168994])}, {'concept:name': 'Payment Handled', 'case_elapsed_time': array([580071.28793263])}]
# [{'concept:name': 'Declaration FINAL_APPROVED by SUPERVISOR', 'case_elapsed_time': array([377122.68996693])}, {'concept:name': 'Request Payment', 'case_elapsed_time': array([470647.75176164])}, {'concept:name': 'Payment Handled', 'case_elapsed_time': array([594546.68084404])}]
# [{'concept:name': 'Request Payment', 'case_elapsed_time': array([322693.85457613])}, {'concept:name': 'Request Payment', 'case_elapsed_time': array([518297.60086043])}, {'concept:name': 'Payment Handled', 'case_elapsed_time': array([608699.82838209])}]
# [{'concept:name': 'Declaration FINAL_APPROVED by SUPERVISOR', 'case_elapsed_time': array([428842.92892925])}, {'concept:name': 'Request Payment', 'case_elapsed_time': array([484140.11523878])}, {'concept:name': 'Payment Handled', 'case_elapsed_time': array([598833.62590466])}]
# [{'concept:name': 'Declaration FINAL_APPROVED by SUPERVISOR', 'case_elapsed_time': array([343147.92150144])}, {'concept:name': 'Request Payment', 'case_elapsed_time': array([457888.17730125])}, {'concept:name': 'Payment Handled', 'case_elapsed_time': array([580064.5638315])}]
# [{'concept:name': 'Request Payment', 'case_elapsed_time': array([341448.99439166])}, {'concept:name': 'Request Payment', 'case_elapsed_time': array([521562.12077043])}, {'concept:name': 'Payment Handled', 'case_elapsed_time': array([610826.86491381])}]
# [{'concept:name': 'Declaration FINAL_APPROVED by SUPERVISOR', 'case_elapsed_time': array([428849.89005806])}, {'concept:name': 'Request Payment', 'case_elapsed_time': array([484148.57338454])}, {'concept:name': 'Payment Handled', 'case_elapsed_time': array([598839.88842556])}]
# [{'concept:name': 'Declaration FINAL_APPROVED by SUPERVISOR', 'case_elapsed_time': array([343140.23681444])}, {'concept:name': 'Request Payment', 'case_elapsed_time': array([457892.69330237])}, {'concept:name': 'Payment Handled', 'case_elapsed_time': array([580067.75746766])}]
# [{'concept:name': 'Request Payment', 'case_elapsed_time': array([321917.77603958])}, {'concept:name': 'Request Payment', 'case_elapsed_time': array([517634.19779957])}, {'concept:name': 'Payment Handled', 'case_elapsed_time': array([608316.03066183])}]
# [{'concept:name': 'Declaration FINAL_APPROVED by SUPERVISOR', 'case_elapsed_time': array([428860.66858009])}, {'concept:name': 'Request Payment', 'case_elapsed_time': array([484161.59743199])}, {'concept:name': 'Payment Handled', 'case_elapsed_time': array([598848.69587527])}]
# [{'concept:name': 'Declaration FINAL_APPROVED by SUPERVISOR', 'case_elapsed_time': array([343156.77885172])}, {'concept:name': 'Request Payment', 'case_elapsed_time': array([457914.42499841])}, {'concept:name': 'Payment Handled', 'case_elapsed_time': array([580081.21814505])}]
# [{'concept:name': 'Request Payment', 'case_elapsed_time': array([319999.72307391])}, {'concept:name': 'Request Payment', 'case_elapsed_time': array([516604.32498963])}, {'concept:name': 'Payment Handled', 'case_elapsed_time': array([607670.40467723])}]
# [{'concept:name': 'Declaration FINAL_APPROVED by SUPERVISOR', 'case_elapsed_time': array([428863.26340947])}, {'concept:name': 'Request Payment', 'case_elapsed_time': array([484164.94076985])}, {'concept:name': 'Payment Handled', 'case_elapsed_time': array([598850.19289222])}]
# [{'concept:name': 'Declaration FINAL_APPROVED by SUPERVISOR', 'case_elapsed_time': array([343155.13213308])}, {'concept:name': 'Request Payment', 'case_elapsed_time': array([457915.14855661])}, {'concept:name': 'Payment Handled', 'case_elapsed_time': array([580080.17023319])}]
# [{'concept:name': 'Declaration FINAL_APPROVED by SUPERVISOR', 'case_elapsed_time': array([388081.75224242])}, {'concept:name': 'Request Payment', 'case_elapsed_time': array([476042.3770881])}, {'concept:name': 'Payment Handled', 'case_elapsed_time': array([598472.05888609])}]
# [{'concept:name': 'Request Payment', 'case_elapsed_time': array([832830.01232237])}, {'concept:name': 'Request Payment', 'case_elapsed_time': array([832830.01232237])}, {'concept:name': 'Payment Handled', 'case_elapsed_time': array([832830.01232237])}]
# [{'concept:name': 'Declaration FINAL_APPROVED by SUPERVISOR', 'case_elapsed_time': array([428863.98696766])}, {'concept:name': 'Request Payment', 'case_elapsed_time': array([484165.8639303])}, {'concept:name': 'Payment Handled', 'case_elapsed_time': array([598850.61704702])}]
# [{'concept:name': 'Declaration FINAL_APPROVED by SUPERVISOR', 'case_elapsed_time': array([343164.01443364])}, {'concept:name': 'Request Payment', 'case_elapsed_time': array([457920.03881197])}, {'concept:name': 'Payment Handled', 'case_elapsed_time': array([580083.0769411])}]
# [{'concept:name': 'Request Payment', 'case_elapsed_time': array([319832.75578355])}, {'concept:name': 'Request Payment', 'case_elapsed_time': array([516507.11868909])}, {'concept:name': 'Payment Handled', 'case_elapsed_time': array([607611.43468459])}]
# [{'concept:name': 'Declaration FINAL_APPROVED by SUPERVISOR', 'case_elapsed_time': array([428864.56082416])}, {'concept:name': 'Request Payment', 'case_elapsed_time': array([484166.53758792])}, {'concept:name': 'Payment Handled', 'case_elapsed_time': array([598851.10357753])}]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 9
#       5 results = {}
#       6 concept_name = 'concept:name'  # Match the concept_name used in ProbabilisticEvaluation
#       8 for i, ((case_name_orig, prefix_len_orig, prefix_orig, predicted_suffixes_orig, suffix_orig, mean_pred_orig),
# ----> 9         (case_name_pert, prefix_len_pert, prefix_pert, predicted_suffixes_pert, suffix_pert, mean_pred_pert)) in enumerate(
#      10     tqdm(zip(eval_original.evaluate_with_predifined_prefix(random_order=False),
#      11              eval_perturbed.evaluate_with_predifined_prefix(random_order=False)),
#      12          desc="Evaluating robustness")):
#      13
#      14     # Ensure we're comparing the same case and prefix length
#      15     assert case_name_orig == case_name_pert, f"Case mismatch: {case_name_orig} != {case_name_pert}"
#      17     assert prefix_len_orig == prefix_len_pert, f"Prefix length mismatch: {prefix_len_orig} != {prefix_len_pert}"
#
# File ~/.local/share/virtualenvs/Probabilistic_Suffix_Prediction_U-ED-LSTM_-32bEAP25/lib/python3.13/site-packages/tqdm/notebook.py:250, in tqdm_notebook.__iter__(self)
#     248 try:
#     249     it = super().__iter__()
# --> 250     for obj in it:
#     251         # return super(tqdm...) will not catch exception
#     252         yield obj
#     253 # NB: except ... [ as ...] breaks IPython async KeyboardInterrupt
#
# File ~/.local/share/virtualenvs/Probabilistic_Suffix_Prediction_U-ED-LSTM_-32bEAP25/lib/python3.13/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1178 time = self._time
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#    1183         # Update and possibly print the progressbar.
#    1184         # Note: does not call self.update(1) for speed optimisation.
#
# File ~/Desktop/Robustness-in-suffix-prediction/ml_models/notebooks/evaluation_run_notebooks/normal_4layer/BPIC20/../../../../evaluation/probabilistic_evaluation.py:228, in ProbabilisticEvaluation.evaluate_with_predifined_prefix(self, random_order, include_model_states, use_multiprocessing)
#     222 # Sequential processing (original behavior)
#     223 # Note: Multiprocessing is disabled due to PyTorch tensor file descriptor issues
#     224 # PyTorch tensors create file descriptors when pickled for multiprocessing,
#     225 # which causes "too many open files" errors even with small numbers of processes.
#     226 # Sequential processing avoids this issue entirely.
#     227 for (case_name, prefix_len), (prefix, suffix) in tqdm(items, total=len(items)):
# --> 228     yield self._evaluate_single(case_name, prefix_len, prefix, suffix, include_model_states)
#
# File ~/Desktop/Robustness-in-suffix-prediction/ml_models/notebooks/evaluation_run_notebooks/normal_4layer/BPIC20/../../../../evaluation/probabilistic_evaluation.py:171, in ProbabilisticEvaluation._evaluate_single(self, case_name, prefix_len, prefix, suffix, include_model_states)
#     168 mean_prediction = self._predict_suffix_with_means(prefix, prefix_len)
#     169 # print("Mean Pred: ", mean_prediction)
# --> 171 predicted_suffixes = self.predict_probabilistic_suffix(prefix, prefix_len, include_model_states)
#     173 return case_name, prefix_len, readable_prefix, predicted_suffixes, readable_suffix, mean_prediction
#
# File ~/Desktop/Robustness-in-suffix-prediction/ml_models/notebooks/evaluation_run_notebooks/normal_4layer/BPIC20/../../../../evaluation/probabilistic_evaluation.py:156, in ProbabilisticEvaluation.predict_probabilistic_suffix(self, prefix, prefix_len, include_model_states)
#     154 suffixes = []
#     155 for i in range(self.samples_per_case):
# --> 156     suffix = self.sample_suffix(prefix, prefix_len, include_model_states)
#     157     suffixes.append(suffix)
#     158 return suffixes
#
# File ~/Desktop/Robustness-in-suffix-prediction/ml_models/notebooks/evaluation_run_notebooks/normal_4layer/BPIC20/../../../../evaluation/probabilistic_evaluation.py:113, in ProbabilisticEvaluation.sample_suffix(self, prefix, prefix_len, include_model_states)
#     112 def sample_suffix(self, prefix, prefix_len, include_model_states):
# --> 113     prediction, (h, c), z = self.model.inference(prefix=prefix)
#     114     suffix = []
#     115     max_iteration = self.dataset.encoder_decoder.window_size - \
#     116                     self.dataset.encoder_decoder.min_suffix_size - \
#     117                     prefix_len
#
# File ~/Desktop/Robustness-in-suffix-prediction/ml_models/notebooks/evaluation_run_notebooks/normal_4layer/BPIC20/../../../../model/dropout_uncertainty_enc_dec_LSTM/dropout_uncertainty_model.py:412, in DropoutUncertaintyEncoderDecoderLSTM.inference(self, prefix, last_event, hx, z)
#     408 with torch.no_grad():
#     409     # First Prediciton
#     410     if prefix is not None:
#     411         # Call encoder
# --> 412         (h_enc, c_enc) = self.encoder(input=prefix)
#     414         # Get SOS event: Last prefx event:
#     415         cat_prefixes, num_prefixes = prefix
#
# File ~/.local/share/virtualenvs/Probabilistic_Suffix_Prediction_U-ED-LSTM_-32bEAP25/lib/python3.13/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/.local/share/virtualenvs/Probabilistic_Suffix_Prediction_U-ED-LSTM_-32bEAP25/lib/python3.13/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/Desktop/Robustness-in-suffix-prediction/ml_models/notebooks/evaluation_run_notebooks/normal_4layer/BPIC20/../../../../model/dropout_uncertainty_enc_dec_LSTM/dropout_uncertainty_encoder.py:80, in DropoutUncertaintyLSTMEncoder.forward(self, input)
#      78 # Pass through the remaining LSTM cell: Layer gets for: input: h_n Tensor, hx: (h, c)
#      79 for _, layer in enumerate(self.hidden_layers):
# ---> 80     outputs, (h, c), _ = layer(input=outputs, hx=(h, c), z=None)
#      82 return (h, c)
#
# File ~/.local/share/virtualenvs/Probabilistic_Suffix_Prediction_U-ED-LSTM_-32bEAP25/lib/python3.13/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/.local/share/virtualenvs/Probabilistic_Suffix_Prediction_U-ED-LSTM_-32bEAP25/lib/python3.13/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/Desktop/Robustness-in-suffix-prediction/ml_models/notebooks/evaluation_run_notebooks/normal_4layer/BPIC20/../../../../model/dropout_uncertainty_enc_dec_LSTM/dropout_uncertainty_LSTM_cell.py:185, in DropoutUncertaintyLSTMCell.forward(self, input, hx, z)
#     182 for t in range(T):
#     183     # Drop out randm input and hidden values
#     184     x_i, x_f, x_c, x_o = (input[t] * zx_ for zx_ in zx)
# --> 185     h_i, h_f, h_c, h_o = (h_t * zh_ for zh_ in zh)
#     187     # Compute LSTM gates
#     188     # Input gate: Store new information
#     189     i = torch.sigmoid(self.Wi(x_i) + self.Ui(h_i))
#
# File ~/Desktop/Robustness-in-suffix-prediction/ml_models/notebooks/evaluation_run_notebooks/normal_4layer/BPIC20/../../../../model/dropout_uncertainty_enc_dec_LSTM/dropout_uncertainty_LSTM_cell.py:185, in <genexpr>(.0)
#     182 for t in range(T):
#     183     # Drop out randm input and hidden values
#     184     x_i, x_f, x_c, x_o = (input[t] * zx_ for zx_ in zx)
# --> 185     h_i, h_f, h_c, h_o = (h_t * zh_ for zh_ in zh)
#     187     # Compute LSTM gates
#     188     # Input gate: Store new information
#     189     i = torch.sigmoid(self.Wi(x_i) + self.Ui(h_i))
#
# KeyboardInterrupt:

# %%
# Load all saved chunks and combine them
all_results = {}
# Get all chunk files and sort them
chunk_files = [f for f in os.listdir(output_dir) if f.startswith('robustness_results_part_')]
chunk_files.sort()  # Ensure correct order

print(f"Found {len(chunk_files)} chunk files")

for chunk_file in chunk_files:
    chunk_path = os.path.join(output_dir, chunk_file)
    print(f"Loading {chunk_file}...")
    with open(chunk_path, 'rb') as f:
        chunk_results = pickle.load(f)
        all_results.update(chunk_results)
        print(f"  Added {len(chunk_results)} results from {chunk_file}")

# Also add the final results if any (e.g. from a still-running evaluation loop)
if 'results' in locals() and len(results) > 0:
    print(f"Adding final {len(results)} results...")
    all_results.update(results)

print(f"\nTotal results loaded: {len(all_results)}")

# Save combined results into a single pickle file
combined_results_path = os.path.join(output_dir, 'robustness_results.pkl')
with open(combined_results_path, 'wb') as f:
    pickle.dump(all_results, f)

print(f"Combined results saved to {combined_results_path}")
# Out:
# Found 9 chunk files
# Loading robustness_results_part_050.pkl...
#   Added 50 results from robustness_results_part_050.pkl
# Loading robustness_results_part_100.pkl...
#   Added 50 results from robustness_results_part_100.pkl
# Loading robustness_results_part_150.pkl...
#   Added 50 results from robustness_results_part_150.pkl
# Loading robustness_results_part_200.pkl...
#   Added 50 results from robustness_results_part_200.pkl
# Loading robustness_results_part_250.pkl...
#   Added 50 results from robustness_results_part_250.pkl
# Loading robustness_results_part_300.pkl...
#   Added 50 results from robustness_results_part_300.pkl
# Loading robustness_results_part_350.pkl...
#   Added 50 results from robustness_results_part_350.pkl
# Loading robustness_results_part_400.pkl...
#   Added 50 results from robustness_results_part_400.pkl
# Loading robustness_results_part_432.pkl...
#   Added 32 results from robustness_results_part_432.pkl
# Adding final 32 results...
#
# Total results loaded: 432
# Combined results saved to ../../../../../evaluation_results/robustness/BPIC20/loop_augmentation/robustness_results.pkl
