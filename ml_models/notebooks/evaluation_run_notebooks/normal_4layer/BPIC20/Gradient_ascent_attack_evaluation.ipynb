# %%
import importlib
import sys
import torch
import pickle
import os
from tqdm.notebook import tqdm

sys.path.insert(0, '..')
sys.path.insert(0, '../..')
sys.path.insert(0, '../../..')
sys.path.insert(0, '../../../..')
sys.path.insert(0, '../../../../..')

from model.dropout_uncertainty_enc_dec_LSTM.dropout_uncertainty_model import DropoutUncertaintyEncoderDecoderLSTM

# %%
# Load model
file_path_model = '../../../training_variational_dropout/BPIC20/BPIC_2020_setting_2_2.pkl'
model = DropoutUncertaintyEncoderDecoderLSTM.load(file_path_model, dropout=0.1)

# Load the dataset
file_path_data_set = '../../../../../encoded_data/BPIC20/BPIC_2020_all_5_val.pkl'
bpic_20_test_dataset = torch.load(file_path_data_set, weights_only=False)

print(f"Model loaded")
print(f"Dataset loaded: {len(bpic_20_test_dataset)} cases")
# Out:
# Data set categories:  ([('concept:name', 18, {'Declaration APPROVED by ADMINISTRATION': 1, 'Declaration APPROVED by BUDGET OWNER': 2, 'Declaration APPROVED by PRE_APPROVER': 3, 'Declaration FINAL_APPROVED by SUPERVISOR': 4, 'Declaration FOR_APPROVAL by PRE_APPROVER': 5, 'Declaration FOR_APPROVAL by SUPERVISOR': 6, 'Declaration REJECTED by ADMINISTRATION': 7, 'Declaration REJECTED by BUDGET OWNER': 8, 'Declaration REJECTED by EMPLOYEE': 9, 'Declaration REJECTED by MISSING': 10, 'Declaration REJECTED by PRE_APPROVER': 11, 'Declaration REJECTED by SUPERVISOR': 12, 'Declaration SAVED by EMPLOYEE': 13, 'Declaration SUBMITTED by EMPLOYEE': 14, 'EOS': 15, 'Payment Handled': 16, 'Request Payment': 17}), ('org:resource', 4, {'EOS': 1, 'STAFF MEMBER': 2, 'SYSTEM': 3}), ('org:role', 9, {'ADMINISTRATION': 1, 'BUDGET OWNER': 2, 'EMPLOYEE': 3, 'EOS': 4, 'MISSING': 5, 'PRE_APPROVER': 6, 'SUPERVISOR': 7, 'UNDEFINED': 8}), ('case:BudgetNumber', 3, {'EOS': 1, 'budget 86566': 2}), ('case:DeclarationNumber', 6535, {'EOS': 1, 'UNKNOWN': 2, 'declaration number 120850': 3, 'declaration number 120856': 4, 'declaration number 120861': 5, 'declaration number 120866': 6, 'declaration number 120875': 7, 'declaration number 120880': 8, 'declaration number 120885': 9, 'declaration number 120891': 10, 'declaration number 120902': 11, 'declaration number 120907': 12, 'declaration number 120915': 13, 'declaration number 120920': 14, 'declaration number 120925': 15, 'declaration number 120934': 16, 'declaration number 120939': 17, 'declaration number 120944': 18, 'declaration number 120954': 19, 'declaration number 120959': 20, 'declaration number 120965': 21, 'declaration number 120971': 22, 'declaration number 120976': 23, 'declaration number 120981': 24, 'declaration number 120986': 25, 'declaration number 120992': 26, 'declaration number 120997': 27, 'declaration number 121002': 28, 'declaration number 121007': 29, 'declaration number 121012': 30, 'declaration number 121018': 31, 'declaration number 121023': 32, 'declaration number 121028': 33, 'declaration number 121033': 34, 'declaration number 121038': 35, 'declaration number 121043': 36, 'declaration number 121048': 37, 'declaration number 121053': 38, 'declaration number 121059': 39, 'declaration number 121070': 40, 'declaration number 121078': 41, 'declaration number 121083': 42, 'declaration number 121088': 43, 'declaration number 121093': 44, 'declaration number 121098': 45, 'declaration number 121103': 46, 'declaration number 121108': 47, 'declaration number 121113': 48, 'declaration number 121118': 49, 'declaration number 121126': 50, 'declaration number 121131': 51, 'declaration number 121137': 52, 'declaration number 121143': 53, 'declaration number 121148': 54, 'declaration number 121153': 55, 'declaration number 121158': 56, 'declaration number 121164': 57, 'declaration number 121170': 58, 'declaration number 121176': 59, 'declaration number 121181': 60, 'declaration number 121190': 61, 'declaration number 121195': 62, 'declaration number 121201': 63, 'declaration number 121206': 64, 'declaration number 121211': 65, 'declaration number 121217': 66, 'declaration number 121222': 67, 'declaration number 121228': 68, 'declaration number 121233': 69, 'declaration number 121239': 70, 'declaration number 121251': 71, 'declaration number 121257': 72, 'declaration number 121262': 73, 'declaration number 121271': 74, 'declaration number 121276': 75, 'declaration number 121281': 76, 'declaration number 121286': 77, 'declaration number 121292': 78, 'declaration number 121297': 79, 'declaration number 121302': 80, 'declaration number 121307': 81, 'declaration number 121313': 82, 'declaration number 121318': 83, 'declaration number 121324': 84, 'declaration number 121330': 85, 'declaration number 121335': 86, 'declaration number 121340': 87, 'declaration number 121345': 88, 'declaration number 121355': 89, 'declaration number 121360': 90, 'declaration number 121366': 91, 'declaration number 121371': 92, 'd ...
# Encoder input features:  [['concept:name', 'org:resource', 'org:role', 'case:BudgetNumber', 'case:DeclarationNumber'], ['case_elapsed_time', 'event_elapsed_time', 'day_in_week', 'seconds_in_day']]
# Decoder input+output features:  [['concept:name'], ['case_elapsed_time']]
#
#
# Sequence length of decoder output:  4
#
#
# Cells hidden size:  128
# Number of LSTM layer:  4
# Dropout rate:  0.1
#
#
# Encoder number of labels for each input feature (categorical, numerical):  [[18, 4, 9, 3, 6535], [1, 1, 1, 1]]
# Encoder indices of tensors in dataset used as input:  [[0, 1, 2, 3, 4], [0, 1, 2, 3]]
# Embeddings encoder:  ModuleList(
#   (0): Embedding(18, 8)
#   (1): Embedding(4, 3)
#   (2): Embedding(9, 5)
#   (3): Embedding(3, 3)
#   (4): Embedding(6535, 219)
# )
# Total embedding feature size encoder:  238
# Total numerical feature size encoder:  4
# Input feature size encoder:  242
# Encoder initialized!
#
# Decoder label values size for each categorical input feature:  [18]
# Decoder label values size for each numerical input feature:  [1]
# Decoder indices of tensors in dataset used as input:  [[0], [0]]
# Embeddings decoder:  ModuleList(
#   (0): Embedding(18, 8)
# )
# Total embedding feature size decoder:  8
# Total numerical feature size decoder:  1
# Input feature size decoder:  9
# Output feature list of dicts (featue name, feature output size) of decoder:  [{'concept:name': 18}, {'case_elapsed_time': 1}]
# Decoder initialized!
#
# Output feature list of dicts (featue name, tensor index in dataset) of decoder:  [{'concept:name': 0}, {'case_elapsed_time': 0}]
# Model loaded
# Dataset loaded: 10364 cases
# /Users/leonurny/.local/share/virtualenvs/Probabilistic_Suffix_Prediction_U-ED-LSTM_-32bEAP25/lib/python3.13/site-packages/sklearn/base.py:442: InconsistentVersionWarning: Trying to unpickle estimator OrdinalEncoder from version 1.5.2 when using version 1.7.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/leonurny/.local/share/virtualenvs/Probabilistic_Suffix_Prediction_U-ED-LSTM_-32bEAP25/lib/python3.13/site-packages/sklearn/base.py:442: InconsistentVersionWarning: Trying to unpickle estimator SimpleImputer from version 1.5.2 when using version 1.7.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /Users/leonurny/.local/share/virtualenvs/Probabilistic_Suffix_Prediction_U-ED-LSTM_-32bEAP25/lib/python3.13/site-packages/sklearn/base.py:442: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.5.2 when using version 1.7.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
attack_dataset = '../../../../../encoded_data/BPIC20/val_new.pkl'
predefined_dataset = torch.load(attack_dataset, weights_only=False)

# %%
# Import and reload the adversarial attack module
import evaluation.adversarial_attack
importlib.reload(evaluation.adversarial_attack)
from evaluation.adversarial_attack import GradientAscentAttacker

# Create the gradient ascent attacker
attacker = GradientAscentAttacker(
    model=model,
    dataset=bpic_20_test_dataset,
    concept_name='concept:name',
    growing_num_values=['case_elapsed_time'],
    all_cat=['concept:name'],
    all_num=['case_elapsed_time'],
    dataset_predefined_prefixes=predefined_dataset
)

print("GradientAscentAttacker initialized")
# Out:
# GradientAscentAttacker initialized

# %%
# Configure attack parameters
max_iterations = 15  # Maximum gradient ascent steps per attack
embedding_step_size = 0.3    # Learning rate for embedding perturbations
time_step_size = 0.001        # Learning rate for time feature perturbations
embedding_epsilon = 10.0     # Maximum allowed perturbation for embeddings (L_inf norm)
time_epsilon = 0.1           # Maximum allowed perturbation for time features (L_inf norm)
early_stop = True            # Stop when prediction becomes wrong

print(f"Attack parameters:")
print(f"  Max iterations: {max_iterations}")
print(f"  Embedding step size: {embedding_step_size}")
print(f"  Time step size: {time_step_size}")
print(f"  Embedding epsilon: {embedding_epsilon}")
print(f"  Time epsilon: {time_epsilon}")
print(f"  Early stop: {early_stop}")
# Out:
# Attack parameters:
#   Max iterations: 15
#   Embedding step size: 0.3
#   Time step size: 0.001
#   Embedding epsilon: 10.0
#   Time epsilon: 0.1
#   Early stop: True

# %%
# Function to save results in chunks
def save_chunk(results, chunk_number):
    filename = os.path.join(output_dir, f'gradient_ascent_attack_part_{chunk_number:04d}.pkl')
    with open(filename, 'wb') as f:
        pickle.dump(results, f)
    print(f"Saved {len(results)} results to {filename}")

# Set output directory
output_dir = '../../../../../evaluation_results/robustness/BPIC20/gradient_ascent_attack/'
os.makedirs(output_dir, exist_ok=True)

save_every = 50  # Save every N successful attacks
print(f"Output directory: {output_dir}")
print(f"Saving every {save_every} attacks")
# Out:
# Output directory: ../../../../../evaluation_results/robustness/BPIC20/gradient_ascent_attack/
# Saving every 50 attacks

# %%
# Perform gradient ascent attacks on all predefined prefixes
print("Starting gradient ascent attacks...")
print(f"Total prefix-suffix pairs to attack: {len(predefined_dataset)}")

results = attacker.attack_predefined_prefixes(
    max_iterations=max_iterations,
    embedding_step_size=embedding_step_size,
    time_step_size=time_step_size,
    embedding_epsilon=embedding_epsilon,
    time_epsilon=time_epsilon,
    early_stop=early_stop,
    attackable_features="all",
    enable_time_shifting=True
)

print(f"\nAttack completed!")
print(f"Total attacks performed: {len(results)}")
print(f"Successful attacks: {sum(1 for r in results.values() if r['success'])}")
print(f"Failed attacks: {sum(1 for r in results.values() if not r['success'])}")
# Out:
# Starting gradient ascent attacks...
# Total prefix-suffix pairs to attack: 5660
# Performing gradient ascent attacks:   0%|          | 0/5660 [00:00<?, ?it/s]
# Performing gradient ascent attacks:  40%|████      | 2272/5660 [06:31<13:10,  4.28it/s]

# %%
# Save results
if len(results) > 0:
    if len(results) <= save_every:
        filename = os.path.join(output_dir, 'gradient_ascent_attack_all.pkl')
        with open(filename, 'wb') as f:
            pickle.dump(results, f)
        print(f"Saved all {len(results)} results to {filename}")
    else:
        results_list = list(results.items())
        for i in range(0, len(results_list), save_every):
            chunk = dict(results_list[i:i+save_every])
            chunk_number = (i // save_every) + 1
            save_chunk(chunk, chunk_number)
        print(f"Saved {len(results)} results in chunks")
else:
    print("No results to save")
# Out:
# Saved 50 results to ../../../../../evaluation_results/robustness/BPIC20/gradient_ascent_attack/gradient_ascent_attack_part_0001.pkl
# Saved 50 results to ../../../../../evaluation_results/robustness/BPIC20/gradient_ascent_attack/gradient_ascent_attack_part_0002.pkl
# Saved 50 results to ../../../../../evaluation_results/robustness/BPIC20/gradient_ascent_attack/gradient_ascent_attack_part_0003.pkl
# Saved 50 results to ../../../../../evaluation_results/robustness/BPIC20/gradient_ascent_attack/gradient_ascent_attack_part_0004.pkl
# Saved 50 results to ../../../../../evaluation_results/robustness/BPIC20/gradient_ascent_attack/gradient_ascent_attack_part_0005.pkl
# Saved 50 results to ../../../../../evaluation_results/robustness/BPIC20/gradient_ascent_attack/gradient_ascent_attack_part_0006.pkl
# Saved 50 results to ../../../../../evaluation_results/robustness/BPIC20/gradient_ascent_attack/gradient_ascent_attack_part_0007.pkl
# Saved 50 results to ../../../../../evaluation_results/robustness/BPIC20/gradient_ascent_attack/gradient_ascent_attack_part_0008.pkl
# Saved 50 results to ../../../../../evaluation_results/robustness/BPIC20/gradient_ascent_attack/gradient_ascent_attack_part_0009.pkl
# Saved 50 results to ../../../../../evaluation_results/robustness/BPIC20/gradient_ascent_attack/gradient_ascent_attack_part_0010.pkl
# Saved 50 results to ../../../../../evaluation_results/robustness/BPIC20/gradient_ascent_attack/gradient_ascent_attack_part_0011.pkl
# Saved 50 results to ../../../../../evaluation_results/robustness/BPIC20/gradient_ascent_attack/gradient_ascent_attack_part_0012.pkl
# Saved 50 results to ../../../../../evaluation_results/robustness/BPIC20/gradient_ascent_attack/gradient_ascent_attack_part_0013.pkl
# Saved 50 results to ../../../../../evaluation_results/robustness/BPIC20/gradient_ascent_attack/gradient_ascent_attack_part_0014.pkl
# Saved 50 results to ../../../../../evaluation_results/robustness/BPIC20/gradient_ascent_attack/gradient_ascent_attack_part_0015.pkl
# Saved 50 results to ../../../../../evaluation_results/robustness/BPIC20/gradient_ascent_attack/gradient_ascent_attack_part_0016.pkl
# Saved 50 results to ../../../../../evaluation_results/robustness/BPIC20/gradient_ascent_attack/gradient_ascent_attack_part_0017.pkl
# Saved 50 results to ../../../../../evaluation_results/robustness/BPIC20/gradient_ascent_attack/gradient_ascent_attack_part_0018.pkl
# Saved 50 results to ../../../../../evaluation_results/robustness/BPIC20/gradient_ascent_attack/gradient_ascent_attack_part_0019.pkl
# Saved 50 results to ../../../../../evaluation_results/robustness/BPIC20/gradient_ascent_attack/gradient_ascent_attack_part_0020.pkl
# Saved 50 results to ../../../../../evaluation_results/robustness/BPIC20/gradient_ascent_attack/gradient_ascent_attack_part_0021.pkl
# Saved 50 results to ../../../../../evaluation_results/robustness/BPIC20/gradient_ascent_attack/gradient_ascent_attack_part_0022.pkl
# Saved 50 results to ../../../../../evaluation_results/robustness/BPIC20/gradient_ascent_attack/gradient_ascent_attack_part_0023.pkl
# Saved 50 results to ../../../../../evaluation_results/robustness/BPIC20/gradient_ascent_attack/gradient_ascent_attack_part_0024.pkl
# Saved 50 results to ../../../../../evaluation_results/robustness/BPIC20/gradient_ascent_attack/gradient_ascent_attack_part_0025.pkl
# Saved 50 results to ../../../../../evaluation_results/robustness/BPIC20/gradient_ascent_attack/gradient_ascent_attack_part_0026.pkl
# Saved 50 results to ../../../../../evaluation_results/robustness/BPIC20/gradient_ascent_attack/gradient_ascent_attack_part_0027.pkl
# Saved 50 results to ../../../../../evaluation_results/robustness/BPIC20/gradient_ascent_attack/gradient_ascent_attack_part_0028.pkl
# Saved 31 results to ../../../../../evaluation_results/robustness/BPIC20/gradient_ascent_attack/gradient_ascent_attack_part_0029.pkl
# Saved 1431 results in chunks

# %%
# Debug: check predicted vs true suffix for first 20 prefixes
correct_count = 0
total_count = 0
for (case_id, prefix_len), (prefix, suffix) in list(predefined_dataset.items())[:200]:
    pred = attacker._predict_suffix_with_means(prefix, prefix_len)
    detached_suffix = attacker._detach_case(suffix)
    true_suffix = attacker.case_to_readable(detached_suffix, prune_eos=True)
    
    pred_activities = [e.get('concept:name') for e in pred]
    true_activities = [e.get('concept:name') for e in true_suffix]
    
    total_count += 1
    if pred_activities == true_activities:
        correct_count += 1
    else:
        print(f"Case {case_id}, prefix_len={prefix_len}")
        print(f"  Predicted: {pred_activities}")
        print(f"  True:      {true_activities}")
        print()

print(f"\nCorrect: {correct_count}/{total_count}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       2 correct_count = 0
#       3 total_count = 0
# ----> 4 for (case_id, prefix_len), (prefix, suffix) in list(predefined_dataset.items())[:200]:
#       5     pred = attacker._predict_suffix_with_means(prefix, prefix_len)
#       6     detached_suffix = attacker._detach_case(suffix)
#
# NameError: name 'predefined_dataset' is not defined

# %%
# Print summary statistics
if len(results) > 0:
    successful_attacks = [r for r in results.values() if r['success']]
    failed_attacks = [r for r in results.values() if not r['success']]
    
    print("\n=== Attack Summary ===")
    print(f"Total attacks: {len(results)}")
    print(f"Successful attacks: {len(successful_attacks)}")
    print(f"Failed attacks: {len(failed_attacks)}")
    
    if successful_attacks:
        num_steps = [r['num_steps'] for r in successful_attacks]
        print(f"\nSuccessful attack statistics:")
        print(f"  Average steps: {sum(num_steps) / len(num_steps):.2f}")
        print(f"  Min steps: {min(num_steps)}")
        print(f"  Max steps: {max(num_steps)}")
    
    if failed_attacks:
        num_steps_failed = [r['num_steps'] for r in failed_attacks]
        print(f"\nFailed attack statistics:")
        print(f"  Average steps: {sum(num_steps_failed) / len(num_steps_failed):.2f}")
        print(f"  All reached max iterations: {all(n == max_iterations for n in num_steps_failed)}")
else:
    print("No results to summarize")
# Out:
# === Attack Summary ===
# Total attacks: 1431
# Successful attacks: 578
# Failed attacks: 853
#
# Successful attack statistics:
#   Average steps: 9.21
#   Min steps: 7
#   Max steps: 10
#
# Failed attack statistics:
#   Average steps: 10.00
#   All reached max iterations: True

# %%
# Example: Inspect a few attack results
if len(results) > 0:
    print("\n=== Example Attack Results ===")
    
    successful = [(k, v) for k, v in results.items() if v['success']]
    if successful:
        print(f"\nFirst successful attack:")
        (case_id, prefix_len), result = successful[0]
        print(f"  Case ID: {case_id}, Prefix Length: {prefix_len}")
        print(f"  Steps taken: {result['num_steps']}")
        print(f"  Original suffix length: {len(result['original_suffix'])}")
        print(f"  Perturbed suffix length: {len(result['perturbed_suffix'])}")
        
        if result['original_suffix'] and result['perturbed_suffix']:
            orig_activities = [e.get('concept:name', 'N/A') for e in result['original_suffix']]
            pert_activities = [e.get('concept:name', 'N/A') for e in result['perturbed_suffix']]
            print(f"  Original activities: {orig_activities}")
            print(f"  Perturbed activities: {pert_activities}")
    
    failed = [(k, v) for k, v in results.items() if not v['success']]
    if failed:
        print(f"\nFirst failed attack:")
        (case_id, prefix_len), result = failed[0]
        print(f"  Case ID: {case_id}, Prefix Length: {prefix_len}")
        print(f"  Steps taken: {result['num_steps']}")
        print(f"  Note: Attack did not succeed within {max_iterations} iterations")
else:
    print("No results to inspect")
# Out:
# === Example Attack Results ===
#
# First successful attack:
#   Case ID: declaration 100005, Prefix Length: 2
#   Steps taken: 10
#   Original suffix length: 3
#   Perturbed suffix length: 3
#   Original activities: ['Declaration FINAL_APPROVED by SUPERVISOR', 'Request Payment', 'Payment Handled']
#   Perturbed activities: ['Request Payment', 'Request Payment', 'Payment Handled']
#
# First failed attack:
#   Case ID: declaration 100000, Prefix Length: 2
#   Steps taken: 10
#   Note: Attack did not succeed within 10 iterations

# %%
# Print before/after prefix and suffix for all attack candidates
if len(results) > 0:
    print("\n" + "="*80)
    print("BEFORE/AFTER PREFIX AND SUFFIX FOR ALL ATTACK CANDIDATES")
    print("="*80)
    
    for idx, ((case_id, prefix_len), result) in enumerate(results.items(), 1):
        print(f"\n{'='*80}")
        print(f"Attack #{idx}: Case ID: {case_id}, Prefix Length: {prefix_len}")
        print(f"Status: {'SUCCESS' if result['success'] else 'FAILED'}")
        print(f"Steps taken: {result['num_steps']}")
        print(f"{'='*80}")
        
        original_prefix_readable = attacker.case_to_readable(
            (result['original_prefix'][0], result['original_prefix'][1]), 
            prune_eos=True
        )
        
        perturbed_prefix_readable = attacker.case_to_readable(
            (result['perturbed_prefix'][0], result['perturbed_prefix'][1]), 
            prune_eos=True
        )
        
        print(f"\n--- PREFIX COMPARISON (Length: {len(original_prefix_readable)}) ---")
        max_prefix_len = max(len(original_prefix_readable), len(perturbed_prefix_readable))
        for i in range(max_prefix_len):
            print(f"\n  Event {i+1}:")
            orig_event = original_prefix_readable[i] if i < len(original_prefix_readable) else {}
            pert_event = perturbed_prefix_readable[i] if i < len(perturbed_prefix_readable) else {}
            
            all_keys = set(orig_event.keys()) | set(pert_event.keys())
            
            for key in sorted(all_keys):
                orig_value = orig_event.get(key, 'N/A')
                pert_value = pert_event.get(key, 'N/A')
                
                if orig_value != pert_value:
                    print(f"    {key} = [{orig_value}] -> [{pert_value}] \u26a0\ufe0f CHANGED")
                else:
                    print(f"    {key} = [{orig_value}], [{pert_value}]")
        
        print(f"\n--- SUFFIX COMPARISON ---")
        orig_suffix = result['original_suffix']
        pert_suffix = result['perturbed_suffix']
        max_suffix_len = max(len(orig_suffix), len(pert_suffix))
        
        for i in range(max_suffix_len):
            orig_event = orig_suffix[i] if i < len(orig_suffix) else {}
            pert_event = pert_suffix[i] if i < len(pert_suffix) else {}
            
            all_keys = set(orig_event.keys()) | set(pert_event.keys())
            
            print(f"\n  Event {i+1}:")
            for key in sorted(all_keys):
                orig_value = orig_event.get(key, 'N/A')
                pert_value = pert_event.get(key, 'N/A')
                
                if orig_value != pert_value:
                    print(f"    {key} = [{orig_value}] -> [{pert_value}] \u26a0\ufe0f CHANGED")
                else:
                    print(f"    {key} = [{orig_value}], [{pert_value}]")
        
        orig_prefix_activities = [e.get('concept:name', 'N/A') for e in original_prefix_readable]
        pert_prefix_activities = [e.get('concept:name', 'N/A') for e in perturbed_prefix_readable]
        orig_suffix_activities = [e.get('concept:name', 'N/A') for e in result['original_suffix']]
        pert_suffix_activities = [e.get('concept:name', 'N/A') for e in result['perturbed_suffix']]
        
        print(f"\n--- ACTIVITY SEQUENCE SUMMARY ---")
        print(f"Prefix activities: {orig_prefix_activities} -> {pert_prefix_activities}")
        print(f"Suffix activities: {orig_suffix_activities} -> {pert_suffix_activities}")
        
        prefix_changed = orig_prefix_activities != pert_prefix_activities
        print(f"\nPrefix changed: {prefix_changed}")
        if prefix_changed:
            print("  Positions changed:")
            for i, (orig, pert) in enumerate(zip(orig_prefix_activities, pert_prefix_activities)):
                if orig != pert:
                    print(f"    Position {i+1}: '{orig}' -> '{pert}'")
        
        suffix_changed = orig_suffix_activities != pert_suffix_activities
        print(f"Suffix changed: {suffix_changed}")
        if suffix_changed:
            print("  Positions changed:")
            min_len = min(len(orig_suffix_activities), len(pert_suffix_activities))
            for i in range(min_len):
                if orig_suffix_activities[i] != pert_suffix_activities[i]:
                    print(f"    Position {i+1}: '{orig_suffix_activities[i]}' -> '{pert_suffix_activities[i]}'")
            if len(orig_suffix_activities) != len(pert_suffix_activities):
                print(f"  Length difference: {len(orig_suffix_activities)} vs {len(pert_suffix_activities)}")
        
        print(f"\n{'-'*80}")
    
    print(f"\n{'='*80}")
    print(f"Total attacks printed: {len(results)}")
    print(f"{'='*80}")
else:
    print("No results to print")
# Out:
# ================================================================================
# BEFORE/AFTER PREFIX AND SUFFIX FOR ALL ATTACK CANDIDATES
# ================================================================================
#
# ================================================================================
# Attack #1: Case ID: declaration 100000, Prefix Length: 2
# Status: FAILED
# Steps taken: 10
# ================================================================================
#
# --- PREFIX COMPARISON (Length: 2) ---
#
#   Event 1:
#     case:BudgetNumber = [budget 86566], [budget 86566]
#     case:DeclarationNumber = [None], [None]
#     case_elapsed_time = [-0.012600072368513793] -> [8371.90498447558] ⚠️ CHANGED
#     concept:name = [Declaration SUBMITTED by EMPLOYEE], [Declaration SUBMITTED by EMPLOYEE]
#     day_in_week = [0.9999999789825007] -> [0.8904437774003215] ⚠️ CHANGED
#     event_elapsed_time = [231062.453125] -> [231062.45324333638] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER], [STAFF MEMBER]
#     org:role = [EMPLOYEE] -> [UNDEFINED] ⚠️ CHANGED
#     seconds_in_day = [33606.99967952852] -> [33032.678257953114] ⚠️ CHANGED
#
#   Event 2:
#     case:BudgetNumber = [budget 86566], [budget 86566]
#     case:DeclarationNumber = [None], [None]
#     case_elapsed_time = [693519.0122815539] -> [609799.7615852271] ⚠️ CHANGED
#     concept:name = [Declaration APPROVED by ADMINISTRATION], [Declaration APPROVED by ADMINISTRATION]
#     day_in_week = [1.9999999994143962] -> [1.956177484090556] ⚠️ CHANGED
#     event_elapsed_time = [693519.0342706754], [693519.0342706754]
#     org:resource = [STAFF MEMBER], [STAFF MEMBER]
#     org:role = [ADMINISTRATION], [ADMINISTRATION]
#     seconds_in_day = [35926.0000274991] -> [36117.44050135757] ⚠️ CHANGED
#
# --- SUFFIX COMPARISON ---
#
#   Event 1:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [783538.0097018804] -> [[609799.76158523]] ⚠️ CHANGED
#     concept:name = [Declaration FINAL_APPROVED by SUPERVISOR], [Declaration FINAL_APPROVED by SUPERVISOR]
#     day_in_week = [2.9999999871959684] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [90018.99519746666] -> [N/A] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER] -> [N/A] ⚠️ CHANGED
#     org:role = [SUPERVISOR] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [39545.00000172186] -> [N/A] ⚠️ CHANGED
#
#   Event 2:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [876162.0162154031] -> [[609799.76158523]] ⚠️ CHANGED
#     concept:name = [Request Payment], [Request Payment]
#     day_in_week = [4.00000005660335] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [92623.99672710808] -> [N/A] ⚠️ CHANGED
#     org:resource = [SYSTEM] -> [N/A] ⚠️ CHANGED
#     org:role = [UNDEFINED] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [45768.999990654134] -> [N/A] ⚠️ CHANGED
#
#   Event 3:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [1152672.9978466744] -> [[609799.76158523]] ⚠️ CHANGED
#     concept:name = [Payment Handled], [Payment Handled]
#     day_in_week = [4.0176413973469494e-08] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [276510.99826067325] -> [N/A] ⚠️ CHANGED
#     org:resource = [SYSTEM] -> [N/A] ⚠️ CHANGED
#     org:role = [UNDEFINED] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [63079.99959036002] -> [N/A] ⚠️ CHANGED
#
# --- ACTIVITY SEQUENCE SUMMARY ---
# Prefix activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION'] -> ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION']
# Suffix activities: ['Declaration FINAL_APPROVED by SUPERVISOR', 'Request Payment', 'Payment Handled'] -> ['Declaration FINAL_APPROVED by SUPERVISOR', 'Request Payment', 'Payment Handled']
#
# Prefix changed: False
# Suffix changed: False
#
# --------------------------------------------------------------------------------
#
# ================================================================================
# Attack #2: Case ID: declaration 100005, Prefix Length: 2
# Status: SUCCESS
# Steps taken: 10
# ================================================================================
#
# --- PREFIX COMPARISON (Length: 2) ---
#
#   Event 1:
#     case:BudgetNumber = [budget 86566], [budget 86566]
#     case:DeclarationNumber = [None], [None]
#     case_elapsed_time = [-0.012600072368513793], [-0.012600072368513793]
#     concept:name = [Declaration SUBMITTED by EMPLOYEE], [Declaration SUBMITTED by EMPLOYEE]
#     day_in_week = [0.9999999789825007] -> [0.8904437774003215] ⚠️ CHANGED
#     event_elapsed_time = [231062.453125] -> [207088.52497853004] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER], [STAFF MEMBER]
#     org:role = [EMPLOYEE] -> [UNDEFINED] ⚠️ CHANGED
#     seconds_in_day = [34733.99974874998] -> [34925.44022260845] ⚠️ CHANGED
#
#   Event 2:
#     case:BudgetNumber = [budget 86566], [budget 86566]
#     case:DeclarationNumber = [None], [None]
#     case_elapsed_time = [3.031334390223492] -> [-0.012600072368513793] ⚠️ CHANGED
#     concept:name = [Declaration APPROVED by ADMINISTRATION] -> [Request Payment] ⚠️ CHANGED
#     day_in_week = [0.9999999789825007] -> [0.8904437774003215] ⚠️ CHANGED
#     event_elapsed_time = [2.9929483454907313] -> [-0.007862518745241687] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER], [STAFF MEMBER]
#     org:role = [ADMINISTRATION] -> [UNDEFINED] ⚠️ CHANGED
#     seconds_in_day = [34736.99963553547] -> [35502.761530969336] ⚠️ CHANGED
#
# --- SUFFIX COMPARISON ---
#
#   Event 1:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [1516.016463991662] -> [[366651.3059128]] ⚠️ CHANGED
#     concept:name = [Declaration FINAL_APPROVED by SUPERVISOR] -> [Request Payment] ⚠️ CHANGED
#     day_in_week = [0.9999999789825007] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [1512.9962120337586] -> [N/A] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER] -> [N/A] ⚠️ CHANGED
#     org:role = [SUPERVISOR] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [36250.00035215873] -> [N/A] ⚠️ CHANGED
#
#   Event 2:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [97584.01026939112] -> [[535907.31063272]] ⚠️ CHANGED
#     concept:name = [Request Payment], [Request Payment]
#     day_in_week = [1.9999999994143962] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [96067.99877683283] -> [N/A] ⚠️ CHANGED
#     org:resource = [SYSTEM] -> [N/A] ⚠️ CHANGED
#     org:role = [UNDEFINED] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [45917.99988286337] -> [N/A] ⚠️ CHANGED
#
#   Event 3:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [201143.00203580887] -> [[618637.42609283]] ⚠️ CHANGED
#     concept:name = [Payment Handled], [Payment Handled]
#     day_in_week = [2.9999999871959684] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [103558.9991482777] -> [N/A] ⚠️ CHANGED
#     org:resource = [SYSTEM] -> [N/A] ⚠️ CHANGED
#     org:role = [UNDEFINED] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [63076.99970357454] -> [N/A] ⚠️ CHANGED
#
# --- ACTIVITY SEQUENCE SUMMARY ---
# Prefix activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION'] -> ['Declaration SUBMITTED by EMPLOYEE', 'Request Payment']
# Suffix activities: ['Declaration FINAL_APPROVED by SUPERVISOR', 'Request Payment', 'Payment Handled'] -> ['Request Payment', 'Request Payment', 'Payment Handled']
#
# Prefix changed: True
#   Positions changed:
#     Position 2: 'Declaration APPROVED by ADMINISTRATION' -> 'Request Payment'
# Suffix changed: True
#   Positions changed:
#     Position 1: 'Declaration FINAL_APPROVED by SUPERVISOR' -> 'Request Payment'
#
# --------------------------------------------------------------------------------
#
# ================================================================================
# Attack #3: Case ID: declaration 100010, Prefix Length: 2
# Status: SUCCESS
# Steps taken: 9
# ================================================================================
#
# --- PREFIX COMPARISON (Length: 2) ---
#
#   Event 1:
#     case:BudgetNumber = [budget 86566], [budget 86566]
#     case:DeclarationNumber = [None], [None]
#     case_elapsed_time = [-0.012600072368513793], [-0.012600072368513793]
#     concept:name = [Declaration SUBMITTED by EMPLOYEE], [Declaration SUBMITTED by EMPLOYEE]
#     day_in_week = [0.9999999789825007] -> [0.9233106378749754] ⚠️ CHANGED
#     event_elapsed_time = [231062.453125] -> [203092.87088793627] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER], [STAFF MEMBER]
#     org:role = [EMPLOYEE] -> [UNDEFINED] ⚠️ CHANGED
#     seconds_in_day = [35000.99994233498] -> [35096.720179264215] ⚠️ CHANGED
#
#   Event 2:
#     case:BudgetNumber = [budget 86566], [budget 86566]
#     case:DeclarationNumber = [None], [None]
#     case_elapsed_time = [1.983422526041977] -> [-0.012600072368513793] ⚠️ CHANGED
#     concept:name = [Declaration APPROVED by ADMINISTRATION] -> [Request Payment] ⚠️ CHANGED
#     day_in_week = [0.9999999789825007] -> [0.9452218781914111] ⚠️ CHANGED
#     event_elapsed_time = [1.9926780574023724] -> [-0.007862518745241687] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER] -> [SYSTEM] ⚠️ CHANGED
#     org:role = [ADMINISTRATION] -> [UNDEFINED] ⚠️ CHANGED
#     seconds_in_day = [35003.000247217045] -> [35673.041905721686] ⚠️ CHANGED
#
# --- SUFFIX COMPARISON ---
#
#   Event 1:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [1198.0001634986256] -> [[366728.42723594]] ⚠️ CHANGED
#     concept:name = [Declaration FINAL_APPROVED by SUPERVISOR] -> [Request Payment] ⚠️ CHANGED
#     day_in_week = [0.9999999789825007] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [1196.005794550496] -> [N/A] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER] -> [N/A] ⚠️ CHANGED
#     org:role = [SUPERVISOR] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [36198.99999465507] -> [N/A] ⚠️ CHANGED
#
#   Event 2:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [97312.00228979159] -> [[535988.82320559]] ⚠️ CHANGED
#     concept:name = [Request Payment], [Request Payment]
#     day_in_week = [1.9999999994143962] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [96113.99930210473] -> [N/A] ⚠️ CHANGED
#     org:resource = [SYSTEM] -> [N/A] ⚠️ CHANGED
#     org:role = [UNDEFINED] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [45912.99997646463] -> [N/A] ⚠️ CHANGED
#
#   Event 3:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [200876.00906298787] -> [[618690.50781881]] ⚠️ CHANGED
#     concept:name = [Payment Handled], [Payment Handled]
#     day_in_week = [2.9999999871959684] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [103564.00049971808] -> [N/A] ⚠️ CHANGED
#     org:resource = [SYSTEM] -> [N/A] ⚠️ CHANGED
#     org:role = [UNDEFINED] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [63076.99970357454] -> [N/A] ⚠️ CHANGED
#
# --- ACTIVITY SEQUENCE SUMMARY ---
# Prefix activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION'] -> ['Declaration SUBMITTED by EMPLOYEE', 'Request Payment']
# Suffix activities: ['Declaration FINAL_APPROVED by SUPERVISOR', 'Request Payment', 'Payment Handled'] -> ['Request Payment', 'Request Payment', 'Payment Handled']
#
# Prefix changed: True
#   Positions changed:
#     Position 2: 'Declaration APPROVED by ADMINISTRATION' -> 'Request Payment'
# Suffix changed: True
#   Positions changed:
#     Position 1: 'Declaration FINAL_APPROVED by SUPERVISOR' -> 'Request Payment'
#
# --------------------------------------------------------------------------------
#
# ================================================================================
# Attack #4: Case ID: declaration 100015, Prefix Length: 3
# Status: FAILED
# Steps taken: 10
# ================================================================================
#
# --- PREFIX COMPARISON (Length: 3) ---
#
#   Event 1:
#     case:BudgetNumber = [budget 86566], [budget 86566]
#     case:DeclarationNumber = [None], [None]
#     case_elapsed_time = [-0.012600072368513793] -> [8371.90498447558] ⚠️ CHANGED
#     concept:name = [Declaration SUBMITTED by EMPLOYEE], [Declaration SUBMITTED by EMPLOYEE]
#     day_in_week = [0.9999999789825007] -> [0.9342662580331932] ⚠️ CHANGED
#     event_elapsed_time = [231062.453125] -> [231062.45324333638] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER], [STAFF MEMBER]
#     org:role = [EMPLOYEE], [EMPLOYEE]
#     seconds_in_day = [47202.99993255373] -> [47011.55917342645] ⚠️ CHANGED
#
#   Event 2:
#     case:BudgetNumber = [budget 86566], [budget 86566]
#     case:DeclarationNumber = [None], [None]
#     case_elapsed_time = [3.031334390223492] -> [8371.90498447558] ⚠️ CHANGED
#     concept:name = [Declaration APPROVED by ADMINISTRATION], [Declaration APPROVED by ADMINISTRATION]
#     day_in_week = [0.9999999789825007] -> [0.9342662580331932] ⚠️ CHANGED
#     event_elapsed_time = [2.9929483454907313] -> [3995.643251080124] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER], [STAFF MEMBER]
#     org:role = [ADMINISTRATION], [ADMINISTRATION]
#     seconds_in_day = [47205.99996197362] -> [47014.55920284634] ⚠️ CHANGED
#
#   Event 3:
#     case:BudgetNumber = [budget 86566], [budget 86566]
#     case:DeclarationNumber = [None], [None]
#     case_elapsed_time = [91415.00302558811] -> [7695.802229826164] ⚠️ CHANGED
#     concept:name = [Declaration APPROVED by BUDGET OWNER], [Declaration APPROVED by BUDGET OWNER]
#     day_in_week = [1.9999999994143962] -> [1.9342662233676677] ⚠️ CHANGED
#     event_elapsed_time = [91412.00256138886] -> [83420.70033419109] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER], [STAFF MEMBER]
#     org:role = [BUDGET OWNER], [BUDGET OWNER]
#     seconds_in_day = [52218.00004656181] -> [52026.55957270334] ⚠️ CHANGED
#
# --- SUFFIX COMPARISON ---
#
#   Event 1:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [164859.0038383623] -> [[377128.22892964]] ⚠️ CHANGED
#     concept:name = [Declaration FINAL_APPROVED by SUPERVISOR], [Declaration FINAL_APPROVED by SUPERVISOR]
#     day_in_week = [2.9999999871959684] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [73444.00448091712] -> [N/A] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER] -> [N/A] ⚠️ CHANGED
#     org:role = [SUPERVISOR] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [39261.9996512308] -> [N/A] ⚠️ CHANGED
#
#   Event 2:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [242163.01295308868] -> [[470670.55631982]] ⚠️ CHANGED
#     concept:name = [Request Payment], [Request Payment]
#     day_in_week = [4.00000005660335] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [77303.99989068546] -> [N/A] ⚠️ CHANGED
#     org:resource = [SYSTEM] -> [N/A] ⚠️ CHANGED
#     org:role = [UNDEFINED] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [30165.999454004013] -> [N/A] ⚠️ CHANGED
#
#   Event 3:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [534259.0014085202] -> [[594562.57417398]] ⚠️ CHANGED
#     concept:name = [Payment Handled], [Payment Handled]
#     day_in_week = [4.0176413973469494e-08] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [292095.9982525533] -> [N/A] ⚠️ CHANGED
#     org:resource = [SYSTEM] -> [N/A] ⚠️ CHANGED
#     org:role = [UNDEFINED] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [63062.00026964713] -> [N/A] ⚠️ CHANGED
#
# --- ACTIVITY SEQUENCE SUMMARY ---
# Prefix activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by BUDGET OWNER'] -> ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by BUDGET OWNER']
# Suffix activities: ['Declaration FINAL_APPROVED by SUPERVISOR', 'Request Payment', 'Payment Handled'] -> ['Declaration FINAL_APPROVED by SUPERVISOR', 'Request Payment', 'Payment Handled']
#
# Prefix changed: False
# Suffix changed: False
#
# --------------------------------------------------------------------------------
#
# ================================================================================
# Attack #5: Case ID: declaration 100021, Prefix Length: 3
# Status: FAILED
# Steps taken: 10
# ================================================================================
#
# --- PREFIX COMPARISON (Length: 3) ---
#
#   Event 1:
#     case:BudgetNumber = [budget 86566], [budget 86566]
#     case:DeclarationNumber = [None], [None]
#     case_elapsed_time = [-0.012600072368513793], [-0.012600072368513793]
#     concept:name = [Declaration SUBMITTED by EMPLOYEE], [Declaration SUBMITTED by EMPLOYEE]
#     day_in_week = [1.9999999994143962] -> [1.956177484090556] ⚠️ CHANGED
#     event_elapsed_time = [231062.453125] -> [223071.14357365135] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER], [STAFF MEMBER]
#     org:role = [EMPLOYEE], [EMPLOYEE]
#     seconds_in_day = [39954.99974340752] -> [40146.44021726599] ⚠️ CHANGED
#
#   Event 2:
#     case:BudgetNumber = [budget 86566], [budget 86566]
#     case:DeclarationNumber = [None], [None]
#     case_elapsed_time = [300.98760776920244] -> [-0.012600072368513793] ⚠️ CHANGED
#     concept:name = [Declaration APPROVED by ADMINISTRATION], [Declaration APPROVED by ADMINISTRATION]
#     day_in_week = [1.9999999994143962] -> [1.9342662233676677] ⚠️ CHANGED
#     event_elapsed_time = [301.0020463145338] -> [-0.007862518745241687] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER], [STAFF MEMBER]
#     org:role = [ADMINISTRATION], [ADMINISTRATION]
#     seconds_in_day = [40255.99998514909], [40255.99998514909]
#
#   Event 3:
#     case:BudgetNumber = [budget 86566], [budget 86566]
#     case:DeclarationNumber = [None], [None]
#     case_elapsed_time = [8260.027917834232] -> [-0.012600072368513793] ⚠️ CHANGED
#     concept:name = [Declaration APPROVED by BUDGET OWNER], [Declaration APPROVED by BUDGET OWNER]
#     day_in_week = [1.9999999994143962] -> [1.956177484090556] ⚠️ CHANGED
#     event_elapsed_time = [7958.999923949683] -> [-0.007862518745241687] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER], [STAFF MEMBER]
#     org:role = [BUDGET OWNER], [BUDGET OWNER]
#     seconds_in_day = [48215.000015088124] -> [48980.76253454751] ⚠️ CHANGED
#
# --- SUFFIX COMPARISON ---
#
#   Event 1:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [94809.01490165695] -> [[377003.47751724]] ⚠️ CHANGED
#     concept:name = [Declaration FINAL_APPROVED by SUPERVISOR], [Declaration FINAL_APPROVED by SUPERVISOR]
#     day_in_week = [2.9999999871959684] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [86548.99802823152] -> [N/A] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER] -> [N/A] ⚠️ CHANGED
#     org:role = [SUPERVISOR] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [48363.99997861456] -> [N/A] ⚠️ CHANGED
#
#   Event 2:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [695370.9968992143] -> [[470722.80221134]] ⚠️ CHANGED
#     concept:name = [Request Payment], [Request Payment]
#     day_in_week = [2.9999999871959684] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [600562.0111229969] -> [N/A] ⚠️ CHANGED
#     org:resource = [SYSTEM] -> [N/A] ⚠️ CHANGED
#     org:role = [UNDEFINED] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [44125.99999605079] -> [N/A] ⚠️ CHANGED
#
#   Event 3:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [1059925.0133795075] -> [[594600.64830505]] ⚠️ CHANGED
#     concept:name = [Payment Handled], [Payment Handled]
#     day_in_week = [4.0176413973469494e-08] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [364554.0001135077] -> [N/A] ⚠️ CHANGED
#     org:resource = [SYSTEM] -> [N/A] ⚠️ CHANGED
#     org:role = [UNDEFINED] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [63079.99959036002] -> [N/A] ⚠️ CHANGED
#
# --- ACTIVITY SEQUENCE SUMMARY ---
# Prefix activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by BUDGET OWNER'] -> ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by BUDGET OWNER']
# Suffix activities: ['Declaration FINAL_APPROVED by SUPERVISOR', 'Request Payment', 'Payment Handled'] -> ['Declaration FINAL_APPROVED by SUPERVISOR', 'Request Payment', 'Payment Handled']
#
# Prefix changed: False
# Suffix changed: False
#
# --------------------------------------------------------------------------------
#
# ================================================================================
# Attack #6: Case ID: declaration 100027, Prefix Length: 2
# Status: SUCCESS
# Steps taken: 9
# ================================================================================
#
# --- PREFIX COMPARISON (Length: 2) ---
#
#   Event 1:
#     case:BudgetNumber = [budget 86566], [budget 86566]
#     case:DeclarationNumber = [None], [None]
#     case_elapsed_time = [-0.012600072368513793], [-0.012600072368513793]
#     concept:name = [Declaration SUBMITTED by EMPLOYEE], [Declaration SUBMITTED by EMPLOYEE]
#     day_in_week = [2.9999999871959684] -> [2.9452218864048785] ⚠️ CHANGED
#     event_elapsed_time = [231062.453125] -> [211084.1790691238] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER], [STAFF MEMBER]
#     org:role = [EMPLOYEE] -> [UNDEFINED] ⚠️ CHANGED
#     seconds_in_day = [33655.999732150114] -> [33751.71996907935] ⚠️ CHANGED
#
#   Event 2:
#     case:BudgetNumber = [budget 86566], [budget 86566]
#     case:DeclarationNumber = [None], [None]
#     case_elapsed_time = [325.98779081436805] -> [-0.012600072368513793] ⚠️ CHANGED
#     concept:name = [Declaration APPROVED by ADMINISTRATION] -> [Request Payment] ⚠️ CHANGED
#     day_in_week = [2.9999999871959684] -> [2.967133126721315] ⚠️ CHANGED
#     event_elapsed_time = [326.00880351645174] -> [-0.007862518745241687] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER], [STAFF MEMBER]
#     org:role = [ADMINISTRATION], [ADMINISTRATION]
#     seconds_in_day = [33982.000361691804] -> [34460.60154633797] ⚠️ CHANGED
#
# --- SUFFIX COMPARISON ---
#
#   Event 1:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [341448.9943916589] -> [[366786.1621896]] ⚠️ CHANGED
#     concept:name = [Declaration FINAL_APPROVED by SUPERVISOR] -> [Request Payment] ⚠️ CHANGED
#     day_in_week = [4.0176413973469494e-08] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [341123.0020387475] -> [N/A] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER] -> [N/A] ⚠️ CHANGED
#     org:role = [SUPERVISOR] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [29504.999675639414] -> [N/A] ⚠️ CHANGED
#
#   Event 2:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [613165.0057855962] -> [[536052.44642591]] ⚠️ CHANGED
#     concept:name = [Request Payment], [Request Payment]
#     day_in_week = [2.9999999871959684] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [271716.0001991255] -> [N/A] ⚠️ CHANGED
#     org:resource = [SYSTEM] -> [N/A] ⚠️ CHANGED
#     org:role = [UNDEFINED] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [42020.9997498171] -> [N/A] ⚠️ CHANGED
#
#   Event 3:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [979824.0276981817] -> [[618776.46154195]] ⚠️ CHANGED
#     concept:name = [Payment Handled], [Payment Handled]
#     day_in_week = [4.0176413973469494e-08] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [366658.9974868867] -> [N/A] ⚠️ CHANGED
#     org:resource = [SYSTEM] -> [N/A] ⚠️ CHANGED
#     org:role = [UNDEFINED] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [63079.99959036002] -> [N/A] ⚠️ CHANGED
#
# --- ACTIVITY SEQUENCE SUMMARY ---
# Prefix activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION'] -> ['Declaration SUBMITTED by EMPLOYEE', 'Request Payment']
# Suffix activities: ['Declaration FINAL_APPROVED by SUPERVISOR', 'Request Payment', 'Payment Handled'] -> ['Request Payment', 'Request Payment', 'Payment Handled']
#
# Prefix changed: True
#   Positions changed:
#     Position 2: 'Declaration APPROVED by ADMINISTRATION' -> 'Request Payment'
# Suffix changed: True
#   Positions changed:
#     Position 1: 'Declaration FINAL_APPROVED by SUPERVISOR' -> 'Request Payment'
#
# --------------------------------------------------------------------------------
#
# ================================================================================
# Attack #7: Case ID: declaration 100032, Prefix Length: 2
# Status: FAILED
# Steps taken: 10
# ================================================================================
#
# --- PREFIX COMPARISON (Length: 2) ---
#
#   Event 1:
#     case:BudgetNumber = [budget 86566], [budget 86566]
#     case:DeclarationNumber = [None], [None]
#     case_elapsed_time = [-0.012600072368513793] -> [8371.90498447558] ⚠️ CHANGED
#     concept:name = [Declaration SUBMITTED by EMPLOYEE], [Declaration SUBMITTED by EMPLOYEE]
#     day_in_week = [2.9999999871959684] -> [2.934266266246661] ⚠️ CHANGED
#     event_elapsed_time = [231062.453125] -> [207088.52497853004] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER], [STAFF MEMBER]
#     org:role = [EMPLOYEE], [EMPLOYEE]
#     seconds_in_day = [41646.99979063246] -> [41455.559316773986] ⚠️ CHANGED
#
#   Event 2:
#     case:BudgetNumber = [budget 86566], [budget 86566]
#     case:DeclarationNumber = [None], [None]
#     case_elapsed_time = [21.993549075210467] -> [-0.012600072368513793] ⚠️ CHANGED
#     concept:name = [Declaration APPROVED by ADMINISTRATION], [Declaration APPROVED by ADMINISTRATION]
#     day_in_week = [2.9999999871959684] -> [2.934266266246661] ⚠️ CHANGED
#     event_elapsed_time = [21.99808381893672] -> [-0.007862518745241687] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER], [STAFF MEMBER]
#     org:role = [ADMINISTRATION], [ADMINISTRATION]
#     seconds_in_day = [41668.99972110948] -> [41860.44019496795] ⚠️ CHANGED
#
# --- SUFFIX COMPARISON ---
#
#   Event 1:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [92530.00619934732] -> [[344118.03838484]] ⚠️ CHANGED
#     concept:name = [Declaration FINAL_APPROVED by SUPERVISOR], [Declaration FINAL_APPROVED by SUPERVISOR]
#     day_in_week = [4.00000005660335] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [92508.00109763007] -> [N/A] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER] -> [N/A] ⚠️ CHANGED
#     org:role = [SUPERVISOR] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [47776.999998816864] -> [N/A] ⚠️ CHANGED
#
#   Event 2:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [420926.99958852096] -> [[458948.73895863]] ⚠️ CHANGED
#     concept:name = [Request Payment], [Request Payment]
#     day_in_week = [0.9999999789825007] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [328396.9978048076] -> [N/A] ⚠️ CHANGED
#     org:resource = [SYSTEM] -> [N/A] ⚠️ CHANGED
#     org:role = [UNDEFINED] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [30574.00003188284] -> [N/A] ⚠️ CHANGED
#
#   Event 3:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [626223.0105747344] -> [[580819.89620816]] ⚠️ CHANGED
#     concept:name = [Payment Handled], [Payment Handled]
#     day_in_week = [2.9999999871959684] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [205295.99894436848] -> [N/A] ⚠️ CHANGED
#     org:resource = [SYSTEM] -> [N/A] ⚠️ CHANGED
#     org:role = [UNDEFINED] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [63070.00034810016] -> [N/A] ⚠️ CHANGED
#
# --- ACTIVITY SEQUENCE SUMMARY ---
# Prefix activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION'] -> ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION']
# Suffix activities: ['Declaration FINAL_APPROVED by SUPERVISOR', 'Request Payment', 'Payment Handled'] -> ['Declaration FINAL_APPROVED by SUPERVISOR', 'Request Payment', 'Payment Handled']
#
# Prefix changed: False
# Suffix changed: False
#
# --------------------------------------------------------------------------------
#
# ================================================================================
# Attack #8: Case ID: declaration 100037, Prefix Length: 2
# Status: SUCCESS
# Steps taken: 10
# ================================================================================
#
# --- PREFIX COMPARISON (Length: 2) ---
#
#   Event 1:
#     case:BudgetNumber = [budget 86566], [budget 86566]
#     case:DeclarationNumber = [None], [None]
#     case_elapsed_time = [-0.012600072368513793] -> [8371.90498447558] ⚠️ CHANGED
#     concept:name = [Declaration SUBMITTED by EMPLOYEE], [Declaration SUBMITTED by EMPLOYEE]
#     day_in_week = [2.9999999871959684] -> [2.9561775065630966] ⚠️ CHANGED
#     event_elapsed_time = [231062.453125] -> [207088.52497853004] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER], [STAFF MEMBER]
#     org:role = [EMPLOYEE], [EMPLOYEE]
#     seconds_in_day = [51371.000013142715], [51371.000013142715]
#
#   Event 2:
#     case:BudgetNumber = [budget 86566], [budget 86566]
#     case:DeclarationNumber = [None], [None]
#     case_elapsed_time = [87.01398521871306] -> [-0.012600072368513793] ⚠️ CHANGED
#     concept:name = [Declaration APPROVED by ADMINISTRATION] -> [Request Payment] ⚠️ CHANGED
#     day_in_week = [2.9999999871959684] -> [2.9561775065630966] ⚠️ CHANGED
#     event_elapsed_time = [86.99183658466791] -> [3995.643251080124] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER], [STAFF MEMBER]
#     org:role = [ADMINISTRATION], [ADMINISTRATION]
#     seconds_in_day = [51458.00001051299] -> [52415.20237980533] ⚠️ CHANGED
#
# --- SUFFIX COMPARISON ---
#
#   Event 1:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [9071.01189957175] -> [[366653.02748229]] ⚠️ CHANGED
#     concept:name = [Declaration FINAL_APPROVED by SUPERVISOR] -> [Request Payment] ⚠️ CHANGED
#     day_in_week = [2.9999999871959684] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [8983.991177717107] -> [N/A] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER] -> [N/A] ⚠️ CHANGED
#     org:role = [SUPERVISOR] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [60442.000250472585] -> [N/A] ⚠️ CHANGED
#
#   Event 2:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [457274.00036801543] -> [[535922.23090165]] ⚠️ CHANGED
#     concept:name = [Request Payment], [Request Payment]
#     day_in_week = [0.9999999789825007] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [448203.0080954913] -> [N/A] ⚠️ CHANGED
#     org:resource = [SYSTEM] -> [N/A] ⚠️ CHANGED
#     org:role = [UNDEFINED] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [76644.99925411094] -> [N/A] ⚠️ CHANGED
#
#   Event 3:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [616499.0122323001] -> [[618694.08818435]] ⚠️ CHANGED
#     concept:name = [Payment Handled], [Payment Handled]
#     day_in_week = [2.9999999871959684] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [159224.99927208846] -> [N/A] ⚠️ CHANGED
#     org:resource = [SYSTEM] -> [N/A] ⚠️ CHANGED
#     org:role = [UNDEFINED] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [63070.00034810016] -> [N/A] ⚠️ CHANGED
#
# --- ACTIVITY SEQUENCE SUMMARY ---
# Prefix activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION'] -> ['Declaration SUBMITTED by EMPLOYEE', 'Request Payment']
# Suffix activities: ['Declaration FINAL_APPROVED by SUPERVISOR', 'Request Payment', 'Payment Handled'] -> ['Request Payment', 'Request Payment', 'Payment Handled']
#
# Prefix changed: True
#   Positions changed:
#     Position 2: 'Declaration APPROVED by ADMINISTRATION' -> 'Request Payment'
# Suffix changed: True
#   Positions changed:
#     Position 1: 'Declaration FINAL_APPROVED by SUPERVISOR' -> 'Request Payment'
#
# --------------------------------------------------------------------------------
#
# ================================================================================
# Attack #9: Case ID: declaration 100042, Prefix Length: 3
# Status: FAILED
# Steps taken: 10
# ================================================================================
#
# --- PREFIX COMPARISON (Length: 3) ---
#
#   Event 1:
#     case:BudgetNumber = [budget 86566], [budget 86566]
#     case:DeclarationNumber = [None], [None]
#     case_elapsed_time = [-0.012600072368513793] -> [50231.49290721532] ⚠️ CHANGED
#     concept:name = [Declaration SUBMITTED by EMPLOYEE], [Declaration SUBMITTED by EMPLOYEE]
#     day_in_week = [4.00000005660335] -> [3.9780888162869132] ⚠️ CHANGED
#     event_elapsed_time = [231062.453125] -> [223071.14357365135] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER], [STAFF MEMBER]
#     org:role = [EMPLOYEE], [EMPLOYEE]
#     seconds_in_day = [50122.00003122218] -> [50313.44079034946] ⚠️ CHANGED
#
#   Event 2:
#     case:BudgetNumber = [budget 86566], [budget 86566]
#     case:DeclarationNumber = [None], [None]
#     case_elapsed_time = [7.023379587044474] -> [8371.90498447558] ⚠️ CHANGED
#     concept:name = [Declaration APPROVED by ADMINISTRATION], [Declaration APPROVED by ADMINISTRATION]
#     day_in_week = [4.00000005660335] -> [3.956177575970478] ⚠️ CHANGED
#     event_elapsed_time = [6.994029497785959] -> [-0.007862518745241687] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER], [STAFF MEMBER]
#     org:role = [ADMINISTRATION], [ADMINISTRATION]
#     seconds_in_day = [50129.000028551374], [50129.000028551374]
#
#   Event 3:
#     case:BudgetNumber = [budget 86566], [budget 86566]
#     case:DeclarationNumber = [None], [None]
#     case_elapsed_time = [249920.00587562876] -> [166200.83003014931] ⚠️ CHANGED
#     concept:name = [Declaration APPROVED by BUDGET OWNER], [Declaration APPROVED by BUDGET OWNER]
#     day_in_week = [4.0176413973469494e-08] -> [-0.04382244045645778] ⚠️ CHANGED
#     event_elapsed_time = [249913.0000696103] -> [225939.07031630652] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER], [STAFF MEMBER]
#     org:role = [BUDGET OWNER], [BUDGET OWNER]
#     seconds_in_day = [40841.999741188556], [40841.999741188556]
#
# --- SUFFIX COMPARISON ---
#
#   Event 1:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [832830.0123223747] -> [[384651.4876059]] ⚠️ CHANGED
#     concept:name = [Declaration FINAL_APPROVED by SUPERVISOR], [Declaration FINAL_APPROVED by SUPERVISOR]
#     day_in_week = [4.0176413973469494e-08] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [582910.0031897203] -> [N/A] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER] -> [N/A] ⚠️ CHANGED
#     org:role = [SUPERVISOR] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [18952.0004520358] -> [N/A] ⚠️ CHANGED
#
#   Event 2:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [928780.9893029418] -> [[474504.34187489]] ⚠️ CHANGED
#     concept:name = [Request Payment], [Request Payment]
#     day_in_week = [0.9999999789825007] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [95951.00287706676] -> [N/A] ⚠️ CHANGED
#     org:resource = [SYSTEM] -> [N/A] ⚠️ CHANGED
#     org:role = [UNDEFINED] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [28503.000974880943] -> [N/A] ⚠️ CHANGED
#
#   Event 3:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [1136153.0166119912] -> [[597342.17286883]] ⚠️ CHANGED
#     concept:name = [Payment Handled], [Payment Handled]
#     day_in_week = [2.9999999871959684] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [207371.99889887546] -> [N/A] ⚠️ CHANGED
#     org:resource = [SYSTEM] -> [N/A] ⚠️ CHANGED
#     org:role = [UNDEFINED] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [63075.00053976771] -> [N/A] ⚠️ CHANGED
#
# --- ACTIVITY SEQUENCE SUMMARY ---
# Prefix activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by BUDGET OWNER'] -> ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by BUDGET OWNER']
# Suffix activities: ['Declaration FINAL_APPROVED by SUPERVISOR', 'Request Payment', 'Payment Handled'] -> ['Declaration FINAL_APPROVED by SUPERVISOR', 'Request Payment', 'Payment Handled']
#
# Prefix changed: False
# Suffix changed: False
#
# --------------------------------------------------------------------------------
#
# ================================================================================
# Attack #10: Case ID: declaration 100048, Prefix Length: 2
# Status: SUCCESS
# Steps taken: 9
# ================================================================================
#
# --- PREFIX COMPARISON (Length: 2) ---
#
#   Event 1:
#     case:BudgetNumber = [budget 86566], [budget 86566]
#     case:DeclarationNumber = [None], [None]
#     case_elapsed_time = [-0.012600072368513793], [-0.012600072368513793]
#     concept:name = [Declaration SUBMITTED by EMPLOYEE], [Declaration SUBMITTED by EMPLOYEE]
#     day_in_week = [4.00000005660335] -> [3.9233107154958238] ⚠️ CHANGED
#     event_elapsed_time = [231062.453125] -> [203092.87088793627] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER], [STAFF MEMBER]
#     org:role = [EMPLOYEE] -> [UNDEFINED] ⚠️ CHANGED
#     seconds_in_day = [50713.99998873582] -> [51384.042645681286] ⚠️ CHANGED
#
#   Event 2:
#     case:BudgetNumber = [budget 86566], [budget 86566]
#     case:DeclarationNumber = [None], [None]
#     case_elapsed_time = [180.0286383050261] -> [-0.012600072368513793] ⚠️ CHANGED
#     concept:name = [Declaration APPROVED by ADMINISTRATION] -> [Request Payment] ⚠️ CHANGED
#     day_in_week = [4.00000005660335] -> [3.9452219558122597] ⚠️ CHANGED
#     event_elapsed_time = [179.9931574165239] -> [-0.007862518745241687] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER], [STAFF MEMBER]
#     org:role = [ADMINISTRATION], [ADMINISTRATION]
#     seconds_in_day = [50894.00004231614] -> [51755.48288785127] ⚠️ CHANGED
#
# --- SUFFIX COMPARISON ---
#
#   Event 1:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [2837.982230924419] -> [[366500.75590831]] ⚠️ CHANGED
#     concept:name = [Declaration FINAL_APPROVED by SUPERVISOR] -> [Request Payment] ⚠️ CHANGED
#     day_in_week = [4.00000005660335] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [2657.996084411134] -> [N/A] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER] -> [N/A] ⚠️ CHANGED
#     org:role = [SUPERVISOR] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [53552.00000623936] -> [N/A] ⚠️ CHANGED
#
#   Event 2:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [75991.01284941414] -> [[535770.70783614]] ⚠️ CHANGED
#     concept:name = [Request Payment], [Request Payment]
#     day_in_week = [5.000000060710083] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [73152.99727496461] -> [N/A] ⚠️ CHANGED
#     org:resource = [SYSTEM] -> [N/A] ⚠️ CHANGED
#     org:role = [UNDEFINED] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [40305.00003777068] -> [N/A] ⚠️ CHANGED
#
#   Event 3:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [530737.0008208983] -> [[618589.33442335]] ⚠️ CHANGED
#     concept:name = [Payment Handled], [Payment Handled]
#     day_in_week = [2.9999999871959684] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [454745.9903934322] -> [N/A] ⚠️ CHANGED
#     org:resource = [SYSTEM] -> [N/A] ⚠️ CHANGED
#     org:role = [UNDEFINED] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [63051.00030440862] -> [N/A] ⚠️ CHANGED
#
# --- ACTIVITY SEQUENCE SUMMARY ---
# Prefix activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION'] -> ['Declaration SUBMITTED by EMPLOYEE', 'Request Payment']
# Suffix activities: ['Declaration FINAL_APPROVED by SUPERVISOR', 'Request Payment', 'Payment Handled'] -> ['Request Payment', 'Request Payment', 'Payment Handled']
#
# Prefix changed: True
#   Positions changed:
#     Position 2: 'Declaration APPROVED by ADMINISTRATION' -> 'Request Payment'
# Suffix changed: True
#   Positions changed:
#     Position 1: 'Declaration FINAL_APPROVED by SUPERVISOR' -> 'Request Payment'
#
# --------------------------------------------------------------------------------
#
# ================================================================================
# Attack #11: Case ID: declaration 100053, Prefix Length: 3
# Status: FAILED
# Steps taken: 10
# ================================================================================
#
# --- PREFIX COMPARISON (Length: 3) ---
#
#   Event 1:
#     case:BudgetNumber = [budget 86566], [budget 86566]
#     case:DeclarationNumber = [None], [None]
#     case_elapsed_time = [-0.012600072368513793], [-0.012600072368513793]
#     concept:name = [Declaration SUBMITTED by EMPLOYEE], [Declaration SUBMITTED by EMPLOYEE]
#     day_in_week = [4.00000005660335] -> [3.956177575970478] ⚠️ CHANGED
#     event_elapsed_time = [231062.453125] -> [199097.21679734247] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER], [STAFF MEMBER]
#     org:role = [EMPLOYEE], [EMPLOYEE]
#     seconds_in_day = [51218.99994887919] -> [51410.44070800646] ⚠️ CHANGED
#
#   Event 2:
#     case:BudgetNumber = [budget 86566], [budget 86566]
#     case:DeclarationNumber = [None], [None]
#     case_elapsed_time = [7.023379587044474] -> [-0.012600072368513793] ⚠️ CHANGED
#     concept:name = [Declaration APPROVED by ADMINISTRATION] -> [Request Payment] ⚠️ CHANGED
#     day_in_week = [4.00000005660335] -> [3.956177575970478] ⚠️ CHANGED
#     event_elapsed_time = [6.994029497785959] -> [3995.643251080124] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER], [STAFF MEMBER]
#     org:role = [ADMINISTRATION], [ADMINISTRATION]
#     seconds_in_day = [51226.000017525585] -> [51608.88125051133] ⚠️ CHANGED
#
#   Event 3:
#     case:BudgetNumber = [budget 86566], [budget 86566]
#     case:DeclarationNumber = [None], [None]
#     case_elapsed_time = [1674.9996639557066] -> [-0.012600072368513793] ⚠️ CHANGED
#     concept:name = [Declaration APPROVED by BUDGET OWNER], [Declaration APPROVED by BUDGET OWNER]
#     day_in_week = [4.00000005660335] -> [3.9780888162869132] ⚠️ CHANGED
#     event_elapsed_time = [1667.990474767139] -> [3995.643251080124] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER] -> [SYSTEM] ⚠️ CHANGED
#     org:role = [BUDGET OWNER] -> [UNDEFINED] ⚠️ CHANGED
#     seconds_in_day = [52894.000114660244] -> [53659.76201009411] ⚠️ CHANGED
#
# --- SUFFIX COMPARISON ---
#
#   Event 1:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [572524.0021343324] -> [[377879.73143794]] ⚠️ CHANGED
#     concept:name = [Declaration FINAL_APPROVED by SUPERVISOR], [Declaration FINAL_APPROVED by SUPERVISOR]
#     day_in_week = [4.00000005660335] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [570849.0060316469] -> [N/A] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER] -> [N/A] ⚠️ CHANGED
#     org:role = [SUPERVISOR] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [18942.999650604124] -> [N/A] ⚠️ CHANGED
#
#   Event 2:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [7008676.702409746] -> [[471661.83104276]] ⚠️ CHANGED
#     concept:name = [Request Payment], [Request Payment]
#     day_in_week = [0.9999999789825007] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [6436152.875544716] -> [N/A] ⚠️ CHANGED
#     org:resource = [SYSTEM] -> [N/A] ⚠️ CHANGED
#     org:role = [UNDEFINED] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [61496.00003171337] -> [N/A] ⚠️ CHANGED
#
#   Event 3:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [7183058.817516085] -> [[595231.51619756]] ⚠️ CHANGED
#     concept:name = [Payment Handled], [Payment Handled]
#     day_in_week = [2.9999999871959684] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [174381.9996834731] -> [N/A] ⚠️ CHANGED
#     org:resource = [SYSTEM] -> [N/A] ⚠️ CHANGED
#     org:role = [UNDEFINED] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [63078.00042655319] -> [N/A] ⚠️ CHANGED
#
# --- ACTIVITY SEQUENCE SUMMARY ---
# Prefix activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by BUDGET OWNER'] -> ['Declaration SUBMITTED by EMPLOYEE', 'Request Payment', 'Declaration APPROVED by BUDGET OWNER']
# Suffix activities: ['Declaration FINAL_APPROVED by SUPERVISOR', 'Request Payment', 'Payment Handled'] -> ['Declaration FINAL_APPROVED by SUPERVISOR', 'Request Payment', 'Payment Handled']
#
# Prefix changed: True
#   Positions changed:
#     Position 2: 'Declaration APPROVED by ADMINISTRATION' -> 'Request Payment'
# Suffix changed: False
#
# --------------------------------------------------------------------------------
#
# ================================================================================
# Attack #12: Case ID: declaration 100059, Prefix Length: 2
# Status: SUCCESS
# Steps taken: 10
# ================================================================================
#
# --- PREFIX COMPARISON (Length: 2) ---
#
#   Event 1:
#     case:BudgetNumber = [budget 86566], [budget 86566]
#     case:DeclarationNumber = [None], [None]
#     case_elapsed_time = [-0.012600072368513793] -> [8371.90498447558] ⚠️ CHANGED
#     concept:name = [Declaration SUBMITTED by EMPLOYEE], [Declaration SUBMITTED by EMPLOYEE]
#     day_in_week = [4.00000005660335] -> [3.956177575970478] ⚠️ CHANGED
#     event_elapsed_time = [231062.453125] -> [199097.21679734247] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER], [STAFF MEMBER]
#     org:role = [EMPLOYEE] -> [UNDEFINED] ⚠️ CHANGED
#     seconds_in_day = [51621.99990718725] -> [52196.32132876266] ⚠️ CHANGED
#
#   Event 2:
#     case:BudgetNumber = [budget 86566], [budget 86566]
#     case:DeclarationNumber = [None], [None]
#     case_elapsed_time = [3.031334390223492] -> [-0.012600072368513793] ⚠️ CHANGED
#     concept:name = [Declaration APPROVED by ADMINISTRATION] -> [Request Payment] ⚠️ CHANGED
#     day_in_week = [4.00000005660335] -> [3.9342663356540415] ⚠️ CHANGED
#     event_elapsed_time = [2.9929483454907313] -> [-0.007862518745241687] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER] -> [SYSTEM] ⚠️ CHANGED
#     org:role = [ADMINISTRATION], [ADMINISTRATION]
#     seconds_in_day = [51625.00007924154] -> [52390.76197467541] ⚠️ CHANGED
#
# --- SUFFIX COMPARISON ---
#
#   Event 1:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [240196.0075331944] -> [[366755.548193]] ⚠️ CHANGED
#     concept:name = [Declaration FINAL_APPROVED by SUPERVISOR] -> [Request Payment] ⚠️ CHANGED
#     day_in_week = [4.0176413973469494e-08] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [240193.0000675114] -> [N/A] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER] -> [N/A] ⚠️ CHANGED
#     org:role = [SUPERVISOR] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [32618.00010781539] -> [N/A] ⚠️ CHANGED
#
#   Event 2:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [241090.99911604292] -> [[536036.95230049]] ⚠️ CHANGED
#     concept:name = [Request Payment], [Request Payment]
#     day_in_week = [4.0176413973469494e-08] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [894.995885717246] -> [N/A] ⚠️ CHANGED
#     org:resource = [SYSTEM] -> [N/A] ⚠️ CHANGED
#     org:role = [UNDEFINED] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [33513.00018404946] -> [N/A] ⚠️ CHANGED
#
#   Event 3:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [529828.9976657364] -> [[618755.47835439]] ⚠️ CHANGED
#     concept:name = [Payment Handled], [Payment Handled]
#     day_in_week = [2.9999999871959684] -> [N/A] ⚠️ CHANGED
# ...
# Suffix activities: ['Declaration FINAL_APPROVED by SUPERVISOR', 'Request Payment', 'Payment Handled'] -> ['Declaration FINAL_APPROVED by SUPERVISOR', 'Request Payment', 'Payment Handled']
#
# Prefix changed: False
# Suffix changed: False
#
# --------------------------------------------------------------------------------
#
# ================================================================================
# Attack #1428: Case ID: declaration 108830, Prefix Length: 2
# Status: SUCCESS
# Steps taken: 9
# ================================================================================
#
# --- PREFIX COMPARISON (Length: 2) ---
#
#   Event 1:
#     case:BudgetNumber = [budget 86566], [budget 86566]
#     case:DeclarationNumber = [None], [None]
#     case_elapsed_time = [-0.012600072368513793], [-0.012600072368513793]
#     concept:name = [Declaration SUBMITTED by EMPLOYEE], [Declaration SUBMITTED by EMPLOYEE]
#     day_in_week = [0.9999999789825007] -> [0.9013993975585395] ⚠️ CHANGED
#     event_elapsed_time = [231062.453125] -> [195101.5627067487] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER], [STAFF MEMBER]
#     org:role = [EMPLOYEE] -> [UNDEFINED] ⚠️ CHANGED
#     seconds_in_day = [57073.00016048774] -> [57934.482292850844] ⚠️ CHANGED
#
#   Event 2:
#     case:BudgetNumber = [budget 86566], [budget 86566]
#     case:DeclarationNumber = [None], [None]
#     case_elapsed_time = [133.0223061122233] -> [-0.012600072368513793] ⚠️ CHANGED
#     concept:name = [Declaration APPROVED by ADMINISTRATION] -> [Request Payment] ⚠️ CHANGED
#     day_in_week = [0.9999999789825007] -> [0.9233106378749754] ⚠️ CHANGED
#     event_elapsed_time = [133.00426983617945] -> [-0.007862518745241687] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER], [STAFF MEMBER]
#     org:role = [ADMINISTRATION], [ADMINISTRATION]
#     seconds_in_day = [57205.99989579091] -> [58067.482028154016] ⚠️ CHANGED
#
# --- SUFFIX COMPARISON ---
#
#   Event 1:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [1816.0186605339986] -> [[366400.83002698]] ⚠️ CHANGED
#     concept:name = [Declaration FINAL_APPROVED by SUPERVISOR] -> [Request Payment] ⚠️ CHANGED
#     day_in_week = [0.9999999789825007] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [1682.9945290882606] -> [N/A] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER] -> [N/A] ⚠️ CHANGED
#     org:role = [SUPERVISOR] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [58889.00028265941] -> [N/A] ⚠️ CHANGED
#
#   Event 2:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [581246.9951436598] -> [[535683.83095255]] ⚠️ CHANGED
#     concept:name = [Request Payment], [Request Payment]
#     day_in_week = [0.9999999789825007] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [579431.0154958722] -> [N/A] ⚠️ CHANGED
#     org:resource = [SYSTEM] -> [N/A] ⚠️ CHANGED
#     org:role = [UNDEFINED] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [33519.99953952384] -> [N/A] ⚠️ CHANGED
#
#   Event 3:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [783601.0091651429] -> [[618544.61104201]] ⚠️ CHANGED
#     concept:name = [Payment Handled], [Payment Handled]
#     day_in_week = [2.9999999871959684] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [202353.99861448735] -> [N/A] ⚠️ CHANGED
#     org:resource = [SYSTEM] -> [N/A] ⚠️ CHANGED
#     org:role = [UNDEFINED] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [63073.99981678906] -> [N/A] ⚠️ CHANGED
#
# --- ACTIVITY SEQUENCE SUMMARY ---
# Prefix activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION'] -> ['Declaration SUBMITTED by EMPLOYEE', 'Request Payment']
# Suffix activities: ['Declaration FINAL_APPROVED by SUPERVISOR', 'Request Payment', 'Payment Handled'] -> ['Request Payment', 'Request Payment', 'Payment Handled']
#
# Prefix changed: True
#   Positions changed:
#     Position 2: 'Declaration APPROVED by ADMINISTRATION' -> 'Request Payment'
# Suffix changed: True
#   Positions changed:
#     Position 1: 'Declaration FINAL_APPROVED by SUPERVISOR' -> 'Request Payment'
#
# --------------------------------------------------------------------------------
#
# ================================================================================
# Attack #1429: Case ID: declaration 108837, Prefix Length: 2
# Status: FAILED
# Steps taken: 10
# ================================================================================
#
# --- PREFIX COMPARISON (Length: 2) ---
#
#   Event 1:
#     case:BudgetNumber = [budget 86566], [budget 86566]
#     case:DeclarationNumber = [None], [None]
#     case_elapsed_time = [-0.012600072368513793], [-0.012600072368513793]
#     concept:name = [Declaration SUBMITTED by EMPLOYEE], [Declaration SUBMITTED by EMPLOYEE]
#     day_in_week = [1.9999999994143962] -> [1.9342662233676677] ⚠️ CHANGED
#     event_elapsed_time = [231062.453125] -> [215079.83315971761] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER], [STAFF MEMBER]
#     org:role = [EMPLOYEE], [EMPLOYEE]
#     seconds_in_day = [31561.000439789128] -> [30986.679018213727] ⚠️ CHANGED
#
#   Event 2:
#     case:BudgetNumber = [budget 86566], [budget 86566]
#     case:DeclarationNumber = [None], [None]
#     case_elapsed_time = [22.99156037438661] -> [-0.012600072368513793] ⚠️ CHANGED
#     concept:name = [Declaration APPROVED by ADMINISTRATION], [Declaration APPROVED by ADMINISTRATION]
#     day_in_week = [1.9999999994143962] -> [1.9342662233676677] ⚠️ CHANGED
#     event_elapsed_time = [22.99835410702508] -> [-0.007862518745241687] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER], [STAFF MEMBER]
#     org:role = [ADMINISTRATION], [ADMINISTRATION]
#     seconds_in_day = [31583.999952169568] -> [31966.880899886506] ⚠️ CHANGED
#
# --- SUFFIX COMPARISON ---
#
#   Event 1:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [4701.019823723589] -> [[344508.88455989]] ⚠️ CHANGED
#     concept:name = [Declaration FINAL_APPROVED by SUPERVISOR], [Declaration FINAL_APPROVED by SUPERVISOR]
#     day_in_week = [1.9999999994143962] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [4677.994299262908] -> [N/A] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER] -> [N/A] ⚠️ CHANGED
#     org:role = [SUPERVISOR] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [36261.99989930066] -> [N/A] ⚠️ CHANGED
#
#   Event 2:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [87666.99654168967] -> [[459339.73483538]] ⚠️ CHANGED
#     concept:name = [Request Payment], [Request Payment]
#     day_in_week = [2.9999999871959684] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [82965.99413240302] -> [N/A] ⚠️ CHANGED
#     org:resource = [SYSTEM] -> [N/A] ⚠️ CHANGED
#     org:role = [UNDEFINED] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [32828.000170325766] -> [N/A] ⚠️ CHANGED
#
#   Event 3:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [463513.00017144246] -> [[581106.9492081]] ⚠️ CHANGED
#     concept:name = [Payment Handled], [Payment Handled]
#     day_in_week = [4.0176413973469494e-08] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [375846.0037636836] -> [N/A] ⚠️ CHANGED
#     org:resource = [SYSTEM] -> [N/A] ⚠️ CHANGED
#     org:role = [UNDEFINED] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [63073.99981678906] -> [N/A] ⚠️ CHANGED
#
# --- ACTIVITY SEQUENCE SUMMARY ---
# Prefix activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION'] -> ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION']
# Suffix activities: ['Declaration FINAL_APPROVED by SUPERVISOR', 'Request Payment', 'Payment Handled'] -> ['Declaration FINAL_APPROVED by SUPERVISOR', 'Request Payment', 'Payment Handled']
#
# Prefix changed: False
# Suffix changed: False
#
# --------------------------------------------------------------------------------
#
# ================================================================================
# Attack #1430: Case ID: declaration 108842, Prefix Length: 2
# Status: FAILED
# Steps taken: 10
# ================================================================================
#
# --- PREFIX COMPARISON (Length: 2) ---
#
#   Event 1:
#     case:BudgetNumber = [budget 86566], [budget 86566]
#     case:DeclarationNumber = [None], [None]
#     case_elapsed_time = [-0.012600072368513793], [-0.012600072368513793]
#     concept:name = [Declaration SUBMITTED by EMPLOYEE], [Declaration SUBMITTED by EMPLOYEE]
#     day_in_week = [1.9999999994143962] -> [1.9342662233676677] ⚠️ CHANGED
#     event_elapsed_time = [231062.453125] -> [231062.45324333638] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER], [STAFF MEMBER]
#     org:role = [EMPLOYEE], [EMPLOYEE]
#     seconds_in_day = [31960.999798139692] -> [31386.678376564287] ⚠️ CHANGED
#
#   Event 2:
#     case:BudgetNumber = [budget 86566], [budget 86566]
#     case:DeclarationNumber = [None], [None]
#     case_elapsed_time = [5.027356988633983] -> [-0.012600072368513793] ⚠️ CHANGED
#     concept:name = [Declaration APPROVED by ADMINISTRATION], [Declaration APPROVED by ADMINISTRATION]
#     day_in_week = [1.9999999994143962] -> [1.9780887427727987] ⚠️ CHANGED
#     event_elapsed_time = [4.993488921638345] -> [-0.007862518745241687] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER], [STAFF MEMBER]
#     org:role = [ADMINISTRATION], [ADMINISTRATION]
#     seconds_in_day = [31965.99998980724], [31965.99998980724]
#
# --- SUFFIX COMPARISON ---
#
#   Event 1:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [4255.008574106905] -> [[344172.08069669]] ⚠️ CHANGED
#     concept:name = [Declaration FINAL_APPROVED by SUPERVISOR], [Declaration FINAL_APPROVED by SUPERVISOR]
#     day_in_week = [1.9999999994143962] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [4249.997695762431] -> [N/A] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER] -> [N/A] ⚠️ CHANGED
#     org:role = [SUPERVISOR] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [36215.999733464545] -> [N/A] ⚠️ CHANGED
#
#   Event 2:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [87305.01784346643] -> [[458994.14847275]] ⚠️ CHANGED
#     concept:name = [Request Payment], [Request Payment]
#     day_in_week = [2.9999999871959684] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [83050.00492862181] -> [N/A] ⚠️ CHANGED
#     org:resource = [SYSTEM] -> [N/A] ⚠️ CHANGED
#     org:role = [UNDEFINED] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [32866.00025770885] -> [N/A] ⚠️ CHANGED
#
#   Event 3:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [463112.9999716565] -> [[580832.87035505]] ⚠️ CHANGED
#     concept:name = [Payment Handled], [Payment Handled]
#     day_in_week = [4.0176413973469494e-08] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [375807.9934927367] -> [N/A] ⚠️ CHANGED
#     org:resource = [SYSTEM] -> [N/A] ⚠️ CHANGED
#     org:role = [UNDEFINED] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [63073.99981678906] -> [N/A] ⚠️ CHANGED
#
# --- ACTIVITY SEQUENCE SUMMARY ---
# Prefix activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION'] -> ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION']
# Suffix activities: ['Declaration FINAL_APPROVED by SUPERVISOR', 'Request Payment', 'Payment Handled'] -> ['Declaration FINAL_APPROVED by SUPERVISOR', 'Request Payment', 'Payment Handled']
#
# Prefix changed: False
# Suffix changed: False
#
# --------------------------------------------------------------------------------
#
# ================================================================================
# Attack #1431: Case ID: declaration 108847, Prefix Length: 2
# Status: SUCCESS
# Steps taken: 9
# ================================================================================
#
# --- PREFIX COMPARISON (Length: 2) ---
#
#   Event 1:
#     case:BudgetNumber = [budget 86566], [budget 86566]
#     case:DeclarationNumber = [None], [None]
#     case_elapsed_time = [-0.012600072368513793], [-0.012600072368513793]
#     concept:name = [Declaration SUBMITTED by EMPLOYEE], [Declaration SUBMITTED by EMPLOYEE]
#     day_in_week = [1.9999999994143962] -> [1.9013993322833358] ⚠️ CHANGED
#     event_elapsed_time = [231062.453125] -> [195101.5627067487] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER], [STAFF MEMBER]
#     org:role = [EMPLOYEE] -> [UNDEFINED] ⚠️ CHANGED
#     seconds_in_day = [37061.999757077014] -> [37157.71999400625] ⚠️ CHANGED
#
#   Event 2:
#     case:BudgetNumber = [budget 86566], [budget 86566]
#     case:DeclarationNumber = [None], [None]
#     case_elapsed_time = [219.00097953912336] -> [-0.012600072368513793] ⚠️ CHANGED
#     concept:name = [Declaration APPROVED by ADMINISTRATION] -> [Request Payment] ⚠️ CHANGED
#     day_in_week = [1.9999999994143962] -> [1.9013993322833358] ⚠️ CHANGED
#     event_elapsed_time = [219.00369865150424] -> [-0.007862518745241687] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER], [STAFF MEMBER]
#     org:role = [ADMINISTRATION], [ADMINISTRATION]
#     seconds_in_day = [37280.999479943835] -> [37951.041138448476] ⚠️ CHANGED
#
# --- SUFFIX COMPARISON ---
#
#   Event 1:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [1446.0059713521623] -> [[366502.30282583]] ⚠️ CHANGED
#     concept:name = [Declaration FINAL_APPROVED by SUPERVISOR] -> [Request Payment] ⚠️ CHANGED
#     day_in_week = [1.9999999994143962] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [1226.9903575216304] -> [N/A] ⚠️ CHANGED
#     org:resource = [STAFF MEMBER] -> [N/A] ⚠️ CHANGED
#     org:role = [SUPERVISOR] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [38507.99995929056] -> [N/A] ⚠️ CHANGED
#
#   Event 2:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [19245.986597836367] -> [[535770.00922823]] ⚠️ CHANGED
#     concept:name = [Request Payment], [Request Payment]
#     day_in_week = [1.9999999994143962] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [17799.992441474606] -> [N/A] ⚠️ CHANGED
#     org:resource = [SYSTEM] -> [N/A] ⚠️ CHANGED
#     org:role = [UNDEFINED] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [56307.99993277137] -> [N/A] ⚠️ CHANGED
#
#   Event 3:
#     case:BudgetNumber = [budget 86566] -> [N/A] ⚠️ CHANGED
#     case:DeclarationNumber = [None] -> [N/A] ⚠️ CHANGED
#     case_elapsed_time = [112395.99496660737] -> [[618603.55608437]] ⚠️ CHANGED
#     concept:name = [Payment Handled], [Payment Handled]
#     day_in_week = [2.9999999871959684] -> [N/A] ⚠️ CHANGED
#     event_elapsed_time = [93149.99600288083] -> [N/A] ⚠️ CHANGED
#     org:resource = [SYSTEM] -> [N/A] ⚠️ CHANGED
#     org:role = [UNDEFINED] -> [N/A] ⚠️ CHANGED
#     seconds_in_day = [63057.999659883] -> [N/A] ⚠️ CHANGED
#
# --- ACTIVITY SEQUENCE SUMMARY ---
# Prefix activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION'] -> ['Declaration SUBMITTED by EMPLOYEE', 'Request Payment']
# Suffix activities: ['Declaration FINAL_APPROVED by SUPERVISOR', 'Request Payment', 'Payment Handled'] -> ['Request Payment', 'Request Payment', 'Payment Handled']
#
# Prefix changed: True
#   Positions changed:
#     Position 2: 'Declaration APPROVED by ADMINISTRATION' -> 'Request Payment'
# Suffix changed: True
#   Positions changed:
#     Position 1: 'Declaration FINAL_APPROVED by SUPERVISOR' -> 'Request Payment'
#
# --------------------------------------------------------------------------------
#
# ================================================================================
# Total attacks printed: 1431
# ================================================================================
