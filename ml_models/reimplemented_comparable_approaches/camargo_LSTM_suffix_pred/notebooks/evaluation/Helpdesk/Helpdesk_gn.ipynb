# %%
import sys
import pickle
import os
import torch
from tqdm.notebook import tqdm
from tqdm import tqdm
import random
from typing import Optional, Tuple, List

sys.path.insert(0, '..')
sys.path.insert(0, '../..')
sys.path.insert(0, '../../..')
sys.path.insert(0, '../../../..')
sys.path.insert(0, '../../../../..')
sys.path.insert(0, '../../../../../..')

from joinLSTM.model import FullShared_Join_LSTM

# %%
#load model
file_path_model = '../../training/Helpdesk/Helpdesk_camargo_leon.pkl'

model = FullShared_Join_LSTM.load(file_path_model)

# Load the dataset
#file_path_data_set = '../../../../../../encoded_data/compare_camargo/helpdesk_all_5_test.pkl'
file_path_data_set = '../../../../../../encoded_data/helpdesk_all_5_test.pkl'
helpdesk_test_dataset = torch.load(file_path_data_set, weights_only=False)
# Out:
# Data set categories:  ([('Activity', 16, {'Assign seriousness': 1, 'Closed': 2, 'Create SW anomaly': 3, 'DUPLICATE': 4, 'EOS': 5, 'INVALID': 6, 'Insert ticket': 7, 'RESOLVED': 8, 'Require upgrade': 9, 'Resolve SW anomaly': 10, 'Resolve ticket': 11, 'Schedule intervention': 12, 'Take in charge ticket': 13, 'VERIFIED': 14, 'Wait': 15}), ('Resource', 24, {'EOS': 1, 'Value 1': 2, 'Value 10': 3, 'Value 11': 4, 'Value 12': 5, 'Value 13': 6, 'Value 14': 7, 'Value 15': 8, 'Value 16': 9, 'Value 17': 10, 'Value 18': 11, 'Value 19': 12, 'Value 2': 13, 'Value 20': 14, 'Value 21': 15, 'Value 22': 16, 'Value 3': 17, 'Value 4': 18, 'Value 5': 19, 'Value 6': 20, 'Value 7': 21, 'Value 8': 22, 'Value 9': 23}), ('Variant index', 166, {'1.0': 1, '10.0': 2, '100.0': 3, '101.0': 4, '102.0': 5, '103.0': 6, '104.0': 7, '105.0': 8, '106.0': 9, '107.0': 10, '108.0': 11, '109.0': 12, '11.0': 13, '110.0': 14, '111.0': 15, '112.0': 16, '113.0': 17, '114.0': 18, '12.0': 19, '13.0': 20, '14.0': 21, '15.0': 22, '16.0': 23, '168.0': 24, '169.0': 25, '17.0': 26, '170.0': 27, '171.0': 28, '172.0': 29, '173.0': 30, '174.0': 31, '175.0': 32, '176.0': 33, '177.0': 34, '178.0': 35, '179.0': 36, '18.0': 37, '180.0': 38, '181.0': 39, '182.0': 40, '183.0': 41, '184.0': 42, '185.0': 43, '186.0': 44, '187.0': 45, '188.0': 46, '189.0': 47, '19.0': 48, '190.0': 49, '191.0': 50, '192.0': 51, '193.0': 52, '194.0': 53, '195.0': 54, '196.0': 55, '197.0': 56, '198.0': 57, '199.0': 58, '2.0': 59, '20.0': 60, '200.0': 61, '201.0': 62, '202.0': 63, '203.0': 64, '204.0': 65, '205.0': 66, '206.0': 67, '207.0': 68, '208.0': 69, '209.0': 70, '21.0': 71, '210.0': 72, '211.0': 73, '212.0': 74, '213.0': 75, '214.0': 76, '215.0': 77, '216.0': 78, '217.0': 79, '218.0': 80, '219.0': 81, '22.0': 82, '220.0': 83, '221.0': 84, '222.0': 85, '223.0': 86, '224.0': 87, '225.0': 88, '226.0': 89, '23.0': 90, '24.0': 91, '25.0': 92, '26.0': 93, '27.0': 94, '28.0': 95, '29.0': 96, '3.0': 97, '30.0': 98, '31.0': 99, '32.0': 100, '33.0': 101, '34.0': 102, '35.0': 103, '36.0': 104, '37.0': 105, '38.0': 106, '39.0': 107, '4.0': 108, '40.0': 109, '41.0': 110, '42.0': 111, '43.0': 112, '44.0': 113, '45.0': 114, '46.0': 115, '47.0': 116, '48.0': 117, '49.0': 118, '5.0': 119, '50.0': 120, '52.0': 121, '53.0': 122, '54.0': 123, '55.0': 124, '56.0': 125, '57.0': 126, '58.0': 127, '59.0': 128, '6.0': 129, '60.0': 130, '62.0': 131, '63.0': 132, '64.0': 133, '65.0': 134, '66.0': 135, '67.0': 136, '68.0': 137, '69.0': 138, '7.0': 139, '70.0': 140, '71.0': 141, '72.0': 142, '74.0': 143, '75.0': 144, '76.0': 145, '77.0': 146, '79.0': 147, '8.0': 148, '80.0': 149, '82.0': 150, '83.0': 151, '84.0': 152, '85.0': 153, '86.0': 154, '87.0': 155, '88.0': 156, '9.0': 157, '90.0': 158, '91.0': 159, '92.0': 160, '93.0': 161, '94.0': 162, '95.0': 163, '99.0': 164, nan: 165}), ('seriousness', 3, {'EOS': 1, 'Value 1': 2}), ('customer', 358, {'EOS': 1, 'Value 1': 2, 'Value 10': 3, 'Value 100': 4, 'Value 101': 5, 'Value 102': 6, 'Value 103': 7, 'Value 104': 8, 'Value 105': 9, 'Value 106': 10, 'Value 107': 11, 'Value 108': 12, 'Value 11': 13, 'Value 110': 14, 'Value 112': 15, 'Value 113': 16, 'Value 115': 17, 'Value 116': 18, 'Value 117': 19, 'Value 118': 20, 'Value 119': 21, 'Value 12': 22, 'Value 120': 23, 'Value 121': 24, 'Value 122': 25, 'Value 123': 26, 'Value 124': 27, 'Value 125': 28, 'Value 126': 29, 'Value 127': 30, 'Value 128': 31, 'Value 129': 32, 'Value 13': 33, 'Value 130': 34, 'Value 131': 35, 'Value 132': 36, 'Value 133': 37, 'Value 134': 38, 'Value 135': 39, 'Value 136': 40, 'Value 137': 41, 'Value 138': 42, 'Value 139': 43, 'Value 14': 44, 'Value 140': 45, 'Value 141': 46, 'Value 142': 47, 'Value 143': 48, 'Value 144': 49, 'Value 145': 50, 'Value 146': 51, 'Value 147': 52, 'Value 148': 53, 'Value 149': 54, 'Value 15': 55, 'Value 150': 56, 'Value 151': 57, 'Value 152': 58, 'Value 153': 59, 'Value 154': 60, 'Value 155': 61, 'Value 156': 62, 'Value 157': 63, 'Value 158': 64, 'Value 159': 65, 'Value 16': 66, 'Value 160 ...
# Model input features:  [['Activity', 'Resource', 'Variant index', 'seriousness', 'customer', 'product', 'responsible_section', 'seriousness_2', 'service_level', 'service_type', 'support_section', 'workgroup'], ['case_elapsed_time', 'event_elapsed_time', 'day_in_week', 'seconds_in_day']]
#
#
# Embeddings:  ModuleList(
#   (0): Embedding(16, 8)
#   (1): Embedding(24, 9)
#   (2): Embedding(166, 28)
#   (3): Embedding(3, 3)
#   (4): Embedding(358, 43)
#   (5): Embedding(23, 9)
#   (6): Embedding(9, 5)
#   (7-9): 3 x Embedding(6, 4)
#   (10): Embedding(8, 5)
#   (11): Embedding(6, 4)
# )
# Total embedding feature size:  126
# Input feature size:  130
# Cells hidden size:  50
# Number of LSTM layer:  1
# /Users/leonurny/.local/share/virtualenvs/Probabilistic_Suffix_Prediction_U-ED-LSTM_-32bEAP25/lib/python3.13/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   warnings.warn(

# %%
# Global placeholders for multiprocessing workers

# Model
global_model = None
# Number of samples
global_samples_per_case = None
# Categorical categories, tensors:
global_cat_categories = None
# Global scaler params for case_elapsed_time
global_scaler_params = None
#
global_dict_cat_class_id = None

def init_worker(model: FullShared_Join_LSTM,
                samples_per_case: int,
                cat_categories,
                scaler_params,
                dict_cat_class_ids,
                ):
    """
    Initializer for each worker process, setting global variables.
    """
    global global_model, global_samples_per_case, global_cat_categories, global_scaler_params, global_dict_cat_class_id
    
    # Models have already been moved to CPU before forking
    model.eval()
    
    global_model = model
    global_samples_per_case = samples_per_case
    global_cat_categories = cat_categories
    global_scaler_params = scaler_params
    global_dict_cat_class_id = dict_cat_class_ids

# %%
@torch.no_grad()
def iterate_case(full_case: Tuple[List[torch.Tensor], List[torch.Tensor]],
                 concept_name_id: int,
                 min_suffix_size: int):
    
    cats_full, nums_full, _ = full_case
    seq_len = cats_full[0].size(0)
    window_size = seq_len - min_suffix_size

    # Initialize with all‐zero padding, batch dim = 1
    cats_prefix: List[torch.Tensor] = [torch.zeros((1, window_size), dtype=cat.dtype) for cat in cats_full]
    nums_prefix: List[torch.Tensor] = [torch.zeros((1, window_size), dtype=num.dtype) for num in nums_full]

    prefix_length = 0

    # Slide the window one event at a time
    for i in range(window_size):
        # Roll left by 1 and insert the new event at the rightmost slot
        for j, cat_stream in enumerate(cats_full):
            cats_prefix[j][0] = torch.roll(cats_prefix[j][0], shifts=-1, dims=0)
            cats_prefix[j][0, -1] = cat_stream[i]

        for j, num_stream in enumerate(nums_full):
            nums_prefix[j][0] = torch.roll(nums_prefix[j][0], shifts=-1, dims=0)
            nums_prefix[j][0, -1] = num_stream[i]

        # Only start yielding once we've seen at least one real “activity” token
        if prefix_length > 0 or cats_prefix[concept_name_id][0, -1] != 0:
            prefix_length += 1
            
            yield prefix_length, (cats_prefix, nums_prefix)

# %%
@torch.no_grad()
def _evaluate_case(case_name: str,
                   full_case: Tuple[List[torch.Tensor], List[torch.Tensor], str],
                   concept_name_id: int,
                   min_suffix_size: int,
                   ):

    # List of tensors for test samples:
    cats_full, nums_full, _ = full_case
    # Denormalization values for numerical variables:
    mean_s, std_s = global_scaler_params
    
    act2idx, res2idx = global_dict_cat_class_id  # expect tuple of two dicts
    # Invert them:
    idx2act = {ix:name for name, ix in act2idx.items() }
    idx2res = {ix:name for name, ix in res2idx.items() }

    results = []
    # iterate_case already defined elsewhere
    for prefix_length, (cats_pref, nums_pref) in iterate_case(full_case, concept_name_id, min_suffix_size):

        # prefix_prep
        acts = cats_pref[0][0].tolist()
        ress = cats_pref[1][0].tolist()
        times = nums_pref[0][0].tolist()
        # Build the prefix
        prefix_prep = [{"Activity": idx2act[a], "Resource": idx2res[r], "case_elapsed_time": t * std_s + mean_s} for a, r, t in zip(acts, ress, times) if a != 0]

        # true target: Get from the activity full tensor all indices of the last n values which are not zero
        non_zero_ids = (cats_full[0] != 0).nonzero(as_tuple=True)[0]
        
        # Get the activity ids without the EOS:
        true_acts = cats_full[0][(non_zero_ids[0]+prefix_length):-1].tolist()
        true_ress = cats_full[1][(non_zero_ids[0]+prefix_length):-1].tolist()
        true_nums = nums_full[0][(non_zero_ids[0]+prefix_length):-1].tolist()
        
        # Build target as list of dicts:
        target = [{"Activity": idx2act[a]} for a in true_acts if idx2act[a] != "EOS"]
        if target == []:
            continue

        # MOST LIKELY
        cats_pref_clone = [t.clone() for t in cats_pref]
        # print(cats_pref_clone)
        nums_pref_clone = [t.clone() for t in nums_pref]
        ml_list = []
        # Iterate through window size - pref len:
        for i in range(len(cats_pref[0][0])-prefix_length):
            # Predictions
            act_probs = global_model((cats_pref_clone, nums_pref_clone))
            # Index of most likely prediction
            index_act = act_probs.argmax(dim=-1).item()
            
            # NaN is predicted new value at positon 0
            if index_act == 0:
                act = 'NaN'
            
            #  Stop the suffix creation if EOS is predicted
            elif idx2act[index_act] == 'EOS':
                break
            
            else:
                act = idx2act[index_act]
            
            # Add to Most-likely:
            ml_list.append({"Activity": act})
                        
            # Update Prefix Most Likely
            cats_pref_clone[0] = torch.cat([cats_pref_clone[0][:, 1:], torch.tensor([[index_act]])], dim=1)
            if i < len(true_acts):
                cats_pref_clone[1] = torch.cat([cats_pref_clone[1][:, 1:], torch.tensor([[true_ress[i]]])], dim=1)
                nums_pref_clone[0] = torch.cat([nums_pref_clone[0][:, 1:], torch.tensor([[true_nums[i]]])], dim=1)
                
        most_likely = ml_list
        
        # RANDOM SAMPLING
        samples_lists = []
        for _ in range(global_samples_per_case):
            cats_pref_clone_samples = [t.clone() for t in cats_pref]
            nums_pref_clone_samples = [t.clone() for t in nums_pref]
            # Iterate through window size - pref len:
            samples = []
            for i in range(len(cats_pref[0][0])-prefix_length):
                # Predictions
                act_probs_sample = global_model((cats_pref_clone_samples, nums_pref_clone_samples)).squeeze(0)              
                # Ranodm Smapling:
                random_index_act = torch.multinomial(act_probs_sample, num_samples=1).item()    
                
                # NaN is predicted new value at positon 0
                if random_index_act == 0:
                   act = 'NaN'
                
                #  Stop the suffix creation if EOS is predicted
                elif idx2act[random_index_act] == 'EOS':
                    break
                
                else:
                    act = idx2act[random_index_act]
                
                samples.append({"Activity": act })
                
                # Update Prefix Most Likely
                cats_pref_clone_samples[0] = torch.cat([cats_pref_clone_samples[0][:, 1:], torch.tensor([[random_index_act]])], dim=1)
                if i < len(true_acts):
                    cats_pref_clone_samples[1] = torch.cat([cats_pref_clone_samples[1][:, 1:], torch.tensor([[true_ress[i]]])], dim=1)
                    nums_pref_clone_samples[0] = torch.cat([nums_pref_clone_samples[0][:, 1:], torch.tensor([[true_nums[i]]])], dim=1)
            
            samples_lists.append(samples)
            
        random_suffixes = samples_lists

        results.append((case_name, prefix_length, prefix_prep, random_suffixes, target, most_likely))
        
        # print("Case Name: ", case_name)
        # print("Prefix length: ", prefix_length)
        # print("Prefix prepared: ", prefix_prep)
        # print("Random Suffixes: ", random_suffixes)
        # print("Target: ", target)
        # print("Most Likely: ", most_likely)

    return results

# %%
def evaluate_seq_processing(model: FullShared_Join_LSTM,
                            dataset,
                            device,
                            samples_per_case: int = 1,
                            random_order: Optional[bool]= False,
                            ):
    """
    Sequential evaluation yielding tuples per case and prefix length.
    """
    
    # Move models to CPU
    model.to('cpu')
    
    # Category names and ids
    concept_name = 'Activity'
    # Id of activity in cat list
    concept_name_id = [i for i, cat in enumerate(helpdesk_test_dataset.all_categories[0]) if cat[0] == concept_name][0]
    
    # Dict with key: act class, value: index position
    act_classes_id =  helpdesk_test_dataset.all_categories[0][0][2]
    # Dict with key: res class, value: index position
    res_classes_id =  helpdesk_test_dataset.all_categories[0][1][2]
    
    # Id of EOS token in activity
    eos_value = 'EOS'
    # index of EOS value in activity dict:
    eos_id = [v for k, v in helpdesk_test_dataset.all_categories[0][concept_name_id][2].items() if k == eos_value][0]
    
    cases = {}
    for event in dataset:
        # Get suffix being the last 
        suffix = event[0][concept_name_id][-dataset.encoder_decoder.min_suffix_size:]
        if torch.all(suffix  == eos_id).item():
            cases[event[2]] = event
            
    case_items = list(cases.items())
    if random_order:
        case_items = random.sample(case_items, len(case_items))
    
    # Tuple of category (e.g., Activity) with amount classes, dict with class and index
    cat_categories, _ = model.data_set_categories
    # print(cat_categories)
    
    # Scaler used in dataset to normalize/ denormalize the numerical attributes:
    scaler = dataset.encoder_decoder.continuous_encoders['case_elapsed_time']
    scaler_params = (scaler.mean_.item(), scaler.scale_.item())
    
    # Initialize globals for identical logic
    init_worker(model, samples_per_case, cat_categories, scaler_params, (act_classes_id, res_classes_id))
    
    # for cats, nums, case_name in tqdm(cases, total=len(cases)):
    for _, (case_name, full_case) in tqdm(enumerate(case_items), total=len(cases)):
        
        # Get a list with the results for all cases of one case:
        results = _evaluate_case(case_name=case_name,
                                 full_case=full_case,
                                 concept_name_id=concept_name_id,
                                 min_suffix_size=dataset.encoder_decoder.min_suffix_size)
        
        # Return the results for inserting:
        for res in results:
            yield res

# %%
output_dir = '../../../../../../evaluation_results/Helpdesk/eval_camargo_sl5/'

def save_chunk(results, i):
    chunk_number = (i + 1)
    filename = os.path.join(output_dir, f'results_part_{chunk_number:03d}.pkl')
    with open(filename, 'wb') as f:
        pickle.dump(results, f)
    print(f"Saved {len(results)} results to {filename}")

# %%
# Is set to four in the method parameters -> call if change
num_processes=16

save_every = 50

results = {}

for i, (case_name, prefix_len, prefix, sampled_cets, target_cet, mean_cet) in enumerate(evaluate_seq_processing(model=model,
                                                                                                                dataset=helpdesk_test_dataset,
                                                                                                                device = torch.device("cpu"),
                                                                                                                samples_per_case=1)
                                                                                                                ):

# for i, (case_name, prefix_len, prefix, sampled_cets, target_cet, mean_cet) in enumerate(evaluate_parallel_processing(model=model,
#                                                                                                                      dataset=helpdesk_test_dataset,
#                                                                                                                      samples_per_case=1000,
#   
#          
#                                                                                                      processes=num_processes)):
    print(case_name)
    print(sampled_cets)
    print(target_cet)
  
    print(mean_cet)

    #print(mean_cet)
    # print(case_name, prefix_len)
    # if (case_name != '1016'):
    #    break
    
    assert((case_name, prefix_len) not in results)
    
    results[(case_name, prefix_len)] = (prefix, target_cet, mean_cet, sampled_cets)
    
    if (i + 1) % save_every == 0:
        save_chunk(results, i)
        results = {}

if len(results):
    save_chunk(results, i)
# Out:
#   4%|▎         | 34/916 [00:00<00:05, 166.31it/s]
# Case 1617
# [[{'Activity': 'Closed'}, {'Activity': 'VERIFIED'}, {'Activity': 'DUPLICATE'}]]
# [{'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1617
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1617
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1617
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1618
# [[{'Activity': 'Take in charge ticket'}, {'Activity': 'Create SW anomaly'}, {'Activity': 'INVALID'}, {'Activity': 'DUPLICATE'}, {'Activity': 'Take in charge ticket'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1618
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1618
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1619
# [[{'Activity': 'RESOLVED'}, {'Activity': 'Schedule intervention'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'NaN'}, {'Activity': 'Resolve ticket'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1619
# [[{'Activity': 'Resolve SW anomaly'}, {'Activity': 'Wait'}, {'Activity': 'DUPLICATE'}, {'Activity': 'Insert ticket'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1619
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 162
# [[{'Activity': 'NaN'}, {'Activity': 'Schedule intervention'}, {'Activity': 'Require upgrade'}, {'Activity': 'Schedule intervention'}, {'Activity': 'Create SW anomaly'}, {'Activity': 'DUPLICATE'}, {'Activity': 'DUPLICATE'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Closed'}, {'Activity': 'NaN'}, {'Activity': 'Wait'}, {'Activity': 'Schedule intervention'}]]
# [{'Activity': 'Assign seriousness'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 162
# [[{'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Require upgrade'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 162
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1620
# [[{'Activity': 'Require upgrade'}, {'Activity': 'Assign seriousness'}, {'Activity': 'Closed'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1620
# [[{'Activity': 'Closed'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Take in charge ticket'}]]
# [{'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1620
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1620
# [[{'Activity': 'Assign seriousness'}]]
# [{'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1620
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1620
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1621
# [[{'Activity': 'Closed'}, {'Activity': 'RESOLVED'}, {'Activity': 'Create SW anomaly'}, {'Activity': 'Resolve SW anomaly'}, {'Activity': 'Assign seriousness'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1621
# [[{'Activity': 'VERIFIED'}, {'Activity': 'NaN'}, {'Activity': 'Wait'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1621
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1622
# [[]]
# [{'Activity': 'Assign seriousness'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1622
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1622
# [[]]
# [{'Activity': 'Wait'}, {'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1622
# [[]]
# [{'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1622
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1622
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1622
# [[{'Activity': 'Wait'}]]
# [{'Activity': 'Closed'}]
# []
# Case 1623
# [[{'Activity': 'Wait'}, {'Activity': 'Schedule intervention'}, {'Activity': 'Resolve SW anomaly'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1623
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1623
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1624
# [[{'Activity': 'Resolve ticket'}, {'Activity': 'Wait'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1624
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1624
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1625
# [[{'Activity': 'Insert ticket'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1625
# [[{'Activity': 'Insert ticket'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1625
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1626
# [[{'Activity': 'Schedule intervention'}, {'Activity': 'Schedule intervention'}, {'Activity': 'Resolve SW anomaly'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Closed'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1626
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1626
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1627
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1627
# [[{'Activity': 'Wait'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1627
# [[{'Activity': 'INVALID'}]]
# [{'Activity': 'Closed'}]
# []
# Case 1628
# [[{'Activity': 'Resolve ticket'}, {'Activity': 'RESOLVED'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Insert ticket'}, {'Activity': 'Closed'}, {'Activity': 'Insert ticket'}, {'Activity': 'DUPLICATE'}, {'Activity': 'Insert ticket'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1628
# [[{'Activity': 'Require upgrade'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1628
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1629
# [[{'Activity': 'Resolve ticket'}, {'Activity': 'Create SW anomaly'}, {'Activity': 'Schedule intervention'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Assign seriousness'}, {'Activity': 'Require upgrade'}, {'Activity': 'Schedule intervention'}, {'Activity': 'Take in charge ticket'}]]
# [{'Activity': 'Assign seriousness'}, {'Activity': 'Assign seriousness'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1629
# [[]]
# [{'Activity': 'Assign seriousness'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1629
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Saved 50 results to ../../../../../../evaluation_results/Helpdesk/eval_camargo_sl5/results_part_050.pkl
# Case 1629
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1629
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 163
# [[{'Activity': 'Wait'}, {'Activity': 'RESOLVED'}, {'Activity': 'Insert ticket'}, {'Activity': 'DUPLICATE'}, {'Activity': 'Require upgrade'}, {'Activity': 'DUPLICATE'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 163
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 163
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1630
# [[{'Activity': 'Require upgrade'}, {'Activity': 'DUPLICATE'}, {'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1630
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1630
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1631
# [[{'Activity': 'INVALID'}, {'Activity': 'Closed'}, {'Activity': 'Closed'}, {'Activity': 'Resolve SW anomaly'}, {'Activity': 'Schedule intervention'}, {'Activity': 'DUPLICATE'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1631
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1631
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1632
# [[{'Activity': 'Schedule intervention'}, {'Activity': 'Require upgrade'}, {'Activity': 'VERIFIED'}, {'Activity': 'Wait'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1632
# [[{'Activity': 'Require upgrade'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1632
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1633
# [[{'Activity': 'Resolve ticket'}, {'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'RESOLVED'}, {'Activity': 'Insert ticket'}, {'Activity': 'NaN'}, {'Activity': 'Closed'}, {'Activity': 'Closed'}, {'Activity': 'Wait'}, {'Activity': 'VERIFIED'}, {'Activity': 'DUPLICATE'}, {'Activity': 'Closed'}]]
# [{'Activity': 'Assign seriousness'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# [{'Activity': 'Closed'}]
# Case 1633
# [[{'Activity': 'Resolve SW anomaly'}, {'Activity': 'Resolve SW anomaly'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1633
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1633
# [[{'Activity': 'Require upgrade'}, {'Activity': 'Closed'}]]
# [{'Activity': 'Closed'}]
# []
# Case 1634
# [[{'Activity': 'Resolve ticket'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'NaN'}, {'Activity': 'Require upgrade'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve SW anomaly'}, {'Activity': 'Resolve ticket'}, {'Activity': 'NaN'}, {'Activity': 'Wait'}, {'Activity': 'Resolve SW anomaly'}, {'Activity': 'Closed'}, {'Activity': 'Closed'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1634
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1634
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1635
# [[{'Activity': 'NaN'}, {'Activity': 'Assign seriousness'}, {'Activity': 'NaN'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1635
# [[{'Activity': 'Require upgrade'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1635
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1636
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1636
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1636
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1637
# [[{'Activity': 'DUPLICATE'}, {'Activity': 'DUPLICATE'}, {'Activity': 'Resolve SW anomaly'}, {'Activity': 'Resolve SW anomaly'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1637
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1637
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1638
# [[{'Activity': 'Insert ticket'}, {'Activity': 'Require upgrade'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'VERIFIED'}, {'Activity': 'Create SW anomaly'}, {'Activity': 'NaN'}, {'Activity': 'Require upgrade'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Require upgrade'}, {'Activity': 'Take in charge ticket'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1638
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1638
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1639
# [[{'Activity': 'Assign seriousness'}, {'Activity': 'NaN'}, {'Activity': 'NaN'}, {'Activity': 'Require upgrade'}, {'Activity': 'Require upgrade'}, {'Activity': 'Wait'}, {'Activity': 'Assign seriousness'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1639
# [[{'Activity': 'Wait'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1639
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 164
# [[{'Activity': 'Resolve ticket'}, {'Activity': 'INVALID'}, {'Activity': 'Insert ticket'}, {'Activity': 'NaN'}, {'Activity': 'INVALID'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Require upgrade'}, {'Activity': 'Schedule intervention'}, {'Activity': 'VERIFIED'}, {'Activity': 'Wait'}, {'Activity': 'RESOLVED'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 164
# [[{'Activity': 'INVALID'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 164
# [[{'Activity': 'Require upgrade'}]]
# [{'Activity': 'Closed'}]
# []
# Case 1640
# [[{'Activity': 'VERIFIED'}, {'Activity': 'Require upgrade'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1640
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1640
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1641
# [[{'Activity': 'DUPLICATE'}]]
# [{'Activity': 'Assign seriousness'}, {'Activity': 'Assign seriousness'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# [{'Activity': 'Closed'}]
# Case 1641
# [[]]
# [{'Activity': 'Assign seriousness'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1641
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1641
# [[]]
# [{'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1641
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1641
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1641
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1642
# [[{'Activity': 'RESOLVED'}, {'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Resolve SW anomaly'}, {'Activity': 'Closed'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Require upgrade'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Saved 50 results to ../../../../../../evaluation_results/Helpdesk/eval_camargo_sl5/results_part_100.pkl
# Case 1642
# [[{'Activity': 'Closed'}, {'Activity': 'Require upgrade'}, {'Activity': 'Assign seriousness'}, {'Activity': 'Schedule intervention'}, {'Activity': 'Take in charge ticket'}]]
# [{'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1642
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1642
# [[{'Activity': 'DUPLICATE'}]]
# [{'Activity': 'Closed'}]
# []
# Case 1643
# [[{'Activity': 'Create SW anomaly'}, {'Activity': 'Assign seriousness'}]]
# [{'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1643
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1643
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1644
# [[{'Activity': 'Require upgrade'}, {'Activity': 'Require upgrade'}, {'Activity': 'Resolve SW anomaly'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1644
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1644
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1645
# [[{'Activity': 'Insert ticket'}, {'Activity': 'Closed'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1645
# [[{'Activity': 'RESOLVED'}, {'Activity': 'Assign seriousness'}]]
# [{'Activity': 'Closed'}]
# []
# Case 1646
# [[{'Activity': 'Insert ticket'}, {'Activity': 'Assign seriousness'}, {'Activity': 'Closed'}, {'Activity': 'RESOLVED'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1646
# [[{'Activity': 'Take in charge ticket'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1646
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1647
# [[{'Activity': 'Wait'}, {'Activity': 'Schedule intervention'}, {'Activity': 'Closed'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1647
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1647
# [[]]
# [{'Activity': 'Closed'}]
# []
#   8%|▊         | 69/916 [00:00<00:04, 172.14it/s]
# Case 1648
# [[{'Activity': 'Resolve ticket'}, {'Activity': 'Resolve SW anomaly'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1648
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1648
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1649
# [[{'Activity': 'Closed'}, {'Activity': 'VERIFIED'}, {'Activity': 'Resolve SW anomaly'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1649
# [[{'Activity': 'NaN'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1649
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 165
# [[{'Activity': 'Schedule intervention'}, {'Activity': 'INVALID'}, {'Activity': 'Create SW anomaly'}, {'Activity': 'Closed'}, {'Activity': 'Create SW anomaly'}, {'Activity': 'NaN'}, {'Activity': 'Require upgrade'}, {'Activity': 'Resolve SW anomaly'}, {'Activity': 'INVALID'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 165
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1650
# [[{'Activity': 'Closed'}, {'Activity': 'VERIFIED'}, {'Activity': 'Closed'}, {'Activity': 'DUPLICATE'}, {'Activity': 'Wait'}, {'Activity': 'DUPLICATE'}, {'Activity': 'VERIFIED'}, {'Activity': 'Schedule intervention'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Wait'}, {'Activity': 'Schedule intervention'}, {'Activity': 'Insert ticket'}]]
# [{'Activity': 'Create SW anomaly'}, {'Activity': 'Create SW anomaly'}, {'Activity': 'Resolve SW anomaly'}, {'Activity': 'Resolve SW anomaly'}, {'Activity': 'Require upgrade'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1650
# [[{'Activity': 'Create SW anomaly'}]]
# [{'Activity': 'Create SW anomaly'}, {'Activity': 'Resolve SW anomaly'}, {'Activity': 'Resolve SW anomaly'}, {'Activity': 'Require upgrade'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1650
# [[]]
# [{'Activity': 'Resolve SW anomaly'}, {'Activity': 'Resolve SW anomaly'}, {'Activity': 'Require upgrade'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1650
# [[]]
# [{'Activity': 'Resolve SW anomaly'}, {'Activity': 'Require upgrade'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1650
# [[{'Activity': 'DUPLICATE'}]]
# [{'Activity': 'Require upgrade'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1650
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1650
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1651
# [[{'Activity': 'RESOLVED'}, {'Activity': 'VERIFIED'}, {'Activity': 'Resolve SW anomaly'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# [{'Activity': 'Closed'}]
# Case 1651
# [[{'Activity': 'Resolve SW anomaly'}, {'Activity': 'Wait'}, {'Activity': 'Closed'}, {'Activity': 'Wait'}, {'Activity': 'Closed'}]]
# [{'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1651
# [[{'Activity': 'DUPLICATE'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1651
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1652
# [[{'Activity': 'RESOLVED'}]]
# [{'Activity': 'Assign seriousness'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# [{'Activity': 'Closed'}, {'Activity': 'Closed'}, {'Activity': 'Closed'}, {'Activity': 'Closed'}]
# Case 1652
# [[{'Activity': 'DUPLICATE'}, {'Activity': 'VERIFIED'}, {'Activity': 'NaN'}, {'Activity': 'INVALID'}, {'Activity': 'Schedule intervention'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1652
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1652
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1653
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1653
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1653
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1654
# [[{'Activity': 'NaN'}, {'Activity': 'Resolve ticket'}, {'Activity': 'VERIFIED'}, {'Activity': 'NaN'}, {'Activity': 'NaN'}, {'Activity': 'Insert ticket'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1654
# [[{'Activity': 'DUPLICATE'}, {'Activity': 'Require upgrade'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1654
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1655
# [[{'Activity': 'Create SW anomaly'}, {'Activity': 'Resolve ticket'}, {'Activity': 'NaN'}, {'Activity': 'NaN'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1655
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1655
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1656
# [[{'Activity': 'INVALID'}, {'Activity': 'Closed'}, {'Activity': 'RESOLVED'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Saved 50 results to ../../../../../../evaluation_results/Helpdesk/eval_camargo_sl5/results_part_150.pkl
# Case 1656
# [[{'Activity': 'Take in charge ticket'}, {'Activity': 'Insert ticket'}]]
# [{'Activity': 'Closed'}]
# []
# Case 1657
# [[{'Activity': 'VERIFIED'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1657
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1657
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1658
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Require upgrade'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1658
# [[{'Activity': 'Insert ticket'}, {'Activity': 'Assign seriousness'}, {'Activity': 'Resolve SW anomaly'}]]
# [{'Activity': 'Require upgrade'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1658
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1658
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1659
# [[{'Activity': 'DUPLICATE'}, {'Activity': 'DUPLICATE'}, {'Activity': 'Resolve SW anomaly'}, {'Activity': 'Schedule intervention'}]]
# [{'Activity': 'Assign seriousness'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1659
# [[{'Activity': 'Assign seriousness'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1659
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1659
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 166
# [[{'Activity': 'Create SW anomaly'}, {'Activity': 'Require upgrade'}, {'Activity': 'Resolve ticket'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 166
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 166
# [[{'Activity': 'Take in charge ticket'}]]
# [{'Activity': 'Closed'}]
# []
# Case 1660
# [[{'Activity': 'NaN'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Resolve SW anomaly'}, {'Activity': 'Closed'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'INVALID'}, {'Activity': 'RESOLVED'}, {'Activity': 'INVALID'}, {'Activity': 'DUPLICATE'}, {'Activity': 'INVALID'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1660
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1660
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1661
# [[{'Activity': 'Require upgrade'}, {'Activity': 'Schedule intervention'}, {'Activity': 'INVALID'}, {'Activity': 'Require upgrade'}, {'Activity': 'Closed'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1661
# [[{'Activity': 'Wait'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1661
# [[{'Activity': 'Take in charge ticket'}]]
# [{'Activity': 'Closed'}]
# []
# Case 1662
# [[{'Activity': 'Require upgrade'}, {'Activity': 'Create SW anomaly'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Assign seriousness'}, {'Activity': 'NaN'}, {'Activity': 'Closed'}, {'Activity': 'Wait'}, {'Activity': 'Wait'}, {'Activity': 'Schedule intervention'}, {'Activity': 'Assign seriousness'}]]
# [{'Activity': 'Assign seriousness'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# [{'Activity': 'Closed'}]
# Case 1662
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1662
# [[{'Activity': 'Insert ticket'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1662
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1663
# [[{'Activity': 'VERIFIED'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1663
# [[{'Activity': 'INVALID'}]]
# [{'Activity': 'Closed'}]
# []
# Case 1664
# [[{'Activity': 'NaN'}, {'Activity': 'Resolve SW anomaly'}, {'Activity': 'NaN'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1664
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1665
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1665
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1665
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1666
# [[{'Activity': 'Take in charge ticket'}, {'Activity': 'INVALID'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1666
# [[{'Activity': 'Closed'}, {'Activity': 'INVALID'}, {'Activity': 'Assign seriousness'}, {'Activity': 'Assign seriousness'}, {'Activity': 'RESOLVED'}]]
# [{'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1666
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1666
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1667
# [[{'Activity': 'Wait'}, {'Activity': 'Closed'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1667
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1667
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1668
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1668
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1668
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1669
# [[{'Activity': 'DUPLICATE'}, {'Activity': 'VERIFIED'}, {'Activity': 'Closed'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1669
# [[{'Activity': 'Resolve SW anomaly'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1669
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 167
# [[{'Activity': 'RESOLVED'}, {'Activity': 'Insert ticket'}, {'Activity': 'Wait'}, {'Activity': 'Schedule intervention'}, {'Activity': 'Resolve SW anomaly'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 167
# [[]]
# [{'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 167
# [[{'Activity': 'VERIFIED'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 167
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 167
# [[]]
# [{'Activity': 'Closed'}]
# []
# Saved 50 results to ../../../../../../evaluation_results/Helpdesk/eval_camargo_sl5/results_part_200.pkl
# Case 1670
# [[{'Activity': 'Take in charge ticket'}, {'Activity': 'RESOLVED'}, {'Activity': 'Schedule intervention'}, {'Activity': 'VERIFIED'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Create SW anomaly'}, {'Activity': 'Schedule intervention'}, {'Activity': 'Create SW anomaly'}, {'Activity': 'NaN'}, {'Activity': 'Wait'}, {'Activity': 'Require upgrade'}, {'Activity': 'Wait'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1670
# [[]]
# [{'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1670
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1670
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1670
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1671
# [[{'Activity': 'INVALID'}, {'Activity': 'Create SW anomaly'}, {'Activity': 'RESOLVED'}, {'Activity': 'Create SW anomaly'}, {'Activity': 'Resolve ticket'}, {'Activity': 'RESOLVED'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Create SW anomaly'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1671
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1671
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1672
# [[{'Activity': 'Resolve ticket'}, {'Activity': 'Require upgrade'}, {'Activity': 'Resolve SW anomaly'}, {'Activity': 'Require upgrade'}, {'Activity': 'INVALID'}, {'Activity': 'RESOLVED'}, {'Activity': 'Closed'}, {'Activity': 'Create SW anomaly'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1672
# [[]]
# [{'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1672
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1672
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1672
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1673
# [[{'Activity': 'Resolve ticket'}, {'Activity': 'INVALID'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1673
# [[{'Activity': 'DUPLICATE'}, {'Activity': 'VERIFIED'}, {'Activity': 'Closed'}, {'Activity': 'Wait'}, {'Activity': 'Schedule intervention'}, {'Activity': 'Resolve SW anomaly'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1673
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1674
# [[{'Activity': 'RESOLVED'}, {'Activity': 'VERIFIED'}, {'Activity': 'Require upgrade'}, {'Activity': 'Insert ticket'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Assign seriousness'}, {'Activity': 'VERIFIED'}, {'Activity': 'Resolve SW anomaly'}, {'Activity': 'Require upgrade'}, {'Activity': 'Require upgrade'}, {'Activity': 'Require upgrade'}, {'Activity': 'Create SW anomaly'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1674
# [[{'Activity': 'Schedule intervention'}, {'Activity': 'VERIFIED'}, {'Activity': 'Take in charge ticket'}]]
# [{'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1674
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1674
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1675
# [[{'Activity': 'Resolve SW anomaly'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1675
# [[{'Activity': 'NaN'}, {'Activity': 'Insert ticket'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1675
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1676
# [[{'Activity': 'Insert ticket'}, {'Activity': 'Assign seriousness'}, {'Activity': 'Closed'}]]
# [{'Activity': 'Assign seriousness'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1676
# [[{'Activity': 'RESOLVED'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1676
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1676
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1677
# [[{'Activity': 'Resolve ticket'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1677
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1677
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1678
# [[{'Activity': 'DUPLICATE'}, {'Activity': 'Assign seriousness'}, {'Activity': 'Wait'}, {'Activity': 'Require upgrade'}, {'Activity': 'NaN'}, {'Activity': 'Require upgrade'}, {'Activity': 'INVALID'}, {'Activity': 'Assign seriousness'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1678
# [[{'Activity': 'Schedule intervention'}, {'Activity': 'Schedule intervention'}]]
# [{'Activity': 'Closed'}]
# []
# Case 1679
# [[{'Activity': 'Insert ticket'}, {'Activity': 'Create SW anomaly'}, {'Activity': 'Resolve SW anomaly'}, {'Activity': 'VERIFIED'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# [{'Activity': 'Closed'}]
# Case 1679
# [[{'Activity': 'Closed'}, {'Activity': 'Schedule intervention'}]]
# [{'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1679
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1679
# [[]]
# [{'Activity': 'Closed'}]
# []
#   9%|▉         | 87/916 [00:00<00:04, 171.11it/s]
# Case 168
# [[{'Activity': 'Insert ticket'}, {'Activity': 'VERIFIED'}, {'Activity': 'Closed'}, {'Activity': 'Schedule intervention'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'RESOLVED'}, {'Activity': 'RESOLVED'}, {'Activity': 'DUPLICATE'}, {'Activity': 'Require upgrade'}, {'Activity': 'INVALID'}, {'Activity': 'Resolve SW anomaly'}, {'Activity': 'Schedule intervention'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 168
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 168
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1680
# [[{'Activity': 'Resolve ticket'}, {'Activity': 'Require upgrade'}, {'Activity': 'Create SW anomaly'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1680
# [[]]
# [{'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1680
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1680
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1681
# [[{'Activity': 'NaN'}, {'Activity': 'Schedule intervention'}, {'Activity': 'Require upgrade'}, {'Activity': 'Create SW anomaly'}, {'Activity': 'INVALID'}, {'Activity': 'NaN'}, {'Activity': 'Require upgrade'}, {'Activity': 'DUPLICATE'}, {'Activity': 'INVALID'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Resolve SW anomaly'}, {'Activity': 'Resolve ticket'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1681
# [[]]
# [{'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1681
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1681
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1682
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1682
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1682
# [[]]
# [{'Activity': 'Closed'}]
# []
# Saved 50 results to ../../../../../../evaluation_results/Helpdesk/eval_camargo_sl5/results_part_250.pkl
# Case 1683
# [[{'Activity': 'DUPLICATE'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1683
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1683
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1684
# [[{'Activity': 'INVALID'}, {'Activity': 'DUPLICATE'}, {'Activity': 'RESOLVED'}, {'Activity': 'NaN'}, {'Activity': 'Insert ticket'}, {'Activity': 'DUPLICATE'}, {'Activity': 'Assign seriousness'}, {'Activity': 'Wait'}, {'Activity': 'Closed'}, {'Activity': 'VERIFIED'}, {'Activity': 'Create SW anomaly'}, {'Activity': 'Resolve SW anomaly'}]]
# [{'Activity': 'Assign seriousness'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1684
# [[{'Activity': 'Resolve SW anomaly'}, {'Activity': 'Require upgrade'}, {'Activity': 'Assign seriousness'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1684
# [[]]
# [{'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1684
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1684
# [[]]
# [{'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1684
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1684
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1684
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1685
# [[{'Activity': 'Schedule intervention'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1685
# [[]]
# [{'Activity': 'Wait'}, {'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1685
# [[]]
# [{'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1685
# [[{'Activity': 'Schedule intervention'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1685
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1686
# [[{'Activity': 'Wait'}, {'Activity': 'VERIFIED'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1686
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1686
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1687
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1687
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1687
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1688
# [[{'Activity': 'RESOLVED'}, {'Activity': 'VERIFIED'}, {'Activity': 'Assign seriousness'}, {'Activity': 'Resolve ticket'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1688
# [[]]
# [{'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1688
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1688
# [[]]
# [{'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1688
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1688
# [[{'Activity': 'Closed'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1688
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1689
# [[{'Activity': 'NaN'}, {'Activity': 'RESOLVED'}, {'Activity': 'Require upgrade'}, {'Activity': 'Resolve SW anomaly'}, {'Activity': 'Resolve SW anomaly'}, {'Activity': 'NaN'}, {'Activity': 'RESOLVED'}, {'Activity': 'Assign seriousness'}, {'Activity': 'INVALID'}, {'Activity': 'Closed'}, {'Activity': 'Insert ticket'}, {'Activity': 'Closed'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1689
# [[]]
# [{'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1689
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1689
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 169
# [[{'Activity': 'NaN'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 169
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1690
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1690
# [[]]
# [{'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1690
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1690
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1691
# [[{'Activity': 'DUPLICATE'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]]
# [{'Activity': 'Assign seriousness'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# [{'Activity': 'Closed'}, {'Activity': 'Closed'}]
# Case 1691
# [[{'Activity': 'RESOLVED'}, {'Activity': 'NaN'}, {'Activity': 'Wait'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1691
# [[]]
# [{'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1691
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1691
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1692
# [[{'Activity': 'Schedule intervention'}, {'Activity': 'Wait'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# [{'Activity': 'Closed'}]
# Case 1692
# [[{'Activity': 'RESOLVED'}, {'Activity': 'Require upgrade'}, {'Activity': 'Insert ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Insert ticket'}]]
# [{'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1692
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1692
# [[{'Activity': 'INVALID'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1692
# [[{'Activity': 'INVALID'}]]
# [{'Activity': 'Closed'}]
# []
# Case 1693
# [[{'Activity': 'Resolve ticket'}, {'Activity': 'VERIFIED'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Saved 50 results to ../../../../../../evaluation_results/Helpdesk/eval_camargo_sl5/results_part_300.pkl
# Case 1693
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1693
# [[]]
# [{'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1693
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1693
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1693
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1694
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1694
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1694
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1695
# [[{'Activity': 'NaN'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1695
# [[{'Activity': 'NaN'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1695
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1696
# [[{'Activity': 'INVALID'}, {'Activity': 'Create SW anomaly'}, {'Activity': 'DUPLICATE'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1696
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1696
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1697
# [[{'Activity': 'Resolve ticket'}, {'Activity': 'DUPLICATE'}, {'Activity': 'RESOLVED'}, {'Activity': 'Insert ticket'}, {'Activity': 'INVALID'}, {'Activity': 'Insert ticket'}, {'Activity': 'Resolve SW anomaly'}, {'Activity': 'Closed'}, {'Activity': 'Resolve SW anomaly'}, {'Activity': 'Schedule intervention'}, {'Activity': 'Closed'}, {'Activity': 'NaN'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1697
# [[]]
# [{'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1697
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1697
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1698
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1698
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1698
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1699
# [[{'Activity': 'NaN'}, {'Activity': 'Closed'}, {'Activity': 'Create SW anomaly'}, {'Activity': 'VERIFIED'}, {'Activity': 'Insert ticket'}, {'Activity': 'VERIFIED'}, {'Activity': 'RESOLVED'}, {'Activity': 'Assign seriousness'}, {'Activity': 'Assign seriousness'}, {'Activity': 'Create SW anomaly'}, {'Activity': 'Require upgrade'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1699
# [[{'Activity': 'Require upgrade'}, {'Activity': 'NaN'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1699
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 17
# [[{'Activity': 'INVALID'}, {'Activity': 'Insert ticket'}, {'Activity': 'Assign seriousness'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 17
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 17
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 170
# [[{'Activity': 'Closed'}, {'Activity': 'VERIFIED'}, {'Activity': 'RESOLVED'}, {'Activity': 'RESOLVED'}, {'Activity': 'Insert ticket'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# [{'Activity': 'Closed'}, {'Activity': 'Closed'}]
# Case 170
# [[{'Activity': 'Take in charge ticket'}, {'Activity': 'Closed'}, {'Activity': 'DUPLICATE'}]]
# [{'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 170
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 170
# [[]]
# [{'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 170
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 170
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1700
# [[{'Activity': 'INVALID'}, {'Activity': 'NaN'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1700
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 1700
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 1701
# [[{'Activity': 'Closed'}, {'Activity': 'Require upgrade'}, {'Activity': 'Create SW anomaly'}, {'Activity': 'Wait'}, {'Activity': 'Wait'}, {'Activity': 'INVALID'}, {'Activity': 'NaN'}, {'Activity': 'Insert ticket'}, {'Activity': 'Insert ticket'}, {'Activity': 'Schedule intervention'}, {'Activity': 'Wait'}, {'Activity': 'Assign seriousness'}]]
# [{'Activity': 'Assign seriousness'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# [{'Activity': 'Closed'}]
# Case 1701
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# ...
# []
# Case 2074
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2074
# [[{'Activity': 'Closed'}]]
# [{'Activity': 'Closed'}]
# []
# Case 2075
# [[{'Activity': 'Take in charge ticket'}, {'Activity': 'Create SW anomaly'}, {'Activity': 'Closed'}, {'Activity': 'Schedule intervention'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2075
# [[{'Activity': 'INVALID'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2075
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 2076
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2076
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2076
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 2077
# [[{'Activity': 'Resolve SW anomaly'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2077
# [[{'Activity': 'DUPLICATE'}, {'Activity': 'Insert ticket'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2077
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 2078
# [[{'Activity': 'Resolve SW anomaly'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve SW anomaly'}, {'Activity': 'Insert ticket'}]]
# [{'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2078
# [[{'Activity': 'INVALID'}, {'Activity': 'RESOLVED'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2078
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2078
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 2079
# [[{'Activity': 'Take in charge ticket'}, {'Activity': 'RESOLVED'}, {'Activity': 'Closed'}, {'Activity': 'VERIFIED'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Insert ticket'}]]
# [{'Activity': 'Wait'}, {'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2079
# [[{'Activity': 'NaN'}]]
# [{'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2079
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2079
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 208
# [[{'Activity': 'Resolve ticket'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 208
# [[{'Activity': 'VERIFIED'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 208
# [[{'Activity': 'Closed'}]]
# [{'Activity': 'Closed'}]
# []
# Case 2080
# [[{'Activity': 'Insert ticket'}, {'Activity': 'Wait'}, {'Activity': 'Closed'}, {'Activity': 'Wait'}, {'Activity': 'INVALID'}, {'Activity': 'Require upgrade'}, {'Activity': 'Resolve SW anomaly'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2080
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2080
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2080
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 2081
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Require upgrade'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2081
# [[]]
# [{'Activity': 'Require upgrade'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2081
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2081
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 2082
# [[{'Activity': 'Assign seriousness'}, {'Activity': 'Closed'}, {'Activity': 'Wait'}, {'Activity': 'Schedule intervention'}, {'Activity': 'Create SW anomaly'}, {'Activity': 'Wait'}, {'Activity': 'Assign seriousness'}, {'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'NaN'}, {'Activity': 'NaN'}, {'Activity': 'DUPLICATE'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# [{'Activity': 'Closed'}]
# Case 2082
# [[{'Activity': 'VERIFIED'}]]
# [{'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2082
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2082
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2082
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2082
# [[]]
# [{'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2082
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2082
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2082
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 2083
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2083
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2083
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 2084
# [[{'Activity': 'Insert ticket'}, {'Activity': 'NaN'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2084
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Saved 50 results to ../../../../../../evaluation_results/Helpdesk/eval_camargo_sl5/results_part_1900.pkl
# Case 2084
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 2085
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2085
# [[{'Activity': 'Schedule intervention'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2085
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2085
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 2086
# [[{'Activity': 'Take in charge ticket'}, {'Activity': 'DUPLICATE'}, {'Activity': 'Assign seriousness'}, {'Activity': 'Wait'}, {'Activity': 'DUPLICATE'}, {'Activity': 'INVALID'}, {'Activity': 'NaN'}]]
# [{'Activity': 'Assign seriousness'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2086
# [[{'Activity': 'Require upgrade'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2086
# [[{'Activity': 'DUPLICATE'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2086
# [[]]
# [{'Activity': 'Closed'}]
# []
#  57%|█████▋    | 526/916 [00:03<00:02, 149.07it/s]
# Case 2087
# [[{'Activity': 'Schedule intervention'}, {'Activity': 'Insert ticket'}, {'Activity': 'INVALID'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2087
# [[]]
# [{'Activity': 'Wait'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2087
# [[]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2087
# [[{'Activity': 'Require upgrade'}]]
# [{'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2087
# [[{'Activity': 'Assign seriousness'}]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2087
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 2088
# [[{'Activity': 'RESOLVED'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}, {'Activity': 'INVALID'}, {'Activity': 'Require upgrade'}, {'Activity': 'Closed'}, {'Activity': 'Resolve SW anomaly'}, {'Activity': 'Wait'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Insert ticket'}, {'Activity': 'DUPLICATE'}, {'Activity': 'Schedule intervention'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Create SW anomaly'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2088
# [[{'Activity': 'Wait'}, {'Activity': 'Require upgrade'}, {'Activity': 'VERIFIED'}]]
# [{'Activity': 'Create SW anomaly'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2088
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2088
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 2089
# [[{'Activity': 'Wait'}, {'Activity': 'RESOLVED'}]]
# [{'Activity': 'Assign seriousness'}, {'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2089
# [[{'Activity': 'Insert ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Require upgrade'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2089
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 2089
# [[]]
# [{'Activity': 'Closed'}]
# []
# Case 209
# [[{'Activity': 'Take in charge ticket'}]]
# [{'Activity': 'Take in charge ticket'}, {'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 209
# [[]]
# [{'Activity': 'Resolve ticket'}, {'Activity': 'Closed'}]
# []
# Case 209
# [[]]
# [{'Activity': 'Closed'}]
# []
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 8
#       4 save_every = 50
#       6 results = {}
# ----> 8 for i, (case_name, prefix_len, prefix, sampled_cets, target_cet, mean_cet) in enumerate(evaluate_seq_processing(model=model,
#       9                                                                                                                 dataset=helpdesk_test_dataset,
#      10                                                                                                                 device = torch.device("cpu"),
#      11                                                                                                                 samples_per_case=1)
#      12                                                                                                                 ):
#      13
#      14 # for i, (case_name, prefix_len, prefix, sampled_cets, target_cet, mean_cet) in enumerate(evaluate_parallel_processing(model=model,
#      15 #                                                                                                                      dataset=helpdesk_test_dataset,
#      16 #                                                                                                                      samples_per_case=1000,
#      17 #
#      18 #
#      19 #                                                                                                      processes=num_processes)):
#      20     print(case_name)
#      21     print(sampled_cets)
#
# Cell In[28], line 55, in evaluate_seq_processing(model, dataset, device, samples_per_case, random_order)
#      51 # for cats, nums, case_name in tqdm(cases, total=len(cases)):
#      52 for _, (case_name, full_case) in tqdm(enumerate(case_items), total=len(cases)):
#      53
#      54     # Get a list with the results for all cases of one case:
# ---> 55     results = _evaluate_case(case_name=case_name,
#      56                              full_case=full_case,
#      57                              concept_name_id=concept_name_id,
#      58                              min_suffix_size=dataset.encoder_decoder.min_suffix_size)
#      60     # Return the results for inserting:
#      61     for res in results:
#
# File ~/.local/share/virtualenvs/Probabilistic_Suffix_Prediction_U-ED-LSTM_-32bEAP25/lib/python3.13/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# Cell In[27], line 50, in _evaluate_case(case_name, full_case, concept_name_id, min_suffix_size)
#      47 # Iterate through window size - pref len:
#      48 for i in range(len(cats_pref[0][0])-prefix_length):
#      49     # Predictions
# ---> 50     act_probs = global_model((cats_pref_clone, nums_pref_clone))
#      51     # Index of most likely prediction
#      52     index_act = act_probs.argmax(dim=-1).item()
#
# File ~/.local/share/virtualenvs/Probabilistic_Suffix_Prediction_U-ED-LSTM_-32bEAP25/lib/python3.13/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/.local/share/virtualenvs/Probabilistic_Suffix_Prediction_U-ED-LSTM_-32bEAP25/lib/python3.13/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/Desktop/Robustness-in-suffix-prediction/src/reimplemented_comparable_approaches/camargo_LSTM_suffix_pred/notebooks/evaluation/Helpdesk/../../../joinLSTM/model.py:122, in FullShared_Join_LSTM.forward(self, input)
#     119 y = y.transpose(1, 2) # (B, T, hidden_size)
#     121 # Head LSTMs (batch_first=True); grab only last hidden states
# --> 122 _, (h_act,  _) = self.lstm_act(y) # h_act: (1, B, hidden_size)
#     123 # print(h_act.shape)
#     124 h_act  = h_act.squeeze(0) # (B, hidden_size)
#
# File ~/.local/share/virtualenvs/Probabilistic_Suffix_Prediction_U-ED-LSTM_-32bEAP25/lib/python3.13/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/.local/share/virtualenvs/Probabilistic_Suffix_Prediction_U-ED-LSTM_-32bEAP25/lib/python3.13/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/.local/share/virtualenvs/Probabilistic_Suffix_Prediction_U-ED-LSTM_-32bEAP25/lib/python3.13/site-packages/torch/nn/modules/rnn.py:1124, in LSTM.forward(self, input, hx)
#    1121         hx = self.permute_hidden(hx, sorted_indices)
#    1123 if batch_sizes is None:
# -> 1124     result = _VF.lstm(
#    1125         input,
#    1126         hx,
#    1127         self._flat_weights,  # type: ignore[arg-type]
#    1128         self.bias,
#    1129         self.num_layers,
#    1130         self.dropout,
#    1131         self.training,
#    1132         self.bidirectional,
#    1133         self.batch_first,
#    1134     )
#    1135 else:
#    1136     result = _VF.lstm(
#    1137         input,
#    1138         batch_sizes,
#    (...)   1145         self.bidirectional,
#    1146     )
#
# KeyboardInterrupt:
