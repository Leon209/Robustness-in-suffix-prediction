# %%
"""
Use of same experimental setup as for our Probabilistic Suffix Prediction.

Reimplementation for comparison: 
- Paper: Camargo, Manuel, Marlon Dumas, and Oscar González-Rojas. "Learning accurate LSTM models of business processes." International Conference on Business Process Management. Cham: Springer International Publishing, 2019.
- Github (code) from: https://github.com/AdaptiveBProcess/GenerativeLSTM/tree/master/
"""
# Out:
# '\nUse of same experimental setup as for our Probabilistic Suffix Prediction.\n\nReimplementation for comparison: \n- Paper: Camargo, Manuel, Marlon Dumas, and Oscar González-Rojas. "Learning accurate LSTM models of business processes." International Conference on Business Process Management. Cham: Springer International Publishing, 2019.\n- Github (code) from: https://github.com/AdaptiveBProcess/GenerativeLSTM/tree/master/\n'

# %% [markdown]
# # Imports

# %%
import importlib
import sys
import torch

sys.path.insert(0, '..')
sys.path.insert(0, '../..')
sys.path.insert(0, '../../..')
sys.path.insert(0, '../../../..')
sys.path.insert(0, '../../../../..')

# %% [markdown]
# # Data

# %% [markdown]
# ### Load Data Files

# %%
# Path to your pickle file (saved with torch.save)
#file_path_train = '../../../../../../encoded_data/compare_camargo/helpdesk_all_5_train.pkl'
file_path_train = '../../../../../../encoded_data/helpdesk_all_5_train.pkl'
# Load the dataset using torch.load
helpdesk_train_dataset = torch.load(file_path_train, weights_only=False)
# Check the type of the loaded dataset
print(type(helpdesk_train_dataset))

# Path to your pickle file (saved with torch.save)
#file_path_val = '../../../../../../encoded_data/compare_camargo/helpdesk_all_5_val.pkl'
file_path_val = '../../../../../../encoded_data/helpdesk_all_5_val.pkl'
# Load the dataset using torch.load
helpdesk_val_dataset = torch.load(file_path_val, weights_only=False)
# Check the type of the loaded dataset
print(type(helpdesk_val_dataset))
# Out:
# <class 'event_log_loader.new_event_log_loader.EventLogDataset'>
# <class 'event_log_loader.new_event_log_loader.EventLogDataset'>

# %% [markdown]
# ### Train Data Insights

# %%
# Helpdesk Dataset Categories, Features:
helpdesk_all_categories = helpdesk_train_dataset.all_categories

helpdesk_all_categories_cat = helpdesk_all_categories[0]
print(helpdesk_all_categories_cat)

helpdesk_all_categories_num = helpdesk_all_categories[1]
print(helpdesk_all_categories_num)

for i, cat in enumerate(helpdesk_all_categories_cat):
     print(f"Helpdesk (5) Categorical feature: {cat[0]}, Index position in categorical data list: {i}")
     print(f"Helpdesk (5) Total Amount of Category labels: {cat[1]}")

print('\n')    

for i, num in enumerate(helpdesk_all_categories_num):
     print(f"Helpdesk (5) Numerical feature: {num[0]}, Index position in categorical data list: {i}")
     print(f"Helpdesk (5) Amount Numerical: {num[1]}")
     
# Get concept_name id:
concept_name = 'Activity'
concept_name_id = [i for i, cat in enumerate(helpdesk_all_categories[0]) if cat[0] == concept_name][0]
print("ID concet name in cat list: ", concept_name_id)

# Output size
concept_name = 'Activity'
concept_name_size = [cat[1] for _, cat in enumerate(helpdesk_all_categories[0]) if cat[0] == concept_name][0]
print("ID concept name in cat list: ", concept_name_size)
    
# Id of EOS token in activity
eos_value = 'EOS'
eos_id = [v for k, v in helpdesk_all_categories[0][concept_name_id][2].items() if k == eos_value][0]
# Get EOS id of concept name list:

print("ID EOS in concept name tensor: ", eos_id)
# Out:
# [('Activity', 16, {'Assign seriousness': 1, 'Closed': 2, 'Create SW anomaly': 3, 'DUPLICATE': 4, 'EOS': 5, 'INVALID': 6, 'Insert ticket': 7, 'RESOLVED': 8, 'Require upgrade': 9, 'Resolve SW anomaly': 10, 'Resolve ticket': 11, 'Schedule intervention': 12, 'Take in charge ticket': 13, 'VERIFIED': 14, 'Wait': 15}), ('Resource', 24, {'EOS': 1, 'Value 1': 2, 'Value 10': 3, 'Value 11': 4, 'Value 12': 5, 'Value 13': 6, 'Value 14': 7, 'Value 15': 8, 'Value 16': 9, 'Value 17': 10, 'Value 18': 11, 'Value 19': 12, 'Value 2': 13, 'Value 20': 14, 'Value 21': 15, 'Value 22': 16, 'Value 3': 17, 'Value 4': 18, 'Value 5': 19, 'Value 6': 20, 'Value 7': 21, 'Value 8': 22, 'Value 9': 23}), ('Variant index', 166, {'1.0': 1, '10.0': 2, '100.0': 3, '101.0': 4, '102.0': 5, '103.0': 6, '104.0': 7, '105.0': 8, '106.0': 9, '107.0': 10, '108.0': 11, '109.0': 12, '11.0': 13, '110.0': 14, '111.0': 15, '112.0': 16, '113.0': 17, '114.0': 18, '12.0': 19, '13.0': 20, '14.0': 21, '15.0': 22, '16.0': 23, '168.0': 24, '169.0': 25, '17.0': 26, '170.0': 27, '171.0': 28, '172.0': 29, '173.0': 30, '174.0': 31, '175.0': 32, '176.0': 33, '177.0': 34, '178.0': 35, '179.0': 36, '18.0': 37, '180.0': 38, '181.0': 39, '182.0': 40, '183.0': 41, '184.0': 42, '185.0': 43, '186.0': 44, '187.0': 45, '188.0': 46, '189.0': 47, '19.0': 48, '190.0': 49, '191.0': 50, '192.0': 51, '193.0': 52, '194.0': 53, '195.0': 54, '196.0': 55, '197.0': 56, '198.0': 57, '199.0': 58, '2.0': 59, '20.0': 60, '200.0': 61, '201.0': 62, '202.0': 63, '203.0': 64, '204.0': 65, '205.0': 66, '206.0': 67, '207.0': 68, '208.0': 69, '209.0': 70, '21.0': 71, '210.0': 72, '211.0': 73, '212.0': 74, '213.0': 75, '214.0': 76, '215.0': 77, '216.0': 78, '217.0': 79, '218.0': 80, '219.0': 81, '22.0': 82, '220.0': 83, '221.0': 84, '222.0': 85, '223.0': 86, '224.0': 87, '225.0': 88, '226.0': 89, '23.0': 90, '24.0': 91, '25.0': 92, '26.0': 93, '27.0': 94, '28.0': 95, '29.0': 96, '3.0': 97, '30.0': 98, '31.0': 99, '32.0': 100, '33.0': 101, '34.0': 102, '35.0': 103, '36.0': 104, '37.0': 105, '38.0': 106, '39.0': 107, '4.0': 108, '40.0': 109, '41.0': 110, '42.0': 111, '43.0': 112, '44.0': 113, '45.0': 114, '46.0': 115, '47.0': 116, '48.0': 117, '49.0': 118, '5.0': 119, '50.0': 120, '52.0': 121, '53.0': 122, '54.0': 123, '55.0': 124, '56.0': 125, '57.0': 126, '58.0': 127, '59.0': 128, '6.0': 129, '60.0': 130, '62.0': 131, '63.0': 132, '64.0': 133, '65.0': 134, '66.0': 135, '67.0': 136, '68.0': 137, '69.0': 138, '7.0': 139, '70.0': 140, '71.0': 141, '72.0': 142, '74.0': 143, '75.0': 144, '76.0': 145, '77.0': 146, '79.0': 147, '8.0': 148, '80.0': 149, '82.0': 150, '83.0': 151, '84.0': 152, '85.0': 153, '86.0': 154, '87.0': 155, '88.0': 156, '9.0': 157, '90.0': 158, '91.0': 159, '92.0': 160, '93.0': 161, '94.0': 162, '95.0': 163, '99.0': 164, nan: 165}), ('seriousness', 3, {'EOS': 1, 'Value 1': 2}), ('customer', 358, {'EOS': 1, 'Value 1': 2, 'Value 10': 3, 'Value 100': 4, 'Value 101': 5, 'Value 102': 6, 'Value 103': 7, 'Value 104': 8, 'Value 105': 9, 'Value 106': 10, 'Value 107': 11, 'Value 108': 12, 'Value 11': 13, 'Value 110': 14, 'Value 112': 15, 'Value 113': 16, 'Value 115': 17, 'Value 116': 18, 'Value 117': 19, 'Value 118': 20, 'Value 119': 21, 'Value 12': 22, 'Value 120': 23, 'Value 121': 24, 'Value 122': 25, 'Value 123': 26, 'Value 124': 27, 'Value 125': 28, 'Value 126': 29, 'Value 127': 30, 'Value 128': 31, 'Value 129': 32, 'Value 13': 33, 'Value 130': 34, 'Value 131': 35, 'Value 132': 36, 'Value 133': 37, 'Value 134': 38, 'Value 135': 39, 'Value 136': 40, 'Value 137': 41, 'Value 138': 42, 'Value 139': 43, 'Value 14': 44, 'Value 140': 45, 'Value 141': 46, 'Value 142': 47, 'Value 143': 48, 'Value 144': 49, 'Value 145': 50, 'Value 146': 51, 'Value 147': 52, 'Value 148': 53, 'Value 149': 54, 'Value 15': 55, 'Value 150': 56, 'Value 151': 57, 'Value 152': 58, 'Value 153': 59, 'Value 154': 60, 'Value 155': 61, 'Value 156': 62, 'Value 157': 63, 'Value 158': 64, 'Value 159': 65, 'Value 16': 66, 'Value 160': 67, 'Value 161': 68, ...
# [('case_elapsed_time', 1, {}), ('event_elapsed_time', 1, {}), ('day_in_week', 1, {}), ('seconds_in_day', 1, {})]
# Helpdesk (5) Categorical feature: Activity, Index position in categorical data list: 0
# Helpdesk (5) Total Amount of Category labels: 16
# Helpdesk (5) Categorical feature: Resource, Index position in categorical data list: 1
# Helpdesk (5) Total Amount of Category labels: 24
# Helpdesk (5) Categorical feature: Variant index, Index position in categorical data list: 2
# Helpdesk (5) Total Amount of Category labels: 166
# Helpdesk (5) Categorical feature: seriousness, Index position in categorical data list: 3
# Helpdesk (5) Total Amount of Category labels: 3
# Helpdesk (5) Categorical feature: customer, Index position in categorical data list: 4
# Helpdesk (5) Total Amount of Category labels: 358
# Helpdesk (5) Categorical feature: product, Index position in categorical data list: 5
# Helpdesk (5) Total Amount of Category labels: 23
# Helpdesk (5) Categorical feature: responsible_section, Index position in categorical data list: 6
# Helpdesk (5) Total Amount of Category labels: 9
# Helpdesk (5) Categorical feature: seriousness_2, Index position in categorical data list: 7
# Helpdesk (5) Total Amount of Category labels: 6
# Helpdesk (5) Categorical feature: service_level, Index position in categorical data list: 8
# Helpdesk (5) Total Amount of Category labels: 6
# Helpdesk (5) Categorical feature: service_type, Index position in categorical data list: 9
# Helpdesk (5) Total Amount of Category labels: 6
# Helpdesk (5) Categorical feature: support_section, Index position in categorical data list: 10
# Helpdesk (5) Total Amount of Category labels: 8
# Helpdesk (5) Categorical feature: workgroup, Index position in categorical data list: 11
# Helpdesk (5) Total Amount of Category labels: 6
#
#
# Helpdesk (5) Numerical feature: case_elapsed_time, Index position in categorical data list: 0
# Helpdesk (5) Amount Numerical: 1
# Helpdesk (5) Numerical feature: event_elapsed_time, Index position in categorical data list: 1
# Helpdesk (5) Amount Numerical: 1
# Helpdesk (5) Numerical feature: day_in_week, Index position in categorical data list: 2
# Helpdesk (5) Amount Numerical: 1
# Helpdesk (5) Numerical feature: seconds_in_day, Index position in categorical data list: 3
# Helpdesk (5) Amount Numerical: 1
# ID concet name in cat list:  0
# ID concept name in cat list:  16
# ID EOS in concept name tensor:  5

# %% [markdown]
# ### Input Features for Encoder and Decoder

# %%
# Create lists with name of Model features (input)
model_feat_cat = []
model_feat_num = []
for cat in helpdesk_all_categories_cat:
    model_feat_cat.append(cat[0])
for num in helpdesk_all_categories_num:
    model_feat_num.append(num[0])
model_feat = [model_feat_cat, model_feat_num]
print("Input features encoder: ", model_feat)
# Out:
# Input features encoder:  [['Activity', 'Resource', 'Variant index', 'seriousness', 'customer', 'product', 'responsible_section', 'seriousness_2', 'service_level', 'service_type', 'support_section', 'workgroup'], ['case_elapsed_time', 'event_elapsed_time', 'day_in_week', 'seconds_in_day']]

# %% [markdown]
# # Model

# %%
import joinLSTM.model
importlib.reload(joinLSTM.model)
from joinLSTM.model import FullShared_Join_LSTM

"""
Specific model parameters from paper: 
"""

# Size hidden layer
hidden_size = 50

# Number of LSTM cells
num_layers = 1

# STANDARD: One numerical output to predict
input_size = 1

# Hans Weytjens LSTM model
model = FullShared_Join_LSTM(data_set_categories=helpdesk_all_categories,
                             hidden_size=hidden_size,
                             num_layers=num_layers,
                             model_feat=model_feat,
                             input_size=input_size,
                             output_size_act=concept_name_size)
# Out:
# Data set categories:  ([('Activity', 16, {'Assign seriousness': 1, 'Closed': 2, 'Create SW anomaly': 3, 'DUPLICATE': 4, 'EOS': 5, 'INVALID': 6, 'Insert ticket': 7, 'RESOLVED': 8, 'Require upgrade': 9, 'Resolve SW anomaly': 10, 'Resolve ticket': 11, 'Schedule intervention': 12, 'Take in charge ticket': 13, 'VERIFIED': 14, 'Wait': 15}), ('Resource', 24, {'EOS': 1, 'Value 1': 2, 'Value 10': 3, 'Value 11': 4, 'Value 12': 5, 'Value 13': 6, 'Value 14': 7, 'Value 15': 8, 'Value 16': 9, 'Value 17': 10, 'Value 18': 11, 'Value 19': 12, 'Value 2': 13, 'Value 20': 14, 'Value 21': 15, 'Value 22': 16, 'Value 3': 17, 'Value 4': 18, 'Value 5': 19, 'Value 6': 20, 'Value 7': 21, 'Value 8': 22, 'Value 9': 23}), ('Variant index', 166, {'1.0': 1, '10.0': 2, '100.0': 3, '101.0': 4, '102.0': 5, '103.0': 6, '104.0': 7, '105.0': 8, '106.0': 9, '107.0': 10, '108.0': 11, '109.0': 12, '11.0': 13, '110.0': 14, '111.0': 15, '112.0': 16, '113.0': 17, '114.0': 18, '12.0': 19, '13.0': 20, '14.0': 21, '15.0': 22, '16.0': 23, '168.0': 24, '169.0': 25, '17.0': 26, '170.0': 27, '171.0': 28, '172.0': 29, '173.0': 30, '174.0': 31, '175.0': 32, '176.0': 33, '177.0': 34, '178.0': 35, '179.0': 36, '18.0': 37, '180.0': 38, '181.0': 39, '182.0': 40, '183.0': 41, '184.0': 42, '185.0': 43, '186.0': 44, '187.0': 45, '188.0': 46, '189.0': 47, '19.0': 48, '190.0': 49, '191.0': 50, '192.0': 51, '193.0': 52, '194.0': 53, '195.0': 54, '196.0': 55, '197.0': 56, '198.0': 57, '199.0': 58, '2.0': 59, '20.0': 60, '200.0': 61, '201.0': 62, '202.0': 63, '203.0': 64, '204.0': 65, '205.0': 66, '206.0': 67, '207.0': 68, '208.0': 69, '209.0': 70, '21.0': 71, '210.0': 72, '211.0': 73, '212.0': 74, '213.0': 75, '214.0': 76, '215.0': 77, '216.0': 78, '217.0': 79, '218.0': 80, '219.0': 81, '22.0': 82, '220.0': 83, '221.0': 84, '222.0': 85, '223.0': 86, '224.0': 87, '225.0': 88, '226.0': 89, '23.0': 90, '24.0': 91, '25.0': 92, '26.0': 93, '27.0': 94, '28.0': 95, '29.0': 96, '3.0': 97, '30.0': 98, '31.0': 99, '32.0': 100, '33.0': 101, '34.0': 102, '35.0': 103, '36.0': 104, '37.0': 105, '38.0': 106, '39.0': 107, '4.0': 108, '40.0': 109, '41.0': 110, '42.0': 111, '43.0': 112, '44.0': 113, '45.0': 114, '46.0': 115, '47.0': 116, '48.0': 117, '49.0': 118, '5.0': 119, '50.0': 120, '52.0': 121, '53.0': 122, '54.0': 123, '55.0': 124, '56.0': 125, '57.0': 126, '58.0': 127, '59.0': 128, '6.0': 129, '60.0': 130, '62.0': 131, '63.0': 132, '64.0': 133, '65.0': 134, '66.0': 135, '67.0': 136, '68.0': 137, '69.0': 138, '7.0': 139, '70.0': 140, '71.0': 141, '72.0': 142, '74.0': 143, '75.0': 144, '76.0': 145, '77.0': 146, '79.0': 147, '8.0': 148, '80.0': 149, '82.0': 150, '83.0': 151, '84.0': 152, '85.0': 153, '86.0': 154, '87.0': 155, '88.0': 156, '9.0': 157, '90.0': 158, '91.0': 159, '92.0': 160, '93.0': 161, '94.0': 162, '95.0': 163, '99.0': 164, nan: 165}), ('seriousness', 3, {'EOS': 1, 'Value 1': 2}), ('customer', 358, {'EOS': 1, 'Value 1': 2, 'Value 10': 3, 'Value 100': 4, 'Value 101': 5, 'Value 102': 6, 'Value 103': 7, 'Value 104': 8, 'Value 105': 9, 'Value 106': 10, 'Value 107': 11, 'Value 108': 12, 'Value 11': 13, 'Value 110': 14, 'Value 112': 15, 'Value 113': 16, 'Value 115': 17, 'Value 116': 18, 'Value 117': 19, 'Value 118': 20, 'Value 119': 21, 'Value 12': 22, 'Value 120': 23, 'Value 121': 24, 'Value 122': 25, 'Value 123': 26, 'Value 124': 27, 'Value 125': 28, 'Value 126': 29, 'Value 127': 30, 'Value 128': 31, 'Value 129': 32, 'Value 13': 33, 'Value 130': 34, 'Value 131': 35, 'Value 132': 36, 'Value 133': 37, 'Value 134': 38, 'Value 135': 39, 'Value 136': 40, 'Value 137': 41, 'Value 138': 42, 'Value 139': 43, 'Value 14': 44, 'Value 140': 45, 'Value 141': 46, 'Value 142': 47, 'Value 143': 48, 'Value 144': 49, 'Value 145': 50, 'Value 146': 51, 'Value 147': 52, 'Value 148': 53, 'Value 149': 54, 'Value 15': 55, 'Value 150': 56, 'Value 151': 57, 'Value 152': 58, 'Value 153': 59, 'Value 154': 60, 'Value 155': 61, 'Value 156': 62, 'Value 157': 63, 'Value 158': 64, 'Value 159': 65, 'Value 16': 66, 'Value 160 ...
# Model input features:  [['Activity', 'Resource', 'Variant index', 'seriousness', 'customer', 'product', 'responsible_section', 'seriousness_2', 'service_level', 'service_type', 'support_section', 'workgroup'], ['case_elapsed_time', 'event_elapsed_time', 'day_in_week', 'seconds_in_day']]
#
#
# Embeddings:  ModuleList(
#   (0): Embedding(16, 8)
#   (1): Embedding(24, 9)
#   (2): Embedding(166, 28)
#   (3): Embedding(3, 3)
#   (4): Embedding(358, 43)
#   (5): Embedding(23, 9)
#   (6): Embedding(9, 5)
#   (7-9): 3 x Embedding(6, 4)
#   (10): Embedding(8, 5)
#   (11): Embedding(6, 4)
# )
# Total embedding feature size:  126
# Input feature size:  130
# Cells hidden size:  50
# Number of LSTM layer:  1
# /Users/leonurny/.local/share/virtualenvs/Probabilistic_Suffix_Prediction_U-ED-LSTM_-32bEAP25/lib/python3.13/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   warnings.warn(

# %% [markdown]
# # Training Configuration

# %%
import training.train
importlib.reload(training.train)
from training.train import Training

from torch.optim.lr_scheduler import ReduceLROnPlateau

from torch.utils.tensorboard import SummaryWriter

writer = SummaryWriter(comment="Full_helpdesk_camargo_act")

# device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

"""
Parameter of Probabilistic Suffix Prediction experimental design, to ensure fair comparison:
"""

# Start learning rate
learning_rate = 1e-5

# Optimizer and Scheduler
optimizer = torch.optim.Adam(params=model.parameters(), lr=learning_rate, weight_decay=0)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=4, min_lr=1e-10)

# Epochs
num_epochs = 100

# Batch of model input
batch_size = 128

# shuffle data
shuffle = True

optimize_values = {"optimizer":optimizer,
                   "scheduler": scheduler,
                   "epochs":num_epochs,
                   "mini_batches":batch_size,
                   "shuffle": shuffle}

number_tasks = len(model_feat)

trainer = Training(model=model,
                   device=device,
                   data_train=helpdesk_train_dataset,
                   data_val=helpdesk_val_dataset,
                   optimize_values=optimize_values,
                   concept_name_id=concept_name_id,
                   eos_id=eos_id,
                   writer=writer,
                   save_model_n_th_epoch=1,
                   saving_path="Helpdesk_camargo_leon.pkl")

# Train the model:
trainer.train()
# Out:
# Device:  cpu
# Optimizer:  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 1e-05
#     maximize: False
#     weight_decay: 0
# )
# Scheduler:  <torch.optim.lr_scheduler.ReduceLROnPlateau object at 0x142b4e270>
# Epochs:  100
# Mini baches:  128
# Shuffle batched dataset:  True
#   0%|          | 0/100 [00:00<?, ?it/s]
# /Users/leonurny/.local/share/virtualenvs/Probabilistic_Suffix_Prediction_U-ED-LSTM_-32bEAP25/lib/python3.13/site-packages/torch/utils/data/dataloader.py:683: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Epoch [1/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.7749
# Validation: Avg Validation Loss: 2.7705
# Validation Loss for Scheduler: 2.7705
# saving model
# Epoch [2/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.7635
# Validation: Avg Validation Loss: 2.7576
# Validation Loss for Scheduler: 2.7576
# saving model
# Epoch [3/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.7451
# Validation: Avg Validation Loss: 2.7344
# Validation Loss for Scheduler: 2.7344
# saving model
# Epoch [4/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.7099
# Validation: Avg Validation Loss: 2.6882
# Validation Loss for Scheduler: 2.6882
# saving model
# Epoch [5/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.6481
# Validation: Avg Validation Loss: 2.6203
# Validation Loss for Scheduler: 2.6203
# saving model
# Epoch [6/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.5626
# Validation: Avg Validation Loss: 2.5361
# Validation Loss for Scheduler: 2.5361
# saving model
# Epoch [7/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.4731
# Validation: Avg Validation Loss: 2.4515
# Validation Loss for Scheduler: 2.4515
# saving model
# Epoch [8/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.3934
# Validation: Avg Validation Loss: 2.3828
# Validation Loss for Scheduler: 2.3828
# saving model
# Epoch [9/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.3362
# Validation: Avg Validation Loss: 2.3373
# Validation Loss for Scheduler: 2.3373
# saving model
# Epoch [10/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.2926
# Validation: Avg Validation Loss: 2.3026
# Validation Loss for Scheduler: 2.3026
# saving model
# Epoch [11/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.2608
# Validation: Avg Validation Loss: 2.2770
# Validation Loss for Scheduler: 2.2770
# saving model
# Epoch [12/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.2393
# Validation: Avg Validation Loss: 2.2560
# Validation Loss for Scheduler: 2.2560
# saving model
# Epoch [13/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.2229
# Validation: Avg Validation Loss: 2.2430
# Validation Loss for Scheduler: 2.2430
# saving model
# Epoch [14/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.2087
# Validation: Avg Validation Loss: 2.2328
# Validation Loss for Scheduler: 2.2328
# saving model
# Epoch [15/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1977
# Validation: Avg Validation Loss: 2.2236
# Validation Loss for Scheduler: 2.2236
# saving model
# Epoch [16/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1914
# Validation: Avg Validation Loss: 2.2173
# Validation Loss for Scheduler: 2.2173
# saving model
# Epoch [17/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1832
# Validation: Avg Validation Loss: 2.2110
# Validation Loss for Scheduler: 2.2110
# saving model
# Epoch [18/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1798
# Validation: Avg Validation Loss: 2.2038
# Validation Loss for Scheduler: 2.2038
# saving model
# Epoch [19/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1717
# Validation: Avg Validation Loss: 2.2026
# Validation Loss for Scheduler: 2.2026
# saving model
# Epoch [20/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1679
# Validation: Avg Validation Loss: 2.1978
# Validation Loss for Scheduler: 2.1978
# saving model
# Epoch [21/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1639
# Validation: Avg Validation Loss: 2.1956
# Validation Loss for Scheduler: 2.1956
# saving model
# Epoch [22/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1657
# Validation: Avg Validation Loss: 2.1916
# Validation Loss for Scheduler: 2.1916
# saving model
# Epoch [23/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1608
# Validation: Avg Validation Loss: 2.1908
# Validation Loss for Scheduler: 2.1908
# saving model
# Epoch [24/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1581
# Validation: Avg Validation Loss: 2.1899
# Validation Loss for Scheduler: 2.1899
# saving model
# Epoch [25/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1566
# Validation: Avg Validation Loss: 2.1879
# Validation Loss for Scheduler: 2.1879
# saving model
# Epoch [26/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1537
# Validation: Avg Validation Loss: 2.1850
# Validation Loss for Scheduler: 2.1850
# saving model
# Epoch [27/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1558
# Validation: Avg Validation Loss: 2.1828
# Validation Loss for Scheduler: 2.1828
# saving model
# Epoch [28/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1500
# Validation: Avg Validation Loss: 2.1837
# Validation Loss for Scheduler: 2.1837
# saving model
# Epoch [29/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1526
# Validation: Avg Validation Loss: 2.1813
# Validation Loss for Scheduler: 2.1813
# saving model
# Epoch [30/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1524
# Validation: Avg Validation Loss: 2.1798
# Validation Loss for Scheduler: 2.1798
# saving model
# Epoch [31/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1463
# Validation: Avg Validation Loss: 2.1779
# Validation Loss for Scheduler: 2.1779
# saving model
# Epoch [32/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1470
# Validation: Avg Validation Loss: 2.1786
# Validation Loss for Scheduler: 2.1786
# saving model
# Epoch [33/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1468
# Validation: Avg Validation Loss: 2.1773
# Validation Loss for Scheduler: 2.1773
# saving model
# Epoch [34/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1464
# Validation: Avg Validation Loss: 2.1772
# Validation Loss for Scheduler: 2.1772
# saving model
# Epoch [35/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1468
# Validation: Avg Validation Loss: 2.1738
# Validation Loss for Scheduler: 2.1738
# saving model
# Epoch [36/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1421
# Validation: Avg Validation Loss: 2.1742
# Validation Loss for Scheduler: 2.1742
# saving model
# Epoch [37/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1429
# Validation: Avg Validation Loss: 2.1749
# Validation Loss for Scheduler: 2.1749
# saving model
# Epoch [38/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1405
# Validation: Avg Validation Loss: 2.1748
# Validation Loss for Scheduler: 2.1748
# saving model
# Epoch [39/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1421
# Validation: Avg Validation Loss: 2.1740
# Validation Loss for Scheduler: 2.1740
# saving model
# Epoch [40/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1406
# Validation: Avg Validation Loss: 2.1726
# Validation Loss for Scheduler: 2.1726
# saving model
# Epoch [41/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1409
# Validation: Avg Validation Loss: 2.1729
# Validation Loss for Scheduler: 2.1729
# saving model
# Epoch [42/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1382
# Validation: Avg Validation Loss: 2.1718
# Validation Loss for Scheduler: 2.1718
# saving model
# Epoch [43/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1393
# Validation: Avg Validation Loss: 2.1712
# Validation Loss for Scheduler: 2.1712
# saving model
# Epoch [44/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1377
# Validation: Avg Validation Loss: 2.1711
# Validation Loss for Scheduler: 2.1711
# saving model
# Epoch [45/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1397
# Validation: Avg Validation Loss: 2.1703
# Validation Loss for Scheduler: 2.1703
# saving model
# Epoch [46/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1372
# Validation: Avg Validation Loss: 2.1702
# Validation Loss for Scheduler: 2.1702
# saving model
# Epoch [47/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1391
# Validation: Avg Validation Loss: 2.1684
# Validation Loss for Scheduler: 2.1684
# saving model
# Epoch [48/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1362
# Validation: Avg Validation Loss: 2.1701
# Validation Loss for Scheduler: 2.1701
# saving model
# Epoch [49/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1358
# Validation: Avg Validation Loss: 2.1698
# Validation Loss for Scheduler: 2.1698
# saving model
# Epoch [50/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1352
# Validation: Avg Validation Loss: 2.1694
# Validation Loss for Scheduler: 2.1694
# saving model
# Epoch [51/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1344
# Validation: Avg Validation Loss: 2.1677
# Validation Loss for Scheduler: 2.1677
# saving model
# Epoch [52/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1337
# Validation: Avg Validation Loss: 2.1638
# Validation Loss for Scheduler: 2.1638
# saving model
# Epoch [53/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1297
# Validation: Avg Validation Loss: 2.1602
# Validation Loss for Scheduler: 2.1602
# saving model
# Epoch [54/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1262
# Validation: Avg Validation Loss: 2.1606
# Validation Loss for Scheduler: 2.1606
# saving model
# Epoch [55/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1248
# Validation: Avg Validation Loss: 2.1556
# Validation Loss for Scheduler: 2.1556
# saving model
# Epoch [56/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1191
# Validation: Avg Validation Loss: 2.1530
# Validation Loss for Scheduler: 2.1530
# saving model
# Epoch [57/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1150
# Validation: Avg Validation Loss: 2.1492
# Validation Loss for Scheduler: 2.1492
# saving model
# Epoch [58/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1096
# Validation: Avg Validation Loss: 2.1428
# Validation Loss for Scheduler: 2.1428
# saving model
# Epoch [59/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1052
# Validation: Avg Validation Loss: 2.1386
# Validation Loss for Scheduler: 2.1386
# saving model
# Epoch [60/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.1000
# Validation: Avg Validation Loss: 2.1317
# Validation Loss for Scheduler: 2.1317
# saving model
# Epoch [61/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0909
# Validation: Avg Validation Loss: 2.1256
# Validation Loss for Scheduler: 2.1256
# saving model
# Epoch [62/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0852
# Validation: Avg Validation Loss: 2.1199
# Validation Loss for Scheduler: 2.1199
# saving model
# Epoch [63/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0774
# Validation: Avg Validation Loss: 2.1113
# Validation Loss for Scheduler: 2.1113
# saving model
# Epoch [64/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0696
# Validation: Avg Validation Loss: 2.1045
# Validation Loss for Scheduler: 2.1045
# saving model
# Epoch [65/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0625
# Validation: Avg Validation Loss: 2.0958
# Validation Loss for Scheduler: 2.0958
# saving model
# Epoch [66/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0551
# Validation: Avg Validation Loss: 2.0933
# Validation Loss for Scheduler: 2.0933
# saving model
# Epoch [67/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0499
# Validation: Avg Validation Loss: 2.0871
# Validation Loss for Scheduler: 2.0871
# saving model
# Epoch [68/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0423
# Validation: Avg Validation Loss: 2.0812
# Validation Loss for Scheduler: 2.0812
# saving model
# Epoch [69/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0393
# Validation: Avg Validation Loss: 2.0763
# Validation Loss for Scheduler: 2.0763
# saving model
# Epoch [70/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0343
# Validation: Avg Validation Loss: 2.0730
# Validation Loss for Scheduler: 2.0730
# saving model
# Epoch [71/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0300
# Validation: Avg Validation Loss: 2.0680
# Validation Loss for Scheduler: 2.0680
# saving model
# Epoch [72/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0250
# Validation: Avg Validation Loss: 2.0648
# Validation Loss for Scheduler: 2.0648
# saving model
# Epoch [73/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0219
# Validation: Avg Validation Loss: 2.0618
# Validation Loss for Scheduler: 2.0618
# saving model
# Epoch [74/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0178
# Validation: Avg Validation Loss: 2.0583
# Validation Loss for Scheduler: 2.0583
# saving model
# Epoch [75/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0168
# Validation: Avg Validation Loss: 2.0561
# Validation Loss for Scheduler: 2.0561
# saving model
# Epoch [76/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0137
# Validation: Avg Validation Loss: 2.0523
# Validation Loss for Scheduler: 2.0523
# saving model
# Epoch [77/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0111
# Validation: Avg Validation Loss: 2.0504
# Validation Loss for Scheduler: 2.0504
# saving model
# Epoch [78/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0095
# Validation: Avg Validation Loss: 2.0486
# Validation Loss for Scheduler: 2.0486
# saving model
# Epoch [79/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0068
# Validation: Avg Validation Loss: 2.0469
# Validation Loss for Scheduler: 2.0469
# saving model
# Epoch [80/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0039
# Validation: Avg Validation Loss: 2.0440
# Validation Loss for Scheduler: 2.0440
# saving model
# Epoch [81/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0036
# Validation: Avg Validation Loss: 2.0436
# Validation Loss for Scheduler: 2.0436
# saving model
# Epoch [82/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0036
# Validation: Avg Validation Loss: 2.0425
# Validation Loss for Scheduler: 2.0425
# saving model
# Epoch [83/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 2.0027
# Validation: Avg Validation Loss: 2.0391
# Validation Loss for Scheduler: 2.0391
# saving model
# Epoch [84/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9993
# Validation: Avg Validation Loss: 2.0390
# Validation Loss for Scheduler: 2.0390
# saving model
# Epoch [85/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9989
# Validation: Avg Validation Loss: 2.0366
# Validation Loss for Scheduler: 2.0366
# saving model
# Epoch [86/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9974
# Validation: Avg Validation Loss: 2.0369
# Validation Loss for Scheduler: 2.0369
# saving model
# Epoch [87/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9961
# Validation: Avg Validation Loss: 2.0360
# Validation Loss for Scheduler: 2.0360
# saving model
# Epoch [88/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9946
# Validation: Avg Validation Loss: 2.0324
# Validation Loss for Scheduler: 2.0324
# saving model
# Epoch [89/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9933
# Validation: Avg Validation Loss: 2.0327
# Validation Loss for Scheduler: 2.0327
# saving model
# Epoch [90/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9926
# Validation: Avg Validation Loss: 2.0333
# Validation Loss for Scheduler: 2.0333
# saving model
# Epoch [91/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9915
# Validation: Avg Validation Loss: 2.0312
# Validation Loss for Scheduler: 2.0312
# saving model
# Epoch [92/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9917
# Validation: Avg Validation Loss: 2.0307
# Validation Loss for Scheduler: 2.0307
# saving model
# Epoch [93/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9912
# Validation: Avg Validation Loss: 2.0302
# Validation Loss for Scheduler: 2.0302
# saving model
# Epoch [94/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9908
# Validation: Avg Validation Loss: 2.0293
# Validation Loss for Scheduler: 2.0293
# saving model
# Epoch [95/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9910
# Validation: Avg Validation Loss: 2.0295
# Validation Loss for Scheduler: 2.0295
# saving model
# Epoch [96/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9909
# Validation: Avg Validation Loss: 2.0278
# Validation Loss for Scheduler: 2.0278
# saving model
# Epoch [97/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9886
# Validation: Avg Validation Loss: 2.0259
# Validation Loss for Scheduler: 2.0259
# saving model
# Epoch [98/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9901
# Validation: Avg Validation Loss: 2.0275
# Validation Loss for Scheduler: 2.0275
# saving model
# Epoch [99/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9893
# Validation: Avg Validation Loss: 2.0259
# Validation Loss for Scheduler: 2.0259
# saving model
# Epoch [100/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 1.9878
# Validation: Avg Validation Loss: 2.0258
# Validation Loss for Scheduler: 2.0258
# saving model
# Training complete.
# Model saved to path: Helpdesk_camargo_leon.pkl
