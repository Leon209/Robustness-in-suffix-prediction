# %%
"""
Use of same experimental setup as for our Probabilistic Suffix Prediction.

Reimplementation for comparison: 
- Paper: Weytjens, Hans, and Jochen De Weerdt. "Learning uncertainty with artificial neural networks for predictive process monitoring." Applied Soft Computing 125 (2022): 109134.
- Github (code) from: https://github.com/hansweytjens/uncertainty-remaining_time/blob/main/LSTM.ipynb
"""
# Out:
# '\nUse of same experimental setup as for our Probabilistic Suffix Prediction.\n\nReimplementation for comparison: \n- Paper: Weytjens, Hans, and Jochen De Weerdt. "Learning uncertainty with artificial neural networks for predictive process monitoring." Applied Soft Computing 125 (2022): 109134.\n- Github (code) from: https://github.com/hansweytjens/uncertainty-remaining_time/blob/main/LSTM.ipynb\n'

# %% [markdown]
# # Imports

# %%
import importlib
import sys
import torch

sys.path.insert(0, '..')
sys.path.insert(0, '../..')
sys.path.insert(0, '../../..')
sys.path.insert(0, '../../../..')
sys.path.insert(0, '../../../../..')

# %% [markdown]
# # Data

# %% [markdown]
# ### Load Data Files

# %%
# Path to your pickle file (saved with torch.save)
file_path_train = '../../../../../../encoded_data/weytjens/sepsis/Sepsis_all_5_train.pkl'
# Load the dataset using torch.load
sepsis_train_dataset = torch.load(file_path_train, weights_only=False)
# Check the type of the loaded dataset
print(type(sepsis_train_dataset))

# Path to your pickle file (saved with torch.save)
file_path_val = '../../../../../../encoded_data/weytjens/sepsis/Sepsis_all_5_val.pkl'
# Load the dataset using torch.load
sepsis_val_dataset = torch.load(file_path_val, weights_only=False)
# Check the type of the loaded dataset
print(type(sepsis_val_dataset))
# Out:
# <class 'event_log_loader.new_event_log_loader.EventLogDataset'>
# <class 'event_log_loader.new_event_log_loader.EventLogDataset'>

# %% [markdown]
# ### Train Data Insights

# %%
# Helpdesk Dataset Categories, Features:
sepsis_all_categories = sepsis_train_dataset.all_categories

sepsis_all_categories_cat = sepsis_all_categories[0]
print(sepsis_all_categories_cat)

sepsis_all_categories_num = sepsis_all_categories[1]
print(sepsis_all_categories_num)

for i, cat in enumerate(sepsis_all_categories_cat):
     print(f"sepsis (5) Categorical feature: {cat[0]}, Index position in categorical data list: {i}")
     print(f"sepsis (5) Total Amount of Category labels: {cat[1]}")

print('\n')    

for i, num in enumerate(sepsis_all_categories_num):
     print(f"sepsis (5) Numerical feature: {num[0]}, Index position in categorical data list: {i}")
     print(f"sepsis (5) Amount Numerical: {num[1]}")
     
# Get concept_name id:
# 
concept_name = 'concept:name'
concept_name_id = [i for i, cat in enumerate(sepsis_all_categories[0]) if cat[0] == concept_name][0]

print("ID concet name in cat list: ", concept_name_id)
    
# Id of EOS token in activity
eos_value = 'EOS'
eos_id = [v for k, v in sepsis_all_categories[0][concept_name_id][2].items() if k == eos_value][0]
# Get EOS id of concept name list:

print("ID EOS in concept name tensor: ", eos_id)
# Out:
# [('concept:name', 18, {'Admission IC': 1, 'Admission NC': 2, 'CRP': 3, 'EOS': 4, 'ER Registration': 5, 'ER Sepsis Triage': 6, 'ER Triage': 7, 'IV Antibiotics': 8, 'IV Liquid': 9, 'LacticAcid': 10, 'Leucocytes': 11, 'Release A': 12, 'Release B': 13, 'Release C': 14, 'Release D': 15, 'Release E': 16, 'Return ER': 17})]
# [('case_elapsed_time', 1, {})]
# sepsis (5) Categorical feature: concept:name, Index position in categorical data list: 0
# sepsis (5) Total Amount of Category labels: 18
#
#
# sepsis (5) Numerical feature: case_elapsed_time, Index position in categorical data list: 0
# sepsis (5) Amount Numerical: 1
# ID concet name in cat list:  0
# ID EOS in concept name tensor:  4

# %% [markdown]
# ### Input Features for Encoder and Decoder

# %%
# Create lists with name of Model features (input)
model_feat_cat = ['concept:name']
model_feat_num = ['case_elapsed_time']
model_feat = [model_feat_cat, model_feat_num]

print("Features model: ", model_feat)
# Out:
# Features model:  [['concept:name'], ['case_elapsed_time']]

# %% [markdown]
# # Model

# %%
import stochasticLSTM.model
importlib.reload(stochasticLSTM.model)
from stochasticLSTM.model import StochasticLSTMWeytjens

"""
Specific model parameters from paper: 
"""

# Size hidden layer
hidden_size=10

# Number of LSTM cells
num_layers=2

# One numerical output to predict
input_size=1

# Fixed Dropout probability 
p_fix=0.1

# Lambda for L2 (weight, bias, dropout) regularization: According to formula: 1/2N
regularization_term = 0.1

# Hans Weytjens LSTM model
model = StochasticLSTMWeytjens(data_set_categories=sepsis_all_categories,
                               model_feat=model_feat,
                               hidden_size=hidden_size,
                               num_layers=num_layers,
                               input_size=input_size,
                               weight_reg=regularization_term,
                               p_fix=p_fix,
                               device='cpu')
# Out:
# Data set categories:  ([('concept:name', 18, {'Admission IC': 1, 'Admission NC': 2, 'CRP': 3, 'EOS': 4, 'ER Registration': 5, 'ER Sepsis Triage': 6, 'ER Triage': 7, 'IV Antibiotics': 8, 'IV Liquid': 9, 'LacticAcid': 10, 'Leucocytes': 11, 'Release A': 12, 'Release B': 13, 'Release C': 14, 'Release D': 15, 'Release E': 16, 'Return ER': 17})], [('case_elapsed_time', 1, {})])
# Model input features:  [['concept:name'], ['case_elapsed_time']]
#
#
# Embeddings:  ModuleList(
#   (0): Embedding(18, 8)
# )
# Total embedding feature size:  8
# Input feature size:  9
# Cells hidden size:  10
# Number of LSTM layer:  2
# Dropout rate:  0.1
#
#
# Output feature list of dicts (featue name, tensor index in dataset):  {'case_elapsed_time': 0}

# %% [markdown]
# # Loss Object Creation

# %%
import loss_hans.losses
importlib.reload(loss_hans.losses)
from loss_hans.losses import Loss

loss_obj = Loss()

# %% [markdown]
# # Training Configuration

# %%
import training.train
importlib.reload(training.train)
from training.train import Training

from torch.optim.lr_scheduler import ReduceLROnPlateau

from torch.utils.tensorboard import SummaryWriter

writer = SummaryWriter(comment="Full_Sepsis_weytjens_rem_time")

# device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

"""
Parameter of Probabilistic Suffix Prediction experimental design, to ensure fair comparison:
"""

# Start learning rate
learning_rate = 1e-5

# Optimizer and Scheduler
optimizer = torch.optim.Adam(params=model.parameters(), lr=learning_rate, weight_decay=0)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=4, min_lr=1e-9)

# Epochs
num_epochs = 100

# Batch of model input
batch_size = 128

# shuffle data
shuffle = True

optimize_values = {"regularization_term":regularization_term,
                   "optimizer":optimizer,
                   "scheduler": scheduler,
                   "epochs":num_epochs,
                   "mini_batches":batch_size,
                   "shuffle": shuffle}

number_tasks = len(model_feat)

trainer = Training(model=model,
                   device=device,
                   data_train=sepsis_train_dataset,
                   data_val=sepsis_val_dataset,
                   concept_name_id=concept_name_id,
                   eos_id=eos_id,
                   loss_obj=loss_obj,
                   optimize_values=optimize_values,
                   writer=writer,
                   save_model_n_th_epoch=1,
                   saving_path="Sepsis_weytjens_rem_time_1_suffix_length5.pkl")

# Train the model:
trainer.train()
# Out:
# Device:  cpu
# Optimizer:  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 1e-05
#     maximize: False
#     weight_decay: 0
# )
# Scheduler:  <torch.optim.lr_scheduler.ReduceLROnPlateau object at 0x14b433230>
# Epochs:  100
# Mini baches:  128
# Shuffle batched dataset:  True
#   0%|          | 0/100 [00:00<?, ?it/s]
# /Users/leonurny/.local/share/virtualenvs/Probabilistic_Suffix_Prediction_U-ED-LSTM_-32bEAP25/lib/python3.13/site-packages/torch/utils/data/dataloader.py:683: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Epoch [1/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 27.9150
# Validation: Avg Standard Validation Loss: 15.1358
# Validation: Avg Attenuated Validation Loss: 14.9754
# Validation Loss for Scheduler: 15.1358
# saving model
# Epoch [2/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 27.9222
# Validation: Avg Standard Validation Loss: 15.0979
# Validation: Avg Attenuated Validation Loss: 14.8440
# Validation Loss for Scheduler: 15.0979
# saving model
# Epoch [3/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 27.7427
# Validation: Avg Standard Validation Loss: 15.2165
# Validation: Avg Attenuated Validation Loss: 14.9387
# Validation Loss for Scheduler: 15.2165
# saving model
# Epoch [4/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 27.9218
# Validation: Avg Standard Validation Loss: 16.2676
# Validation: Avg Attenuated Validation Loss: 15.9369
# Validation Loss for Scheduler: 16.2676
# saving model
# Epoch [5/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 27.7788
# Validation: Avg Standard Validation Loss: 14.7617
# Validation: Avg Attenuated Validation Loss: 14.3443
# Validation Loss for Scheduler: 14.7617
# saving model
# Epoch [6/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 27.8717
# Validation: Avg Standard Validation Loss: 15.1012
# Validation: Avg Attenuated Validation Loss: 14.6565
# Validation Loss for Scheduler: 15.1012
# saving model
# Epoch [7/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 27.5886
# Validation: Avg Standard Validation Loss: 15.5464
# Validation: Avg Attenuated Validation Loss: 15.0190
# Validation Loss for Scheduler: 15.5464
# saving model
# Epoch [8/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 27.4211
# Validation: Avg Standard Validation Loss: 15.0061
# Validation: Avg Attenuated Validation Loss: 14.4412
# Validation Loss for Scheduler: 15.0061
# saving model
# Epoch [9/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 27.4584
# Validation: Avg Standard Validation Loss: 15.1040
# Validation: Avg Attenuated Validation Loss: 14.5097
# Validation Loss for Scheduler: 15.1040
# saving model
# Epoch [10/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 27.5402
# Validation: Avg Standard Validation Loss: 14.5320
# Validation: Avg Attenuated Validation Loss: 13.9232
# Validation Loss for Scheduler: 14.5320
# saving model
# Epoch [11/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 27.4143
# Validation: Avg Standard Validation Loss: 17.0308
# Validation: Avg Attenuated Validation Loss: 16.2301
# Validation Loss for Scheduler: 17.0308
# saving model
# Epoch [12/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 27.3064
# Validation: Avg Standard Validation Loss: 14.9757
# Validation: Avg Attenuated Validation Loss: 14.2722
# Validation Loss for Scheduler: 14.9757
# saving model
# Epoch [13/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 27.0743
# Validation: Avg Standard Validation Loss: 16.4453
# Validation: Avg Attenuated Validation Loss: 15.5763
# Validation Loss for Scheduler: 16.4453
# saving model
# Epoch [14/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 27.2735
# Validation: Avg Standard Validation Loss: 14.6659
# Validation: Avg Attenuated Validation Loss: 13.9257
# Validation Loss for Scheduler: 14.6659
# saving model
# Epoch [15/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 26.8264
# Validation: Avg Standard Validation Loss: 14.8930
# Validation: Avg Attenuated Validation Loss: 14.0819
# Validation Loss for Scheduler: 14.8930
# saving model
# Epoch [16/100], Learning Rate: 1.0000000000000002e-06
# Training: Avg Attenuated Training Loss: 26.9881
# Validation: Avg Standard Validation Loss: 15.6930
# Validation: Avg Attenuated Validation Loss: 14.7752
# Validation Loss for Scheduler: 15.6930
# saving model
# Epoch [17/100], Learning Rate: 1.0000000000000002e-06
# Training: Avg Attenuated Training Loss: 27.0720
# Validation: Avg Standard Validation Loss: 14.4192
# Validation: Avg Attenuated Validation Loss: 13.6199
# Validation Loss for Scheduler: 14.4192
# saving model
# Epoch [18/100], Learning Rate: 1.0000000000000002e-06
# Training: Avg Attenuated Training Loss: 27.0056
# Validation: Avg Standard Validation Loss: 15.8467
# Validation: Avg Attenuated Validation Loss: 14.8825
# Validation Loss for Scheduler: 15.8467
# saving model
# Epoch [19/100], Learning Rate: 1.0000000000000002e-06
# Training: Avg Attenuated Training Loss: 26.9082
# Validation: Avg Standard Validation Loss: 14.3284
# Validation: Avg Attenuated Validation Loss: 13.4827
# Validation Loss for Scheduler: 14.3284
# saving model
# Epoch [20/100], Learning Rate: 1.0000000000000002e-06
# Training: Avg Attenuated Training Loss: 27.5051
# Validation: Avg Standard Validation Loss: 14.7659
# Validation: Avg Attenuated Validation Loss: 13.9734
# Validation Loss for Scheduler: 14.7659
# saving model
# Epoch [21/100], Learning Rate: 1.0000000000000002e-06
# Training: Avg Attenuated Training Loss: 26.7465
# Validation: Avg Standard Validation Loss: 15.1855
# Validation: Avg Attenuated Validation Loss: 14.2901
# Validation Loss for Scheduler: 15.1855
# saving model
# Epoch [22/100], Learning Rate: 1.0000000000000002e-06
# Training: Avg Attenuated Training Loss: 27.1093
# Validation: Avg Standard Validation Loss: 17.8281
# Validation: Avg Attenuated Validation Loss: 16.7652
# Validation Loss for Scheduler: 17.8281
# saving model
# Epoch [23/100], Learning Rate: 1.0000000000000002e-06
# Training: Avg Attenuated Training Loss: 27.0080
# Validation: Avg Standard Validation Loss: 14.9774
# Validation: Avg Attenuated Validation Loss: 14.1124
# Validation Loss for Scheduler: 14.9774
# saving model
# Epoch [24/100], Learning Rate: 1.0000000000000002e-06
# Training: Avg Attenuated Training Loss: 26.9722
# Validation: Avg Standard Validation Loss: 14.5508
# Validation: Avg Attenuated Validation Loss: 13.6132
# Validation Loss for Scheduler: 14.5508
# saving model
# Epoch [25/100], Learning Rate: 1.0000000000000002e-07
# Training: Avg Attenuated Training Loss: 26.8240
# Validation: Avg Standard Validation Loss: 15.6289
# Validation: Avg Attenuated Validation Loss: 14.6932
# Validation Loss for Scheduler: 15.6289
# saving model
# Epoch [26/100], Learning Rate: 1.0000000000000002e-07
# Training: Avg Attenuated Training Loss: 27.0244
# Validation: Avg Standard Validation Loss: 15.0229
# Validation: Avg Attenuated Validation Loss: 14.1256
# Validation Loss for Scheduler: 15.0229
# saving model
# Epoch [27/100], Learning Rate: 1.0000000000000002e-07
# Training: Avg Attenuated Training Loss: 27.0308
# Validation: Avg Standard Validation Loss: 14.7681
# Validation: Avg Attenuated Validation Loss: 13.8867
# Validation Loss for Scheduler: 14.7681
# saving model
# Epoch [28/100], Learning Rate: 1.0000000000000002e-07
# Training: Avg Attenuated Training Loss: 26.9326
# Validation: Avg Standard Validation Loss: 15.2133
# Validation: Avg Attenuated Validation Loss: 14.3120
# Validation Loss for Scheduler: 15.2133
# saving model
# Epoch [29/100], Learning Rate: 1.0000000000000002e-07
# Training: Avg Attenuated Training Loss: 26.7816
# Validation: Avg Standard Validation Loss: 15.1901
# Validation: Avg Attenuated Validation Loss: 14.1918
# Validation Loss for Scheduler: 15.1901
# saving model
# Epoch [30/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.1991
# Validation: Avg Standard Validation Loss: 14.5488
# Validation: Avg Attenuated Validation Loss: 13.6979
# Validation Loss for Scheduler: 14.5488
# saving model
# Epoch [31/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.8296
# Validation: Avg Standard Validation Loss: 14.8497
# Validation: Avg Attenuated Validation Loss: 14.0031
# Validation Loss for Scheduler: 14.8497
# saving model
# Epoch [32/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.7910
# Validation: Avg Standard Validation Loss: 15.9267
# Validation: Avg Attenuated Validation Loss: 14.9550
# Validation Loss for Scheduler: 15.9267
# saving model
# Epoch [33/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.1811
# Validation: Avg Standard Validation Loss: 14.8385
# Validation: Avg Attenuated Validation Loss: 13.9897
# Validation Loss for Scheduler: 14.8385
# saving model
# Epoch [34/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8590
# Validation: Avg Standard Validation Loss: 15.2555
# Validation: Avg Attenuated Validation Loss: 14.3271
# Validation Loss for Scheduler: 15.2555
# saving model
# Epoch [35/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.1064
# Validation: Avg Standard Validation Loss: 15.1865
# Validation: Avg Attenuated Validation Loss: 14.2815
# Validation Loss for Scheduler: 15.1865
# saving model
# Epoch [36/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.9199
# Validation: Avg Standard Validation Loss: 14.8298
# Validation: Avg Attenuated Validation Loss: 13.9552
# Validation Loss for Scheduler: 14.8298
# saving model
# Epoch [37/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.9085
# Validation: Avg Standard Validation Loss: 13.9093
# Validation: Avg Attenuated Validation Loss: 13.1280
# Validation Loss for Scheduler: 13.9093
# saving model
# Epoch [38/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.0055
# Validation: Avg Standard Validation Loss: 14.5923
# Validation: Avg Attenuated Validation Loss: 13.7937
# Validation Loss for Scheduler: 14.5923
# saving model
# Epoch [39/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.0440
# Validation: Avg Standard Validation Loss: 14.9668
# Validation: Avg Attenuated Validation Loss: 14.0795
# Validation Loss for Scheduler: 14.9668
# saving model
# Epoch [40/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.3288
# Validation: Avg Standard Validation Loss: 14.8421
# Validation: Avg Attenuated Validation Loss: 13.9810
# Validation Loss for Scheduler: 14.8421
# saving model
# Epoch [41/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.1572
# Validation: Avg Standard Validation Loss: 15.9340
# Validation: Avg Attenuated Validation Loss: 14.8849
# Validation Loss for Scheduler: 15.9340
# saving model
# Epoch [42/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.7892
# Validation: Avg Standard Validation Loss: 14.8061
# Validation: Avg Attenuated Validation Loss: 13.8860
# Validation Loss for Scheduler: 14.8061
# saving model
# Epoch [43/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.3493
# Validation: Avg Standard Validation Loss: 15.8757
# Validation: Avg Attenuated Validation Loss: 14.8861
# Validation Loss for Scheduler: 15.8757
# saving model
# Epoch [44/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.9900
# Validation: Avg Standard Validation Loss: 14.5523
# Validation: Avg Attenuated Validation Loss: 13.6517
# Validation Loss for Scheduler: 14.5523
# saving model
# Epoch [45/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.9830
# Validation: Avg Standard Validation Loss: 14.8750
# Validation: Avg Attenuated Validation Loss: 13.9718
# Validation Loss for Scheduler: 14.8750
# saving model
# Epoch [46/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.2527
# Validation: Avg Standard Validation Loss: 14.7525
# Validation: Avg Attenuated Validation Loss: 13.8876
# Validation Loss for Scheduler: 14.7525
# saving model
# Epoch [47/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.9225
# Validation: Avg Standard Validation Loss: 15.3477
# Validation: Avg Attenuated Validation Loss: 14.4566
# Validation Loss for Scheduler: 15.3477
# saving model
# Epoch [48/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.1154
# Validation: Avg Standard Validation Loss: 14.6877
# Validation: Avg Attenuated Validation Loss: 13.8330
# Validation Loss for Scheduler: 14.6877
# saving model
# Epoch [49/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.9284
# Validation: Avg Standard Validation Loss: 14.1795
# Validation: Avg Attenuated Validation Loss: 13.3130
# Validation Loss for Scheduler: 14.1795
# saving model
# Epoch [50/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.0640
# Validation: Avg Standard Validation Loss: 16.2321
# Validation: Avg Attenuated Validation Loss: 15.2004
# Validation Loss for Scheduler: 16.2321
# saving model
# Epoch [51/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.9844
# Validation: Avg Standard Validation Loss: 14.5677
# Validation: Avg Attenuated Validation Loss: 13.6803
# Validation Loss for Scheduler: 14.5677
# saving model
# Epoch [52/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.0188
# Validation: Avg Standard Validation Loss: 16.0041
# Validation: Avg Attenuated Validation Loss: 15.0383
# Validation Loss for Scheduler: 16.0041
# saving model
# Epoch [53/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8852
# Validation: Avg Standard Validation Loss: 15.5507
# Validation: Avg Attenuated Validation Loss: 14.5798
# Validation Loss for Scheduler: 15.5507
# saving model
# Epoch [54/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.8057
# Validation: Avg Standard Validation Loss: 15.0452
# Validation: Avg Attenuated Validation Loss: 14.1267
# Validation Loss for Scheduler: 15.0452
# saving model
# Epoch [55/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.2592
# Validation: Avg Standard Validation Loss: 14.7618
# Validation: Avg Attenuated Validation Loss: 13.8845
# Validation Loss for Scheduler: 14.7618
# saving model
# Epoch [56/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.0090
# Validation: Avg Standard Validation Loss: 14.6766
# Validation: Avg Attenuated Validation Loss: 13.7868
# Validation Loss for Scheduler: 14.6766
# saving model
# Epoch [57/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.9797
# Validation: Avg Standard Validation Loss: 15.3309
# Validation: Avg Attenuated Validation Loss: 14.4243
# Validation Loss for Scheduler: 15.3309
# saving model
# Epoch [58/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.0238
# Validation: Avg Standard Validation Loss: 14.5346
# Validation: Avg Attenuated Validation Loss: 13.5999
# Validation Loss for Scheduler: 14.5346
# saving model
# Epoch [59/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.9416
# Validation: Avg Standard Validation Loss: 15.1319
# Validation: Avg Attenuated Validation Loss: 14.2253
# Validation Loss for Scheduler: 15.1319
# saving model
# Epoch [60/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8951
# Validation: Avg Standard Validation Loss: 15.8606
# Validation: Avg Attenuated Validation Loss: 14.9194
# Validation Loss for Scheduler: 15.8606
# saving model
# Epoch [61/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8451
# Validation: Avg Standard Validation Loss: 14.5178
# Validation: Avg Attenuated Validation Loss: 13.6570
# Validation Loss for Scheduler: 14.5178
# saving model
# Epoch [62/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.9132
# Validation: Avg Standard Validation Loss: 16.5366
# Validation: Avg Attenuated Validation Loss: 15.5104
# Validation Loss for Scheduler: 16.5366
# saving model
# Epoch [63/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.7754
# Validation: Avg Standard Validation Loss: 14.8113
# Validation: Avg Attenuated Validation Loss: 13.9372
# Validation Loss for Scheduler: 14.8113
# saving model
# Epoch [64/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.7937
# Validation: Avg Standard Validation Loss: 15.7547
# Validation: Avg Attenuated Validation Loss: 14.7801
# Validation Loss for Scheduler: 15.7547
# saving model
# Epoch [65/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.9239
# Validation: Avg Standard Validation Loss: 14.8586
# Validation: Avg Attenuated Validation Loss: 13.9959
# Validation Loss for Scheduler: 14.8586
# saving model
# Epoch [66/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.1765
# Validation: Avg Standard Validation Loss: 16.0233
# Validation: Avg Attenuated Validation Loss: 15.0475
# Validation Loss for Scheduler: 16.0233
# saving model
# Epoch [67/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.9790
# Validation: Avg Standard Validation Loss: 16.5830
# Validation: Avg Attenuated Validation Loss: 15.5988
# Validation Loss for Scheduler: 16.5830
# saving model
# Epoch [68/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.0471
# Validation: Avg Standard Validation Loss: 14.5373
# Validation: Avg Attenuated Validation Loss: 13.7191
# Validation Loss for Scheduler: 14.5373
# saving model
# Epoch [69/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.0498
# Validation: Avg Standard Validation Loss: 14.6577
# Validation: Avg Attenuated Validation Loss: 13.8312
# Validation Loss for Scheduler: 14.6577
# saving model
# Epoch [70/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8608
# Validation: Avg Standard Validation Loss: 14.7748
# Validation: Avg Attenuated Validation Loss: 13.8443
# Validation Loss for Scheduler: 14.7748
# saving model
# Epoch [71/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.1126
# Validation: Avg Standard Validation Loss: 16.3711
# Validation: Avg Attenuated Validation Loss: 15.4184
# Validation Loss for Scheduler: 16.3711
# saving model
# Epoch [72/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8592
# Validation: Avg Standard Validation Loss: 15.4043
# Validation: Avg Attenuated Validation Loss: 14.4504
# Validation Loss for Scheduler: 15.4043
# saving model
# Epoch [73/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8586
# Validation: Avg Standard Validation Loss: 15.8809
# Validation: Avg Attenuated Validation Loss: 14.8994
# Validation Loss for Scheduler: 15.8809
# saving model
# Epoch [74/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.9778
# Validation: Avg Standard Validation Loss: 15.2494
# Validation: Avg Attenuated Validation Loss: 14.3474
# Validation Loss for Scheduler: 15.2494
# saving model
# Epoch [75/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.9866
# Validation: Avg Standard Validation Loss: 15.0917
# Validation: Avg Attenuated Validation Loss: 14.1605
# Validation Loss for Scheduler: 15.0917
# saving model
# Epoch [76/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.1821
# Validation: Avg Standard Validation Loss: 16.3852
# Validation: Avg Attenuated Validation Loss: 15.4492
# Validation Loss for Scheduler: 16.3852
# saving model
# Epoch [77/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8947
# Validation: Avg Standard Validation Loss: 14.5905
# Validation: Avg Attenuated Validation Loss: 13.7056
# Validation Loss for Scheduler: 14.5905
# saving model
# Epoch [78/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.6336
# Validation: Avg Standard Validation Loss: 14.5777
# Validation: Avg Attenuated Validation Loss: 13.7049
# Validation Loss for Scheduler: 14.5777
# saving model
# Epoch [79/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.9214
# Validation: Avg Standard Validation Loss: 15.3271
# Validation: Avg Attenuated Validation Loss: 14.4267
# Validation Loss for Scheduler: 15.3271
# saving model
# Epoch [80/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.1152
# Validation: Avg Standard Validation Loss: 14.5644
# Validation: Avg Attenuated Validation Loss: 13.6842
# Validation Loss for Scheduler: 14.5644
# saving model
# Epoch [81/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.3461
# Validation: Avg Standard Validation Loss: 14.4249
# Validation: Avg Attenuated Validation Loss: 13.5361
# Validation Loss for Scheduler: 14.4249
# saving model
# Epoch [82/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.2223
# Validation: Avg Standard Validation Loss: 14.3736
# Validation: Avg Attenuated Validation Loss: 13.4982
# Validation Loss for Scheduler: 14.3736
# saving model
# Epoch [83/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.9965
# Validation: Avg Standard Validation Loss: 15.3061
# Validation: Avg Attenuated Validation Loss: 14.4039
# Validation Loss for Scheduler: 15.3061
# saving model
# Epoch [84/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.4542
# Validation: Avg Standard Validation Loss: 14.9812
# Validation: Avg Attenuated Validation Loss: 14.0970
# Validation Loss for Scheduler: 14.9812
# saving model
# Epoch [85/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.1683
# Validation: Avg Standard Validation Loss: 15.1190
# Validation: Avg Attenuated Validation Loss: 14.2115
# Validation Loss for Scheduler: 15.1190
# saving model
# Epoch [86/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.5711
# Validation: Avg Standard Validation Loss: 14.6698
# Validation: Avg Attenuated Validation Loss: 13.7881
# Validation Loss for Scheduler: 14.6698
# saving model
# Epoch [87/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8560
# Validation: Avg Standard Validation Loss: 14.7838
# Validation: Avg Attenuated Validation Loss: 13.8896
# Validation Loss for Scheduler: 14.7838
# saving model
# Epoch [88/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.0772
# Validation: Avg Standard Validation Loss: 15.2670
# Validation: Avg Attenuated Validation Loss: 14.3115
# Validation Loss for Scheduler: 15.2670
# saving model
# Epoch [89/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.9003
# Validation: Avg Standard Validation Loss: 14.6433
# Validation: Avg Attenuated Validation Loss: 13.8166
# Validation Loss for Scheduler: 14.6433
# saving model
# Epoch [90/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.1818
# Validation: Avg Standard Validation Loss: 14.8371
# Validation: Avg Attenuated Validation Loss: 13.9543
# Validation Loss for Scheduler: 14.8371
# saving model
# Epoch [91/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8795
# Validation: Avg Standard Validation Loss: 14.9968
# Validation: Avg Attenuated Validation Loss: 14.0722
# Validation Loss for Scheduler: 14.9968
# saving model
# Epoch [92/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8611
# Validation: Avg Standard Validation Loss: 15.0625
# Validation: Avg Attenuated Validation Loss: 14.1813
# Validation Loss for Scheduler: 15.0625
# saving model
# Epoch [93/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.3184
# Validation: Avg Standard Validation Loss: 15.5105
# Validation: Avg Attenuated Validation Loss: 14.5892
# Validation Loss for Scheduler: 15.5105
# saving model
# Epoch [94/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.3692
# Validation: Avg Standard Validation Loss: 15.7508
# Validation: Avg Attenuated Validation Loss: 14.8049
# Validation Loss for Scheduler: 15.7508
# saving model
# Epoch [95/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8651
# Validation: Avg Standard Validation Loss: 15.5738
# Validation: Avg Attenuated Validation Loss: 14.6576
# Validation Loss for Scheduler: 15.5738
# saving model
# Epoch [96/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.2704
# Validation: Avg Standard Validation Loss: 15.2098
# Validation: Avg Attenuated Validation Loss: 14.3690
# Validation Loss for Scheduler: 15.2098
# saving model
# Epoch [97/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 26.8366
# Validation: Avg Standard Validation Loss: 15.4235
# Validation: Avg Attenuated Validation Loss: 14.5391
# Validation Loss for Scheduler: 15.4235
# saving model
# Epoch [98/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.0145
# Validation: Avg Standard Validation Loss: 15.5067
# Validation: Avg Attenuated Validation Loss: 14.5928
# Validation Loss for Scheduler: 15.5067
# saving model
# Epoch [99/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.0349
# Validation: Avg Standard Validation Loss: 15.4154
# Validation: Avg Attenuated Validation Loss: 14.4508
# Validation Loss for Scheduler: 15.4154
# saving model
# Epoch [100/100], Learning Rate: 1.0000000000000004e-08
# Training: Avg Attenuated Training Loss: 27.1203
# Validation: Avg Standard Validation Loss: 14.9827
# Validation: Avg Attenuated Validation Loss: 14.0868
# Validation Loss for Scheduler: 14.9827
# saving model
# Training complete.
# Model saved to path: Sepsis_weytjens_rem_time_1_suffix_length5.pkl
