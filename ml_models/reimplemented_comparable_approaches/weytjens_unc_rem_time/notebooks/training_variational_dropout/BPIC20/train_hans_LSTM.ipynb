# %%
"""
Use of same experimental setup as for our Probabilistic Suffix Prediction.

Reimplementation for comparison: 
- Paper: Weytjens, Hans, and Jochen De Weerdt. "Learning uncertainty with artificial neural networks for predictive process monitoring." Applied Soft Computing 125 (2022): 109134.
- Github (code) from: https://github.com/hansweytjens/uncertainty-remaining_time/blob/main/LSTM.ipynb
"""
# Out:
# '\nUse of same experimental setup as for our Probabilistic Suffix Prediction.\n\nReimplementation for comparison: \n- Paper: Weytjens, Hans, and Jochen De Weerdt. "Learning uncertainty with artificial neural networks for predictive process monitoring." Applied Soft Computing 125 (2022): 109134.\n- Github (code) from: https://github.com/hansweytjens/uncertainty-remaining_time/blob/main/LSTM.ipynb\n'

# %% [markdown]
# # Imports

# %%
import importlib
import sys
import torch

sys.path.insert(0, '..')
sys.path.insert(0, '../..')
sys.path.insert(0, '../../..')
sys.path.insert(0, '../../../..')
sys.path.insert(0, '../../../../..')

# %% [markdown]
# # Data

# %% [markdown]
# ### Load Data Files

# %%
# Path to your pickle file (saved with torch.save)
file_path_train = '../../../../../../encoded_data/weytjens/BPIC20/BPIC_2020_all_5_train.pkl'
# Load the dataset using torch.load
bpic17_train_dataset = torch.load(file_path_train, weights_only=False)
# Check the type of the loaded dataset
print(type(bpic17_train_dataset))

# Path to your pickle file (saved with torch.save)
file_path_val = '../../../../../../encoded_data/weytjens/BPIC20/BPIC_2020_all_5_val.pkl'
# Load the dataset using torch.load
bpic17_val_dataset = torch.load(file_path_val, weights_only=False)
# Check the type of the loaded dataset
print(type(bpic17_val_dataset))
# Out:
# <class 'event_log_loader.new_event_log_loader.EventLogDataset'>
# <class 'event_log_loader.new_event_log_loader.EventLogDataset'>

# %% [markdown]
# ### Train Data Insights

# %%
# BPIC 17 Dataset Categories, Features:
bpic17_all_categories = bpic17_train_dataset.all_categories

bpic17_all_categories_cat = bpic17_all_categories[0]
print(bpic17_all_categories_cat)

bpic17_all_categories_num = bpic17_all_categories[1]
print(bpic17_all_categories_num)

for i, cat in enumerate(bpic17_all_categories_cat):
     print(f"bpic17 (5) Categorical feature: {cat[0]}, Index position in categorical data list: {i}")
     print(f"bpic17 (5) Total Amount of Category labels: {cat[1]}")

print('\n')    

for i, num in enumerate(bpic17_all_categories_num):
     print(f"bpic17 (5) Numerical feature: {num[0]}, Index position in categorical data list: {i}")
     print(f"bpic17 (5) Amount Numerical: {num[1]}")
     
# Get concept_name id:
# 
concept_name = 'concept:name'
concept_name_id = [i for i, cat in enumerate(bpic17_all_categories[0]) if cat[0] == concept_name][0]

print("ID concet name in cat list: ", concept_name_id)
    
# Id of EOS token in activity
eos_value = 'EOS'
eos_id = [v for k, v in bpic17_all_categories[0][concept_name_id][2].items() if k == eos_value][0]
# Get EOS id of concept name list:

print("ID EOS in concept name tensor: ", eos_id)
# Out:
# [('concept:name', 18, {'Declaration APPROVED by ADMINISTRATION': 1, 'Declaration APPROVED by BUDGET OWNER': 2, 'Declaration APPROVED by PRE_APPROVER': 3, 'Declaration FINAL_APPROVED by SUPERVISOR': 4, 'Declaration FOR_APPROVAL by PRE_APPROVER': 5, 'Declaration FOR_APPROVAL by SUPERVISOR': 6, 'Declaration REJECTED by ADMINISTRATION': 7, 'Declaration REJECTED by BUDGET OWNER': 8, 'Declaration REJECTED by EMPLOYEE': 9, 'Declaration REJECTED by MISSING': 10, 'Declaration REJECTED by PRE_APPROVER': 11, 'Declaration REJECTED by SUPERVISOR': 12, 'Declaration SAVED by EMPLOYEE': 13, 'Declaration SUBMITTED by EMPLOYEE': 14, 'EOS': 15, 'Payment Handled': 16, 'Request Payment': 17})]
# [('case_elapsed_time', 1, {})]
# bpic17 (5) Categorical feature: concept:name, Index position in categorical data list: 0
# bpic17 (5) Total Amount of Category labels: 18
#
#
# bpic17 (5) Numerical feature: case_elapsed_time, Index position in categorical data list: 0
# bpic17 (5) Amount Numerical: 1
# ID concet name in cat list:  0
# ID EOS in concept name tensor:  15

# %% [markdown]
# ### Input Features for Encoder and Decoder

# %%
# Create lists with name of Model features (input)
model_feat_cat = ['concept:name']
model_feat_num = ['case_elapsed_time']
model_feat = [model_feat_cat, model_feat_num]

print("Features model: ", model_feat)
# Out:
# Features model:  [['concept:name'], ['case_elapsed_time']]

# %% [markdown]
# # Model

# %%
import stochasticLSTM.model
importlib.reload(stochasticLSTM.model)
from stochasticLSTM.model import StochasticLSTMWeytjens

"""
Specific model parameters from paper: 
"""

# Size hidden layer
hidden_size=10

# Number of LSTM cells
num_layers=2

# One numerical output to predict
input_size=1

# Fixed Dropout probability 
p_fix=0.1

# Lambda for L2 (weight, bias, dropout) regularization: According to formula: 1/2N
regularization_term = 0.1

# Hans Weytjens LSTM model
model = StochasticLSTMWeytjens(data_set_categories=bpic17_all_categories,
                               model_feat=model_feat,
                               hidden_size=hidden_size,
                               num_layers=num_layers,
                               input_size=input_size,
                               weight_reg=regularization_term,
                               p_fix=p_fix,
                               device='cpu')
# Out:
# Data set categories:  ([('concept:name', 18, {'Declaration APPROVED by ADMINISTRATION': 1, 'Declaration APPROVED by BUDGET OWNER': 2, 'Declaration APPROVED by PRE_APPROVER': 3, 'Declaration FINAL_APPROVED by SUPERVISOR': 4, 'Declaration FOR_APPROVAL by PRE_APPROVER': 5, 'Declaration FOR_APPROVAL by SUPERVISOR': 6, 'Declaration REJECTED by ADMINISTRATION': 7, 'Declaration REJECTED by BUDGET OWNER': 8, 'Declaration REJECTED by EMPLOYEE': 9, 'Declaration REJECTED by MISSING': 10, 'Declaration REJECTED by PRE_APPROVER': 11, 'Declaration REJECTED by SUPERVISOR': 12, 'Declaration SAVED by EMPLOYEE': 13, 'Declaration SUBMITTED by EMPLOYEE': 14, 'EOS': 15, 'Payment Handled': 16, 'Request Payment': 17})], [('case_elapsed_time', 1, {})])
# Model input features:  [['concept:name'], ['case_elapsed_time']]
#
#
# Embeddings:  ModuleList(
#   (0): Embedding(18, 8)
# )
# Total embedding feature size:  8
# Input feature size:  9
# Cells hidden size:  10
# Number of LSTM layer:  2
# Dropout rate:  0.1
#
#
# Output feature list of dicts (featue name, tensor index in dataset):  {'case_elapsed_time': 0}

# %% [markdown]
# # Loss Object Creation

# %%
import loss_hans.losses
importlib.reload(loss_hans.losses)
from loss_hans.losses import Loss

loss_obj = Loss()

# %% [markdown]
# # Training Configuration

# %%
import training.train
importlib.reload(training.train)
from training.train import Training

from torch.optim.lr_scheduler import ReduceLROnPlateau

from torch.utils.tensorboard import SummaryWriter

writer = SummaryWriter(comment="Full_BPIC20_weytjens_rem_time")

# device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

"""
Parameter of Probabilistic Suffix Prediction experimental design, to ensure fair comparison:
"""

# Start learning rate
learning_rate = 1e-6

# Optimizer and Scheduler
optimizer = torch.optim.Adam(params=model.parameters(), lr=learning_rate, weight_decay=0)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=2, min_lr=1e-10)

# Epochs
num_epochs = 100

# Batch size
batch_size = 256

# shuffle data
shuffle = True

optimize_values = {"regularization_term":regularization_term,
                   "optimizer":optimizer,
                   "scheduler": scheduler,
                   "epochs":num_epochs,
                   "mini_batches":batch_size,
                   "shuffle": shuffle}

number_tasks = len(model_feat)

trainer = Training(model=model,
                   device=device,
                   data_train=bpic17_train_dataset,
                   data_val=bpic17_val_dataset,
                   concept_name_id=concept_name_id,
                   eos_id=eos_id,
                   loss_obj=loss_obj,
                   optimize_values=optimize_values,
                   writer=writer,
                   save_model_n_th_epoch=1,
                   saving_path="BPIC20_weytjens.pkl")

# Train the model:
trainer.train()
# Out:
# Device:  cpu
# Optimizer:  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 1e-06
#     maximize: False
#     weight_decay: 0
# )
# Scheduler:  <torch.optim.lr_scheduler.ReduceLROnPlateau object at 0x15f2df230>
# Epochs:  100
# Mini baches:  256
# Shuffle batched dataset:  True
#   0%|          | 0/100 [00:00<?, ?it/s]
# /Users/leonurny/.local/share/virtualenvs/Probabilistic_Suffix_Prediction_U-ED-LSTM_-32bEAP25/lib/python3.13/site-packages/torch/utils/data/dataloader.py:683: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Epoch [1/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 15.0565
# Validation: Avg Standard Validation Loss: 5.8640
# Validation: Avg Attenuated Validation Loss: 8.0288
# Validation Loss for Scheduler: 5.8640
# saving model
# Epoch [2/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 15.0392
# Validation: Avg Standard Validation Loss: 5.9747
# Validation: Avg Attenuated Validation Loss: 8.1682
# Validation Loss for Scheduler: 5.9747
# saving model
# Epoch [3/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 15.0426
# Validation: Avg Standard Validation Loss: 6.1618
# Validation: Avg Attenuated Validation Loss: 8.5095
# Validation Loss for Scheduler: 6.1618
# saving model
# Epoch [4/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 15.0869
# Validation: Avg Standard Validation Loss: 6.2762
# Validation: Avg Attenuated Validation Loss: 8.6234
# Validation Loss for Scheduler: 6.2762
# saving model
# Epoch [5/100], Learning Rate: 1e-07
# Training: Avg Attenuated Training Loss: 15.0505
# Validation: Avg Standard Validation Loss: 5.8825
# Validation: Avg Attenuated Validation Loss: 8.0144
# Validation Loss for Scheduler: 5.8825
# saving model
# Epoch [6/100], Learning Rate: 1e-07
# Training: Avg Attenuated Training Loss: 15.0418
# Validation: Avg Standard Validation Loss: 5.9548
# Validation: Avg Attenuated Validation Loss: 8.1959
# Validation Loss for Scheduler: 5.9548
# saving model
# Epoch [7/100], Learning Rate: 1e-07
# Training: Avg Attenuated Training Loss: 15.0406
# Validation: Avg Standard Validation Loss: 6.0031
# Validation: Avg Attenuated Validation Loss: 8.2313
# Validation Loss for Scheduler: 6.0031
# saving model
# Epoch [8/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0353
# Validation: Avg Standard Validation Loss: 5.9654
# Validation: Avg Attenuated Validation Loss: 8.1493
# Validation Loss for Scheduler: 5.9654
# saving model
# Epoch [9/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0486
# Validation: Avg Standard Validation Loss: 5.9181
# Validation: Avg Attenuated Validation Loss: 8.0883
# Validation Loss for Scheduler: 5.9181
# saving model
# Epoch [10/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0422
# Validation: Avg Standard Validation Loss: 5.9599
# Validation: Avg Attenuated Validation Loss: 8.1718
# Validation Loss for Scheduler: 5.9599
# saving model
# Epoch [11/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0396
# Validation: Avg Standard Validation Loss: 5.9292
# Validation: Avg Attenuated Validation Loss: 8.1778
# Validation Loss for Scheduler: 5.9292
# saving model
# Epoch [12/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0409
# Validation: Avg Standard Validation Loss: 6.0100
# Validation: Avg Attenuated Validation Loss: 8.2354
# Validation Loss for Scheduler: 6.0100
# saving model
# Epoch [13/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0844
# Validation: Avg Standard Validation Loss: 5.9826
# Validation: Avg Attenuated Validation Loss: 8.1784
# Validation Loss for Scheduler: 5.9826
# saving model
# Epoch [14/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0483
# Validation: Avg Standard Validation Loss: 5.9211
# Validation: Avg Attenuated Validation Loss: 8.1395
# Validation Loss for Scheduler: 5.9211
# saving model
# Epoch [15/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0719
# Validation: Avg Standard Validation Loss: 6.0847
# Validation: Avg Attenuated Validation Loss: 8.3231
# Validation Loss for Scheduler: 6.0847
# saving model
# Epoch [16/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0370
# Validation: Avg Standard Validation Loss: 5.9711
# Validation: Avg Attenuated Validation Loss: 8.1422
# Validation Loss for Scheduler: 5.9711
# saving model
# Epoch [17/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0821
# Validation: Avg Standard Validation Loss: 6.0603
# Validation: Avg Attenuated Validation Loss: 8.3221
# Validation Loss for Scheduler: 6.0603
# saving model
# Epoch [18/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0420
# Validation: Avg Standard Validation Loss: 5.9822
# Validation: Avg Attenuated Validation Loss: 8.2090
# Validation Loss for Scheduler: 5.9822
# saving model
# Epoch [19/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0566
# Validation: Avg Standard Validation Loss: 5.9431
# Validation: Avg Attenuated Validation Loss: 8.0864
# Validation Loss for Scheduler: 5.9431
# saving model
# Epoch [20/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0490
# Validation: Avg Standard Validation Loss: 6.1673
# Validation: Avg Attenuated Validation Loss: 8.4664
# Validation Loss for Scheduler: 6.1673
# saving model
# Epoch [21/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0430
# Validation: Avg Standard Validation Loss: 6.1404
# Validation: Avg Attenuated Validation Loss: 8.4578
# Validation Loss for Scheduler: 6.1404
# saving model
# Epoch [22/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0396
# Validation: Avg Standard Validation Loss: 5.9705
# Validation: Avg Attenuated Validation Loss: 8.1638
# Validation Loss for Scheduler: 5.9705
# saving model
# Epoch [23/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0515
# Validation: Avg Standard Validation Loss: 5.9648
# Validation: Avg Attenuated Validation Loss: 8.1383
# Validation Loss for Scheduler: 5.9648
# saving model
# Epoch [24/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0339
# Validation: Avg Standard Validation Loss: 5.9258
# Validation: Avg Attenuated Validation Loss: 8.1626
# Validation Loss for Scheduler: 5.9258
# saving model
# Epoch [25/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0343
# Validation: Avg Standard Validation Loss: 6.0352
# Validation: Avg Attenuated Validation Loss: 8.2842
# Validation Loss for Scheduler: 6.0352
# saving model
# Epoch [26/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0821
# Validation: Avg Standard Validation Loss: 5.9956
# Validation: Avg Attenuated Validation Loss: 8.2249
# Validation Loss for Scheduler: 5.9956
# saving model
# Epoch [27/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0599
# Validation: Avg Standard Validation Loss: 6.4433
# Validation: Avg Attenuated Validation Loss: 8.8629
# Validation Loss for Scheduler: 6.4433
# saving model
# Epoch [28/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0767
# Validation: Avg Standard Validation Loss: 5.9670
# Validation: Avg Attenuated Validation Loss: 8.1795
# Validation Loss for Scheduler: 5.9670
# saving model
# Epoch [29/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0581
# Validation: Avg Standard Validation Loss: 5.9317
# Validation: Avg Attenuated Validation Loss: 8.1103
# Validation Loss for Scheduler: 5.9317
# saving model
# Epoch [30/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0496
# Validation: Avg Standard Validation Loss: 5.9237
# Validation: Avg Attenuated Validation Loss: 8.1234
# Validation Loss for Scheduler: 5.9237
# saving model
# Epoch [31/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0327
# Validation: Avg Standard Validation Loss: 5.9502
# Validation: Avg Attenuated Validation Loss: 8.1769
# Validation Loss for Scheduler: 5.9502
# saving model
# Epoch [32/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0505
# Validation: Avg Standard Validation Loss: 5.9440
# Validation: Avg Attenuated Validation Loss: 8.1616
# Validation Loss for Scheduler: 5.9440
# saving model
# Epoch [33/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0400
# Validation: Avg Standard Validation Loss: 5.9875
# Validation: Avg Attenuated Validation Loss: 8.1987
# Validation Loss for Scheduler: 5.9875
# saving model
# Epoch [34/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0287
# Validation: Avg Standard Validation Loss: 6.0136
# Validation: Avg Attenuated Validation Loss: 8.2525
# Validation Loss for Scheduler: 6.0136
# saving model
# Epoch [35/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0468
# Validation: Avg Standard Validation Loss: 5.9895
# Validation: Avg Attenuated Validation Loss: 8.2129
# Validation Loss for Scheduler: 5.9895
# saving model
# Epoch [36/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0564
# Validation: Avg Standard Validation Loss: 5.9053
# Validation: Avg Attenuated Validation Loss: 8.0644
# Validation Loss for Scheduler: 5.9053
# saving model
# Epoch [37/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0423
# Validation: Avg Standard Validation Loss: 6.0186
# Validation: Avg Attenuated Validation Loss: 8.2290
# Validation Loss for Scheduler: 6.0186
# saving model
# Epoch [38/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0532
# Validation: Avg Standard Validation Loss: 6.1409
# Validation: Avg Attenuated Validation Loss: 8.4593
# Validation Loss for Scheduler: 6.1409
# saving model
# Epoch [39/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0695
# Validation: Avg Standard Validation Loss: 6.1945
# Validation: Avg Attenuated Validation Loss: 8.4856
# Validation Loss for Scheduler: 6.1945
# saving model
# Epoch [40/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0528
# Validation: Avg Standard Validation Loss: 5.9998
# Validation: Avg Attenuated Validation Loss: 8.2353
# Validation Loss for Scheduler: 5.9998
# saving model
# Epoch [41/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0299
# Validation: Avg Standard Validation Loss: 5.9848
# Validation: Avg Attenuated Validation Loss: 8.1671
# Validation Loss for Scheduler: 5.9848
# saving model
# Epoch [42/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0501
# Validation: Avg Standard Validation Loss: 6.0220
# Validation: Avg Attenuated Validation Loss: 8.2439
# Validation Loss for Scheduler: 6.0220
# saving model
# Epoch [43/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0445
# Validation: Avg Standard Validation Loss: 5.9448
# Validation: Avg Attenuated Validation Loss: 8.1340
# Validation Loss for Scheduler: 5.9448
# saving model
# Epoch [44/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0585
# Validation: Avg Standard Validation Loss: 5.9199
# Validation: Avg Attenuated Validation Loss: 8.0907
# Validation Loss for Scheduler: 5.9199
# saving model
# Epoch [45/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0617
# Validation: Avg Standard Validation Loss: 5.8854
# Validation: Avg Attenuated Validation Loss: 8.0818
# Validation Loss for Scheduler: 5.8854
# saving model
# Epoch [46/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0923
# Validation: Avg Standard Validation Loss: 5.9361
# Validation: Avg Attenuated Validation Loss: 8.1261
# Validation Loss for Scheduler: 5.9361
# saving model
# Epoch [47/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.1197
# Validation: Avg Standard Validation Loss: 5.9449
# Validation: Avg Attenuated Validation Loss: 8.1462
# Validation Loss for Scheduler: 5.9449
# saving model
# Epoch [48/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0487
# Validation: Avg Standard Validation Loss: 5.9650
# Validation: Avg Attenuated Validation Loss: 8.1538
# Validation Loss for Scheduler: 5.9650
# saving model
# Epoch [49/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0542
# Validation: Avg Standard Validation Loss: 6.0890
# Validation: Avg Attenuated Validation Loss: 8.3677
# Validation Loss for Scheduler: 6.0890
# saving model
# Epoch [50/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0967
# Validation: Avg Standard Validation Loss: 5.9602
# Validation: Avg Attenuated Validation Loss: 8.1720
# Validation Loss for Scheduler: 5.9602
# saving model
# Epoch [51/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0336
# Validation: Avg Standard Validation Loss: 5.9606
# Validation: Avg Attenuated Validation Loss: 8.2079
# Validation Loss for Scheduler: 5.9606
# saving model
# Epoch [52/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0474
# Validation: Avg Standard Validation Loss: 5.9652
# Validation: Avg Attenuated Validation Loss: 8.1960
# Validation Loss for Scheduler: 5.9652
# saving model
# Epoch [53/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0731
# Validation: Avg Standard Validation Loss: 5.9598
# Validation: Avg Attenuated Validation Loss: 8.1062
# Validation Loss for Scheduler: 5.9598
# saving model
# Epoch [54/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0421
# Validation: Avg Standard Validation Loss: 6.0263
# Validation: Avg Attenuated Validation Loss: 8.2498
# Validation Loss for Scheduler: 6.0263
# saving model
# Epoch [55/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0487
# Validation: Avg Standard Validation Loss: 6.1244
# Validation: Avg Attenuated Validation Loss: 8.3754
# Validation Loss for Scheduler: 6.1244
# saving model
# Epoch [56/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0667
# Validation: Avg Standard Validation Loss: 5.9479
# Validation: Avg Attenuated Validation Loss: 8.1393
# Validation Loss for Scheduler: 5.9479
# saving model
# Epoch [57/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0413
# Validation: Avg Standard Validation Loss: 5.9447
# Validation: Avg Attenuated Validation Loss: 8.1723
# Validation Loss for Scheduler: 5.9447
# saving model
# Epoch [58/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0571
# Validation: Avg Standard Validation Loss: 5.9763
# Validation: Avg Attenuated Validation Loss: 8.2073
# Validation Loss for Scheduler: 5.9763
# saving model
# Epoch [59/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0457
# Validation: Avg Standard Validation Loss: 5.9216
# Validation: Avg Attenuated Validation Loss: 8.0926
# Validation Loss for Scheduler: 5.9216
# saving model
# Epoch [60/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0508
# Validation: Avg Standard Validation Loss: 5.9542
# Validation: Avg Attenuated Validation Loss: 8.1821
# Validation Loss for Scheduler: 5.9542
# saving model
# Epoch [61/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0581
# Validation: Avg Standard Validation Loss: 6.0555
# Validation: Avg Attenuated Validation Loss: 8.2983
# Validation Loss for Scheduler: 6.0555
# saving model
# Epoch [62/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0415
# Validation: Avg Standard Validation Loss: 5.9375
# Validation: Avg Attenuated Validation Loss: 8.0928
# Validation Loss for Scheduler: 5.9375
# saving model
# Epoch [63/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0437
# Validation: Avg Standard Validation Loss: 5.9246
# Validation: Avg Attenuated Validation Loss: 8.1090
# Validation Loss for Scheduler: 5.9246
# saving model
# Epoch [64/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0709
# Validation: Avg Standard Validation Loss: 5.8831
# Validation: Avg Attenuated Validation Loss: 8.0169
# Validation Loss for Scheduler: 5.8831
# saving model
# Epoch [65/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0364
# Validation: Avg Standard Validation Loss: 6.1776
# Validation: Avg Attenuated Validation Loss: 8.4677
# Validation Loss for Scheduler: 6.1776
# saving model
# Epoch [66/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0387
# Validation: Avg Standard Validation Loss: 5.9222
# Validation: Avg Attenuated Validation Loss: 8.1056
# Validation Loss for Scheduler: 5.9222
# saving model
# Epoch [67/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0507
# Validation: Avg Standard Validation Loss: 5.9646
# Validation: Avg Attenuated Validation Loss: 8.1429
# Validation Loss for Scheduler: 5.9646
# saving model
# Epoch [68/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0501
# Validation: Avg Standard Validation Loss: 5.9507
# Validation: Avg Attenuated Validation Loss: 8.1439
# Validation Loss for Scheduler: 5.9507
# saving model
# Epoch [69/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0963
# Validation: Avg Standard Validation Loss: 5.9616
# Validation: Avg Attenuated Validation Loss: 8.1867
# Validation Loss for Scheduler: 5.9616
# saving model
# Epoch [70/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0467
# Validation: Avg Standard Validation Loss: 5.9284
# Validation: Avg Attenuated Validation Loss: 8.1465
# Validation Loss for Scheduler: 5.9284
# saving model
# Epoch [71/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0332
# Validation: Avg Standard Validation Loss: 6.0055
# Validation: Avg Attenuated Validation Loss: 8.2363
# Validation Loss for Scheduler: 6.0055
# saving model
# Epoch [72/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0622
# Validation: Avg Standard Validation Loss: 5.9704
# Validation: Avg Attenuated Validation Loss: 8.2060
# Validation Loss for Scheduler: 5.9704
# saving model
# Epoch [73/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0522
# Validation: Avg Standard Validation Loss: 6.0047
# Validation: Avg Attenuated Validation Loss: 8.2286
# Validation Loss for Scheduler: 6.0047
# saving model
# Epoch [74/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0506
# Validation: Avg Standard Validation Loss: 5.9252
# Validation: Avg Attenuated Validation Loss: 8.0567
# Validation Loss for Scheduler: 5.9252
# saving model
# Epoch [75/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0508
# Validation: Avg Standard Validation Loss: 5.9913
# Validation: Avg Attenuated Validation Loss: 8.2228
# Validation Loss for Scheduler: 5.9913
# saving model
# Epoch [76/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.1139
# Validation: Avg Standard Validation Loss: 6.0242
# Validation: Avg Attenuated Validation Loss: 8.2614
# Validation Loss for Scheduler: 6.0242
# saving model
# Epoch [77/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0505
# Validation: Avg Standard Validation Loss: 5.9813
# Validation: Avg Attenuated Validation Loss: 8.2278
# Validation Loss for Scheduler: 5.9813
# saving model
# Epoch [78/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.1170
# Validation: Avg Standard Validation Loss: 5.9863
# Validation: Avg Attenuated Validation Loss: 8.1768
# Validation Loss for Scheduler: 5.9863
# saving model
# Epoch [79/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0459
# Validation: Avg Standard Validation Loss: 6.1892
# Validation: Avg Attenuated Validation Loss: 8.5381
# Validation Loss for Scheduler: 6.1892
# saving model
# Epoch [80/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.1546
# Validation: Avg Standard Validation Loss: 6.0286
# Validation: Avg Attenuated Validation Loss: 8.2736
# Validation Loss for Scheduler: 6.0286
# saving model
# Epoch [81/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0553
# Validation: Avg Standard Validation Loss: 5.9646
# Validation: Avg Attenuated Validation Loss: 8.1565
# Validation Loss for Scheduler: 5.9646
# saving model
# Epoch [82/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0396
# Validation: Avg Standard Validation Loss: 5.9237
# Validation: Avg Attenuated Validation Loss: 8.1061
# Validation Loss for Scheduler: 5.9237
# saving model
# Epoch [83/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0397
# Validation: Avg Standard Validation Loss: 5.9052
# Validation: Avg Attenuated Validation Loss: 8.0949
# Validation Loss for Scheduler: 5.9052
# saving model
# Epoch [84/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0470
# Validation: Avg Standard Validation Loss: 5.9201
# Validation: Avg Attenuated Validation Loss: 8.0753
# Validation Loss for Scheduler: 5.9201
# saving model
# Epoch [85/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0540
# Validation: Avg Standard Validation Loss: 6.0210
# Validation: Avg Attenuated Validation Loss: 8.2582
# Validation Loss for Scheduler: 6.0210
# saving model
# Epoch [86/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0383
# Validation: Avg Standard Validation Loss: 5.9361
# Validation: Avg Attenuated Validation Loss: 8.1380
# Validation Loss for Scheduler: 5.9361
# saving model
# Epoch [87/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0498
# Validation: Avg Standard Validation Loss: 5.9376
# Validation: Avg Attenuated Validation Loss: 8.1526
# Validation Loss for Scheduler: 5.9376
# saving model
# Epoch [88/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0488
# Validation: Avg Standard Validation Loss: 5.9546
# Validation: Avg Attenuated Validation Loss: 8.1861
# Validation Loss for Scheduler: 5.9546
# saving model
# Epoch [89/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0427
# Validation: Avg Standard Validation Loss: 5.9708
# Validation: Avg Attenuated Validation Loss: 8.1478
# Validation Loss for Scheduler: 5.9708
# saving model
# Epoch [90/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0505
# Validation: Avg Standard Validation Loss: 5.9635
# Validation: Avg Attenuated Validation Loss: 8.1859
# Validation Loss for Scheduler: 5.9635
# saving model
# Epoch [91/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.1013
# Validation: Avg Standard Validation Loss: 5.9140
# Validation: Avg Attenuated Validation Loss: 8.1191
# Validation Loss for Scheduler: 5.9140
# saving model
# Epoch [92/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.1183
# Validation: Avg Standard Validation Loss: 5.9247
# Validation: Avg Attenuated Validation Loss: 8.1123
# Validation Loss for Scheduler: 5.9247
# saving model
# Epoch [93/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.1025
# Validation: Avg Standard Validation Loss: 5.9079
# Validation: Avg Attenuated Validation Loss: 8.0722
# Validation Loss for Scheduler: 5.9079
# saving model
# Epoch [94/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0547
# Validation: Avg Standard Validation Loss: 5.9487
# Validation: Avg Attenuated Validation Loss: 8.1357
# Validation Loss for Scheduler: 5.9487
# saving model
# Epoch [95/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0431
# Validation: Avg Standard Validation Loss: 5.9361
# Validation: Avg Attenuated Validation Loss: 8.1392
# Validation Loss for Scheduler: 5.9361
# saving model
# Epoch [96/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0610
# Validation: Avg Standard Validation Loss: 6.2270
# Validation: Avg Attenuated Validation Loss: 8.5576
# Validation Loss for Scheduler: 6.2270
# saving model
# Epoch [97/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0344
# Validation: Avg Standard Validation Loss: 5.9948
# Validation: Avg Attenuated Validation Loss: 8.2353
# Validation Loss for Scheduler: 5.9948
# saving model
# Epoch [98/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0491
# Validation: Avg Standard Validation Loss: 5.9054
# Validation: Avg Attenuated Validation Loss: 8.0656
# Validation Loss for Scheduler: 5.9054
# saving model
# Epoch [99/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0496
# Validation: Avg Standard Validation Loss: 5.9032
# Validation: Avg Attenuated Validation Loss: 8.1384
# Validation Loss for Scheduler: 5.9032
# saving model
# Epoch [100/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 15.0645
# Validation: Avg Standard Validation Loss: 6.0824
# Validation: Avg Attenuated Validation Loss: 8.3275
# Validation Loss for Scheduler: 6.0824
# saving model
# Training complete.
# Model saved to path: BPIC20_weytjens.pkl
