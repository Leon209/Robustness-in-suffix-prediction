# %%
"""
Use of same experimental setup as for our Probabilistic Suffix Prediction.

Reimplementation for comparison: 
- Paper: Weytjens, Hans, and Jochen De Weerdt. "Learning uncertainty with artificial neural networks for predictive process monitoring." Applied Soft Computing 125 (2022): 109134.
- Github (code) from: https://github.com/hansweytjens/uncertainty-remaining_time/blob/main/LSTM.ipynb
"""
# Out:
# '\nUse of same experimental setup as for our Probabilistic Suffix Prediction.\n\nReimplementation for comparison: \n- Paper: Weytjens, Hans, and Jochen De Weerdt. "Learning uncertainty with artificial neural networks for predictive process monitoring." Applied Soft Computing 125 (2022): 109134.\n- Github (code) from: https://github.com/hansweytjens/uncertainty-remaining_time/blob/main/LSTM.ipynb\n'

# %% [markdown]
# # Imports

# %%
import importlib
import sys
import torch

sys.path.insert(0, '..')
sys.path.insert(0, '../..')
sys.path.insert(0, '../../..')
sys.path.insert(0, '../../../..')
sys.path.insert(0, '../../../../..')

# %% [markdown]
# # Data

# %% [markdown]
# ### Load Data Files

# %%
# Path to your pickle file (saved with torch.save)
file_path_train = '../../../../../../encoded_data/weytjens/helpdesk/helpdesk_all_5_train.pkl'
# Load the dataset using torch.load
helpdesk_train_dataset = torch.load(file_path_train, weights_only=False)
# Check the type of the loaded dataset
print(type(helpdesk_train_dataset))

# Path to your pickle file (saved with torch.save)
file_path_val = '../../../../../../encoded_data/weytjens/helpdesk/helpdesk_all_5_val.pkl'
# Load the dataset using torch.load
helpdesk_val_dataset = torch.load(file_path_val, weights_only=False)
# Check the type of the loaded dataset
print(type(helpdesk_val_dataset))
# Out:
# <class 'event_log_loader.new_event_log_loader.EventLogDataset'>
# <class 'event_log_loader.new_event_log_loader.EventLogDataset'>

# %% [markdown]
# ### Train Data Insights

# %%
# Helpdesk Dataset Categories, Features:
helpdesk_all_categories = helpdesk_train_dataset.all_categories

helpdesk_all_categories_cat = helpdesk_all_categories[0]
print(helpdesk_all_categories_cat)

helpdesk_all_categories_num = helpdesk_all_categories[1]
print(helpdesk_all_categories_num)

for i, cat in enumerate(helpdesk_all_categories_cat):
     print(f"Helpdesk (5) Categorical feature: {cat[0]}, Index position in categorical data list: {i}")
     print(f"Helpdesk (5) Total Amount of Category labels: {cat[1]}")

print('\n')    

for i, num in enumerate(helpdesk_all_categories_num):
     print(f"Helpdesk (5) Numerical feature: {num[0]}, Index position in categorical data list: {i}")
     print(f"Helpdesk (5) Amount Numerical: {num[1]}")
     
# Get concept_name id:
# 
concept_name = 'Activity'
concept_name_id = [i for i, cat in enumerate(helpdesk_all_categories[0]) if cat[0] == concept_name][0]

print("ID concet name in cat list: ", concept_name_id)
    
# Id of EOS token in activity
eos_value = 'EOS'
eos_id = [v for k, v in helpdesk_all_categories[0][concept_name_id][2].items() if k == eos_value][0]
# Get EOS id of concept name list:

print("ID EOS in concept name tensor: ", eos_id)
# Out:
# [('Activity', 16, {'Assign seriousness': 1, 'Closed': 2, 'Create SW anomaly': 3, 'DUPLICATE': 4, 'EOS': 5, 'INVALID': 6, 'Insert ticket': 7, 'RESOLVED': 8, 'Require upgrade': 9, 'Resolve SW anomaly': 10, 'Resolve ticket': 11, 'Schedule intervention': 12, 'Take in charge ticket': 13, 'VERIFIED': 14, 'Wait': 15})]
# [('case_elapsed_time', 1, {})]
# Helpdesk (5) Categorical feature: Activity, Index position in categorical data list: 0
# Helpdesk (5) Total Amount of Category labels: 16
#
#
# Helpdesk (5) Numerical feature: case_elapsed_time, Index position in categorical data list: 0
# Helpdesk (5) Amount Numerical: 1
# ID concet name in cat list:  0
# ID EOS in concept name tensor:  5

# %% [markdown]
# ### Input Features for Encoder and Decoder

# %%
# Create lists with name of Model features (input)
model_feat_cat = ['Activity']
model_feat_num = ['case_elapsed_time']
model_feat = [model_feat_cat, model_feat_num]

print("Features model: ", model_feat)
# Out:
# Features model:  [['Activity'], ['case_elapsed_time']]

# %% [markdown]
# # Model

# %%
import stochasticLSTM.model
importlib.reload(stochasticLSTM.model)
from stochasticLSTM.model import StochasticLSTMWeytjens

"""
Specific model parameters from paper: 
"""

# Size hidden layer
hidden_size=10

# Number of LSTM cells
num_layers=2

# One numerical output to predict
input_size=1

# Fixed Dropout probability 
p_fix=0.1

# Lambda for L2 (weight, bias, dropout) regularization: According to formula: 1/2N
regularization_term = 0.1

# Hans Weytjens LSTM model
model = StochasticLSTMWeytjens(data_set_categories=helpdesk_all_categories,
                               model_feat=model_feat,
                               hidden_size=hidden_size,
                               num_layers=num_layers,
                               input_size=input_size,
                               weight_reg=regularization_term,
                               p_fix=p_fix,
                               device='cpu')
# Out:
# Data set categories:  ([('Activity', 16, {'Assign seriousness': 1, 'Closed': 2, 'Create SW anomaly': 3, 'DUPLICATE': 4, 'EOS': 5, 'INVALID': 6, 'Insert ticket': 7, 'RESOLVED': 8, 'Require upgrade': 9, 'Resolve SW anomaly': 10, 'Resolve ticket': 11, 'Schedule intervention': 12, 'Take in charge ticket': 13, 'VERIFIED': 14, 'Wait': 15})], [('case_elapsed_time', 1, {})])
# Model input features:  [['Activity'], ['case_elapsed_time']]
#
#
# Embeddings:  ModuleList(
#   (0): Embedding(16, 8)
# )
# Total embedding feature size:  8
# Input feature size:  9
# Cells hidden size:  10
# Number of LSTM layer:  2
# Dropout rate:  0.1
#
#
# Output feature list of dicts (featue name, tensor index in dataset):  {'case_elapsed_time': 0}

# %% [markdown]
# # Loss Object Creation

# %%
import loss_hans.losses
importlib.reload(loss_hans.losses)
from loss_hans.losses import Loss

loss_obj = Loss()

# %% [markdown]
# # Training Configuration

# %%
import training.train
importlib.reload(training.train)
from training.train import Training

from torch.optim.lr_scheduler import ReduceLROnPlateau

from torch.utils.tensorboard import SummaryWriter

writer = SummaryWriter(comment="Full_helpdesk_weytjens_rem_time")

# device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

"""
Parameter of Probabilistic Suffix Prediction experimental design, to ensure fair comparison:
"""

# Start learning rate
learning_rate = 1e-5

# Optimizer and Scheduler
optimizer = torch.optim.Adam(params=model.parameters(), lr=learning_rate, weight_decay=0)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=4, min_lr=1e-10)

# Epochs
num_epochs = 100

# Batch of model input
batch_size = 128

# shuffle data
shuffle = True

optimize_values = {"optimizer":optimizer,
                   "scheduler": scheduler,
                   "epochs":num_epochs,
                   "mini_batches":batch_size,
                   "shuffle": shuffle}

number_tasks = len(model_feat)

trainer = Training(model=model,
                   device=device,
                   data_train=helpdesk_train_dataset,
                   data_val=helpdesk_val_dataset,
                   concept_name_id=concept_name_id,
                   eos_id=eos_id,
                   loss_obj=loss_obj,
                   optimize_values=optimize_values,
                   writer=writer,
                   save_model_n_th_epoch=1,
                   saving_path="Helpdesk_weytjens.pkl")

# Train the model:
trainer.train()
# Out:
# Device:  cpu
# Optimizer:  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 1e-05
#     maximize: False
#     weight_decay: 0
# )
# Scheduler:  <torch.optim.lr_scheduler.ReduceLROnPlateau object at 0x1440e7380>
# Epochs:  100
# Mini baches:  128
# Shuffle batched dataset:  True
#   0%|          | 0/100 [00:00<?, ?it/s]
# /Users/leonurny/.local/share/virtualenvs/Probabilistic_Suffix_Prediction_U-ED-LSTM_-32bEAP25/lib/python3.13/site-packages/torch/utils/data/dataloader.py:683: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Epoch [1/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 18.5661
# Validation: Avg Standard Validation Loss: 4.8556
# Validation: Avg Attenuated Validation Loss: 6.7057
# Validation Loss for Scheduler: 4.8556
# saving model
# Epoch [2/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 18.5350
# Validation: Avg Standard Validation Loss: 4.8448
# Validation: Avg Attenuated Validation Loss: 6.6740
# Validation Loss for Scheduler: 4.8448
# saving model
# Epoch [3/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 18.5292
# Validation: Avg Standard Validation Loss: 4.8257
# Validation: Avg Attenuated Validation Loss: 6.6270
# Validation Loss for Scheduler: 4.8257
# saving model
# Epoch [4/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 18.4902
# Validation: Avg Standard Validation Loss: 4.8143
# Validation: Avg Attenuated Validation Loss: 6.5912
# Validation Loss for Scheduler: 4.8143
# saving model
# Epoch [5/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 18.4379
# Validation: Avg Standard Validation Loss: 4.8002
# Validation: Avg Attenuated Validation Loss: 6.5532
# Validation Loss for Scheduler: 4.8002
# saving model
# Epoch [6/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 18.4117
# Validation: Avg Standard Validation Loss: 4.7861
# Validation: Avg Attenuated Validation Loss: 6.5135
# Validation Loss for Scheduler: 4.7861
# saving model
# Epoch [7/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 18.3601
# Validation: Avg Standard Validation Loss: 4.7730
# Validation: Avg Attenuated Validation Loss: 6.4762
# Validation Loss for Scheduler: 4.7730
# saving model
# Epoch [8/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 18.3226
# Validation: Avg Standard Validation Loss: 4.7525
# Validation: Avg Attenuated Validation Loss: 6.4269
# Validation Loss for Scheduler: 4.7525
# saving model
# Epoch [9/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 18.2837
# Validation: Avg Standard Validation Loss: 4.7362
# Validation: Avg Attenuated Validation Loss: 6.3841
# Validation Loss for Scheduler: 4.7362
# saving model
# Epoch [10/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 18.2621
# Validation: Avg Standard Validation Loss: 4.7170
# Validation: Avg Attenuated Validation Loss: 6.3390
# Validation Loss for Scheduler: 4.7170
# saving model
# Epoch [11/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 18.2393
# Validation: Avg Standard Validation Loss: 4.6996
# Validation: Avg Attenuated Validation Loss: 6.2932
# Validation Loss for Scheduler: 4.6996
# saving model
# Epoch [12/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 18.1834
# Validation: Avg Standard Validation Loss: 4.6823
# Validation: Avg Attenuated Validation Loss: 6.2488
# Validation Loss for Scheduler: 4.6823
# saving model
# Epoch [13/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 18.1618
# Validation: Avg Standard Validation Loss: 4.6632
# Validation: Avg Attenuated Validation Loss: 6.1987
# Validation Loss for Scheduler: 4.6632
# saving model
# Epoch [14/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 18.1065
# Validation: Avg Standard Validation Loss: 4.6414
# Validation: Avg Attenuated Validation Loss: 6.1486
# Validation Loss for Scheduler: 4.6414
# saving model
# Epoch [15/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 18.0531
# Validation: Avg Standard Validation Loss: 4.6185
# Validation: Avg Attenuated Validation Loss: 6.0932
# Validation Loss for Scheduler: 4.6185
# saving model
# Epoch [16/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 18.0317
# Validation: Avg Standard Validation Loss: 4.5972
# Validation: Avg Attenuated Validation Loss: 6.0445
# Validation Loss for Scheduler: 4.5972
# saving model
# Epoch [17/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 17.9830
# Validation: Avg Standard Validation Loss: 4.5694
# Validation: Avg Attenuated Validation Loss: 5.9798
# Validation Loss for Scheduler: 4.5694
# saving model
# Epoch [18/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 17.9448
# Validation: Avg Standard Validation Loss: 4.5517
# Validation: Avg Attenuated Validation Loss: 5.9311
# Validation Loss for Scheduler: 4.5517
# saving model
# Epoch [19/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 17.8892
# Validation: Avg Standard Validation Loss: 4.5215
# Validation: Avg Attenuated Validation Loss: 5.8640
# Validation Loss for Scheduler: 4.5215
# saving model
# Epoch [20/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 17.8449
# Validation: Avg Standard Validation Loss: 4.4966
# Validation: Avg Attenuated Validation Loss: 5.8062
# Validation Loss for Scheduler: 4.4966
# saving model
# Epoch [21/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 17.8034
# Validation: Avg Standard Validation Loss: 4.4693
# Validation: Avg Attenuated Validation Loss: 5.7430
# Validation Loss for Scheduler: 4.4693
# saving model
# Epoch [22/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 17.7738
# Validation: Avg Standard Validation Loss: 4.4383
# Validation: Avg Attenuated Validation Loss: 5.6759
# Validation Loss for Scheduler: 4.4383
# saving model
# Epoch [23/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 17.7065
# Validation: Avg Standard Validation Loss: 4.4099
# Validation: Avg Attenuated Validation Loss: 5.6091
# Validation Loss for Scheduler: 4.4099
# saving model
# Epoch [24/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 17.6680
# Validation: Avg Standard Validation Loss: 4.3770
# Validation: Avg Attenuated Validation Loss: 5.5370
# Validation Loss for Scheduler: 4.3770
# saving model
# Epoch [25/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 17.6243
# Validation: Avg Standard Validation Loss: 4.3446
# Validation: Avg Attenuated Validation Loss: 5.4668
# Validation Loss for Scheduler: 4.3446
# saving model
# Epoch [26/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 17.5850
# Validation: Avg Standard Validation Loss: 4.3097
# Validation: Avg Attenuated Validation Loss: 5.3947
# Validation Loss for Scheduler: 4.3097
# saving model
# Epoch [27/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 17.5286
# Validation: Avg Standard Validation Loss: 4.2770
# Validation: Avg Attenuated Validation Loss: 5.3269
# Validation Loss for Scheduler: 4.2770
# saving model
# Epoch [28/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 17.4954
# Validation: Avg Standard Validation Loss: 4.2442
# Validation: Avg Attenuated Validation Loss: 5.2545
# Validation Loss for Scheduler: 4.2442
# saving model
# Epoch [29/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 17.4391
# Validation: Avg Standard Validation Loss: 4.2084
# Validation: Avg Attenuated Validation Loss: 5.1777
# Validation Loss for Scheduler: 4.2084
# saving model
# Epoch [30/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 17.3837
# Validation: Avg Standard Validation Loss: 4.1593
# Validation: Avg Attenuated Validation Loss: 5.0850
# Validation Loss for Scheduler: 4.1593
# saving model
# Epoch [31/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 17.3442
# Validation: Avg Standard Validation Loss: 4.1289
# Validation: Avg Attenuated Validation Loss: 5.0223
# Validation Loss for Scheduler: 4.1289
# saving model
# Epoch [32/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 17.2828
# Validation: Avg Standard Validation Loss: 4.0876
# Validation: Avg Attenuated Validation Loss: 4.9397
# Validation Loss for Scheduler: 4.0876
# saving model
# Epoch [33/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 17.2301
# Validation: Avg Standard Validation Loss: 4.0506
# Validation: Avg Attenuated Validation Loss: 4.8650
# Validation Loss for Scheduler: 4.0506
# saving model
# Epoch [34/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 17.1874
# Validation: Avg Standard Validation Loss: 4.0102
# Validation: Avg Attenuated Validation Loss: 4.7848
# Validation Loss for Scheduler: 4.0102
# saving model
# Epoch [35/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 17.1469
# Validation: Avg Standard Validation Loss: 3.9696
# Validation: Avg Attenuated Validation Loss: 4.7080
# Validation Loss for Scheduler: 3.9696
# saving model
# Epoch [36/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 17.1109
# Validation: Avg Standard Validation Loss: 3.9222
# Validation: Avg Attenuated Validation Loss: 4.6214
# Validation Loss for Scheduler: 3.9222
# saving model
# Epoch [37/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 17.0462
# Validation: Avg Standard Validation Loss: 3.8806
# Validation: Avg Attenuated Validation Loss: 4.5431
# Validation Loss for Scheduler: 3.8806
# saving model
# Epoch [38/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 16.9868
# Validation: Avg Standard Validation Loss: 3.8376
# Validation: Avg Attenuated Validation Loss: 4.4596
# Validation Loss for Scheduler: 3.8376
# saving model
# Epoch [39/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 16.9348
# Validation: Avg Standard Validation Loss: 3.7940
# Validation: Avg Attenuated Validation Loss: 4.3850
# Validation Loss for Scheduler: 3.7940
# saving model
# Epoch [40/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 16.8958
# Validation: Avg Standard Validation Loss: 3.7435
# Validation: Avg Attenuated Validation Loss: 4.2930
# Validation Loss for Scheduler: 3.7435
# saving model
# Epoch [41/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 16.8468
# Validation: Avg Standard Validation Loss: 3.6952
# Validation: Avg Attenuated Validation Loss: 4.2059
# Validation Loss for Scheduler: 3.6952
# saving model
# Epoch [42/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 16.8121
# Validation: Avg Standard Validation Loss: 3.6527
# Validation: Avg Attenuated Validation Loss: 4.1272
# Validation Loss for Scheduler: 3.6527
# saving model
# Epoch [43/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 16.7589
# Validation: Avg Standard Validation Loss: 3.6044
# Validation: Avg Attenuated Validation Loss: 4.0470
# Validation Loss for Scheduler: 3.6044
# saving model
# Epoch [44/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 16.7027
# Validation: Avg Standard Validation Loss: 3.5559
# Validation: Avg Attenuated Validation Loss: 3.9673
# Validation Loss for Scheduler: 3.5559
# saving model
# Epoch [45/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 16.6624
# Validation: Avg Standard Validation Loss: 3.5109
# Validation: Avg Attenuated Validation Loss: 3.8917
# Validation Loss for Scheduler: 3.5109
# saving model
# Epoch [46/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 16.6114
# Validation: Avg Standard Validation Loss: 3.4597
# Validation: Avg Attenuated Validation Loss: 3.8077
# Validation Loss for Scheduler: 3.4597
# saving model
# Epoch [47/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 16.5718
# Validation: Avg Standard Validation Loss: 3.4103
# Validation: Avg Attenuated Validation Loss: 3.7247
# Validation Loss for Scheduler: 3.4103
# saving model
# Epoch [48/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 16.5123
# Validation: Avg Standard Validation Loss: 3.3620
# Validation: Avg Attenuated Validation Loss: 3.6478
# Validation Loss for Scheduler: 3.3620
# saving model
# Epoch [49/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 16.4858
# Validation: Avg Standard Validation Loss: 3.3133
# Validation: Avg Attenuated Validation Loss: 3.5700
# Validation Loss for Scheduler: 3.3133
# saving model
# Epoch [50/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 16.4474
# Validation: Avg Standard Validation Loss: 3.2555
# Validation: Avg Attenuated Validation Loss: 3.4823
# Validation Loss for Scheduler: 3.2555
# saving model
# Epoch [51/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 16.3999
# Validation: Avg Standard Validation Loss: 3.2076
# Validation: Avg Attenuated Validation Loss: 3.4070
# Validation Loss for Scheduler: 3.2076
# saving model
# Epoch [52/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 16.3549
# Validation: Avg Standard Validation Loss: 3.1536
# Validation: Avg Attenuated Validation Loss: 3.3272
# Validation Loss for Scheduler: 3.1536
# saving model
# Epoch [53/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 16.3124
# Validation: Avg Standard Validation Loss: 3.1021
# Validation: Avg Attenuated Validation Loss: 3.2479
# Validation Loss for Scheduler: 3.1021
# saving model
# Epoch [54/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 16.2724
# Validation: Avg Standard Validation Loss: 3.0418
# Validation: Avg Attenuated Validation Loss: 3.1603
# Validation Loss for Scheduler: 3.0418
# saving model
# Epoch [55/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 16.2411
# Validation: Avg Standard Validation Loss: 2.9932
# Validation: Avg Attenuated Validation Loss: 3.0921
# Validation Loss for Scheduler: 2.9932
# saving model
# Epoch [56/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 16.2019
# Validation: Avg Standard Validation Loss: 2.9403
# Validation: Avg Attenuated Validation Loss: 3.0156
# Validation Loss for Scheduler: 2.9403
# saving model
# Epoch [57/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 16.1816
# Validation: Avg Standard Validation Loss: 2.8890
# Validation: Avg Attenuated Validation Loss: 2.9427
# Validation Loss for Scheduler: 2.8890
# saving model
# Epoch [58/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 16.1505
# Validation: Avg Standard Validation Loss: 2.8408
# Validation: Avg Attenuated Validation Loss: 2.8770
# Validation Loss for Scheduler: 2.8408
# saving model
# Epoch [59/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 16.1240
# Validation: Avg Standard Validation Loss: 2.7823
# Validation: Avg Attenuated Validation Loss: 2.7982
# Validation Loss for Scheduler: 2.7823
# saving model
# Epoch [60/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 16.0856
# Validation: Avg Standard Validation Loss: 2.7338
# Validation: Avg Attenuated Validation Loss: 2.7333
# Validation Loss for Scheduler: 2.7338
# saving model
# Epoch [61/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 16.0626
# Validation: Avg Standard Validation Loss: 2.6836
# Validation: Avg Attenuated Validation Loss: 2.6669
# Validation Loss for Scheduler: 2.6836
# saving model
# Epoch [62/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 16.0398
# Validation: Avg Standard Validation Loss: 2.6297
# Validation: Avg Attenuated Validation Loss: 2.6001
# Validation Loss for Scheduler: 2.6297
# saving model
# Epoch [63/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 16.0035
# Validation: Avg Standard Validation Loss: 2.5789
# Validation: Avg Attenuated Validation Loss: 2.5341
# Validation Loss for Scheduler: 2.5789
# saving model
# Epoch [64/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.9771
# Validation: Avg Standard Validation Loss: 2.5219
# Validation: Avg Attenuated Validation Loss: 2.4644
# Validation Loss for Scheduler: 2.5219
# saving model
# Epoch [65/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.9487
# Validation: Avg Standard Validation Loss: 2.4743
# Validation: Avg Attenuated Validation Loss: 2.4055
# Validation Loss for Scheduler: 2.4743
# saving model
# Epoch [66/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.9425
# Validation: Avg Standard Validation Loss: 2.4199
# Validation: Avg Attenuated Validation Loss: 2.3360
# Validation Loss for Scheduler: 2.4199
# saving model
# Epoch [67/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.9098
# Validation: Avg Standard Validation Loss: 2.3703
# Validation: Avg Attenuated Validation Loss: 2.2798
# Validation Loss for Scheduler: 2.3703
# saving model
# Epoch [68/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.8956
# Validation: Avg Standard Validation Loss: 2.3205
# Validation: Avg Attenuated Validation Loss: 2.2246
# Validation Loss for Scheduler: 2.3205
# saving model
# Epoch [69/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.8853
# Validation: Avg Standard Validation Loss: 2.2790
# Validation: Avg Attenuated Validation Loss: 2.1770
# Validation Loss for Scheduler: 2.2790
# saving model
# Epoch [70/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.8644
# Validation: Avg Standard Validation Loss: 2.2238
# Validation: Avg Attenuated Validation Loss: 2.1141
# Validation Loss for Scheduler: 2.2238
# saving model
# Epoch [71/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.8491
# Validation: Avg Standard Validation Loss: 2.1809
# Validation: Avg Attenuated Validation Loss: 2.0688
# Validation Loss for Scheduler: 2.1809
# saving model
# Epoch [72/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.8366
# Validation: Avg Standard Validation Loss: 2.1262
# Validation: Avg Attenuated Validation Loss: 2.0099
# Validation Loss for Scheduler: 2.1262
# saving model
# Epoch [73/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.8251
# Validation: Avg Standard Validation Loss: 2.0824
# Validation: Avg Attenuated Validation Loss: 1.9611
# Validation Loss for Scheduler: 2.0824
# saving model
# Epoch [74/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.8102
# Validation: Avg Standard Validation Loss: 2.0398
# Validation: Avg Attenuated Validation Loss: 1.9194
# Validation Loss for Scheduler: 2.0398
# saving model
# Epoch [75/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.8165
# Validation: Avg Standard Validation Loss: 1.9905
# Validation: Avg Attenuated Validation Loss: 1.8701
# Validation Loss for Scheduler: 1.9905
# saving model
# Epoch [76/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.8154
# Validation: Avg Standard Validation Loss: 1.9490
# Validation: Avg Attenuated Validation Loss: 1.8284
# Validation Loss for Scheduler: 1.9490
# saving model
# Epoch [77/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.7982
# Validation: Avg Standard Validation Loss: 1.8973
# Validation: Avg Attenuated Validation Loss: 1.7767
# Validation Loss for Scheduler: 1.8973
# saving model
# Epoch [78/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.7945
# Validation: Avg Standard Validation Loss: 1.8579
# Validation: Avg Attenuated Validation Loss: 1.7413
# Validation Loss for Scheduler: 1.8579
# saving model
# Epoch [79/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.7891
# Validation: Avg Standard Validation Loss: 1.8113
# Validation: Avg Attenuated Validation Loss: 1.6934
# Validation Loss for Scheduler: 1.8113
# saving model
# Epoch [80/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.7968
# Validation: Avg Standard Validation Loss: 1.7658
# Validation: Avg Attenuated Validation Loss: 1.6517
# Validation Loss for Scheduler: 1.7658
# saving model
# Epoch [81/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.7896
# Validation: Avg Standard Validation Loss: 1.7215
# Validation: Avg Attenuated Validation Loss: 1.6114
# Validation Loss for Scheduler: 1.7215
# saving model
# Epoch [82/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.7915
# Validation: Avg Standard Validation Loss: 1.6857
# Validation: Avg Attenuated Validation Loss: 1.5806
# Validation Loss for Scheduler: 1.6857
# saving model
# Epoch [83/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.7930
# Validation: Avg Standard Validation Loss: 1.6423
# Validation: Avg Attenuated Validation Loss: 1.5420
# Validation Loss for Scheduler: 1.6423
# saving model
# Epoch [84/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.7974
# Validation: Avg Standard Validation Loss: 1.6046
# Validation: Avg Attenuated Validation Loss: 1.5110
# Validation Loss for Scheduler: 1.6046
# saving model
# Epoch [85/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.8007
# Validation: Avg Standard Validation Loss: 1.5610
# Validation: Avg Attenuated Validation Loss: 1.4748
# Validation Loss for Scheduler: 1.5610
# saving model
# Epoch [86/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.8014
# Validation: Avg Standard Validation Loss: 1.5244
# Validation: Avg Attenuated Validation Loss: 1.4453
# Validation Loss for Scheduler: 1.5244
# saving model
# Epoch [87/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.8165
# Validation: Avg Standard Validation Loss: 1.4768
# Validation: Avg Attenuated Validation Loss: 1.4056
# Validation Loss for Scheduler: 1.4768
# saving model
# Epoch [88/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.8136
# Validation: Avg Standard Validation Loss: 1.4480
# Validation: Avg Attenuated Validation Loss: 1.3842
# Validation Loss for Scheduler: 1.4480
# saving model
# Epoch [89/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.8343
# Validation: Avg Standard Validation Loss: 1.4011
# Validation: Avg Attenuated Validation Loss: 1.3449
# Validation Loss for Scheduler: 1.4011
# saving model
# Epoch [90/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.8304
# Validation: Avg Standard Validation Loss: 1.3693
# Validation: Avg Attenuated Validation Loss: 1.3225
# Validation Loss for Scheduler: 1.3693
# saving model
# Epoch [91/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.8445
# Validation: Avg Standard Validation Loss: 1.3290
# Validation: Avg Attenuated Validation Loss: 1.2898
# Validation Loss for Scheduler: 1.3290
# saving model
# Epoch [92/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.8455
# Validation: Avg Standard Validation Loss: 1.2873
# Validation: Avg Attenuated Validation Loss: 1.2560
# Validation Loss for Scheduler: 1.2873
# saving model
# Epoch [93/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.8536
# Validation: Avg Standard Validation Loss: 1.2545
# Validation: Avg Attenuated Validation Loss: 1.2332
# Validation Loss for Scheduler: 1.2545
# saving model
# Epoch [94/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.8580
# Validation: Avg Standard Validation Loss: 1.2209
# Validation: Avg Attenuated Validation Loss: 1.2063
# Validation Loss for Scheduler: 1.2209
# saving model
# Epoch [95/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.8619
# Validation: Avg Standard Validation Loss: 1.1791
# Validation: Avg Attenuated Validation Loss: 1.1717
# Validation Loss for Scheduler: 1.1791
# saving model
# Epoch [96/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.8688
# Validation: Avg Standard Validation Loss: 1.1419
# Validation: Avg Attenuated Validation Loss: 1.1397
# Validation Loss for Scheduler: 1.1419
# saving model
# Epoch [97/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.8783
# Validation: Avg Standard Validation Loss: 1.1065
# Validation: Avg Attenuated Validation Loss: 1.1127
# Validation Loss for Scheduler: 1.1065
# saving model
# Epoch [98/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.8840
# Validation: Avg Standard Validation Loss: 1.0739
# Validation: Avg Attenuated Validation Loss: 1.0869
# Validation Loss for Scheduler: 1.0739
# saving model
# Epoch [99/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.8876
# Validation: Avg Standard Validation Loss: 1.0471
# Validation: Avg Attenuated Validation Loss: 1.0630
# Validation Loss for Scheduler: 1.0471
# saving model
# Epoch [100/100], Learning Rate: 1e-05
# Training: Avg Attenuated Training Loss: 15.8961
# Validation: Avg Standard Validation Loss: 1.0155
# Validation: Avg Attenuated Validation Loss: 1.0333
# Validation Loss for Scheduler: 1.0155
# saving model
# Training complete.
# Model saved to path: Helpdesk_weytjens.pkl
