# %%
"""
Use of same experimental setup as for our Probabilistic Suffix Prediction.

Reimplementation for comparison: 
- Paper: Weytjens, Hans, and Jochen De Weerdt. "Learning uncertainty with artificial neural networks for predictive process monitoring." Applied Soft Computing 125 (2022): 109134.
- Github (code) from: https://github.com/hansweytjens/uncertainty-remaining_time/blob/main/LSTM.ipynb
"""
# Out:
# '\nUse of same experimental setup as for our Probabilistic Suffix Prediction.\n\nReimplementation for comparison: \n- Paper: Weytjens, Hans, and Jochen De Weerdt. "Learning uncertainty with artificial neural networks for predictive process monitoring." Applied Soft Computing 125 (2022): 109134.\n- Github (code) from: https://github.com/hansweytjens/uncertainty-remaining_time/blob/main/LSTM.ipynb\n'

# %% [markdown]
# # Imports

# %%
import importlib
import sys
import torch

sys.path.insert(0, '..')
sys.path.insert(0, '../..')
sys.path.insert(0, '../../..')
sys.path.insert(0, '../../../..')
sys.path.insert(0, '../../../../..')

# %% [markdown]
# # Data

# %% [markdown]
# ### Load Data Files

# %%
# Path to your pickle file (saved with torch.save)
file_path_train = '../../../../../../encoded_data/weytjens/BPIC17/BPIC_2017_all_5_train.pkl'
# Load the dataset using torch.load
bpic17_train_dataset = torch.load(file_path_train, weights_only=False)
# Check the type of the loaded dataset
print(type(bpic17_train_dataset))

# Path to your pickle file (saved with torch.save)
file_path_val = '../../../../../../encoded_data/weytjens/BPIC17/BPIC_2017_all_5_val.pkl'
# Load the dataset using torch.load
bpic17_val_dataset = torch.load(file_path_val, weights_only=False)
# Check the type of the loaded dataset
print(type(bpic17_val_dataset))
# Out:
# <class 'event_log_loader.new_event_log_loader.EventLogDataset'>
# <class 'event_log_loader.new_event_log_loader.EventLogDataset'>

# %% [markdown]
# ### Train Data Insights

# %%
# BPIC 17 Dataset Categories, Features:
bpic17_all_categories = bpic17_train_dataset.all_categories

bpic17_all_categories_cat = bpic17_all_categories[0]
print(bpic17_all_categories_cat)

bpic17_all_categories_num = bpic17_all_categories[1]
print(bpic17_all_categories_num)

for i, cat in enumerate(bpic17_all_categories_cat):
     print(f"bpic17 (5) Categorical feature: {cat[0]}, Index position in categorical data list: {i}")
     print(f"bpic17 (5) Total Amount of Category labels: {cat[1]}")

print('\n')    

for i, num in enumerate(bpic17_all_categories_num):
     print(f"bpic17 (5) Numerical feature: {num[0]}, Index position in categorical data list: {i}")
     print(f"bpic17 (5) Amount Numerical: {num[1]}")
     
# Get concept_name id:
# 
concept_name = 'concept:name'
concept_name_id = [i for i, cat in enumerate(bpic17_all_categories[0]) if cat[0] == concept_name][0]

print("ID concet name in cat list: ", concept_name_id)
    
# Id of EOS token in activity
eos_value = 'EOS'
eos_id = [v for k, v in bpic17_all_categories[0][concept_name_id][2].items() if k == eos_value][0]
# Get EOS id of concept name list:

print("ID EOS in concept name tensor: ", eos_id)
# Out:
# [('concept:name', 28, {'A_Accepted': 1, 'A_Cancelled': 2, 'A_Complete': 3, 'A_Concept': 4, 'A_Create Application': 5, 'A_Denied': 6, 'A_Incomplete': 7, 'A_Pending': 8, 'A_Submitted': 9, 'A_Validating': 10, 'EOS': 11, 'O_Accepted': 12, 'O_Cancelled': 13, 'O_Create Offer': 14, 'O_Created': 15, 'O_Refused': 16, 'O_Returned': 17, 'O_Sent (mail and online)': 18, 'O_Sent (online only)': 19, 'W_Assess potential fraud': 20, 'W_Call after offers': 21, 'W_Call incomplete files': 22, 'W_Complete application': 23, 'W_Handle leads': 24, 'W_Personal Loan collection': 25, 'W_Shortened completion ': 26, 'W_Validate application': 27})]
# [('case_elapsed_time', 1, {})]
# bpic17 (5) Categorical feature: concept:name, Index position in categorical data list: 0
# bpic17 (5) Total Amount of Category labels: 28
#
#
# bpic17 (5) Numerical feature: case_elapsed_time, Index position in categorical data list: 0
# bpic17 (5) Amount Numerical: 1
# ID concet name in cat list:  0
# ID EOS in concept name tensor:  11

# %% [markdown]
# ### Input Features for Encoder and Decoder

# %%
# Create lists with name of Model features (input)
model_feat_cat = ['concept:name']
model_feat_num = ['case_elapsed_time']
model_feat = [model_feat_cat, model_feat_num]

print("Features model: ", model_feat)
# Out:
# Features model:  [['concept:name'], ['case_elapsed_time']]

# %% [markdown]
# # Model

# %%
import stochasticLSTM.model
importlib.reload(stochasticLSTM.model)
from stochasticLSTM.model import StochasticLSTMWeytjens

"""
Specific model parameters from paper: 
"""

# Size hidden layer
hidden_size=10

# Number of LSTM cells
num_layers=2

# One numerical output to predict
input_size=1

# Fixed Dropout probability 
p_fix=0.1

# Lambda for L2 (weight, bias, dropout) regularization: According to formula: 1/2N
regularization_term = 0.1

# Hans Weytjens LSTM model
model = StochasticLSTMWeytjens(data_set_categories=bpic17_all_categories,
                               model_feat=model_feat,
                               hidden_size=hidden_size,
                               num_layers=num_layers,
                               input_size=input_size,
                               weight_reg=regularization_term,
                               p_fix=p_fix,
                               device='cpu')
# Out:
# Data set categories:  ([('concept:name', 28, {'A_Accepted': 1, 'A_Cancelled': 2, 'A_Complete': 3, 'A_Concept': 4, 'A_Create Application': 5, 'A_Denied': 6, 'A_Incomplete': 7, 'A_Pending': 8, 'A_Submitted': 9, 'A_Validating': 10, 'EOS': 11, 'O_Accepted': 12, 'O_Cancelled': 13, 'O_Create Offer': 14, 'O_Created': 15, 'O_Refused': 16, 'O_Returned': 17, 'O_Sent (mail and online)': 18, 'O_Sent (online only)': 19, 'W_Assess potential fraud': 20, 'W_Call after offers': 21, 'W_Call incomplete files': 22, 'W_Complete application': 23, 'W_Handle leads': 24, 'W_Personal Loan collection': 25, 'W_Shortened completion ': 26, 'W_Validate application': 27})], [('case_elapsed_time', 1, {})])
# Model input features:  [['concept:name'], ['case_elapsed_time']]
#
#
# Embeddings:  ModuleList(
#   (0): Embedding(28, 10)
# )
# Total embedding feature size:  10
# Input feature size:  11
# Cells hidden size:  10
# Number of LSTM layer:  2
# Dropout rate:  0.1
#
#
# Output feature list of dicts (featue name, tensor index in dataset):  {'case_elapsed_time': 0}

# %% [markdown]
# # Loss Object Creation

# %%
import loss_hans.losses
importlib.reload(loss_hans.losses)
from loss_hans.losses import Loss

loss_obj = Loss()

# %% [markdown]
# # Training Configuration

# %%
import training.train
importlib.reload(training.train)
from training.train import Training

from torch.optim.lr_scheduler import ReduceLROnPlateau

from torch.utils.tensorboard import SummaryWriter

writer = SummaryWriter(comment="Full_BPIC17_weytjens_rem_time")

# device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

"""
Parameter of Probabilistic Suffix Prediction experimental design, to ensure fair comparison:
"""

# Start learning rate
learning_rate = 1e-6

# Optimizer and Scheduler
optimizer = torch.optim.Adam(params=model.parameters(), lr=learning_rate, weight_decay=0)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=2, min_lr=1e-10)

# Epochs
num_epochs = 100

# Batch size
batch_size = 256

# shuffle data
shuffle = True

optimize_values = {"regularization_term":regularization_term,
                   "optimizer":optimizer,
                   "scheduler": scheduler,
                   "epochs":num_epochs,
                   "mini_batches":batch_size,
                   "shuffle": shuffle}

number_tasks = len(model_feat)

trainer = Training(model=model,
                   device=device,
                   data_train=bpic17_train_dataset,
                   data_val=bpic17_val_dataset,
                   concept_name_id=concept_name_id,
                   eos_id=eos_id,
                   loss_obj=loss_obj,
                   optimize_values=optimize_values,
                   writer=writer,
                   save_model_n_th_epoch=1,
                   saving_path="BPIC17_weytjens.pkl")

# Train the model:
trainer.train()
# Out:
# Device:  cpu
# Optimizer:  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     capturable: False
#     decoupled_weight_decay: False
#     differentiable: False
#     eps: 1e-08
#     foreach: None
#     fused: None
#     lr: 1e-06
#     maximize: False
#     weight_decay: 0
# )
# Scheduler:  <torch.optim.lr_scheduler.ReduceLROnPlateau object at 0x35c5af620>
# Epochs:  100
# Mini baches:  256
# Shuffle batched dataset:  True
#   0%|          | 0/100 [00:00<?, ?it/s]
# /Users/leonurny/.local/share/virtualenvs/Probabilistic_Suffix_Prediction_U-ED-LSTM_-32bEAP25/lib/python3.13/site-packages/torch/utils/data/dataloader.py:683: UserWarning: 'pin_memory' argument is set as true but not supported on MPS now, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# Epoch [1/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.6920
# Validation: Avg Standard Validation Loss: 2.1382
# Validation: Avg Attenuated Validation Loss: 2.3629
# Validation Loss for Scheduler: 2.1382
# saving model
# Epoch [2/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.6364
# Validation: Avg Standard Validation Loss: 2.1031
# Validation: Avg Attenuated Validation Loss: 2.3028
# Validation Loss for Scheduler: 2.1031
# saving model
# Epoch [3/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.5884
# Validation: Avg Standard Validation Loss: 2.0753
# Validation: Avg Attenuated Validation Loss: 2.2457
# Validation Loss for Scheduler: 2.0753
# saving model
# Epoch [4/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.5393
# Validation: Avg Standard Validation Loss: 2.0496
# Validation: Avg Attenuated Validation Loss: 2.1966
# Validation Loss for Scheduler: 2.0496
# saving model
# Epoch [5/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.4908
# Validation: Avg Standard Validation Loss: 2.0446
# Validation: Avg Attenuated Validation Loss: 2.1686
# Validation Loss for Scheduler: 2.0446
# saving model
# Epoch [6/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.4414
# Validation: Avg Standard Validation Loss: 2.0168
# Validation: Avg Attenuated Validation Loss: 2.1175
# Validation Loss for Scheduler: 2.0168
# saving model
# Epoch [7/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.3947
# Validation: Avg Standard Validation Loss: 1.9780
# Validation: Avg Attenuated Validation Loss: 2.0571
# Validation Loss for Scheduler: 1.9780
# saving model
# Epoch [8/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.3650
# Validation: Avg Standard Validation Loss: 1.9599
# Validation: Avg Attenuated Validation Loss: 2.0189
# Validation Loss for Scheduler: 1.9599
# saving model
# Epoch [9/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.3273
# Validation: Avg Standard Validation Loss: 1.9233
# Validation: Avg Attenuated Validation Loss: 1.9637
# Validation Loss for Scheduler: 1.9233
# saving model
# Epoch [10/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.2892
# Validation: Avg Standard Validation Loss: 1.9077
# Validation: Avg Attenuated Validation Loss: 1.9335
# Validation Loss for Scheduler: 1.9077
# saving model
# Epoch [11/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.2634
# Validation: Avg Standard Validation Loss: 1.8923
# Validation: Avg Attenuated Validation Loss: 1.9021
# Validation Loss for Scheduler: 1.8923
# saving model
# Epoch [12/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.2339
# Validation: Avg Standard Validation Loss: 1.8597
# Validation: Avg Attenuated Validation Loss: 1.8550
# Validation Loss for Scheduler: 1.8597
# saving model
# Epoch [13/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.2057
# Validation: Avg Standard Validation Loss: 1.8245
# Validation: Avg Attenuated Validation Loss: 1.8063
# Validation Loss for Scheduler: 1.8245
# saving model
# Epoch [14/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.1920
# Validation: Avg Standard Validation Loss: 1.8103
# Validation: Avg Attenuated Validation Loss: 1.7799
# Validation Loss for Scheduler: 1.8103
# saving model
# Epoch [15/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.1706
# Validation: Avg Standard Validation Loss: 1.7975
# Validation: Avg Attenuated Validation Loss: 1.7560
# Validation Loss for Scheduler: 1.7975
# saving model
# Epoch [16/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.1578
# Validation: Avg Standard Validation Loss: 1.7618
# Validation: Avg Attenuated Validation Loss: 1.7072
# Validation Loss for Scheduler: 1.7618
# saving model
# Epoch [17/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.1400
# Validation: Avg Standard Validation Loss: 1.7542
# Validation: Avg Attenuated Validation Loss: 1.6927
# Validation Loss for Scheduler: 1.7542
# saving model
# Epoch [18/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.1311
# Validation: Avg Standard Validation Loss: 1.7310
# Validation: Avg Attenuated Validation Loss: 1.6618
# Validation Loss for Scheduler: 1.7310
# saving model
# Epoch [19/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.1255
# Validation: Avg Standard Validation Loss: 1.7027
# Validation: Avg Attenuated Validation Loss: 1.6281
# Validation Loss for Scheduler: 1.7027
# saving model
# Epoch [20/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.1203
# Validation: Avg Standard Validation Loss: 1.6775
# Validation: Avg Attenuated Validation Loss: 1.5954
# Validation Loss for Scheduler: 1.6775
# saving model
# Epoch [21/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.1111
# Validation: Avg Standard Validation Loss: 1.6660
# Validation: Avg Attenuated Validation Loss: 1.5796
# Validation Loss for Scheduler: 1.6660
# saving model
# Epoch [22/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.1102
# Validation: Avg Standard Validation Loss: 1.6384
# Validation: Avg Attenuated Validation Loss: 1.5531
# Validation Loss for Scheduler: 1.6384
# saving model
# Epoch [23/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.1092
# Validation: Avg Standard Validation Loss: 1.6194
# Validation: Avg Attenuated Validation Loss: 1.5265
# Validation Loss for Scheduler: 1.6194
# saving model
# Epoch [24/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.1155
# Validation: Avg Standard Validation Loss: 1.5998
# Validation: Avg Attenuated Validation Loss: 1.5075
# Validation Loss for Scheduler: 1.5998
# saving model
# Epoch [25/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.1218
# Validation: Avg Standard Validation Loss: 1.5923
# Validation: Avg Attenuated Validation Loss: 1.4977
# Validation Loss for Scheduler: 1.5923
# saving model
# Epoch [26/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.1211
# Validation: Avg Standard Validation Loss: 1.5741
# Validation: Avg Attenuated Validation Loss: 1.4741
# Validation Loss for Scheduler: 1.5741
# saving model
# Epoch [27/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.1365
# Validation: Avg Standard Validation Loss: 1.5490
# Validation: Avg Attenuated Validation Loss: 1.4525
# Validation Loss for Scheduler: 1.5490
# saving model
# Epoch [28/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.1405
# Validation: Avg Standard Validation Loss: 1.5372
# Validation: Avg Attenuated Validation Loss: 1.4379
# Validation Loss for Scheduler: 1.5372
# saving model
# Epoch [29/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.1485
# Validation: Avg Standard Validation Loss: 1.5146
# Validation: Avg Attenuated Validation Loss: 1.4166
# Validation Loss for Scheduler: 1.5146
# saving model
# Epoch [30/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.1635
# Validation: Avg Standard Validation Loss: 1.5007
# Validation: Avg Attenuated Validation Loss: 1.4055
# Validation Loss for Scheduler: 1.5007
# saving model
# Epoch [31/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.1732
# Validation: Avg Standard Validation Loss: 1.4862
# Validation: Avg Attenuated Validation Loss: 1.3911
# Validation Loss for Scheduler: 1.4862
# saving model
# Epoch [32/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.1915
# Validation: Avg Standard Validation Loss: 1.4744
# Validation: Avg Attenuated Validation Loss: 1.3826
# Validation Loss for Scheduler: 1.4744
# saving model
# Epoch [33/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.2012
# Validation: Avg Standard Validation Loss: 1.4605
# Validation: Avg Attenuated Validation Loss: 1.3659
# Validation Loss for Scheduler: 1.4605
# saving model
# Epoch [34/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.2180
# Validation: Avg Standard Validation Loss: 1.4454
# Validation: Avg Attenuated Validation Loss: 1.3526
# Validation Loss for Scheduler: 1.4454
# saving model
# Epoch [35/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.2380
# Validation: Avg Standard Validation Loss: 1.4391
# Validation: Avg Attenuated Validation Loss: 1.3500
# Validation Loss for Scheduler: 1.4391
# saving model
# Epoch [36/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.2551
# Validation: Avg Standard Validation Loss: 1.4259
# Validation: Avg Attenuated Validation Loss: 1.3408
# Validation Loss for Scheduler: 1.4259
# saving model
# Epoch [37/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.2709
# Validation: Avg Standard Validation Loss: 1.4164
# Validation: Avg Attenuated Validation Loss: 1.3357
# Validation Loss for Scheduler: 1.4164
# saving model
# Epoch [38/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.2870
# Validation: Avg Standard Validation Loss: 1.4014
# Validation: Avg Attenuated Validation Loss: 1.3115
# Validation Loss for Scheduler: 1.4014
# saving model
# Epoch [39/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.3100
# Validation: Avg Standard Validation Loss: 1.3858
# Validation: Avg Attenuated Validation Loss: 1.3027
# Validation Loss for Scheduler: 1.3858
# saving model
# Epoch [40/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.3206
# Validation: Avg Standard Validation Loss: 1.3716
# Validation: Avg Attenuated Validation Loss: 1.2905
# Validation Loss for Scheduler: 1.3716
# saving model
# Epoch [41/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.3359
# Validation: Avg Standard Validation Loss: 1.3535
# Validation: Avg Attenuated Validation Loss: 1.2744
# Validation Loss for Scheduler: 1.3535
# saving model
# Epoch [42/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.3447
# Validation: Avg Standard Validation Loss: 1.3547
# Validation: Avg Attenuated Validation Loss: 1.2758
# Validation Loss for Scheduler: 1.3547
# saving model
# Epoch [43/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.3651
# Validation: Avg Standard Validation Loss: 1.3347
# Validation: Avg Attenuated Validation Loss: 1.2532
# Validation Loss for Scheduler: 1.3347
# saving model
# Epoch [44/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.3822
# Validation: Avg Standard Validation Loss: 1.3239
# Validation: Avg Attenuated Validation Loss: 1.2467
# Validation Loss for Scheduler: 1.3239
# saving model
# Epoch [45/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.4053
# Validation: Avg Standard Validation Loss: 1.3160
# Validation: Avg Attenuated Validation Loss: 1.2364
# Validation Loss for Scheduler: 1.3160
# saving model
# Epoch [46/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.4212
# Validation: Avg Standard Validation Loss: 1.3042
# Validation: Avg Attenuated Validation Loss: 1.2311
# Validation Loss for Scheduler: 1.3042
# saving model
# Epoch [47/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.4329
# Validation: Avg Standard Validation Loss: 1.2901
# Validation: Avg Attenuated Validation Loss: 1.2205
# Validation Loss for Scheduler: 1.2901
# saving model
# Epoch [48/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.4417
# Validation: Avg Standard Validation Loss: 1.2680
# Validation: Avg Attenuated Validation Loss: 1.2047
# Validation Loss for Scheduler: 1.2680
# saving model
# Epoch [49/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.4680
# Validation: Avg Standard Validation Loss: 1.2617
# Validation: Avg Attenuated Validation Loss: 1.1880
# Validation Loss for Scheduler: 1.2617
# saving model
# Epoch [50/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.4841
# Validation: Avg Standard Validation Loss: 1.2454
# Validation: Avg Attenuated Validation Loss: 1.1707
# Validation Loss for Scheduler: 1.2454
# saving model
# Epoch [51/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.5044
# Validation: Avg Standard Validation Loss: 1.2411
# Validation: Avg Attenuated Validation Loss: 1.1629
# Validation Loss for Scheduler: 1.2411
# saving model
# Epoch [52/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.5249
# Validation: Avg Standard Validation Loss: 1.2310
# Validation: Avg Attenuated Validation Loss: 1.1582
# Validation Loss for Scheduler: 1.2310
# saving model
# Epoch [53/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.5406
# Validation: Avg Standard Validation Loss: 1.2213
# Validation: Avg Attenuated Validation Loss: 1.1443
# Validation Loss for Scheduler: 1.2213
# saving model
# Epoch [54/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.5547
# Validation: Avg Standard Validation Loss: 1.2117
# Validation: Avg Attenuated Validation Loss: 1.1377
# Validation Loss for Scheduler: 1.2117
# saving model
# Epoch [55/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.5811
# Validation: Avg Standard Validation Loss: 1.1919
# Validation: Avg Attenuated Validation Loss: 1.1214
# Validation Loss for Scheduler: 1.1919
# saving model
# Epoch [56/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.5895
# Validation: Avg Standard Validation Loss: 1.1862
# Validation: Avg Attenuated Validation Loss: 1.1122
# Validation Loss for Scheduler: 1.1862
# saving model
# Epoch [57/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.6076
# Validation: Avg Standard Validation Loss: 1.1707
# Validation: Avg Attenuated Validation Loss: 1.0916
# Validation Loss for Scheduler: 1.1707
# saving model
# Epoch [58/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.6199
# Validation: Avg Standard Validation Loss: 1.1632
# Validation: Avg Attenuated Validation Loss: 1.0868
# Validation Loss for Scheduler: 1.1632
# saving model
# Epoch [59/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.6489
# Validation: Avg Standard Validation Loss: 1.1559
# Validation: Avg Attenuated Validation Loss: 1.0757
# Validation Loss for Scheduler: 1.1559
# saving model
# Epoch [60/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.6485
# Validation: Avg Standard Validation Loss: 1.1368
# Validation: Avg Attenuated Validation Loss: 1.0582
# Validation Loss for Scheduler: 1.1368
# saving model
# Epoch [61/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.6719
# Validation: Avg Standard Validation Loss: 1.1425
# Validation: Avg Attenuated Validation Loss: 1.0818
# Validation Loss for Scheduler: 1.1425
# saving model
# Epoch [62/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.6878
# Validation: Avg Standard Validation Loss: 1.1353
# Validation: Avg Attenuated Validation Loss: 1.0652
# Validation Loss for Scheduler: 1.1353
# saving model
# Epoch [63/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.7000
# Validation: Avg Standard Validation Loss: 1.1326
# Validation: Avg Attenuated Validation Loss: 1.0673
# Validation Loss for Scheduler: 1.1326
# saving model
# Epoch [64/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.7137
# Validation: Avg Standard Validation Loss: 1.1129
# Validation: Avg Attenuated Validation Loss: 1.0430
# Validation Loss for Scheduler: 1.1129
# saving model
# Epoch [65/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.7301
# Validation: Avg Standard Validation Loss: 1.1059
# Validation: Avg Attenuated Validation Loss: 1.0274
# Validation Loss for Scheduler: 1.1059
# saving model
# Epoch [66/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.7432
# Validation: Avg Standard Validation Loss: 1.1019
# Validation: Avg Attenuated Validation Loss: 1.0273
# Validation Loss for Scheduler: 1.1019
# saving model
# Epoch [67/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.7558
# Validation: Avg Standard Validation Loss: 1.0850
# Validation: Avg Attenuated Validation Loss: 1.0092
# Validation Loss for Scheduler: 1.0850
# saving model
# Epoch [68/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.7580
# Validation: Avg Standard Validation Loss: 1.0809
# Validation: Avg Attenuated Validation Loss: 1.0104
# Validation Loss for Scheduler: 1.0809
# saving model
# Epoch [69/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.7764
# Validation: Avg Standard Validation Loss: 1.0891
# Validation: Avg Attenuated Validation Loss: 1.0161
# Validation Loss for Scheduler: 1.0891
# saving model
# Epoch [70/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.7861
# Validation: Avg Standard Validation Loss: 1.0765
# Validation: Avg Attenuated Validation Loss: 0.9981
# Validation Loss for Scheduler: 1.0765
# saving model
# Epoch [71/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.8099
# Validation: Avg Standard Validation Loss: 1.0679
# Validation: Avg Attenuated Validation Loss: 0.9912
# Validation Loss for Scheduler: 1.0679
# saving model
# Epoch [72/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.7908
# Validation: Avg Standard Validation Loss: 1.0532
# Validation: Avg Attenuated Validation Loss: 0.9741
# Validation Loss for Scheduler: 1.0532
# saving model
# Epoch [73/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.8267
# Validation: Avg Standard Validation Loss: 1.0547
# Validation: Avg Attenuated Validation Loss: 0.9811
# Validation Loss for Scheduler: 1.0547
# saving model
# Epoch [74/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.8126
# Validation: Avg Standard Validation Loss: 1.0386
# Validation: Avg Attenuated Validation Loss: 0.9674
# Validation Loss for Scheduler: 1.0386
# saving model
# Epoch [75/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.8336
# Validation: Avg Standard Validation Loss: 1.0444
# Validation: Avg Attenuated Validation Loss: 0.9724
# Validation Loss for Scheduler: 1.0444
# saving model
# Epoch [76/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.8443
# Validation: Avg Standard Validation Loss: 1.0319
# Validation: Avg Attenuated Validation Loss: 0.9521
# Validation Loss for Scheduler: 1.0319
# saving model
# Epoch [77/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.8599
# Validation: Avg Standard Validation Loss: 1.0271
# Validation: Avg Attenuated Validation Loss: 0.9547
# Validation Loss for Scheduler: 1.0271
# saving model
# Epoch [78/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.8647
# Validation: Avg Standard Validation Loss: 1.0289
# Validation: Avg Attenuated Validation Loss: 0.9526
# Validation Loss for Scheduler: 1.0289
# saving model
# Epoch [79/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.8662
# Validation: Avg Standard Validation Loss: 1.0237
# Validation: Avg Attenuated Validation Loss: 0.9591
# Validation Loss for Scheduler: 1.0237
# saving model
# Epoch [80/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.8629
# Validation: Avg Standard Validation Loss: 1.0235
# Validation: Avg Attenuated Validation Loss: 0.9475
# Validation Loss for Scheduler: 1.0235
# saving model
# Epoch [81/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.8688
# Validation: Avg Standard Validation Loss: 1.0250
# Validation: Avg Attenuated Validation Loss: 0.9593
# Validation Loss for Scheduler: 1.0250
# saving model
# Epoch [82/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.8856
# Validation: Avg Standard Validation Loss: 1.0097
# Validation: Avg Attenuated Validation Loss: 0.9284
# Validation Loss for Scheduler: 1.0097
# saving model
# Epoch [83/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.8850
# Validation: Avg Standard Validation Loss: 1.0111
# Validation: Avg Attenuated Validation Loss: 0.9353
# Validation Loss for Scheduler: 1.0111
# saving model
# Epoch [84/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.8882
# Validation: Avg Standard Validation Loss: 1.0056
# Validation: Avg Attenuated Validation Loss: 0.9231
# Validation Loss for Scheduler: 1.0056
# saving model
# Epoch [85/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.8934
# Validation: Avg Standard Validation Loss: 0.9866
# Validation: Avg Attenuated Validation Loss: 0.9037
# Validation Loss for Scheduler: 0.9866
# saving model
# Epoch [86/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.8974
# Validation: Avg Standard Validation Loss: 0.9980
# Validation: Avg Attenuated Validation Loss: 0.9286
# Validation Loss for Scheduler: 0.9980
# saving model
# Epoch [87/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.9062
# Validation: Avg Standard Validation Loss: 0.9831
# Validation: Avg Attenuated Validation Loss: 0.9016
# Validation Loss for Scheduler: 0.9831
# saving model
# Epoch [88/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.9036
# Validation: Avg Standard Validation Loss: 0.9899
# Validation: Avg Attenuated Validation Loss: 0.9017
# Validation Loss for Scheduler: 0.9899
# saving model
# Epoch [89/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.9300
# Validation: Avg Standard Validation Loss: 0.9723
# Validation: Avg Attenuated Validation Loss: 0.8967
# Validation Loss for Scheduler: 0.9723
# saving model
# Epoch [90/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.9120
# Validation: Avg Standard Validation Loss: 0.9965
# Validation: Avg Attenuated Validation Loss: 0.9180
# Validation Loss for Scheduler: 0.9965
# saving model
# Epoch [91/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.9149
# Validation: Avg Standard Validation Loss: 0.9964
# Validation: Avg Attenuated Validation Loss: 0.9294
# Validation Loss for Scheduler: 0.9964
# saving model
# Epoch [92/100], Learning Rate: 1e-06
# Training: Avg Attenuated Training Loss: 14.9285
# Validation: Avg Standard Validation Loss: 0.9780
# Validation: Avg Attenuated Validation Loss: 0.8894
# Validation Loss for Scheduler: 0.9780
# saving model
# Epoch [93/100], Learning Rate: 1e-07
# Training: Avg Attenuated Training Loss: 14.9325
# Validation: Avg Standard Validation Loss: 0.9901
# Validation: Avg Attenuated Validation Loss: 0.9104
# Validation Loss for Scheduler: 0.9901
# saving model
# Epoch [94/100], Learning Rate: 1e-07
# Training: Avg Attenuated Training Loss: 14.9007
# Validation: Avg Standard Validation Loss: 0.9819
# Validation: Avg Attenuated Validation Loss: 0.9122
# Validation Loss for Scheduler: 0.9819
# saving model
# Epoch [95/100], Learning Rate: 1e-07
# Training: Avg Attenuated Training Loss: 14.9200
# Validation: Avg Standard Validation Loss: 0.9796
# Validation: Avg Attenuated Validation Loss: 0.9034
# Validation Loss for Scheduler: 0.9796
# saving model
# Epoch [96/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 14.9108
# Validation: Avg Standard Validation Loss: 0.9694
# Validation: Avg Attenuated Validation Loss: 0.8866
# Validation Loss for Scheduler: 0.9694
# saving model
# Epoch [97/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 14.9180
# Validation: Avg Standard Validation Loss: 0.9697
# Validation: Avg Attenuated Validation Loss: 0.8898
# Validation Loss for Scheduler: 0.9697
# saving model
# Epoch [98/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 14.9272
# Validation: Avg Standard Validation Loss: 0.9772
# Validation: Avg Attenuated Validation Loss: 0.8945
# Validation Loss for Scheduler: 0.9772
# saving model
# Epoch [99/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 14.9136
# Validation: Avg Standard Validation Loss: 0.9806
# Validation: Avg Attenuated Validation Loss: 0.9028
# Validation Loss for Scheduler: 0.9806
# saving model
# Epoch [100/100], Learning Rate: 1e-08
# Training: Avg Attenuated Training Loss: 14.9362
# Validation: Avg Standard Validation Loss: 0.9636
# Validation: Avg Attenuated Validation Loss: 0.8700
# Validation Loss for Scheduler: 0.9636
# saving model
# Training complete.
# Model saved to path: BPIC17_weytjens.pkl
