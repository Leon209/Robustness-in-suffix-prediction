# %% [markdown]
# # Process Conformity Analysis
#
# This notebook analyzes what percentage of structural perturbations (e.g., redo_activity_attack) are valid according to the process model discovered from the full dataset.
#
# The analysis:
# 1. Discovers a process model (Petri net) from the full event log dataset
# 2. Loads perturbed prefixes from the structural attack
# 3. Checks if each prefix is valid according to the process model
# 4. Calculates the percentage of valid prefixes

# %%
import sys
import os
import pandas as pd
import torch

sys.path.insert(0, '..')
sys.path.insert(1, '../../..')
sys.path.insert(0, "../../src")

# Add path to import from perturbation_logic
# Notebook is in robustness/perturbator/, module is in robustness/perturbator/perturbation_logic/
perturbation_logic_path = os.path.join(os.getcwd(), 'perturbation_logic')
if os.path.exists(perturbation_logic_path):
    sys.path.insert(0, perturbation_logic_path)
else:
    # Try alternative path if running from different directory
    perturbation_logic_path = 'perturbation_logic'
    if os.path.exists(perturbation_logic_path):
        sys.path.insert(0, perturbation_logic_path)

from perturbation_logic.petri_net_replay_markings import InductiveMiner, is_prefix_valid

print("Imports successful!")
# Out:
# Imports successful!

# %% [markdown]
# ## Step 1: Discover Process Model from Full Dataset
#
# Load the full helpdesk dataset and discover a Petri net process model using Inductive Miner.

# %%
# Path to the full dataset
dataset_path = '../../../data/BPI Challenge 2020.csv'

# Initialize InductiveMiner with helpdesk column names
miner = InductiveMiner(
    path_to_csv_log=dataset_path,
    case_id_col="case:concept:name",
    activity_col="concept:name",
    timestamp_col="time:timestamp",
    resource_col="org:resource"
)

# Discover Petri net model
print("Discovering process model from full dataset...")
net, initial_marking, final_marking = miner.discover_petri_net(visulaize=False)

print(f"Process model discovered successfully!")
print(f"Number of places: {len(net.places)}")
print(f"Number of transitions: {len(net.transitions)}")
# Out:
# Discovering process model from full dataset...
# Process model discovered successfully!
# Number of places: 26
# Number of transitions: 43

# %% [markdown]
# ### Visualize the Discovered Petri Net
#
# Visualize the process model to understand its structure.

# %%
from pm4py.visualization.petri_net import visualizer as pn_visualizer
from IPython.display import Image, display
import tempfile
import os

# Visualize the Petri net
print("Generating Petri net visualization...")
gviz = pn_visualizer.apply(net, initial_marking, final_marking)

# Option 1: View in separate window (uncomment to use)
# pn_visualizer.view(gviz)

# Option 2: Save and display inline in notebook
temp_file = tempfile.NamedTemporaryFile(delete=False, suffix='.png')
temp_path = temp_file.name
temp_file.close()

try:
    pn_visualizer.save(gviz, temp_path)
    print(f"Petri net saved to temporary file")
    
    # Display inline
    display(Image(temp_path))
    
    # Optionally save to a permanent location
    # pn_visualizer.save(gviz, "helpdesk_petri_net.png")
    # print("Also saved to: helpdesk_petri_net.png")
    
finally:
    # Clean up temp file after a delay (or keep it for inspection)
    # os.unlink(temp_path)  # Uncomment to delete temp file immediately
    pass
# Out:
# Generating Petri net visualization...
# Petri net saved to temporary file

# %% [markdown]
# ## Step 2: Load Perturbed Dataset
#
# Load the perturbed dataset containing prefixes and suffixes from the structural attack.

# %%
# Path to perturbed dataset
perturbed_path = '../../../perturbed_data/BPIC20/redo_pert.pkl'

print(f"Loading perturbed dataset from: {perturbed_path}")
perturbed_data = torch.load(perturbed_path, weights_only=False)

print(f"Loaded {len(perturbed_data)} perturbed prefix-suffix pairs")
print(f"Sample keys: {list(perturbed_data.keys())[:5]}")
# Out:
# Loading perturbed dataset from: ../../../perturbed_data/BPIC20/redo_pert.pkl
# Loaded 5660 perturbed prefix-suffix pairs
# Sample keys: [('declaration 100000', 1), ('declaration 100000', 2), ('declaration 100000', 3), ('declaration 100005', 1), ('declaration 100005', 2)]

# %% [markdown]
# ## Step 3: Check Validity of Each Prefix
#
# For each prefix in the perturbed dataset, extract the activity sequence and check if it's valid according to the process model.

# %%
# Activity column name (used in DataFrames)
activity_column = "concept:name"

# Track validity
valid_count = 0
invalid_count = 0
total_count = 0
valid_prefixes = []
invalid_prefixes = []

print("Checking validity of prefixes...")
print("=" * 80)

for (case_id, prefix_length), prefix_suffix_pair in perturbed_data.items():
    total_count += 1
    
    # Handle both formats: [prefix, suffix] or (prefix_df, suffix_df)
    if isinstance(prefix_suffix_pair, (list, tuple)) and len(prefix_suffix_pair) >= 2:
        prefix_data = prefix_suffix_pair[0]
    else:
        prefix_data = prefix_suffix_pair
    
    # Extract activity sequence from prefix
    # Handle both DataFrame and list formats
    if isinstance(prefix_data, pd.DataFrame):
        # Filter out EOS rows if present
        prefix_df = prefix_data[prefix_data[activity_column] != "EOS"]
        if len(prefix_df) == 0:
            # If all are EOS, use the original DataFrame
            prefix_df = prefix_data
        prefix_activities = prefix_df[activity_column].tolist()
    elif isinstance(prefix_data, list):
        # If it's already a list of activities
        prefix_activities = [act for act in prefix_data if act != "EOS"]
        if len(prefix_activities) == 0:
            prefix_activities = prefix_data
    else:
        print(f"Warning: Unknown prefix format for case {case_id}, prefix_length {prefix_length}")
        invalid_count += 1
        invalid_prefixes.append((case_id, prefix_length))
        continue
    
    # Check validity using token replay
    try:
        is_valid = is_prefix_valid(prefix_activities, net, initial_marking, final_marking)
        
        if is_valid:
            valid_count += 1
            valid_prefixes.append((case_id, prefix_length))
        else:
            invalid_count += 1
            invalid_prefixes.append((case_id, prefix_length))
    except Exception as e:
        print(f"Error checking validity for case {case_id}, prefix_length {prefix_length}: {e}")
        invalid_count += 1
        invalid_prefixes.append((case_id, prefix_length))
    
    # Progress update every 100 cases
    if total_count % 100 == 0:
        print(f"Processed {total_count} prefixes... (Valid: {valid_count}, Invalid: {invalid_count})")

print("=" * 80)
print(f"Completed checking {total_count} prefixes")
# Out:
# Checking validity of prefixes...
# ================================================================================
# Processed 100 prefixes... (Valid: 31, Invalid: 69)
# Processed 200 prefixes... (Valid: 63, Invalid: 137)
# Processed 300 prefixes... (Valid: 98, Invalid: 202)
# Processed 400 prefixes... (Valid: 129, Invalid: 271)
# Processed 500 prefixes... (Valid: 162, Invalid: 338)
# Processed 600 prefixes... (Valid: 194, Invalid: 406)
# Processed 700 prefixes... (Valid: 228, Invalid: 472)
# Processed 800 prefixes... (Valid: 262, Invalid: 538)
# Processed 900 prefixes... (Valid: 292, Invalid: 608)
# Processed 1000 prefixes... (Valid: 324, Invalid: 676)
# Processed 1100 prefixes... (Valid: 355, Invalid: 745)
# Processed 1200 prefixes... (Valid: 388, Invalid: 812)
# Processed 1300 prefixes... (Valid: 426, Invalid: 874)
# Processed 1400 prefixes... (Valid: 460, Invalid: 940)
# Processed 1500 prefixes... (Valid: 495, Invalid: 1005)
# Processed 1600 prefixes... (Valid: 529, Invalid: 1071)
# Processed 1700 prefixes... (Valid: 563, Invalid: 1137)
# Processed 1800 prefixes... (Valid: 597, Invalid: 1203)
# Processed 1900 prefixes... (Valid: 628, Invalid: 1272)
# Processed 2000 prefixes... (Valid: 657, Invalid: 1343)
# Processed 2100 prefixes... (Valid: 693, Invalid: 1407)
# Processed 2200 prefixes... (Valid: 727, Invalid: 1473)
# Processed 2300 prefixes... (Valid: 763, Invalid: 1537)
# Processed 2400 prefixes... (Valid: 794, Invalid: 1606)
# Processed 2500 prefixes... (Valid: 828, Invalid: 1672)
# Processed 2600 prefixes... (Valid: 859, Invalid: 1741)
# Processed 2700 prefixes... (Valid: 892, Invalid: 1808)
# Processed 2800 prefixes... (Valid: 923, Invalid: 1877)
# Processed 2900 prefixes... (Valid: 954, Invalid: 1946)
# Processed 3000 prefixes... (Valid: 986, Invalid: 2014)
# Processed 3100 prefixes... (Valid: 1016, Invalid: 2084)
# Processed 3200 prefixes... (Valid: 1046, Invalid: 2154)
# Processed 3300 prefixes... (Valid: 1085, Invalid: 2215)
# Processed 3400 prefixes... (Valid: 1117, Invalid: 2283)
# Processed 3500 prefixes... (Valid: 1150, Invalid: 2350)
# Processed 3600 prefixes... (Valid: 1182, Invalid: 2418)
# Processed 3700 prefixes... (Valid: 1215, Invalid: 2485)
# Processed 3800 prefixes... (Valid: 1249, Invalid: 2551)
# Processed 3900 prefixes... (Valid: 1280, Invalid: 2620)
# Processed 4000 prefixes... (Valid: 1314, Invalid: 2686)
# Processed 4100 prefixes... (Valid: 1348, Invalid: 2752)
# Processed 4200 prefixes... (Valid: 1380, Invalid: 2820)
# Processed 4300 prefixes... (Valid: 1411, Invalid: 2889)
# Processed 4400 prefixes... (Valid: 1443, Invalid: 2957)
# Processed 4500 prefixes... (Valid: 1473, Invalid: 3027)
# Processed 4600 prefixes... (Valid: 1506, Invalid: 3094)
# Processed 4700 prefixes... (Valid: 1540, Invalid: 3160)
# Processed 4800 prefixes... (Valid: 1574, Invalid: 3226)
# Processed 4900 prefixes... (Valid: 1606, Invalid: 3294)
# Processed 5000 prefixes... (Valid: 1637, Invalid: 3363)
# Processed 5100 prefixes... (Valid: 1667, Invalid: 3433)
# Processed 5200 prefixes... (Valid: 1699, Invalid: 3501)
# Processed 5300 prefixes... (Valid: 1732, Invalid: 3568)
# Processed 5400 prefixes... (Valid: 1763, Invalid: 3637)
# Processed 5500 prefixes... (Valid: 1791, Invalid: 3709)
# Processed 5600 prefixes... (Valid: 1824, Invalid: 3776)
# ================================================================================
# Completed checking 5660 prefixes

# %% [markdown]
# ## Step 4: Calculate and Display Results
#
# Calculate the percentage of valid prefixes and display summary statistics.

# %%
# Calculate percentage
if total_count > 0:
    percent_valid = (valid_count / total_count) * 100
    percent_invalid = (invalid_count / total_count) * 100
else:
    percent_valid = 0
    percent_invalid = 0

# Display results
print("=" * 80)
print("PROCESS CONFORMITY ANALYSIS RESULTS")
print("=" * 80)
print(f"\nTotal prefixes analyzed: {total_count}")
print(f"Valid prefixes: {valid_count} ({percent_valid:.2f}%)")
print(f"Invalid prefixes: {invalid_count} ({percent_invalid:.2f}%)")
print("=" * 80)

# Additional statistics
if total_count > 0:
    print(f"\nSummary:")
    print(f"  - Validity rate: {percent_valid:.2f}%")
    print(f"  - Invalid rate: {percent_invalid:.2f}%")
    
    # Helper function to extract activities from prefix data
    def extract_activities(case_id, prefix_len):
        """Extract activity sequence from prefix data."""
        if (case_id, prefix_len) not in perturbed_data:
            return []
        
        prefix_data = perturbed_data[(case_id, prefix_len)]
        if isinstance(prefix_data, (list, tuple)) and len(prefix_data) >= 1:
            prefix_data = prefix_data[0]
        
        if isinstance(prefix_data, pd.DataFrame):
            activities = prefix_data[prefix_data[activity_column] != "EOS"][activity_column].tolist()
        elif isinstance(prefix_data, list):
            activities = [a for a in prefix_data if a != "EOS"]
        else:
            activities = []
        
        return activities
    
    # Show 50 valid prefixes
    print(f"\n{'=' * 80}")
    print(f"VALID PREFIXES (showing up to 50):")
    print(f"{'=' * 80}")
    num_valid_to_show = min(50, len(valid_prefixes))
    for i, (case_id, prefix_len) in enumerate(valid_prefixes[:num_valid_to_show]):
        activities = extract_activities(case_id, prefix_len)
        print(f"  {i+1}. Case: {case_id}, Prefix Length: {prefix_len}, Activities: {activities}")
    
    if len(valid_prefixes) > 50:
        print(f"\n  ... and {len(valid_prefixes) - 50} more valid prefixes")
    
    # Show 50 invalid prefixes
    print(f"\n{'=' * 80}")
    print(f"INVALID PREFIXES (showing up to 50):")
    print(f"{'=' * 80}")
    num_invalid_to_show = min(50, len(invalid_prefixes))
    for i, (case_id, prefix_len) in enumerate(invalid_prefixes[:num_invalid_to_show]):
        activities = extract_activities(case_id, prefix_len)
        print(f"  {i+1}. Case: {case_id}, Prefix Length: {prefix_len}, Activities: {activities}")
    
    if len(invalid_prefixes) > 50:
        print(f"\n  ... and {len(invalid_prefixes) - 50} more invalid prefixes")
# Out:
# ================================================================================
# PROCESS CONFORMITY ANALYSIS RESULTS
# ================================================================================
#
# Total prefixes analyzed: 5660
# Valid prefixes: 1847 (32.63%)
# Invalid prefixes: 3813 (67.37%)
# ================================================================================
#
# Summary:
#   - Validity rate: 32.63%
#   - Invalid rate: 67.37%
#
# ================================================================================
# VALID PREFIXES (showing up to 50):
# ================================================================================
#   1. Case: declaration 100000, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   2. Case: declaration 100005, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   3. Case: declaration 100010, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   4. Case: declaration 100015, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   5. Case: declaration 100021, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   6. Case: declaration 100027, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   7. Case: declaration 100032, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   8. Case: declaration 100037, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   9. Case: declaration 100042, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   10. Case: declaration 100048, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   11. Case: declaration 100053, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   12. Case: declaration 100059, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   13. Case: declaration 100064, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   14. Case: declaration 100069, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   15. Case: declaration 100074, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   16. Case: declaration 100079, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   17. Case: declaration 100085, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   18. Case: declaration 100090, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   19. Case: declaration 100095, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   20. Case: declaration 100100, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   21. Case: declaration 100105, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   22. Case: declaration 100111, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   23. Case: declaration 100116, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   24. Case: declaration 100122, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   25. Case: declaration 100122, Prefix Length: 3, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration REJECTED by ADMINISTRATION', 'Declaration REJECTED by EMPLOYEE', 'Declaration REJECTED by EMPLOYEE']
#   26. Case: declaration 100122, Prefix Length: 4, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration REJECTED by ADMINISTRATION', 'Declaration REJECTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   27. Case: declaration 100131, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   28. Case: declaration 100137, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   29. Case: declaration 100143, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   30. Case: declaration 100149, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   31. Case: declaration 100154, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   32. Case: declaration 100160, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   33. Case: declaration 100166, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   34. Case: declaration 100172, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   35. Case: declaration 100177, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   36. Case: declaration 100182, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   37. Case: declaration 100187, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   38. Case: declaration 100192, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   39. Case: declaration 100197, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   40. Case: declaration 100197, Prefix Length: 4, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by PRE_APPROVER', 'Declaration FINAL_APPROVED by SUPERVISOR', 'Declaration REJECTED by MISSING', 'Declaration REJECTED by MISSING']
#   41. Case: declaration 100197, Prefix Length: 5, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by PRE_APPROVER', 'Declaration FINAL_APPROVED by SUPERVISOR', 'Declaration REJECTED by MISSING', 'Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   42. Case: declaration 100207, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   43. Case: declaration 100213, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   44. Case: declaration 100218, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   45. Case: declaration 100223, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   46. Case: declaration 100228, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   47. Case: declaration 100233, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   48. Case: declaration 100239, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   49. Case: declaration 100245, Prefix Length: 1, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration SUBMITTED by EMPLOYEE']
#   50. Case: declaration 100245, Prefix Length: 3, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration REJECTED by ADMINISTRATION', 'Declaration REJECTED by EMPLOYEE', 'Declaration REJECTED by EMPLOYEE']
#
#   ... and 1797 more valid prefixes
#
# ================================================================================
# INVALID PREFIXES (showing up to 50):
# ================================================================================
#   1. Case: declaration 100000, Prefix Length: 2, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by ADMINISTRATION']
#   2. Case: declaration 100000, Prefix Length: 3, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration FINAL_APPROVED by SUPERVISOR', 'Declaration FINAL_APPROVED by SUPERVISOR']
#   3. Case: declaration 100005, Prefix Length: 2, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by ADMINISTRATION']
#   4. Case: declaration 100005, Prefix Length: 3, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration FINAL_APPROVED by SUPERVISOR', 'Declaration FINAL_APPROVED by SUPERVISOR']
#   5. Case: declaration 100010, Prefix Length: 2, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by ADMINISTRATION']
#   6. Case: declaration 100010, Prefix Length: 3, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration FINAL_APPROVED by SUPERVISOR', 'Declaration FINAL_APPROVED by SUPERVISOR']
#   7. Case: declaration 100015, Prefix Length: 2, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by ADMINISTRATION']
#   8. Case: declaration 100015, Prefix Length: 3, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by BUDGET OWNER', 'Declaration APPROVED by BUDGET OWNER']
#   9. Case: declaration 100015, Prefix Length: 4, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by BUDGET OWNER', 'Declaration FINAL_APPROVED by SUPERVISOR', 'Declaration FINAL_APPROVED by SUPERVISOR']
#   10. Case: declaration 100021, Prefix Length: 2, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by ADMINISTRATION']
#   11. Case: declaration 100021, Prefix Length: 3, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by BUDGET OWNER', 'Declaration APPROVED by BUDGET OWNER']
#   12. Case: declaration 100021, Prefix Length: 4, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by BUDGET OWNER', 'Declaration FINAL_APPROVED by SUPERVISOR', 'Declaration FINAL_APPROVED by SUPERVISOR']
#   13. Case: declaration 100027, Prefix Length: 2, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by ADMINISTRATION']
#   14. Case: declaration 100027, Prefix Length: 3, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration FINAL_APPROVED by SUPERVISOR', 'Declaration FINAL_APPROVED by SUPERVISOR']
#   15. Case: declaration 100032, Prefix Length: 2, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by ADMINISTRATION']
#   16. Case: declaration 100032, Prefix Length: 3, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration FINAL_APPROVED by SUPERVISOR', 'Declaration FINAL_APPROVED by SUPERVISOR']
#   17. Case: declaration 100037, Prefix Length: 2, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by ADMINISTRATION']
#   18. Case: declaration 100037, Prefix Length: 3, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration FINAL_APPROVED by SUPERVISOR', 'Declaration FINAL_APPROVED by SUPERVISOR']
#   19. Case: declaration 100042, Prefix Length: 2, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by ADMINISTRATION']
#   20. Case: declaration 100042, Prefix Length: 3, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by BUDGET OWNER', 'Declaration APPROVED by BUDGET OWNER']
#   21. Case: declaration 100042, Prefix Length: 4, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by BUDGET OWNER', 'Declaration FINAL_APPROVED by SUPERVISOR', 'Declaration FINAL_APPROVED by SUPERVISOR']
#   22. Case: declaration 100048, Prefix Length: 2, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by ADMINISTRATION']
#   23. Case: declaration 100048, Prefix Length: 3, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration FINAL_APPROVED by SUPERVISOR', 'Declaration FINAL_APPROVED by SUPERVISOR']
#   24. Case: declaration 100053, Prefix Length: 2, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by ADMINISTRATION']
#   25. Case: declaration 100053, Prefix Length: 3, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by BUDGET OWNER', 'Declaration APPROVED by BUDGET OWNER']
#   26. Case: declaration 100053, Prefix Length: 4, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by BUDGET OWNER', 'Declaration FINAL_APPROVED by SUPERVISOR', 'Declaration FINAL_APPROVED by SUPERVISOR']
#   27. Case: declaration 100059, Prefix Length: 2, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by ADMINISTRATION']
#   28. Case: declaration 100059, Prefix Length: 3, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration FINAL_APPROVED by SUPERVISOR', 'Declaration FINAL_APPROVED by SUPERVISOR']
#   29. Case: declaration 100064, Prefix Length: 2, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by ADMINISTRATION']
#   30. Case: declaration 100064, Prefix Length: 3, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration FINAL_APPROVED by SUPERVISOR', 'Declaration FINAL_APPROVED by SUPERVISOR']
#   31. Case: declaration 100069, Prefix Length: 2, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by ADMINISTRATION']
#   32. Case: declaration 100069, Prefix Length: 3, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration FINAL_APPROVED by SUPERVISOR', 'Declaration FINAL_APPROVED by SUPERVISOR']
#   33. Case: declaration 100074, Prefix Length: 2, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by ADMINISTRATION']
#   34. Case: declaration 100074, Prefix Length: 3, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration FINAL_APPROVED by SUPERVISOR', 'Declaration FINAL_APPROVED by SUPERVISOR']
#   35. Case: declaration 100079, Prefix Length: 2, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by ADMINISTRATION']
#   36. Case: declaration 100079, Prefix Length: 3, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by BUDGET OWNER', 'Declaration APPROVED by BUDGET OWNER']
#   37. Case: declaration 100079, Prefix Length: 4, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by BUDGET OWNER', 'Declaration FINAL_APPROVED by SUPERVISOR', 'Declaration FINAL_APPROVED by SUPERVISOR']
#   38. Case: declaration 100085, Prefix Length: 2, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by ADMINISTRATION']
#   39. Case: declaration 100085, Prefix Length: 3, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration FINAL_APPROVED by SUPERVISOR', 'Declaration FINAL_APPROVED by SUPERVISOR']
#   40. Case: declaration 100090, Prefix Length: 2, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by ADMINISTRATION']
#   41. Case: declaration 100090, Prefix Length: 3, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration FINAL_APPROVED by SUPERVISOR', 'Declaration FINAL_APPROVED by SUPERVISOR']
#   42. Case: declaration 100095, Prefix Length: 2, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by ADMINISTRATION']
#   43. Case: declaration 100095, Prefix Length: 3, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration FINAL_APPROVED by SUPERVISOR', 'Declaration FINAL_APPROVED by SUPERVISOR']
#   44. Case: declaration 100100, Prefix Length: 2, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by ADMINISTRATION']
#   45. Case: declaration 100100, Prefix Length: 3, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration FINAL_APPROVED by SUPERVISOR', 'Declaration FINAL_APPROVED by SUPERVISOR']
#   46. Case: declaration 100105, Prefix Length: 2, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by ADMINISTRATION']
#   47. Case: declaration 100105, Prefix Length: 3, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by BUDGET OWNER', 'Declaration APPROVED by BUDGET OWNER']
#   48. Case: declaration 100105, Prefix Length: 4, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by BUDGET OWNER', 'Declaration FINAL_APPROVED by SUPERVISOR', 'Declaration FINAL_APPROVED by SUPERVISOR']
#   49. Case: declaration 100111, Prefix Length: 2, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration APPROVED by ADMINISTRATION']
#   50. Case: declaration 100111, Prefix Length: 3, Activities: ['Declaration SUBMITTED by EMPLOYEE', 'Declaration APPROVED by ADMINISTRATION', 'Declaration FINAL_APPROVED by SUPERVISOR', 'Declaration FINAL_APPROVED by SUPERVISOR']
#
#   ... and 3763 more invalid prefixes
