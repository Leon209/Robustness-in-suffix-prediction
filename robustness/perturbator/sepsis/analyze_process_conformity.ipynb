# %% [markdown]
# # Process Conformity Analysis
#
# This notebook analyzes what percentage of structural perturbations (e.g., redo_activity_attack) are valid according to the process model discovered from the full dataset.
#
# The analysis:
# 1. Discovers a process model (Petri net) from the full event log dataset
# 2. Loads perturbed prefixes from the structural attack
# 3. Checks if each prefix is valid according to the process model
# 4. Calculates the percentage of valid prefixes

# %%
import sys
import os
import pandas as pd
import torch

sys.path.insert(0, '..')
sys.path.insert(1, '../../..')
sys.path.insert(0, "../../src")

# Add path to import from perturbation_logic
# Notebook is in robustness/perturbator/, module is in robustness/perturbator/perturbation_logic/
perturbation_logic_path = os.path.join(os.getcwd(), 'perturbation_logic')
if os.path.exists(perturbation_logic_path):
    sys.path.insert(0, perturbation_logic_path)
else:
    # Try alternative path if running from different directory
    perturbation_logic_path = 'perturbation_logic'
    if os.path.exists(perturbation_logic_path):
        sys.path.insert(0, perturbation_logic_path)

from perturbation_logic.petri_net_replay_markings import InductiveMiner, is_prefix_valid

print("Imports successful!")
# Out:
# Imports successful!

# %% [markdown]
# ## Step 1: Discover Process Model from Full Dataset
#
# Load the full helpdesk dataset and discover a Petri net process model using Inductive Miner.

# %%
# Path to the full dataset
dataset_path = '../../../data/Sepsis.csv'

# Initialize InductiveMiner with helpdesk column names
miner = InductiveMiner(
    path_to_csv_log=dataset_path,
    case_id_col="case:concept:name",
    activity_col="concept:name",
    timestamp_col="time:timestamp",
    resource_col="Resource"
)

# Discover Petri net model
print("Discovering process model from full dataset...")
net, initial_marking, final_marking = miner.discover_petri_net(visulaize=False)

print(f"Process model discovered successfully!")
print(f"Number of places: {len(net.places)}")
print(f"Number of transitions: {len(net.transitions)}")
# Out:
# Discovering process model from full dataset...
# Process model discovered successfully!
# Number of places: 39
# Number of transitions: 50

# %% [markdown]
# ### Visualize the Discovered Petri Net
#
# Visualize the process model to understand its structure.

# %%
from pm4py.visualization.petri_net import visualizer as pn_visualizer
from IPython.display import Image, display
import tempfile
import os

# Visualize the Petri net
print("Generating Petri net visualization...")
gviz = pn_visualizer.apply(net, initial_marking, final_marking)

# Option 1: View in separate window (uncomment to use)
# pn_visualizer.view(gviz)

# Option 2: Save and display inline in notebook
temp_file = tempfile.NamedTemporaryFile(delete=False, suffix='.png')
temp_path = temp_file.name
temp_file.close()

try:
    pn_visualizer.save(gviz, temp_path)
    print(f"Petri net saved to temporary file")
    
    # Display inline
    display(Image(temp_path))
    
    # Optionally save to a permanent location
    # pn_visualizer.save(gviz, "helpdesk_petri_net.png")
    # print("Also saved to: helpdesk_petri_net.png")
    
finally:
    # Clean up temp file after a delay (or keep it for inspection)
    # os.unlink(temp_path)  # Uncomment to delete temp file immediately
    pass
# Out:
# Generating Petri net visualization...
# Petri net saved to temporary file

# %% [markdown]
# ## Step 2: Load Perturbed Dataset
#
# Load the perturbed dataset containing prefixes and suffixes from the structural attack.

# %%
# Path to perturbed dataset
perturbed_path = '../../../perturbed_data/sepsis/redo_pert.pkl'

print(f"Loading perturbed dataset from: {perturbed_path}")
perturbed_data = torch.load(perturbed_path, weights_only=False)

print(f"Loaded {len(perturbed_data)} perturbed prefix-suffix pairs")
print(f"Sample keys: {list(perturbed_data.keys())[:5]}")
# Out:
# Loading perturbed dataset from: ../../../perturbed_data/sepsis/redo_pert.pkl
# Loaded 1911 perturbed prefix-suffix pairs
# Sample keys: [('A', 1), ('A', 2), ('A', 3), ('A', 4), ('A', 5)]

# %% [markdown]
# ## Step 3: Check Validity of Each Prefix
#
# For each prefix in the perturbed dataset, extract the activity sequence and check if it's valid according to the process model.

# %%
# Activity column name (used in DataFrames)
activity_column = "concept:name"

# Track validity
valid_count = 0
invalid_count = 0
total_count = 0
valid_prefixes = []
invalid_prefixes = []

print("Checking validity of prefixes...")
print("=" * 80)

for (case_id, prefix_length), prefix_suffix_pair in perturbed_data.items():
    total_count += 1
    
    # Handle both formats: [prefix, suffix] or (prefix_df, suffix_df)
    if isinstance(prefix_suffix_pair, (list, tuple)) and len(prefix_suffix_pair) >= 2:
        prefix_data = prefix_suffix_pair[0]
    else:
        prefix_data = prefix_suffix_pair
    
    # Extract activity sequence from prefix
    # Handle both DataFrame and list formats
    if isinstance(prefix_data, pd.DataFrame):
        # Filter out EOS rows if present
        prefix_df = prefix_data[prefix_data[activity_column] != "EOS"]
        if len(prefix_df) == 0:
            # If all are EOS, use the original DataFrame
            prefix_df = prefix_data
        prefix_activities = prefix_df[activity_column].tolist()
    elif isinstance(prefix_data, list):
        # If it's already a list of activities
        prefix_activities = [act for act in prefix_data if act != "EOS"]
        if len(prefix_activities) == 0:
            prefix_activities = prefix_data
    else:
        print(f"Warning: Unknown prefix format for case {case_id}, prefix_length {prefix_length}")
        invalid_count += 1
        invalid_prefixes.append((case_id, prefix_length))
        continue
    
    # Check validity using token replay
    try:
        is_valid = is_prefix_valid(prefix_activities, net, initial_marking, final_marking)
        
        if is_valid:
            valid_count += 1
            valid_prefixes.append((case_id, prefix_length))
        else:
            invalid_count += 1
            invalid_prefixes.append((case_id, prefix_length))
    except Exception as e:
        print(f"Error checking validity for case {case_id}, prefix_length {prefix_length}: {e}")
        invalid_count += 1
        invalid_prefixes.append((case_id, prefix_length))
    
    # Progress update every 100 cases
    if total_count % 100 == 0:
        print(f"Processed {total_count} prefixes... (Valid: {valid_count}, Invalid: {invalid_count})")

print("=" * 80)
print(f"Completed checking {total_count} prefixes")
# Out:
# Checking validity of prefixes...
# ================================================================================
# Processed 100 prefixes... (Valid: 69, Invalid: 31)
# Processed 200 prefixes... (Valid: 139, Invalid: 61)
# Processed 300 prefixes... (Valid: 209, Invalid: 91)
# Processed 400 prefixes... (Valid: 277, Invalid: 123)
# Processed 500 prefixes... (Valid: 350, Invalid: 150)
# Processed 600 prefixes... (Valid: 416, Invalid: 184)
# Processed 700 prefixes... (Valid: 487, Invalid: 213)
# Processed 800 prefixes... (Valid: 563, Invalid: 237)
# Processed 900 prefixes... (Valid: 634, Invalid: 266)
# Processed 1000 prefixes... (Valid: 704, Invalid: 296)
# Processed 1100 prefixes... (Valid: 775, Invalid: 325)
# Processed 1200 prefixes... (Valid: 848, Invalid: 352)
# Processed 1300 prefixes... (Valid: 915, Invalid: 385)
# Processed 1400 prefixes... (Valid: 985, Invalid: 415)
# Processed 1500 prefixes... (Valid: 1056, Invalid: 444)
# Processed 1600 prefixes... (Valid: 1135, Invalid: 465)
# Processed 1700 prefixes... (Valid: 1202, Invalid: 498)
# Processed 1800 prefixes... (Valid: 1271, Invalid: 529)
# Processed 1900 prefixes... (Valid: 1333, Invalid: 567)
# ================================================================================
# Completed checking 1911 prefixes

# %% [markdown]
# ## Step 4: Calculate and Display Results
#
# Calculate the percentage of valid prefixes and display summary statistics.

# %%
# Calculate percentage
if total_count > 0:
    percent_valid = (valid_count / total_count) * 100
    percent_invalid = (invalid_count / total_count) * 100
else:
    percent_valid = 0
    percent_invalid = 0

# Display results
print("=" * 80)
print("PROCESS CONFORMITY ANALYSIS RESULTS")
print("=" * 80)
print(f"\nTotal prefixes analyzed: {total_count}")
print(f"Valid prefixes: {valid_count} ({percent_valid:.2f}%)")
print(f"Invalid prefixes: {invalid_count} ({percent_invalid:.2f}%)")
print("=" * 80)

# Additional statistics
if total_count > 0:
    print(f"\nSummary:")
    print(f"  - Validity rate: {percent_valid:.2f}%")
    print(f"  - Invalid rate: {percent_invalid:.2f}%")
    
    # Helper function to extract activities from prefix data
    def extract_activities(case_id, prefix_len):
        """Extract activity sequence from prefix data."""
        if (case_id, prefix_len) not in perturbed_data:
            return []
        
        prefix_data = perturbed_data[(case_id, prefix_len)]
        if isinstance(prefix_data, (list, tuple)) and len(prefix_data) >= 1:
            prefix_data = prefix_data[0]
        
        if isinstance(prefix_data, pd.DataFrame):
            activities = prefix_data[prefix_data[activity_column] != "EOS"][activity_column].tolist()
        elif isinstance(prefix_data, list):
            activities = [a for a in prefix_data if a != "EOS"]
        else:
            activities = []
        
        return activities
    
    # Show 50 valid prefixes
    print(f"\n{'=' * 80}")
    print(f"VALID PREFIXES (showing up to 50):")
    print(f"{'=' * 80}")
    num_valid_to_show = min(50, len(valid_prefixes))
    for i, (case_id, prefix_len) in enumerate(valid_prefixes[:num_valid_to_show]):
        activities = extract_activities(case_id, prefix_len)
        print(f"  {i+1}. Case: {case_id}, Prefix Length: {prefix_len}, Activities: {activities}")
    
    if len(valid_prefixes) > 50:
        print(f"\n  ... and {len(valid_prefixes) - 50} more valid prefixes")
    
    # Show 50 invalid prefixes
    print(f"\n{'=' * 80}")
    print(f"INVALID PREFIXES (showing up to 50):")
    print(f"{'=' * 80}")
    num_invalid_to_show = min(50, len(invalid_prefixes))
    for i, (case_id, prefix_len) in enumerate(invalid_prefixes[:num_invalid_to_show]):
        activities = extract_activities(case_id, prefix_len)
        print(f"  {i+1}. Case: {case_id}, Prefix Length: {prefix_len}, Activities: {activities}")
    
    if len(invalid_prefixes) > 50:
        print(f"\n  ... and {len(invalid_prefixes) - 50} more invalid prefixes")
# Out:
# ================================================================================
# PROCESS CONFORMITY ANALYSIS RESULTS
# ================================================================================
#
# Total prefixes analyzed: 1911
# Valid prefixes: 1342 (70.23%)
# Invalid prefixes: 569 (29.77%)
# ================================================================================
#
# Summary:
#   - Validity rate: 70.23%
#   - Invalid rate: 29.77%
#
# ================================================================================
# VALID PREFIXES (showing up to 50):
# ================================================================================
#   1. Case: A, Prefix Length: 2, Activities: ['ER Registration', 'Leucocytes', 'Leucocytes']
#   2. Case: A, Prefix Length: 3, Activities: ['ER Registration', 'Leucocytes', 'CRP', 'CRP']
#   3. Case: A, Prefix Length: 4, Activities: ['ER Registration', 'Leucocytes', 'CRP', 'LacticAcid', 'LacticAcid']
#   4. Case: A, Prefix Length: 5, Activities: ['ER Registration', 'Leucocytes', 'CRP', 'LacticAcid', 'ER Triage', 'ER Triage']
#   5. Case: A, Prefix Length: 9, Activities: ['ER Registration', 'Leucocytes', 'CRP', 'LacticAcid', 'ER Triage', 'ER Sepsis Triage', 'IV Liquid', 'IV Antibiotics', 'Admission NC', 'Admission NC']
#   6. Case: A, Prefix Length: 10, Activities: ['ER Registration', 'Leucocytes', 'CRP', 'LacticAcid', 'ER Triage', 'ER Sepsis Triage', 'IV Liquid', 'IV Antibiotics', 'Admission NC', 'Leucocytes', 'Leucocytes']
#   7. Case: A, Prefix Length: 11, Activities: ['ER Registration', 'Leucocytes', 'CRP', 'LacticAcid', 'ER Triage', 'ER Sepsis Triage', 'IV Liquid', 'IV Antibiotics', 'Admission NC', 'Leucocytes', 'CRP', 'CRP']
#   8. Case: A, Prefix Length: 12, Activities: ['ER Registration', 'Leucocytes', 'CRP', 'LacticAcid', 'ER Triage', 'ER Sepsis Triage', 'IV Liquid', 'IV Antibiotics', 'Admission NC', 'Leucocytes', 'CRP', 'Leucocytes', 'Leucocytes']
#   9. Case: A, Prefix Length: 13, Activities: ['ER Registration', 'Leucocytes', 'CRP', 'LacticAcid', 'ER Triage', 'ER Sepsis Triage', 'IV Liquid', 'IV Antibiotics', 'Admission NC', 'Leucocytes', 'CRP', 'Leucocytes', 'CRP', 'CRP']
#   10. Case: A, Prefix Length: 14, Activities: ['ER Registration', 'Leucocytes', 'CRP', 'LacticAcid', 'ER Triage', 'ER Sepsis Triage', 'IV Liquid', 'IV Antibiotics', 'Admission NC', 'Leucocytes', 'CRP', 'Leucocytes', 'CRP', 'Leucocytes', 'Leucocytes']
#   11. Case: A, Prefix Length: 15, Activities: ['ER Registration', 'Leucocytes', 'CRP', 'LacticAcid', 'ER Triage', 'ER Sepsis Triage', 'IV Liquid', 'IV Antibiotics', 'Admission NC', 'Leucocytes', 'CRP', 'Leucocytes', 'CRP', 'Leucocytes', 'CRP', 'CRP']
#   12. Case: A, Prefix Length: 16, Activities: ['ER Registration', 'Leucocytes', 'CRP', 'LacticAcid', 'ER Triage', 'ER Sepsis Triage', 'IV Liquid', 'IV Antibiotics', 'Admission NC', 'Leucocytes', 'CRP', 'Leucocytes', 'CRP', 'Leucocytes', 'CRP', 'CRP', 'CRP']
#   13. Case: A, Prefix Length: 17, Activities: ['ER Registration', 'Leucocytes', 'CRP', 'LacticAcid', 'ER Triage', 'ER Sepsis Triage', 'IV Liquid', 'IV Antibiotics', 'Admission NC', 'Leucocytes', 'CRP', 'Leucocytes', 'CRP', 'Leucocytes', 'CRP', 'CRP', 'Leucocytes', 'Leucocytes']
#   14. Case: A, Prefix Length: 18, Activities: ['ER Registration', 'Leucocytes', 'CRP', 'LacticAcid', 'ER Triage', 'ER Sepsis Triage', 'IV Liquid', 'IV Antibiotics', 'Admission NC', 'Leucocytes', 'CRP', 'Leucocytes', 'CRP', 'Leucocytes', 'CRP', 'CRP', 'Leucocytes', 'Leucocytes', 'Leucocytes']
#   15. Case: A, Prefix Length: 19, Activities: ['ER Registration', 'Leucocytes', 'CRP', 'LacticAcid', 'ER Triage', 'ER Sepsis Triage', 'IV Liquid', 'IV Antibiotics', 'Admission NC', 'Leucocytes', 'CRP', 'Leucocytes', 'CRP', 'Leucocytes', 'CRP', 'CRP', 'Leucocytes', 'Leucocytes', 'CRP', 'CRP']
#   16. Case: A, Prefix Length: 20, Activities: ['ER Registration', 'Leucocytes', 'CRP', 'LacticAcid', 'ER Triage', 'ER Sepsis Triage', 'IV Liquid', 'IV Antibiotics', 'Admission NC', 'Leucocytes', 'CRP', 'Leucocytes', 'CRP', 'Leucocytes', 'CRP', 'CRP', 'Leucocytes', 'Leucocytes', 'CRP', 'Leucocytes', 'Leucocytes']
#   17. Case: A, Prefix Length: 21, Activities: ['ER Registration', 'Leucocytes', 'CRP', 'LacticAcid', 'ER Triage', 'ER Sepsis Triage', 'IV Liquid', 'IV Antibiotics', 'Admission NC', 'Leucocytes', 'CRP', 'Leucocytes', 'CRP', 'Leucocytes', 'CRP', 'CRP', 'Leucocytes', 'Leucocytes', 'CRP', 'Leucocytes', 'CRP', 'CRP']
#   18. Case: AA, Prefix Length: 2, Activities: ['ER Registration', 'ER Triage', 'ER Triage']
#   19. Case: AA, Prefix Length: 4, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'Leucocytes', 'Leucocytes']
#   20. Case: AA, Prefix Length: 5, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'Leucocytes', 'LacticAcid', 'LacticAcid']
#   21. Case: AA, Prefix Length: 6, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'Leucocytes', 'LacticAcid', 'CRP', 'CRP']
#   22. Case: AAA, Prefix Length: 2, Activities: ['ER Registration', 'ER Triage', 'ER Triage']
#   23. Case: AAA, Prefix Length: 5, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'IV Liquid', 'Leucocytes', 'Leucocytes']
#   24. Case: AAA, Prefix Length: 6, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'IV Liquid', 'Leucocytes', 'CRP', 'CRP']
#   25. Case: AAA, Prefix Length: 7, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'IV Liquid', 'Leucocytes', 'CRP', 'LacticAcid', 'LacticAcid']
#   26. Case: AAA, Prefix Length: 9, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'IV Liquid', 'Leucocytes', 'CRP', 'LacticAcid', 'IV Antibiotics', 'Admission NC', 'Admission NC']
#   27. Case: AB, Prefix Length: 2, Activities: ['ER Registration', 'ER Triage', 'ER Triage']
#   28. Case: AB, Prefix Length: 4, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'CRP', 'CRP']
#   29. Case: AB, Prefix Length: 5, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'CRP', 'LacticAcid', 'LacticAcid']
#   30. Case: AB, Prefix Length: 6, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'CRP', 'LacticAcid', 'Leucocytes', 'Leucocytes']
#   31. Case: ABA, Prefix Length: 2, Activities: ['ER Registration', 'ER Triage', 'ER Triage']
#   32. Case: ABA, Prefix Length: 5, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'IV Liquid', 'LacticAcid', 'LacticAcid']
#   33. Case: ABA, Prefix Length: 6, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'IV Liquid', 'LacticAcid', 'Leucocytes', 'Leucocytes']
#   34. Case: ABA, Prefix Length: 7, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'IV Liquid', 'LacticAcid', 'Leucocytes', 'CRP', 'CRP']
#   35. Case: ABA, Prefix Length: 9, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'IV Liquid', 'LacticAcid', 'Leucocytes', 'CRP', 'IV Antibiotics', 'Admission NC', 'Admission NC']
#   36. Case: ABA, Prefix Length: 10, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'IV Liquid', 'LacticAcid', 'Leucocytes', 'CRP', 'IV Antibiotics', 'Admission NC', 'Leucocytes', 'Leucocytes']
#   37. Case: ABA, Prefix Length: 11, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'IV Liquid', 'LacticAcid', 'Leucocytes', 'CRP', 'IV Antibiotics', 'Admission NC', 'Leucocytes', 'CRP', 'CRP']
#   38. Case: ABA, Prefix Length: 12, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'IV Liquid', 'LacticAcid', 'Leucocytes', 'CRP', 'IV Antibiotics', 'Admission NC', 'Leucocytes', 'CRP', 'Leucocytes', 'Leucocytes']
#   39. Case: ABA, Prefix Length: 13, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'IV Liquid', 'LacticAcid', 'Leucocytes', 'CRP', 'IV Antibiotics', 'Admission NC', 'Leucocytes', 'CRP', 'Leucocytes', 'Leucocytes', 'Leucocytes']
#   40. Case: ABA, Prefix Length: 14, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'IV Liquid', 'LacticAcid', 'Leucocytes', 'CRP', 'IV Antibiotics', 'Admission NC', 'Leucocytes', 'CRP', 'Leucocytes', 'Leucocytes', 'CRP', 'CRP']
#   41. Case: ABA, Prefix Length: 15, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'IV Liquid', 'LacticAcid', 'Leucocytes', 'CRP', 'IV Antibiotics', 'Admission NC', 'Leucocytes', 'CRP', 'Leucocytes', 'Leucocytes', 'CRP', 'CRP', 'CRP']
#   42. Case: ABA, Prefix Length: 16, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'IV Liquid', 'LacticAcid', 'Leucocytes', 'CRP', 'IV Antibiotics', 'Admission NC', 'Leucocytes', 'CRP', 'Leucocytes', 'Leucocytes', 'CRP', 'CRP', 'Leucocytes', 'Leucocytes']
#   43. Case: AC, Prefix Length: 2, Activities: ['ER Registration', 'ER Triage', 'ER Triage']
#   44. Case: AC, Prefix Length: 4, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'Leucocytes', 'Leucocytes']
#   45. Case: AC, Prefix Length: 5, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'Leucocytes', 'LacticAcid', 'LacticAcid']
#   46. Case: AC, Prefix Length: 6, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'Leucocytes', 'LacticAcid', 'CRP', 'CRP']
#   47. Case: AC, Prefix Length: 9, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'Leucocytes', 'LacticAcid', 'CRP', 'IV Liquid', 'IV Antibiotics', 'Admission NC', 'Admission NC']
#   48. Case: AC, Prefix Length: 10, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'Leucocytes', 'LacticAcid', 'CRP', 'IV Liquid', 'IV Antibiotics', 'Admission NC', 'CRP', 'CRP']
#   49. Case: AC, Prefix Length: 11, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'Leucocytes', 'LacticAcid', 'CRP', 'IV Liquid', 'IV Antibiotics', 'Admission NC', 'CRP', 'Leucocytes', 'Leucocytes']
#   50. Case: ACA, Prefix Length: 2, Activities: ['ER Registration', 'ER Triage', 'ER Triage']
#
#   ... and 1292 more valid prefixes
#
# ================================================================================
# INVALID PREFIXES (showing up to 50):
# ================================================================================
#   1. Case: A, Prefix Length: 1, Activities: ['ER Registration', 'ER Registration']
#   2. Case: A, Prefix Length: 6, Activities: ['ER Registration', 'Leucocytes', 'CRP', 'LacticAcid', 'ER Triage', 'ER Sepsis Triage', 'ER Sepsis Triage']
#   3. Case: A, Prefix Length: 7, Activities: ['ER Registration', 'Leucocytes', 'CRP', 'LacticAcid', 'ER Triage', 'ER Sepsis Triage', 'IV Liquid', 'IV Liquid']
#   4. Case: A, Prefix Length: 8, Activities: ['ER Registration', 'Leucocytes', 'CRP', 'LacticAcid', 'ER Triage', 'ER Sepsis Triage', 'IV Liquid', 'IV Antibiotics', 'IV Antibiotics']
#   5. Case: AA, Prefix Length: 1, Activities: ['ER Registration', 'ER Registration']
#   6. Case: AA, Prefix Length: 3, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'ER Sepsis Triage']
#   7. Case: AA, Prefix Length: 7, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'Leucocytes', 'LacticAcid', 'CRP', 'IV Liquid', 'IV Liquid']
#   8. Case: AAA, Prefix Length: 1, Activities: ['ER Registration', 'ER Registration']
#   9. Case: AAA, Prefix Length: 3, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'ER Sepsis Triage']
#   10. Case: AAA, Prefix Length: 4, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'IV Liquid', 'IV Liquid']
#   11. Case: AAA, Prefix Length: 8, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'IV Liquid', 'Leucocytes', 'CRP', 'LacticAcid', 'IV Antibiotics', 'IV Antibiotics']
#   12. Case: AAA, Prefix Length: 10, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'IV Liquid', 'Leucocytes', 'CRP', 'LacticAcid', 'IV Antibiotics', 'Admission NC', 'Release A', 'Release A']
#   13. Case: AB, Prefix Length: 1, Activities: ['ER Registration', 'ER Registration']
#   14. Case: AB, Prefix Length: 3, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'ER Sepsis Triage']
#   15. Case: AB, Prefix Length: 7, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'CRP', 'LacticAcid', 'Leucocytes', 'IV Liquid', 'IV Liquid']
#   16. Case: ABA, Prefix Length: 1, Activities: ['ER Registration', 'ER Registration']
#   17. Case: ABA, Prefix Length: 3, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'ER Sepsis Triage']
#   18. Case: ABA, Prefix Length: 4, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'IV Liquid', 'IV Liquid']
#   19. Case: ABA, Prefix Length: 8, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'IV Liquid', 'LacticAcid', 'Leucocytes', 'CRP', 'IV Antibiotics', 'IV Antibiotics']
#   20. Case: AC, Prefix Length: 1, Activities: ['ER Registration', 'ER Registration']
#   21. Case: AC, Prefix Length: 3, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'ER Sepsis Triage']
#   22. Case: AC, Prefix Length: 7, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'Leucocytes', 'LacticAcid', 'CRP', 'IV Liquid', 'IV Liquid']
#   23. Case: AC, Prefix Length: 8, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'Leucocytes', 'LacticAcid', 'CRP', 'IV Liquid', 'IV Antibiotics', 'IV Antibiotics']
#   24. Case: AC, Prefix Length: 12, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'Leucocytes', 'LacticAcid', 'CRP', 'IV Liquid', 'IV Antibiotics', 'Admission NC', 'CRP', 'Leucocytes', 'Release A', 'Release A']
#   25. Case: ACA, Prefix Length: 1, Activities: ['ER Registration', 'ER Registration']
#   26. Case: ACA, Prefix Length: 3, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'ER Sepsis Triage']
#   27. Case: ACA, Prefix Length: 7, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'CRP', 'LacticAcid', 'Leucocytes', 'IV Liquid', 'IV Liquid']
#   28. Case: AD, Prefix Length: 1, Activities: ['ER Registration', 'ER Registration']
#   29. Case: AD, Prefix Length: 3, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'ER Sepsis Triage']
#   30. Case: AD, Prefix Length: 7, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'LacticAcid', 'CRP', 'Leucocytes', 'IV Liquid', 'IV Liquid']
#   31. Case: AD, Prefix Length: 8, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'LacticAcid', 'CRP', 'Leucocytes', 'IV Liquid', 'IV Antibiotics', 'IV Antibiotics']
#   32. Case: AD, Prefix Length: 28, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'LacticAcid', 'CRP', 'Leucocytes', 'IV Liquid', 'IV Antibiotics', 'Admission NC', 'Admission IC', 'Leucocytes', 'LacticAcid', 'CRP', 'CRP', 'Leucocytes', 'LacticAcid', 'Leucocytes', 'CRP', 'LacticAcid', 'CRP', 'LacticAcid', 'Leucocytes', 'Admission NC', 'CRP', 'Leucocytes', 'Leucocytes', 'CRP', 'Release A', 'Release A']
#   33. Case: ADA, Prefix Length: 1, Activities: ['ER Registration', 'ER Registration']
#   34. Case: ADA, Prefix Length: 3, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'ER Sepsis Triage']
#   35. Case: ADA, Prefix Length: 7, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'LacticAcid', 'Leucocytes', 'CRP', 'IV Antibiotics', 'IV Antibiotics']
#   36. Case: ADA, Prefix Length: 20, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'LacticAcid', 'Leucocytes', 'CRP', 'IV Antibiotics', 'Admission NC', 'CRP', 'Leucocytes', 'Leucocytes', 'CRP', 'CRP', 'Leucocytes', 'CRP', 'Leucocytes', 'CRP', 'CRP', 'Leucocytes', 'Release A', 'Release A']
#   37. Case: ADA, Prefix Length: 21, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'LacticAcid', 'Leucocytes', 'CRP', 'IV Antibiotics', 'Admission NC', 'CRP', 'Leucocytes', 'Leucocytes', 'CRP', 'CRP', 'Leucocytes', 'CRP', 'Leucocytes', 'CRP', 'CRP', 'Leucocytes', 'Release A', 'Return ER', 'Return ER']
#   38. Case: AE, Prefix Length: 1, Activities: ['ER Registration', 'ER Registration']
#   39. Case: AE, Prefix Length: 3, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'ER Sepsis Triage']
#   40. Case: AE, Prefix Length: 7, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'Leucocytes', 'CRP', 'LacticAcid', 'IV Liquid', 'IV Liquid']
#   41. Case: AE, Prefix Length: 8, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'Leucocytes', 'CRP', 'LacticAcid', 'IV Liquid', 'IV Antibiotics', 'IV Antibiotics']
#   42. Case: AE, Prefix Length: 17, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'Leucocytes', 'CRP', 'LacticAcid', 'IV Liquid', 'IV Antibiotics', 'Admission NC', 'Leucocytes', 'CRP', 'Admission IC', 'Leucocytes', 'LacticAcid', 'CRP', 'Admission NC', 'Release A', 'Release A']
#   43. Case: AEA, Prefix Length: 1, Activities: ['ER Registration', 'ER Registration']
#   44. Case: AEA, Prefix Length: 3, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'ER Sepsis Triage']
#   45. Case: AEA, Prefix Length: 7, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'LacticAcid', 'CRP', 'Leucocytes', 'IV Liquid', 'IV Liquid']
#   46. Case: AEA, Prefix Length: 8, Activities: ['ER Registration', 'ER Triage', 'ER Sepsis Triage', 'LacticAcid', 'CRP', 'Leucocytes', 'IV Liquid', 'IV Antibiotics', 'IV Antibiotics']
#   47. Case: AF, Prefix Length: 1, Activities: ['ER Registration', 'ER Registration']
#   48. Case: AF, Prefix Length: 5, Activities: ['ER Registration', 'CRP', 'Leucocytes', 'ER Triage', 'ER Sepsis Triage', 'ER Sepsis Triage']
#   49. Case: AF, Prefix Length: 7, Activities: ['ER Registration', 'CRP', 'Leucocytes', 'ER Triage', 'ER Sepsis Triage', 'LacticAcid', 'IV Liquid', 'IV Liquid']
#   50. Case: AF, Prefix Length: 8, Activities: ['ER Registration', 'CRP', 'Leucocytes', 'ER Triage', 'ER Sepsis Triage', 'LacticAcid', 'IV Liquid', 'IV Antibiotics', 'IV Antibiotics']
#
#   ... and 519 more invalid prefixes
