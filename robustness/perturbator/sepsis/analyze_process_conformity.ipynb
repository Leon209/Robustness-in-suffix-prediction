# %% [markdown]
# # Process Conformity Analysis
#
# This notebook analyzes what percentage of structural perturbations (e.g., redo_activity_attack) are valid according to the process model discovered from the full dataset.
#
# The analysis:
# 1. Discovers a process model (Petri net) from the full event log dataset
# 2. Loads perturbed prefixes from the structural attack
# 3. Checks if each prefix is valid according to the process model
# 4. Calculates the percentage of valid prefixes

# %%
import sys
import os
import pandas as pd
import torch

sys.path.insert(0, '..')
sys.path.insert(1, '../../..')
sys.path.insert(0, "../../src")

# Add path to import from perturbation_logic
# Notebook is in robustness/perturbator/, module is in robustness/perturbator/perturbation_logic/
perturbation_logic_path = os.path.join(os.getcwd(), 'perturbation_logic')
if os.path.exists(perturbation_logic_path):
    sys.path.insert(0, perturbation_logic_path)
else:
    # Try alternative path if running from different directory
    perturbation_logic_path = 'perturbation_logic'
    if os.path.exists(perturbation_logic_path):
        sys.path.insert(0, perturbation_logic_path)

from perturbation_logic.petri_net_replay_markings import InductiveMiner, is_prefix_valid

print("Imports successful!")
# Out:
# Imports successful!

# %% [markdown]
# ## Step 1: Discover Process Model from Full Dataset
#
# Load the full helpdesk dataset and discover a Petri net process model using Inductive Miner.

# %%
# Path to the full dataset
dataset_path = '../../../data/Sepsis.csv'

# Initialize InductiveMiner with helpdesk column names
miner = InductiveMiner(
    path_to_csv_log=dataset_path,
    case_id_col="case:concept:name",
    activity_col="concept:name",
    timestamp_col="time:timestamp",
    resource_col="Resource"
)

# Discover Petri net model
print("Discovering process model from full dataset...")
net, initial_marking, final_marking = miner.discover_petri_net(visulaize=False)

print(f"Process model discovered successfully!")
print(f"Number of places: {len(net.places)}")
print(f"Number of transitions: {len(net.transitions)}")
# Out:
# Discovering process model from full dataset...
# Process model discovered successfully!
# Number of places: 39
# Number of transitions: 50

# %% [markdown]
# ### Visualize the Discovered Petri Net
#
# Visualize the process model to understand its structure.

# %%
from pm4py.visualization.petri_net import visualizer as pn_visualizer
from IPython.display import Image, display
import tempfile
import os

# Visualize the Petri net
print("Generating Petri net visualization...")
gviz = pn_visualizer.apply(net, initial_marking, final_marking)

# Option 1: View in separate window (uncomment to use)
# pn_visualizer.view(gviz)

# Option 2: Save and display inline in notebook
temp_file = tempfile.NamedTemporaryFile(delete=False, suffix='.png')
temp_path = temp_file.name
temp_file.close()

try:
    pn_visualizer.save(gviz, temp_path)
    print(f"Petri net saved to temporary file")
    
    # Display inline
    display(Image(temp_path))
    
    # Optionally save to a permanent location
    # pn_visualizer.save(gviz, "helpdesk_petri_net.png")
    # print("Also saved to: helpdesk_petri_net.png")
    
finally:
    # Clean up temp file after a delay (or keep it for inspection)
    # os.unlink(temp_path)  # Uncomment to delete temp file immediately
    pass
# Out:
# Generating Petri net visualization...
# Petri net saved to temporary file

# %% [markdown]
# ## Step 2: Load Perturbed Dataset
#
# Load the perturbed dataset containing prefixes and suffixes from the structural attack.

# %%
# Path to perturbed dataset
perturbed_path = '../../../perturbed_data/helpdesk/loop_augmentation_pert.pkl'

print(f"Loading perturbed dataset from: {perturbed_path}")
perturbed_data = torch.load(perturbed_path, weights_only=False)

print(f"Loaded {len(perturbed_data)} perturbed prefix-suffix pairs")
print(f"Sample keys: {list(perturbed_data.keys())[:5]}")
# Out:
# Loading perturbed dataset from: ../../perturbed_data/helpdesk/loop_augmentation_pert.pkl
# Loaded 379 perturbed prefix-suffix pairs
# Sample keys: [('Case 1307', 2), ('Case 1308', 2), ('Case 131', 2), ('Case 1310', 2), ('Case 1311', 2)]

# %% [markdown]
# ## Step 3: Check Validity of Each Prefix
#
# For each prefix in the perturbed dataset, extract the activity sequence and check if it's valid according to the process model.

# %%
# Activity column name (used in DataFrames)
activity_column = "Activity"

# Track validity
valid_count = 0
invalid_count = 0
total_count = 0
valid_prefixes = []
invalid_prefixes = []

print("Checking validity of prefixes...")
print("=" * 80)

for (case_id, prefix_length), prefix_suffix_pair in perturbed_data.items():
    total_count += 1
    
    # Handle both formats: [prefix, suffix] or (prefix_df, suffix_df)
    if isinstance(prefix_suffix_pair, (list, tuple)) and len(prefix_suffix_pair) >= 2:
        prefix_data = prefix_suffix_pair[0]
    else:
        prefix_data = prefix_suffix_pair
    
    # Extract activity sequence from prefix
    # Handle both DataFrame and list formats
    if isinstance(prefix_data, pd.DataFrame):
        # Filter out EOS rows if present
        prefix_df = prefix_data[prefix_data[activity_column] != "EOS"]
        if len(prefix_df) == 0:
            # If all are EOS, use the original DataFrame
            prefix_df = prefix_data
        prefix_activities = prefix_df[activity_column].tolist()
    elif isinstance(prefix_data, list):
        # If it's already a list of activities
        prefix_activities = [act for act in prefix_data if act != "EOS"]
        if len(prefix_activities) == 0:
            prefix_activities = prefix_data
    else:
        print(f"Warning: Unknown prefix format for case {case_id}, prefix_length {prefix_length}")
        invalid_count += 1
        invalid_prefixes.append((case_id, prefix_length))
        continue
    
    # Check validity using token replay
    try:
        is_valid = is_prefix_valid(prefix_activities, net, initial_marking, final_marking)
        
        if is_valid:
            valid_count += 1
            valid_prefixes.append((case_id, prefix_length))
        else:
            invalid_count += 1
            invalid_prefixes.append((case_id, prefix_length))
    except Exception as e:
        print(f"Error checking validity for case {case_id}, prefix_length {prefix_length}: {e}")
        invalid_count += 1
        invalid_prefixes.append((case_id, prefix_length))
    
    # Progress update every 100 cases
    if total_count % 100 == 0:
        print(f"Processed {total_count} prefixes... (Valid: {valid_count}, Invalid: {invalid_count})")

print("=" * 80)
print(f"Completed checking {total_count} prefixes")
# Out:
# Checking validity of prefixes...
# ================================================================================
# Processed 100 prefixes... (Valid: 100, Invalid: 0)
# Processed 200 prefixes... (Valid: 200, Invalid: 0)
# Processed 300 prefixes... (Valid: 300, Invalid: 0)
# ================================================================================
# Completed checking 379 prefixes

# %% [markdown]
# ## Step 4: Calculate and Display Results
#
# Calculate the percentage of valid prefixes and display summary statistics.

# %%
# Calculate percentage
if total_count > 0:
    percent_valid = (valid_count / total_count) * 100
    percent_invalid = (invalid_count / total_count) * 100
else:
    percent_valid = 0
    percent_invalid = 0

# Display results
print("=" * 80)
print("PROCESS CONFORMITY ANALYSIS RESULTS")
print("=" * 80)
print(f"\nTotal prefixes analyzed: {total_count}")
print(f"Valid prefixes: {valid_count} ({percent_valid:.2f}%)")
print(f"Invalid prefixes: {invalid_count} ({percent_invalid:.2f}%)")
print("=" * 80)

# Additional statistics
if total_count > 0:
    print(f"\nSummary:")
    print(f"  - Validity rate: {percent_valid:.2f}%")
    print(f"  - Invalid rate: {percent_invalid:.2f}%")
    
    # Helper function to extract activities from prefix data
    def extract_activities(case_id, prefix_len):
        """Extract activity sequence from prefix data."""
        if (case_id, prefix_len) not in perturbed_data:
            return []
        
        prefix_data = perturbed_data[(case_id, prefix_len)]
        if isinstance(prefix_data, (list, tuple)) and len(prefix_data) >= 1:
            prefix_data = prefix_data[0]
        
        if isinstance(prefix_data, pd.DataFrame):
            activities = prefix_data[prefix_data[activity_column] != "EOS"][activity_column].tolist()
        elif isinstance(prefix_data, list):
            activities = [a for a in prefix_data if a != "EOS"]
        else:
            activities = []
        
        return activities
    
    # Show 50 valid prefixes
    print(f"\n{'=' * 80}")
    print(f"VALID PREFIXES (showing up to 50):")
    print(f"{'=' * 80}")
    num_valid_to_show = min(50, len(valid_prefixes))
    for i, (case_id, prefix_len) in enumerate(valid_prefixes[:num_valid_to_show]):
        activities = extract_activities(case_id, prefix_len)
        print(f"  {i+1}. Case: {case_id}, Prefix Length: {prefix_len}, Activities: {activities}")
    
    if len(valid_prefixes) > 50:
        print(f"\n  ... and {len(valid_prefixes) - 50} more valid prefixes")
    
    # Show 50 invalid prefixes
    print(f"\n{'=' * 80}")
    print(f"INVALID PREFIXES (showing up to 50):")
    print(f"{'=' * 80}")
    num_invalid_to_show = min(50, len(invalid_prefixes))
    for i, (case_id, prefix_len) in enumerate(invalid_prefixes[:num_invalid_to_show]):
        activities = extract_activities(case_id, prefix_len)
        print(f"  {i+1}. Case: {case_id}, Prefix Length: {prefix_len}, Activities: {activities}")
    
    if len(invalid_prefixes) > 50:
        print(f"\n  ... and {len(invalid_prefixes) - 50} more invalid prefixes")
# Out:
# ================================================================================
# PROCESS CONFORMITY ANALYSIS RESULTS
# ================================================================================
#
# Total prefixes analyzed: 379
# Valid prefixes: 379 (100.00%)
# Invalid prefixes: 0 (0.00%)
# ================================================================================
#
# Summary:
#   - Validity rate: 100.00%
#   - Invalid rate: 0.00%
#
# ================================================================================
# VALID PREFIXES (showing up to 50):
# ================================================================================
#   1. Case: Case 1307, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Wait', 'Take in charge ticket']
#   2. Case: Case 1308, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Wait', 'Take in charge ticket']
#   3. Case: Case 131, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Wait', 'Take in charge ticket']
#   4. Case: Case 1310, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Wait', 'Take in charge ticket']
#   5. Case: Case 1311, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Wait', 'Take in charge ticket']
#   6. Case: Case 1312, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Wait', 'Take in charge ticket']
#   7. Case: Case 1313, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Wait', 'Take in charge ticket']
#   8. Case: Case 1314, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Wait', 'Take in charge ticket']
#   9. Case: Case 1315, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Wait', 'Take in charge ticket']
#   10. Case: Case 1316, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Wait', 'Take in charge ticket']
#   11. Case: Case 1318, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Wait', 'Take in charge ticket']
#   12. Case: Case 1319, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Wait', 'Take in charge ticket']
#   13. Case: Case 132, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Wait', 'Take in charge ticket']
#   14. Case: Case 1320, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Wait', 'Take in charge ticket']
#   15. Case: Case 1321, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Wait', 'Take in charge ticket']
#   16. Case: Case 1322, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Wait', 'Take in charge ticket']
#   17. Case: Case 1323, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Wait', 'Take in charge ticket']
#   18. Case: Case 1324, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Wait', 'Take in charge ticket']
#   19. Case: Case 1326, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Resolve ticket', 'Take in charge ticket']
#   20. Case: Case 1328, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Resolve ticket', 'Take in charge ticket']
#   21. Case: Case 1329, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Resolve ticket', 'Take in charge ticket']
#   22. Case: Case 133, Prefix Length: 3, Activities: ['Assign seriousness', 'Assign seriousness', 'Take in charge ticket', 'Resolve ticket', 'Take in charge ticket', 'Wait', 'Take in charge ticket']
#   23. Case: Case 1331, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Resolve ticket', 'Take in charge ticket', 'Wait', 'Take in charge ticket']
#   24. Case: Case 1332, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Resolve ticket', 'Take in charge ticket', 'Wait', 'Take in charge ticket']
#   25. Case: Case 1324, Prefix Length: 3, Activities: ['Assign seriousness', 'Take in charge ticket', 'Resolve ticket', 'Take in charge ticket', 'Wait', 'Take in charge ticket', 'Resolve ticket']
#   26. Case: Case 1330, Prefix Length: 2, Activities: ['Assign seriousness', 'Resolve ticket', 'Take in charge ticket', 'Wait', 'Take in charge ticket', 'Resolve ticket']
#   27. Case: Case 1336, Prefix Length: 3, Activities: ['Assign seriousness', 'Take in charge ticket', 'Resolve ticket', 'Take in charge ticket', 'Wait', 'Take in charge ticket', 'Resolve ticket']
#   28. Case: Case 1333, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Wait', 'Take in charge ticket']
#   29. Case: Case 1334, Prefix Length: 3, Activities: ['Assign seriousness', 'Assign seriousness', 'Take in charge ticket', 'Wait', 'Take in charge ticket']
#   30. Case: Case 1335, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Wait', 'Take in charge ticket']
#   31. Case: Case 1336, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Wait', 'Take in charge ticket']
#   32. Case: Case 1337, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Wait', 'Take in charge ticket']
#   33. Case: Case 1339, Prefix Length: 3, Activities: ['Assign seriousness', 'Assign seriousness', 'Take in charge ticket', 'Wait', 'Take in charge ticket']
#   34. Case: Case 134, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Wait', 'Take in charge ticket']
#   35. Case: Case 1340, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Wait', 'Take in charge ticket']
#   36. Case: Case 1341, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Wait', 'Take in charge ticket']
#   37. Case: Case 1343, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Wait', 'Take in charge ticket', 'Resolve ticket', 'Take in charge ticket']
#   38. Case: Case 1344, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Wait', 'Take in charge ticket', 'Resolve ticket', 'Take in charge ticket']
#   39. Case: Case 1345, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Wait', 'Take in charge ticket', 'Resolve ticket', 'Take in charge ticket']
#   40. Case: Case 1346, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Wait', 'Take in charge ticket', 'Resolve ticket', 'Take in charge ticket', 'Wait', 'Take in charge ticket']
#   41. Case: Case 1347, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Wait', 'Take in charge ticket', 'Resolve ticket', 'Take in charge ticket', 'Wait', 'Take in charge ticket']
#   42. Case: Case 1348, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Wait', 'Take in charge ticket', 'Resolve ticket', 'Take in charge ticket', 'Wait', 'Take in charge ticket']
#   43. Case: Case 1307, Prefix Length: 3, Activities: ['Assign seriousness', 'Take in charge ticket', 'Wait', 'Take in charge ticket', 'Resolve ticket', 'Take in charge ticket', 'Wait']
#   44. Case: Case 1310, Prefix Length: 3, Activities: ['Assign seriousness', 'Take in charge ticket', 'Wait', 'Take in charge ticket', 'Resolve ticket', 'Take in charge ticket', 'Wait']
#   45. Case: Case 1315, Prefix Length: 3, Activities: ['Assign seriousness', 'Take in charge ticket', 'Wait', 'Take in charge ticket', 'Resolve ticket', 'Take in charge ticket', 'Wait']
#   46. Case: Case 1349, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Resolve ticket', 'Take in charge ticket']
#   47. Case: Case 135, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Resolve ticket', 'Take in charge ticket']
#   48. Case: Case 1350, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Resolve ticket', 'Take in charge ticket']
#   49. Case: Case 1351, Prefix Length: 3, Activities: ['Insert ticket', 'Assign seriousness', 'Take in charge ticket', 'Resolve ticket', 'Take in charge ticket', 'Wait', 'Take in charge ticket']
#   50. Case: Case 1352, Prefix Length: 2, Activities: ['Assign seriousness', 'Take in charge ticket', 'Resolve ticket', 'Take in charge ticket', 'Wait', 'Take in charge ticket']
#
#   ... and 329 more valid prefixes
#
# ================================================================================
# INVALID PREFIXES (showing up to 50):
# ================================================================================
